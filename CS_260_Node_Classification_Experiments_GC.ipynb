# %% [markdown]
# <a href="https://colab.research.google.com/github/camligorkem/cs-260c-project/blob/main/CS_260_Node_Classification_Experiments_GC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd "/content/drive/My Drive/cs260c/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs260c

# %%
# Install required packages.
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
#      |████████████████████████████████| 7.9 MB 5.4 MB/s
#      |████████████████████████████████| 3.5 MB 4.5 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch 
import numpy as np
import math


from torch_geometric.utils import degree
import torch_geometric
import torch_geometric.utils as tg_utils
import pandas as pd

# %%
# !rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Done!

# %%
def get_masked_noise(data,  noise_level=0.15):
  x = data.x
  noise_added_node_num = int(noise_level * x.shape[0])
  chose_random_rows = np.random.choice(x.shape[0], noise_added_node_num, replace=False)
  #print(chose_random_rows)
  mask_rows = torch.zeros(x.shape)
  mask_rows[chose_random_rows,:] = torch.ones(1, x.shape[1])
  noise = (0.1**0.5)*torch.randn(x.shape)
  masked_noise = noise* mask_rows.int().float()

  #print(mask_rows)
  #print(noise)
  #print(masked_noise)
  return x + masked_noise

# %%
# remove x% edges
def remove_from_all_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index

  if bidirectional:
    noise_level /= 2
  
  edge_ratio_to_keep = 1 - noise_level
  num_edges_keep= int(edge_ratio_to_keep * edge_index.shape[1])
  chose_random_edge_indices = np.random.choice(edge_index.shape[1], num_edges_keep, replace=False)

  #print(edge_index[0][chose_random_edge_indices].shape)
  #print(num_edges_keep)
  #print(edge_index.shape[1])

  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_index_removed[0] = edge_index[0][chose_random_edge_indices]
  edge_index_removed[1] = edge_index[1][chose_random_edge_indices]

  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    edge_index_removed = torch.zeros((2,len(final_edges_bidirec_1)), dtype=torch.int64)
    edge_index_removed[0] = final_edges_bidirec_0
    edge_index_removed[1] = final_edges_bidirec_1

  return edge_index_removed

# %%
# remove x% edges from random k, top_k, bottom_k nodes

def choose_nodes(data, num_nodes, k_nodes, choose_type):
  if choose_type=='random':
    nodes_chosen = torch.from_numpy(np.random.choice(num_nodes, k_nodes, replace=False))
  elif choose_type=='top_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    top_k_nodes_degrees, top_k_nodes_indices = torch.topk(dg, k_nodes)
    #print(top_k_nodes_degrees, top_k_nodes_indices)
    nodes_chosen = top_k_nodes_indices
  elif choose_type=='bottom_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    bottom_k_nodes_degrees, bottom_k_nodes_indices = torch.topk(dg, k_nodes, largest=False)
    #print(bottom_k_nodes_degrees, bottom_k_nodes_indices)
    nodes_chosen = bottom_k_nodes_indices
  else:
    raise 'choose_type should be from random, top_k, bottom_k'
  return nodes_chosen

# to do loop for each node separately
def remove_edges_from_chosen_nodes(data, nodes_chosen, edges_to_remove_per_node_ratio):
  edges_0_list, edges_1_list = [],[]
  for nc in nodes_chosen:
    edge_0, edge_1 = remove_edge_per_node(data=data, node=nc, 
                                          edges_to_remove_per_node_ratio=edges_to_remove_per_node_ratio)
    edges_0_list.append(edge_0)
    edges_1_list.append(edge_1)

  edges_0 = torch.cat(edges_0_list, 0)
  edges_1 = torch.cat(edges_1_list, 0)

  return edges_0, edges_1

def remove_edge_per_node(data, node, edges_to_remove_per_node_ratio=0.1):
  mask_node_indices = torch.isin(data.edge_index[0], node)

  select_node_edges_0 = data.edge_index[0][mask_node_indices]
  select_node_edges_1 = data.edge_index[1][mask_node_indices]
  #print(select_node_edges_0)
  #print(select_node_edges_1)

  # choose how much of the edges we will remove for this node
  # we decide on number of edges to remove for each node based on the number of edges each node has
  # and by taking the ratio given by edges_to_remove_per_node_ratio
  # note: we use ceil to remove at least one node (unless ratio is 0)
  num_edges_remove = int(math.ceil(edges_to_remove_per_node_ratio* select_node_edges_0.shape[0]))
  # print(num_edges_remove)
  num_edges_keep = select_node_edges_0.shape[0] - num_edges_remove

  # choose random edges to keep, the rest is removed
  chose_random_edge_indices = np.random.choice(select_node_edges_0.shape[0], num_edges_keep, replace=False)
  # print(num_edges_keep)
  
  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_node_index_removed_0 = select_node_edges_0[chose_random_edge_indices]
  edge_node_index_removed_1 = select_node_edges_1[chose_random_edge_indices]

  return edge_node_index_removed_0, edge_node_index_removed_1

def remove_edges_from_nodes(data, noise_level = 0.15, k_nodes=10,
                            choose_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  edge_p_node_ratio_to_keep = 1 - noise_level

  # choose topk, bottomk, or random
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=choose_type)

  # keep edges from remaining nodes
  mask_node_indices = torch.isin(data.edge_index[0],nodes_chosen)
  index_keep = torch.ones(data.edge_index[0].shape[0], dtype=bool)
  index_keep[mask_node_indices] = False
  edges_to_keep_0 = data.edge_index[0][index_keep]
  edges_to_keep_1 = data.edge_index[1][index_keep]
  #print(edges_to_keep_0) 
  #print(edges_to_keep_1)

  # remove one-directional or bi-directional
  edges_0_kept_chosen_nodes, edges_1_kept_chosen_nodes = remove_edges_from_chosen_nodes(data=data, 
                                                                                        nodes_chosen=nodes_chosen,
                                                                                        edges_to_remove_per_node_ratio=noise_level)
  # concat edges to keep and edges_kept_chosen_nodes
  final_edges_0 = torch.cat([edges_to_keep_0, edges_0_kept_chosen_nodes], 0)
  final_edges_1 = torch.cat([edges_to_keep_1, edges_1_kept_chosen_nodes], 0)

  # do bidirectional here! IF bidirectional set to true remove both directions of the edges.
  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    final_edges_0 = final_edges_bidirec_0
    final_edges_1 = final_edges_bidirec_1
  edge_index_removed = torch.zeros((2, final_edges_0.shape[0]), dtype=torch.int64)
  edge_index_removed[0] = final_edges_0
  edge_index_removed[1] = final_edges_1

    
  # use TORCH_GEOMETRIC.UTILS.SORT_EDGE_INDEX
  edge_index_removed_sorted = tg_utils.sort_edge_index(edge_index_removed)
  return edge_index_removed_sorted

# %%
def add_random_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index
  num_nodes = data.num_nodes

  if bidirectional:
    noise_level /= 2

  new_edges = edge_index.T
  edge_num = new_edges.shape[0]
  num_of_new_edges = int(edge_num * noise_level)

  for i in range(num_of_new_edges):
    while True:
      new_edge = ((torch.rand(1,2) * 1000000).to(int) % num_nodes)
      new_edge_flip = torch.flip(new_edge, [1])
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break

  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %%
for added_ratio in [0.15]:
  new_edges = add_random_edges(data,  noise_level=added_ratio, bidirectional=True)
  data[f'edge_index_added_n_{added_ratio}'] = new_edges

# %%
## Helper function of add_edges_to_nodes

def add_edges_to_a_node(data, new_edges, node, num_to_add=0, bidirectional=False):
  for i in range(num_to_add):

    # Running till we find the right edge to add
    while True:
      #create a random node. 1000000 is a arbitrary number which can be replaced to any number bigger than data.num_nodes
      new_index = ((torch.rand(1) * 1000000).to(int) % data.num_nodes).item()
      new_edge = torch.tensor([[node, new_index]])
      new_edge_flip = torch.flip(new_edge, [1])
      #check whether the new edge and flip one exists or not 
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
  return new_edges

## Adding x% edges to random k, top k, or bottom k nodes

def add_edges_to_nodes(data, noise_level=0.15, k_nodes=10, chosse_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  #choose nodes by three different types
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=chosse_type)
  
  new_edges = data.edge_index.T

  #add new edges to every chosen node
  for node in nodes_chosen:
    edge_num_of_node = torch.isin(data.edge_index, node).to(int).sum()
    edge_num_to_add = int(edge_num_of_node * noise_level)
    
    new_edges = add_edges_to_a_node(data, new_edges, node.item(), edge_num_to_add, bidirectional)
  
  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %% [markdown]
# ## Experiments

# %%
# !pip install class-resolver

from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT
from class_resolver import ClassResolver
# Out:
# Collecting class-resolver
#   Downloading class_resolver-0.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: class-resolver
# Successfully installed class-resolver-0.3.4

# %%
def get_model(model_name, model_params):
  # add more model from here if needed: https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#models
  # you can also check model parameters from above
  model = None
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
  if model_name=='MLP':
    model = MLP(**model_params).to(device)
  elif model_name=='GNN':
    model = GCN(**model_params).to(device)
  elif model_name=='GAT':
    model = GAT(**model_params).to(device)
  elif model_name=='Graphsage':
    model = GraphSAGE(**model_params).to(device)
  else:
    raise 'Model names should be within MLP, GNN, GAT, Graphsage'
  return model

# %%
# Creating MLP example, add all parameters you want to use to create/tune model in the below dictionary
model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3}
mlp_model = get_model(model_name='MLP', model_params=model_params)
print(mlp_model)

model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
gnn_model = get_model(model_name='GNN', model_params=model_params)
print(gnn_model)
# Out:
# MLP(1433, 16, 16, 7)
# GCN(1433, 7, num_layers=3)

# %%
def get_noise_function(noise_info):
  '''
  This function directly returns the function we created for different noise logics
  Change the name of the function below if noise logic function name is changed.
  '''
  noise_fn = None 
  if noise_info['noise_type']=='feature_noise':
    noise_fn = get_masked_noise
  elif noise_info['noise_type']=='edge_removal':
    if noise_info['strategy']=='all_edges' :
      noise_fn = remove_from_all_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = remove_edges_from_nodes
  elif noise_info['noise_type']=='edge_addition':
    if noise_info['strategy']=='all_edges' :
      noise_fn = add_random_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = add_edges_to_nodes
  else:
    raise 'Noise type should be chosen from feature_noise, edge_removal, edge_addition' 
  return noise_fn
  

def create_noised_data_for_experiment(data, noise_info):
  '''
  Create noised data outside of experiment, so that you can use same data in different experiments
  '''
  noise_data_names = []
  noise_fn = get_noise_function(noise_info)
  
  if noise_info.get('strategy')=='nodes':
    add_prefix = f"{noise_info.get('strategy', '')}_choose_type-{noise_info['params'].get('choose_type', '')}_bidirec-{noise_info['params'].get('bidirectional', '')}"
  elif noise_info.get('strategy')=='all_edges':
    add_prefix = f"{noise_info.get('strategy', '')}_"
  else: 
    add_prefix=''

  if noise_info.get('strategy')=='nodes':
    for k_nodes in noise_info['k_nodes_list']:
      for noise_level in noise_info['noise_levels']:
        noise_data_name = f'{noise_info["noise_type"]}_{add_prefix}_knodes-{k_nodes}_noiselvl-{noise_level}'
        noise_info['params']['noise_level'] = noise_level
        noise_info['params']['k_nodes'] = k_nodes
        noised_data = noise_fn(**noise_info['params'])
        data[noise_data_name] = noised_data
        noise_data_names.append(noise_data_name)

  else: # all_edges and gaussian noisee case
    for noise_level in noise_info['noise_levels']:
      noise_data_name = f'{noise_info["noise_type"]}_{add_prefix}_noiselvl-{noise_level}'
      noise_info['params']['noise_level'] = noise_level
      noised_data = noise_fn(**noise_info['params'])
      data[noise_data_name] = noised_data
      noise_data_names.append(noise_data_name)
  return noise_data_names
 
# reuse train and test
def train(model, optimizer, model_name, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  model.train()
  optimizer.zero_grad()  # Clear gradients.
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

def test(model, model_name, x_type='x', edge_type='edge_index'):
  model.eval()
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.

  pred = out.argmax(dim=1)  # Use the class with highest probability.
  test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
  test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
  return test_acc

def validation(model, model_name, x_type='x', edge_type='edge_index'):
  model.eval()
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  val_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
  val_acc = int(val_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
  return val_acc

def experiment(dataset_name, model_names, model_params, data, x_types, edge_types, noise_info, opt_params,  num_epochs=50, mlp_epochs=50, repeat_num=1, print_updates=False,print_updates_detail=False):
  '''
  Assumes the noisy data is already created and inside the data object (so that we can use same data sample for different models to compare)
  '''
  exp_count = len(x_types)*len(edge_types)*len(model_names)
  count=0
  res = []
  
  for model_name in model_names:
    for x_type in x_types:
      for ed_type in edge_types:
        count+=1
        test_accs = []
        for exp_num in range(1, repeat_num+1): # we will repeat experiment repeat many times, to increase results reliability
           
          model =  get_model(model_name=model_name, model_params=model_params[model_name])
          optimizer = torch.optim.Adam(model.parameters(), lr=opt_params[model_name]['lr'], weight_decay=opt_params[model_name]['weight_decay']) 
          epochs = mlp_epochs if model_name=='MLP' else num_epochs

          for epoch in range(num_epochs):
              loss = train(model, optimizer, model_name=model_name, x_type=x_type, edge_type=ed_type)
              # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

          # we test our results in original data, no noise added ones 
          # if you want to test on noised data change them to x_type=x_type and edge_type=ed_type below
          test_acc = test(model, model_name=model_name, x_type='x',edge_type='edge_index') 
          test_accs.append(test_acc)
          if print_updates_detail:
            print(f'Exp_num:{exp_num} Test Accuracy: {test_acc:.4f}')

        mean_test_acc = round(np.mean(test_accs), 3)
        # TODO we can add other metrics such as runtime to log in here later
        exp_res = {'dataset_name': dataset_name,
                  'model_name':model_name, 'x_type':x_type, 
                'edge_type':ed_type, 'mean_test_accuracy':str(mean_test_acc), 'test_accuracies': ','.join([str(acc) for acc in test_accs]),
                  'num_epochs':epochs, 'model_params': model_params[model_name],
                  'noise_info':noise_info, 'repeat_num':repeat_num} # TODO add more info on experiment noise_info
        res.append(exp_res)
        if print_updates:
            print(f'Run {model_name}: {count}/{exp_count}: {x_type} - {ed_type} Avg. Test Accuracy: {mean_test_acc}')
        
        

  res_df = pd.DataFrame(res, columns=exp_res.keys())
  return res_df

# %%
dataset_name='Cora'

# %%
def nodes_percent_to_num_nodes(percents, num_nodes):
  return [round(pct*num_nodes) for pct in percents]

# %%
# Optimized Model Params

model_params = {
    'GNN':{'in_channels':1433, 'hidden_channels':30, 'out_channels':7, 'num_layers':2, 'dropout':0.2, 'aggr' :'add'},
    'GAT':{'in_channels':1433, 'hidden_channels':15, 'out_channels':7, 'num_layers':2, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels': 42, 'out_channels':7, 'num_layers':2, 'dropout':0.2},
    'MLP': {'in_channels':1433, 'hidden_channels':100,  'out_channels':7, 'num_layers':2, 'dropout': 0.2 },
}
opt_params = {
    'GNN':{'lr':0.05, 'weight_decay':1e-6}, 
    'GAT':{'lr':0.05, 'weight_decay':5e-4}, 
    'Graphsage':{'lr':0.05, 'weight_decay':5e-4}, 
    'MLP':{'lr':0.05, 'weight_decay':0.001}, 
}

# %% [markdown]
# ### Gaussian Experiment add MLP part

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = 'Experiment_MLP_gaussian.csv'
# **** DONT forget to change this *****

data = data.to('cpu')
# noise data creation example: add noise feature
feature_noise_params = {'data':data}
noise_info = {'noise_type':'feature_noise', 'params':feature_noise_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],
              'noise_param_name':'noise_level'}

noise_var_names_feat_exp = create_noised_data_for_experiment(data=data, noise_info=noise_info)
#print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['MLP']
exp_gaussian_feats_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=noise_var_names_feat_exp, edge_types=['edge_index'],
                                    noise_info=noise_info, num_epochs=50, repeat_num=10, print_updates=True)

# Do for node strategies only
data = data.to('cpu')
exp_gaussian_feats_df.to_csv(EXPERIMENT_FILENAME)
exp_gaussian_feats_df
# Out:
# Run MLP: 1/12: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.556
# Run MLP: 2/12: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.527
# Run MLP: 3/12: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.535
# Run MLP: 4/12: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.521
# Run MLP: 5/12: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.525
# Run MLP: 6/12: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.474
# Run MLP: 7/12: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.456
# Run MLP: 8/12: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.462
# Run MLP: 9/12: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.144
# Run MLP: 10/12: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.1
# Run MLP: 11/12: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.132
# Run MLP: 12/12: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.131
#    dataset_name model_name                        x_type   edge_type  \
# 0          Cora        MLP     feature_noise__noiselvl-0  edge_index
# 1          Cora        MLP  feature_noise__noiselvl-0.01  edge_index
# 2          Cora        MLP  feature_noise__noiselvl-0.05  edge_index
# 3          Cora        MLP   feature_noise__noiselvl-0.1  edge_index
# 4          Cora        MLP  feature_noise__noiselvl-0.15  edge_index
# 5          Cora        MLP   feature_noise__noiselvl-0.3  edge_index
# 6          Cora        MLP  feature_noise__noiselvl-0.45  edge_index
# 7          Cora        MLP   feature_noise__noiselvl-0.6  edge_index
# 8          Cora        MLP   feature_noise__noiselvl-0.9  edge_index
# 9          Cora        MLP  feature_noise__noiselvl-0.95  edge_index
# 10         Cora        MLP  feature_noise__noiselvl-0.99  edge_index
# 11         Cora        MLP     feature_noise__noiselvl-1  edge_index
#
#    mean_test_accuracy                                    test_accuracies  \
# 0               0.556  0.571,0.579,0.559,0.559,0.522,0.552,0.58,0.548...
# 1               0.527  0.532,0.534,0.541,0.512,0.524,0.528,0.51,0.506...
# 2               0.535  0.54,0.555,0.513,0.548,0.541,0.525,0.525,0.535...
# 3               0.521  0.483,0.532,0.502,0.533,0.512,0.552,0.547,0.54...
# 4               0.525  0.534,0.538,0.531,0.522,0.508,0.497,0.532,0.53...
# 5               0.474  0.443,0.481,0.458,0.5,0.472,0.479,0.465,0.476,...
# 6               0.456  0.402,0.505,0.438,0.474,0.459,0.463,0.506,0.41...
# 7               0.462  0.489,0.464,0.451,0.484,0.453,0.454,0.467,0.46...
# 8               0.144  0.144,0.146,0.144,0.144,0.144,0.144,0.144,0.14...
# 9                 0.1  0.093,0.103,0.093,0.093,0.119,0.093,0.126,0.09...
# 10              0.132  0.131,0.127,0.13,0.13,0.13,0.13,0.168,0.144,0....
# 11              0.131  0.144,0.128,0.103,0.071,0.149,0.319,0.1,0.064,...
#
#     num_epochs                                       model_params  \
# 0           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 1           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 2           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 3           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 4           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 5           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 6           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 7           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 8           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 9           50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 10          50  {'in_channels': 1433, 'hidden_channels': 100, ...
# 11          50  {'in_channels': 1433, 'hidden_channels': 100, ...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'feature_noise', 'params': {'da...          10
# 1   {'noise_type': 'feature_noise', 'params': {'da...          10
# 2   {'noise_type': 'feature_noise', 'params': {'da...          10
# 3   {'noise_type': 'feature_noise', 'params': {'da...          10
# 4   {'noise_type': 'feature_noise', 'params': {'da...          10
# 5   {'noise_type': 'feature_noise', 'params': {'da...          10
# 6   {'noise_type': 'feature_noise', 'params': {'da...          10
# 7   {'noise_type': 'feature_noise', 'params': {'da...          10
# 8   {'noise_type': 'feature_noise', 'params': {'da...          10
# 9   {'noise_type': 'feature_noise', 'params': {'da...          10
# 10  {'noise_type': 'feature_noise', 'params': {'da...          10
# 11  {'noise_type': 'feature_noise', 'params': {'da...          10

# %%
exp_gaussian_feats_df['test_accuracies'][0]
# Out:
# '0.528,0.557,0.566,0.57,0.553,0.585,0.497,0.541,0.578,0.583'

# %%
gaus_prev_exp = pd.read_csv('Experiment_1_add_gaussian_noise.csv', index_col=0)
gaus_prev_exp = pd.concat([gaus_prev_exp,exp_gaussian_feats_df] )

gaus_prev_exp.to_csv('Experiment_1_add_gaussian_noise.csv')

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Experiment 1 - Add gaussian noise

# %%
folder_name = 'exp_results/results_v5'
bidirectional_type = False
post_fix= f'_bidirectional_{bidirectional_type}'
num_repeat = 5

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_1_add_gaussian_noise{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

feature_noise_params = {'data':data}
noise_info = {'noise_type':'feature_noise', 'params':feature_noise_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'noise_level'}

noise_var_names_feat_exp = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage', 'MLP']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=noise_var_names_feat_exp, edge_types=['edge_index'],
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10024], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9496], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9528], edge_removal_all_edges__noiselvl-0.15=[2, 9046], edge_removal_all_edges__noiselvl-0.3=[2, 7646], edge_removal_all_edges__noiselvl-0.45=[2, 6344], edge_removal_all_edges__noiselvl-0.6=[2, 5102], edge_removal_all_edges__noiselvl-0.9=[2, 3214], edge_removal_all_edges__noiselvl-0.95=[2, 2922], edge_removal_all_edges__noiselvl-0.99=[2, 2684], edge_removal_all_edges__noiselvl-1=[2, 2636], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10258], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10186], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9946], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 10052], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9780], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9986], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9930], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9852], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9696], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9304], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9352], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9494 ...
# Run GNN: 1/48: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.798
# Run GNN: 2/48: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.782
# Run GNN: 3/48: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.747
# Run GNN: 4/48: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.633
# Run GNN: 5/48: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.517
# Run GNN: 6/48: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.128
# Run GNN: 7/48: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.13
# Run GNN: 8/48: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.064
# Run GNN: 9/48: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.171
# Run GNN: 10/48: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.162
# Run GNN: 11/48: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.147
# Run GNN: 12/48: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.2
# Run GAT: 13/48: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.77
# Run GAT: 14/48: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.646
# Run GAT: 15/48: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.365
# Run GAT: 16/48: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.214
# Run GAT: 17/48: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.246
# Run GAT: 18/48: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.106
# Run GAT: 19/48: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.135
# Run GAT: 20/48: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.095
# Run GAT: 21/48: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.161
# Run GAT: 22/48: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.13
# Run GAT: 23/48: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.16
# Run GAT: 24/48: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.122
# Run Graphsage: 25/48: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.779
# Run Graphsage: 26/48: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.768
# Run Graphsage: 27/48: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.731
# Run Graphsage: 28/48: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.659
# Run Graphsage: 29/48: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.511
# Run Graphsage: 30/48: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.197
# Run Graphsage: 31/48: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.077
# Run Graphsage: 32/48: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.064
# Run Graphsage: 33/48: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.15
# Run Graphsage: 34/48: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.161
# Run Graphsage: 35/48: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.117
# Run Graphsage: 36/48: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.15
# Run MLP: 37/48: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.498
# Run MLP: 38/48: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.534
# Run MLP: 39/48: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.544
# Run MLP: 40/48: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.561
# Run MLP: 41/48: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.525
# Run MLP: 42/48: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.442
# Run MLP: 43/48: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.135
# Run MLP: 44/48: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.159
# Run MLP: 45/48: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.064
# Run MLP: 46/48: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.319
# Run MLP: 47/48: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.13
# Run MLP: 48/48: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.128
#    dataset_name model_name                        x_type   edge_type  \
# 0          Cora        GNN     feature_noise__noiselvl-0  edge_index
# 1          Cora        GNN  feature_noise__noiselvl-0.01  edge_index
# 2          Cora        GNN  feature_noise__noiselvl-0.05  edge_index
# 3          Cora        GNN   feature_noise__noiselvl-0.1  edge_index
# 4          Cora        GNN  feature_noise__noiselvl-0.15  edge_index
# 5          Cora        GNN   feature_noise__noiselvl-0.3  edge_index
# 6          Cora        GNN  feature_noise__noiselvl-0.45  edge_index
# 7          Cora        GNN   feature_noise__noiselvl-0.6  edge_index
# 8          Cora        GNN   feature_noise__noiselvl-0.9  edge_index
# 9          Cora        GNN  feature_noise__noiselvl-0.95  edge_index
# 10         Cora        GNN  feature_noise__noiselvl-0.99  edge_index
# 11         Cora        GNN     feature_noise__noiselvl-1  edge_index
# 12         Cora        GAT     feature_noise__noiselvl-0  edge_index
# 13         Cora        GAT  feature_noise__noiselvl-0.01  edge_index
# 14         Cora        GAT  feature_noise__noiselvl-0.05  edge_index
# 15         Cora        GAT   feature_noise__noiselvl-0.1  edge_index
# 16         Cora        GAT  feature_noise__noiselvl-0.15  edge_index
# 17         Cora        GAT   feature_noise__noiselvl-0.3  edge_index
# 18         Cora        GAT  feature_noise__noiselvl-0.45  edge_index
# 19         Cora        GAT   feature_noise__noiselvl-0.6  edge_index
# 20         Cora        GAT   feature_noise__noiselvl-0.9  edge_index
# 21         Cora        GAT  feature_noise__noiselvl-0.95  edge_index
# 22         Cora        GAT  feature_noise__noiselvl-0.99  edge_index
# 23         Cora        GAT     feature_noise__noiselvl-1  edge_index
# 24         Cora  Graphsage     feature_noise__noiselvl-0  edge_index
# 25         Cora  Graphsage  feature_noise__noiselvl-0.01  edge_index
# 26         Cora  Graphsage  feature_noise__noiselvl-0.05  edge_index
# 27         Cora  Graphsage   feature_noise__noiselvl-0.1  edge_index
# 28         Cora  Graphsage  feature_noise__noiselvl-0.15  edge_index
# 29         Cora  Graphsage   feature_noise__noiselvl-0.3  edge_index
# 30         Cora  Graphsage  feature_noise__noiselvl-0.45  edge_index
# 31         Cora  Graphsage   feature_noise__noiselvl-0.6  edge_index
# 32         Cora  Graphsage   feature_noise__noiselvl-0.9  edge_index
# 33         Cora  Graphsage  feature_noise__noiselvl-0.95  edge_index
# 34         Cora  Graphsage  feature_noise__noiselvl-0.99  edge_index
# 35         Cora  Graphsage     feature_noise__noiselvl-1  edge_index
# 36         Cora        MLP     feature_noise__noiselvl-0  edge_index
# 37         Cora        MLP  feature_noise__noiselvl-0.01  edge_index
# 38         Cora        MLP  feature_noise__noiselvl-0.05  edge_index
# 39         Cora        MLP   feature_noise__noiselvl-0.1  edge_index
# 40         Cora        MLP  feature_noise__noiselvl-0.15  edge_index
# 41         Cora        MLP   feature_noise__noiselvl-0.3  edge_index
# 42         Cora        MLP  feature_noise__noiselvl-0.45  edge_index
# 43         Cora        MLP   feature_noise__noiselvl-0.6  edge_index
# 44         Cora        MLP   feature_noise__noiselvl-0.9  edge_index
# 45         Cora        MLP  feature_noise__noiselvl-0.95  edge_index
# 46         Cora        MLP  feature_noise__noiselvl-0.99  edge_index
# 47         Cora        MLP     feature_noise__noiselvl-1  edge_index
#
#    mean_test_accuracy                test_accuracies  num_epochs  \
# 0               0.798    0.787,0.799,0.799,0.803,0.8          25
# 1               0.782  0.779,0.796,0.771,0.785,0.779          25
# 2               0.747   0.735,0.747,0.753,0.752,0.75          25
# 3               0.633  0.636,0.596,0.689,0.623,0.619          25
# 4               0.517  0.566,0.553,0.516,0.501,0.447          25
# 5               0.128   0.121,0.08,0.125,0.182,0.134          25
# 6                0.13   0.171,0.144,0.07,0.088,0.177          25
# 7               0.064  0.064,0.064,0.064,0.064,0.064          25
# 8               0.171    0.331,0.132,0.133,0.13,0.13          25
# 9               0.162  0.143,0.134,0.152,0.286,0.096          25
# 10              0.147  0.154,0.158,0.091,0.129,0.202          25
# 11                0.2  0.187,0.136,0.151,0.358,0.167          25
# 12               0.77  0.765,0.756,0.767,0.803,0.759          25
# 13              0.646  0.715,0.658,0.608,0.544,0.703          25
# 14              0.365  0.445,0.379,0.244,0.367,0.389          25
# 15              0.214   0.21,0.148,0.311,0.336,0.064          25
# 16              0.246   0.144,0.321,0.319,0.13,0.314          25
# 17              0.106  0.064,0.273,0.064,0.066,0.064          25
# 18              0.135  0.091,0.064,0.144,0.064,0.314          25
# 19              0.095  0.128,0.072,0.064,0.064,0.149          25
# 20              0.161   0.154,0.144,0.13,0.272,0.103          25
# 21               0.13    0.103,0.12,0.103,0.193,0.13          25
# 22               0.16    0.13,0.32,0.188,0.093,0.069          25
# 23              0.122   0.103,0.144,0.144,0.13,0.091          25
# 24              0.779   0.769,0.772,0.774,0.79,0.791          25
# 25              0.768  0.768,0.754,0.786,0.757,0.775          25
# 26              0.731   0.731,0.74,0.728,0.725,0.731          25
# 27              0.659  0.671,0.668,0.674,0.632,0.649          25
# 28              0.511    0.577,0.508,0.5,0.482,0.486          25
# 29              0.197  0.158,0.217,0.165,0.285,0.159          25
# 30              0.077  0.065,0.125,0.065,0.065,0.064          25
# 31              0.064  0.064,0.064,0.064,0.064,0.064          25
# 32               0.15    0.129,0.129,0.26,0.13,0.103          25
# 33              0.161   0.13,0.145,0.065,0.314,0.152          25
# 34              0.117  0.103,0.099,0.149,0.132,0.102          25
# 35               0.15  0.104,0.131,0.319,0.103,0.091          25
# 36              0.498     0.53,0.52,0.51,0.468,0.462          25
# 37              0.534   0.565,0.494,0.555,0.515,0.54          25
# 38              0.544  0.572,0.541,0.545,0.527,0.533          25
# 39              0.561  0.593,0.561,0.526,0.553,0.571          25
# 40              0.525   0.517,0.518,0.51,0.539,0.543          25
# 41              0.442  0.399,0.401,0.508,0.467,0.435          25
# 42              0.135   0.108,0.196,0.084,0.069,0.22          25
# 43              0.159   0.266,0.144,0.17,0.085,0.128          25
# 44              0.064  0.064,0.064,0.064,0.064,0.064          25
# 45              0.319  0.319,0.319,0.319,0.319,0.319          25
# 46               0.13       0.13,0.13,0.13,0.13,0.13          25
# 47              0.128  0.153,0.073,0.142,0.145,0.128          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
# 36  {'in_channels': 1433, 'hidden_channels': 100, ...
# 37  {'in_channels': 1433, 'hidden_channels': 100, ...
# 38  {'in_channels': 1433, 'hidden_channels': 100, ...
# 39  {'in_channels': 1433, 'hidden_channels': 100, ...
# 40  {'in_channels': 1433, 'hidden_channels': 100, ...
# 41  {'in_channels': 1433, 'hidden_channels': 100, ...
# 42  {'in_channels': 1433, 'hidden_channels': 100, ...
# 43  {'in_channels': 1433, 'hidden_channels': 100, ...
# 44  {'in_channels': 1433, 'hidden_channels': 100, ...
# 45  {'in_channels': 1433, 'hidden_channels': 100, ...
# 46  {'in_channels': 1433, 'hidden_channels': 100, ...
# 47  {'in_channels': 1433, 'hidden_channels': 100, ...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'feature_noise', 'params': {'da...           5
# 1   {'noise_type': 'feature_noise', 'params': {'da...           5
# 2   {'noise_type': 'feature_noise', 'params': {'da...           5
# 3   {'noise_type': 'feature_noise', 'params': {'da...           5
# 4   {'noise_type': 'feature_noise', 'params': {'da...           5
# 5   {'noise_type': 'feature_noise', 'params': {'da...           5
# 6   {'noise_type': 'feature_noise', 'params': {'da...           5
# 7   {'noise_type': 'feature_noise', 'params': {'da...           5
# 8   {'noise_type': 'feature_noise', 'params': {'da...           5
# 9   {'noise_type': 'feature_noise', 'params': {'da...           5
# 10  {'noise_type': 'feature_noise', 'params': {'da...           5
# 11  {'noise_type': 'feature_noise', 'params': {'da...           5
# 12  {'noise_type': 'feature_noise', 'params': {'da...           5
# 13  {'noise_type': 'feature_noise', 'params': {'da...           5
# 14  {'noise_type': 'feature_noise', 'params': {'da...           5
# 15  {'noise_type': 'feature_noise', 'params': {'da...           5
# 16  {'noise_type': 'feature_noise', 'params': {'da...           5
# 17  {'noise_type': 'feature_noise', 'params': {'da...           5
# 18  {'noise_type': 'feature_noise', 'params': {'da...           5
# 19  {'noise_type': 'feature_noise', 'params': {'da...           5
# 20  {'noise_type': 'feature_noise', 'params': {'da...           5
# 21  {'noise_type': 'feature_noise', 'params': {'da...           5
# 22  {'noise_type': 'feature_noise', 'params': {'da...           5
# 23  {'noise_type': 'feature_noise', 'params': {'da...           5
# 24  {'noise_type': 'feature_noise', 'params': {'da...           5
# 25  {'noise_type': 'feature_noise', 'params': {'da...           5
# 26  {'noise_type': 'feature_noise', 'params': {'da...           5
# 27  {'noise_type': 'feature_noise', 'params': {'da...           5
# 28  {'noise_type': 'feature_noise', 'params': {'da...           5
# 29  {'noise_type': 'feature_noise', 'params': {'da...           5
# 30  {'noise_type': 'feature_noise', 'params': {'da...           5
# 31  {'noise_type': 'feature_noise', 'params': {'da...           5
# 32  {'noise_type': 'feature_noise', 'params': {'da...           5
# 33  {'noise_type': 'feature_noise', 'params': {'da...           5
# 34  {'noise_type': 'feature_noise', 'params': {'da...           5
# 35  {'noise_type': 'feature_noise', 'params': {'da...           5
# 36  {'noise_type': 'feature_noise', 'params': {'da...           5
# 37  {'noise_type': 'feature_noise', 'params': {'da...           5
# 38  {'noise_type': 'feature_noise', 'params': {'da...           5
# 39  {'noise_type': 'feature_noise', 'params': {'da...           5
# 40  {'noise_type': 'feature_noise', 'params': {'da...           5
# 41  {'noise_type': 'feature_noise', 'params': {'da...           5
# 42  {'noise_type': 'feature_noise', 'params': {'da...           5
# 43  {'noise_type': 'feature_noise', 'params': {'da...           5
# 44  {'noise_type': 'feature_noise', 'params': {'da...           5
# 45  {'noise_type': 'feature_noise', 'params': {'da...           5
# 46  {'noise_type': 'feature_noise', 'params': {'da...           5
# 47  {'noise_type': 'feature_noise', 'params': {'da...           5

# %% [markdown]
# ### Experiment 2 - Remove edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_2_remove_random_edges{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

remove_edge_params = {'data':data, 'bidirectional':bidirectional_type}
noise_info = {'noise_type':'edge_removal', 'strategy':'all_edges','params':remove_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_remove_ratio'}

exp_rm_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10024], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9496], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10258], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10186], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9946], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 10052], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9780], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9986], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9930], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9852], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9696], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9304], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9352], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9494 ...
# Run GNN: 1/36: x - edge_removal_all_edges__noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 2/36: x - edge_removal_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.792
# Run GNN: 3/36: x - edge_removal_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.802
# Run GNN: 4/36: x - edge_removal_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 5/36: x - edge_removal_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.792
# Run GNN: 6/36: x - edge_removal_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 7/36: x - edge_removal_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.801
#    dataset_name model_name x_type                              edge_type  \
# 0          Cora        GNN      x     edge_removal_all_edges__noiselvl-0
# 1          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.01
# 2          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.05
# 3          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.1
# 4          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.15
# 5          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.3
# 6          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.45
# 7          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.6
# 8          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.9
# 9          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.95
# 10         Cora        GNN      x  edge_removal_all_edges__noiselvl-0.99
# 11         Cora        GNN      x     edge_removal_all_edges__noiselvl-1
# 12         Cora        GAT      x     edge_removal_all_edges__noiselvl-0
# 13         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.01
# 14         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.05
# 15         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.1
# 16         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.15
# 17         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.3
# 18         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.45
# 19         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.6
# 20         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.9
# 21         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.95
# 22         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.99
# 23         Cora        GAT      x     edge_removal_all_edges__noiselvl-1
# 24         Cora  Graphsage      x     edge_removal_all_edges__noiselvl-0
# 25         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.01
# 26         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.05
# 27         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.1
# 28         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.15
# 29         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.3
# 30         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.45
# 31         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.6
# 32         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.9
# 33         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.95
# 34         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.99
# 35         Cora  Graphsage      x     edge_removal_all_edges__noiselvl-1
#
#    mean_test_accuracy                test_accuracies  num_epochs  \
# 0               0.799    0.798,0.802,0.789,0.806,0.8          25
# 1               0.792   0.796,0.794,0.79,0.769,0.813          25
# 2               0.802  0.801,0.798,0.811,0.811,0.789          25
# 3               0.795   0.793,0.801,0.787,0.79,0.804          25
# 4               0.792  0.791,0.791,0.798,0.779,0.801          25
# 5               0.788  0.777,0.786,0.794,0.793,0.789          25
# 6               0.801  0.807,0.792,0.822,0.789,0.797          25
# 7               0.769    0.766,0.78,0.765,0.756,0.78          25
# 8               0.745    0.732,0.74,0.754,0.74,0.758          25
# 9               0.764   0.776,0.725,0.782,0.765,0.77          25
# 10              0.778  0.775,0.792,0.768,0.782,0.772          25
# 11              0.777    0.764,0.787,0.77,0.77,0.792          25
# 12              0.745  0.778,0.655,0.744,0.789,0.758          25
# 13              0.756   0.751,0.772,0.753,0.765,0.74          25
# 14               0.76  0.801,0.791,0.772,0.712,0.726          25
# 15              0.754  0.779,0.737,0.761,0.776,0.715          25
# 16              0.761  0.753,0.755,0.718,0.775,0.803          25
# 17              0.776   0.812,0.787,0.707,0.792,0.78          25
# 18               0.78  0.779,0.783,0.796,0.779,0.765          25
# 19              0.757   0.763,0.775,0.766,0.742,0.74          25
# 20              0.748  0.763,0.715,0.755,0.779,0.728          25
# 21              0.747  0.773,0.751,0.735,0.721,0.753          25
# 22              0.723   0.765,0.74,0.692,0.721,0.698          25
# 23              0.762  0.764,0.772,0.736,0.754,0.785          25
# 24              0.781   0.785,0.791,0.776,0.774,0.78          25
# 25              0.777  0.777,0.774,0.788,0.776,0.769          25
# 26              0.776   0.772,0.774,0.78,0.765,0.789          25
# 27              0.777   0.79,0.782,0.773,0.766,0.773          25
# 28              0.786  0.779,0.788,0.789,0.784,0.789          25
# 29              0.766  0.746,0.773,0.762,0.781,0.769          25
# 30              0.774    0.775,0.775,0.782,0.77,0.77          25
# 31              0.761   0.766,0.774,0.754,0.761,0.75          25
# 32              0.741   0.743,0.727,0.737,0.76,0.739          25
# 33              0.724   0.72,0.721,0.732,0.729,0.716          25
# 34              0.725   0.729,0.716,0.71,0.737,0.733          25
# 35              0.715  0.696,0.705,0.734,0.718,0.723          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 1   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 2   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 3   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 4   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 5   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 6   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 7   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 8   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 9   {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 10  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 11  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 12  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 13  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 14  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 15  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 16  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 17  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 18  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 19  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 20  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 21  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 22  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 23  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 24  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 25  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 26  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 27  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 28  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 29  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 30  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 31  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 32  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 33  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 34  {'noise_type': 'edge_removal', 'strategy': 'al...           5
# 35  {'noise_type': 'edge_removal', 'strategy': 'al...           5

# %% [markdown]
# ### Experiment 3 - Add edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_3_add_random_edges{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

add_edge_params = {'data':data, 'bidirectional':bidirectional_type}
# edge_addition_params = {'data':data}
noise_info = {'noise_type':'edge_addition', 'strategy':'all_edges','params':add_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_add_ratio'}

exp_add_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10024], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9496], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10258], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10186], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9946], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 10052], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9780], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9986], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9930], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9852], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9696], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9304], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9352], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9494 ...
# Run GNN: 1/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 2/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.803
# Run GNN: 4/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 5/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.791
# Run GNN: 6/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.765
# Run GNN: 7/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.764
# Run GNN: 8/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.777
# Run GNN: 9/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.77
# Run GNN: 10/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.741
# Run GNN: 11/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.746
# Run GNN: 12/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.759
# Run GAT: 13/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.762
# Run GAT: 14/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.764
# Run GAT: 15/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.731
# Run GAT: 16/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.739
# Run GAT: 17/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.745
# Run GAT: 18/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.721
# Run GAT: 19/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.713
# Run GAT: 20/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.706
# Run GAT: 21/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.648
# Run GAT: 22/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.632
# Run GAT: 23/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.605
# Run GAT: 24/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.647
# Run Graphsage: 25/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.772
# Run Graphsage: 26/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.773
# Run Graphsage: 27/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.778
# Run Graphsage: 28/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.768
# Run Graphsage: 29/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.765
# Run Graphsage: 30/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run Graphsage: 31/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.753
# Run Graphsage: 32/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.755
# Run Graphsage: 33/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.749
# Run Graphsage: 34/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.752
# Run Graphsage: 35/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.746
# Run Graphsage: 36/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.737
#    dataset_name model_name x_type                               edge_type  \
# 0          Cora        GNN      x     edge_addition_all_edges__noiselvl-0
# 1          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.01
# 2          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.05
# 3          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.1
# 4          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.15
# 5          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.3
# 6          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.45
# 7          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.6
# 8          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.9
# 9          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.95
# 10         Cora        GNN      x  edge_addition_all_edges__noiselvl-0.99
# 11         Cora        GNN      x     edge_addition_all_edges__noiselvl-1
# 12         Cora        GAT      x     edge_addition_all_edges__noiselvl-0
# 13         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.01
# 14         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.05
# 15         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.1
# 16         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.15
# 17         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.3
# 18         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.45
# 19         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.6
# 20         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.9
# 21         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.95
# 22         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.99
# 23         Cora        GAT      x     edge_addition_all_edges__noiselvl-1
# 24         Cora  Graphsage      x     edge_addition_all_edges__noiselvl-0
# 25         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.01
# 26         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.05
# 27         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.1
# 28         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.15
# 29         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.3
# 30         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.45
# 31         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.6
# 32         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.9
# 33         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.95
# 34         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.99
# 35         Cora  Graphsage      x     edge_addition_all_edges__noiselvl-1
#
#    mean_test_accuracy                test_accuracies  num_epochs  \
# 0               0.795     0.792,0.79,0.785,0.8,0.807          25
# 1               0.791  0.786,0.804,0.783,0.787,0.793          25
# 2               0.803  0.791,0.803,0.804,0.812,0.804          25
# 3               0.793   0.799,0.801,0.79,0.775,0.799          25
# 4               0.791  0.808,0.781,0.779,0.796,0.789          25
# 5               0.765  0.759,0.746,0.775,0.779,0.768          25
# 6               0.764    0.762,0.76,0.75,0.766,0.782          25
# 7               0.777    0.767,0.77,0.773,0.785,0.79          25
# 8                0.77    0.76,0.764,0.77,0.774,0.784          25
# 9               0.741  0.739,0.746,0.742,0.761,0.719          25
# 10              0.746  0.743,0.738,0.753,0.747,0.749          25
# 11              0.759  0.757,0.761,0.771,0.751,0.754          25
# 12              0.762    0.796,0.735,0.682,0.798,0.8          25
# 13              0.764  0.774,0.777,0.747,0.793,0.728          25
# 14              0.731  0.727,0.709,0.744,0.767,0.707          25
# 15              0.739    0.751,0.67,0.724,0.75,0.801          25
# 16              0.745   0.675,0.748,0.758,0.756,0.79          25
# 17              0.721  0.752,0.673,0.701,0.738,0.741          25
# 18              0.713   0.751,0.755,0.671,0.73,0.659          25
# 19              0.706    0.68,0.769,0.661,0.72,0.698          25
# 20              0.648  0.599,0.672,0.632,0.685,0.654          25
# 21              0.632   0.53,0.718,0.539,0.638,0.734          25
# 22              0.605    0.67,0.585,0.512,0.737,0.52          25
# 23              0.647  0.746,0.579,0.592,0.656,0.662          25
# 24              0.772  0.784,0.763,0.773,0.772,0.766          25
# 25              0.773  0.777,0.757,0.785,0.786,0.761          25
# 26              0.778  0.771,0.781,0.775,0.787,0.776          25
# 27              0.768  0.775,0.771,0.764,0.772,0.758          25
# 28              0.765   0.768,0.748,0.77,0.759,0.779          25
# 29              0.776  0.783,0.775,0.768,0.777,0.777          25
# 30              0.753    0.757,0.77,0.749,0.737,0.75          25
# 31              0.755   0.76,0.761,0.753,0.753,0.748          25
# 32              0.749  0.746,0.751,0.761,0.731,0.758          25
# 33              0.752  0.737,0.756,0.755,0.758,0.753          25
# 34              0.746  0.745,0.741,0.756,0.745,0.742          25
# 35              0.737  0.747,0.743,0.737,0.729,0.729          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 1   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 2   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 3   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 4   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 5   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 6   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 7   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 8   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 9   {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 10  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 11  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 12  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 13  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 14  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 15  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 16  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 17  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 18  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 19  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 20  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 21  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 22  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 23  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 24  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 25  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 26  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 27  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 28  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 29  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 30  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 31  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 32  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 33  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 34  {'noise_type': 'edge_addition', 'strategy': 'a...           5
# 35  {'noise_type': 'edge_addition', 'strategy': 'a...           5

# %% [markdown]
# ### Experiment 4 - Remove Edges: Random - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_4_remove_random_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'random'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9500], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10268], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10170], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10142], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 10012], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9924], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9838], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9660], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9470], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9226], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9374 ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.79
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.795
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.805
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.797
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.789
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.784
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.799
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.806
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.801
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.789
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.797
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.793
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.796
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.788
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.794
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.797
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.8
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.799
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.802
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.784
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.793
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.786
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.795
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.804
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.803
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.796
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.793
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.801
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.793
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.79
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.777
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.81
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.766
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.786
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.788
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.783
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.8
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.792
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.793
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.782
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.777
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.783
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.797
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.803
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.775
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.776
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.786
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.8
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.79
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.79
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.774
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.795
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.782
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.785
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.791
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.782
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.788
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.772
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.752
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.735
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.759
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.768
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.803
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.766
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.756
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.786
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.793
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.743
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.751
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.801
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.78
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.771
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.783
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.757
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.9 Avg. Test Accuracy: 0.739
# Run GNN: 106/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.756
# Run GNN: 107/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.783
# Run GNN: 108/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.79
# Run GNN: 109/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0 Avg. Test Accuracy: 0.79
# Run GNN: 110/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.01 Avg. Test Accuracy: 0.782
# Run GNN: 111/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 112/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.1 Avg. Test Accuracy: 0.78
# Run GNN: 113/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.15 Avg. Test Accuracy: 0.769
# Run GNN: 114/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.3 Avg. Test Accuracy: 0.796
# Run GNN: 115/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.45 Avg. Test Accuracy: 0.78
# Run GNN: 116/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.6 Avg. Test Accuracy: 0.776
# Run GNN: 117/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.9 Avg. Test Accuracy: 0.728
# Run GNN: 118/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.95 Avg. Test Accuracy: 0.747
# Run GNN: 119/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.99 Avg. Test Accuracy: 0.717
# Run GNN: 120/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-1 Avg. Test Accuracy: 0.772
# Run GNN: 121/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 122/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.01 Avg. Test Accuracy: 0.799
# Run GNN: 123/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GNN: 124/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.1 Avg. Test Accuracy: 0.78
# Run GNN: 125/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.15 Avg. Test Accuracy: 0.784
# Run GNN: 126/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run GNN: 127/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.45 Avg. Test Accuracy: 0.776
# Run GNN: 128/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.6 Avg. Test Accuracy: 0.772
# Run GNN: 129/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.9 Avg. Test Accuracy: 0.761
# Run GNN: 130/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.95 Avg. Test Accuracy: 0.729
# Run GNN: 131/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-0.99 Avg. Test Accuracy: 0.728
# Run GNN: 132/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2437_noiselvl-1 Avg. Test Accuracy: 0.754
# Run GNN: 133/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 134/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.01 Avg. Test Accuracy: 0.771
# Run GNN: 135/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.05 Avg. Test Accuracy: 0.785
# Run GNN: 136/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.1 Avg. Test Accuracy: 0.754
# Run GNN: 137/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.15 Avg. Test Accuracy: 0.781
# Run GNN: 138/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run GNN: 139/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.45 Avg. Test Accuracy: 0.769
# Run GNN: 140/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.6 Avg. Test Accuracy: 0.766
# Run GNN: 141/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.9 Avg. Test Accuracy: 0.778
# Run GNN: 142/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.95 Avg. Test Accuracy: 0.767
# Run GNN: 143/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.99 Avg. Test Accuracy: 0.761
# Run GNN: 144/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.759
# Run GAT: 145/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.76
# Run GAT: 146/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.739
# Run GAT: 147/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.767
# Run GAT: 148/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.77
# Run GAT: 149/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.761
# Run GAT: 150/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.765
# Run GAT: 151/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.764
# Run GAT: 152/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run GAT: 153/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.765
# Run GAT: 154/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0
432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.3 Avg. Test Accuracy: 0.757
# Run Graphsage: 427/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.45 Avg. Test Accuracy: 0.762
# Run Graphsage: 428/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.6 Avg. Test Accuracy: 0.742
# Run Graphsage: 429/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.9 Avg. Test Accuracy: 0.724
# Run Graphsage: 430/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.95 Avg. Test Accuracy: 0.716
# Run Graphsage: 431/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-0.99 Avg. Test Accuracy: 0.677
# Run Graphsage: 432/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.705
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-random_bidirec-...                0.8
# 1    edge_removal_nodes_choose_type-random_bidirec-...              0.791
# 2    edge_removal_nodes_choose_type-random_bidirec-...              0.796
# 3    edge_removal_nodes_choose_type-random_bidirec-...               0.79
# 4    edge_removal_nodes_choose_type-random_bidirec-...               0.79
# ..                                                 ...                ...
# 427  edge_removal_nodes_choose_type-random_bidirec-...              0.742
# 428  edge_removal_nodes_choose_type-random_bidirec-...              0.724
# 429  edge_removal_nodes_choose_type-random_bidirec-...              0.716
# 430  edge_removal_nodes_choose_type-random_bidirec-...              0.677
# 431  edge_removal_nodes_choose_type-random_bidirec-...              0.705
#
#                    test_accuracies  num_epochs  \
# 0    0.789,0.806,0.789,0.802,0.813          25
# 1    0.789,0.799,0.777,0.796,0.792          25
# 2    0.801,0.798,0.793,0.789,0.799          25
# 3    0.789,0.783,0.795,0.789,0.794          25
# 4      0.79,0.791,0.79,0.788,0.793          25
# ..                             ...         ...
# 427    0.74,0.736,0.748,0.74,0.746          25
# 428   0.696,0.71,0.741,0.731,0.741          25
# 429   0.718,0.714,0.705,0.723,0.72          25
# 430  0.666,0.665,0.715,0.653,0.688          25
# 431  0.716,0.705,0.704,0.686,0.714          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# ..                                                 ...         ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...           5
#
#     choose_type bidirectional k_nodes noise_level
# 0        random          True     135           0
# 1        random          True     135        0.01
# 2        random          True     135        0.05
# 3        random          True     135         0.1
# 4        random          True     135        0.15
# ..          ...           ...     ...         ...
# 427      random          True    2708         0.6
# 428      random          True    2708         0.9
# 429      random          True    2708        0.95
# 430      random          True    2708        0.99
# 431      random          True    2708           1
#
# [432 rows x 14 columns]

# %% [markdown]
# ### Experiment 5 - Remove Edges: topk - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_5_remove_topk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9500], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10268], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10170], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10142], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 10012], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9924], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9838], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9660], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9470], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9226], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9374 ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.793
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.796
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.795
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.792
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.795
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.79
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.792
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.781
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.79
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.803
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.794
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.795
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.792
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.78
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.769
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.788
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.793
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.806
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.797
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.786
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.804
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.778
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.793
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.783
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.785
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.8
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.798
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.792
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.792
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.786
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.788
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.781
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.79
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.78
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.791
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.803
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.792
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.78
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.773
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.775
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.789
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.8
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.783
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.76
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.754
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.803
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.778
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.804
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.798
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.766
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.778
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.776
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.776
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.746
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.772
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.777
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.777
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.789
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.763
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.773
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.741
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.741
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.732
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.747
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.776
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.782
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.775
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.774
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.797
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.775
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0
432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.99 Avg. Test Accuracy: 0.714
# Run Graphsage: 432/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.697
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.799
# 1    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.793
# 2    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.796
# 3    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.788
# 4    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.796
# ..                                                 ...                ...
# 427  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.737
# 428  edge_removal_nodes_choose_type-top_k_bidirec-T...               0.69
# 429  edge_removal_nodes_choose_type-top_k_bidirec-T...               0.71
# 430  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.714
# 431  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.697
#
#                    test_accuracies  num_epochs  \
# 0      0.792,0.8,0.805,0.787,0.811          25
# 1      0.792,0.786,0.801,0.8,0.785          25
# 2    0.788,0.787,0.799,0.811,0.797          25
# 3      0.79,0.79,0.773,0.797,0.788          25
# 4    0.805,0.802,0.791,0.778,0.806          25
# ..                             ...         ...
# 427  0.735,0.723,0.731,0.732,0.762          25
# 428    0.703,0.69,0.694,0.673,0.69          25
# 429  0.699,0.719,0.707,0.701,0.725          25
# 430    0.696,0.724,0.71,0.72,0.722          25
# 431    0.7,0.698,0.711,0.692,0.686          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# ..                                                 ...         ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...           5
#
#     choose_type bidirectional k_nodes noise_level
# 0           top          True     135           0
# 1           top          True     135        0.01
# 2           top          True     135        0.05
# 3           top          True     135         0.1
# 4           top          True     135        0.15
# ..          ...           ...     ...         ...
# 427         top          True    2708         0.6
# 428         top          True    2708         0.9
# 429         top          True    2708        0.95
# 430         top          True    2708        0.99
# 431         top          True    2708           1
#
# [432 rows x 14 columns]

# %% [markdown]
# ### Experiment 6 - Remove Edges: Bottom k - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_6_remove_bottomk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent =  [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9500], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10268], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10170], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10142], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 10012], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9924], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9918], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9838], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9660], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9470], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9226], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9374 ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.794
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.794
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.794
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.781
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.802
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.796
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.797
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.805
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.789
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.788
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.795
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.79
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.792
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.797
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.796
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.795
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.798
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.801
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.79
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.8
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.795
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.794
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.794
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.801
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.793
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.796
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.792
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.794
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.792
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.798
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.792
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.784
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.792
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.792
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.778
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.781
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.797
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.795
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.784
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.783
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.772
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.793
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.78
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.79
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.792
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.774
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.793
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.767
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.792
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.779
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.773
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.777
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.775
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.775
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.772
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.769
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.772
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.768
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.767
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.763
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.772
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.772
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.785
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.783
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.766
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.802
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.765
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.799
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.9 Avg. Test Accuracy: 0.78
# Run GNN: 106/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.771
# Run GNN: 107/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.767
# Run GNN: 108/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.739
# Run GNN: 109/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-
432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.688
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-bottom_k_bidire...              0.794
# 1    edge_removal_nodes_choose_type-bottom_k_bidire...              0.787
# 2    edge_removal_nodes_choose_type-bottom_k_bidire...              0.788
# 3    edge_removal_nodes_choose_type-bottom_k_bidire...              0.796
# 4    edge_removal_nodes_choose_type-bottom_k_bidire...              0.794
# ..                                                 ...                ...
# 427  edge_removal_nodes_choose_type-bottom_k_bidire...              0.748
# 428  edge_removal_nodes_choose_type-bottom_k_bidire...              0.667
# 429  edge_removal_nodes_choose_type-bottom_k_bidire...              0.671
# 430  edge_removal_nodes_choose_type-bottom_k_bidire...              0.703
# 431  edge_removal_nodes_choose_type-bottom_k_bidire...              0.688
#
#                    test_accuracies  num_epochs  \
# 0    0.796,0.789,0.803,0.789,0.794          25
# 1    0.798,0.792,0.764,0.793,0.789          25
# 2    0.777,0.791,0.789,0.798,0.787          25
# 3    0.794,0.801,0.797,0.801,0.787          25
# 4    0.792,0.809,0.797,0.779,0.791          25
# ..                             ...         ...
# 427  0.759,0.754,0.731,0.756,0.741          25
# 428  0.656,0.663,0.659,0.684,0.675          25
# 429  0.657,0.645,0.707,0.658,0.689          25
# 430   0.68,0.684,0.719,0.732,0.699          25
# 431  0.674,0.684,0.692,0.697,0.694          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# ..                                                 ...         ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...           5
#
#     choose_type bidirectional k_nodes noise_level
# 0        bottom          True     135           0
# 1        bottom          True     135        0.01
# 2        bottom          True     135        0.05
# 3        bottom          True     135         0.1
# 4        bottom          True     135        0.15
# ..          ...           ...     ...         ...
# 427      bottom          True    2708         0.6
# 428      bottom          True    2708         0.9
# 429      bottom          True    2708        0.95
# 430      bottom          True    2708        0.99
# 431      bottom          True    2708           1
#
# [432 rows x 14 columns]

# %% [markdown]
# ### Experiment 7 - Add Edges: random nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_7_add_random_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'random'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_add_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9514], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10290], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10292], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10260], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10178], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10208], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10164], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9910], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9990], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9966], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10004], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9950], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9846], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9666], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9360], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9370], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9200] ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.802
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.799
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.804
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.792
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.789
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.804
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.787
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.8
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.793
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.795
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.804
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.795
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.792
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.788
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.801
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.79
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.779
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.792
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.779
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.793
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.789
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.792
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.784
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.801
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.781
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.794
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.786
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.795
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.79
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.784
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.786
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.772
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.788
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.803
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.797
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.792
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.784
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.796
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.79
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.788
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.771
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.782
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.772
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.779
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.781
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.797
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.786
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.778
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.74
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.792
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.802
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.784
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.783
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.782
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.774
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.763
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.776
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.773
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.767
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.789
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.78
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.785
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.793
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.79
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.778
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.755
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.773
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.807
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.764
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.786
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.773
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.9 Avg. Test Accuracy: 0.788
# Run GNN: 106/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.755
# Run GNN: 107/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.778
# Run GNN: 108/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.757
# Run GNN: 109/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 110/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.01 Avg. Test Accuracy: 0.777
# Run GNN: 111/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.05 Avg. Test Accuracy: 0.779
# Run GNN: 112/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0.1 Avg. Test Accuracy: 0.778
# Run GNN: 113/432: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2573_noiselvl-0
x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.714
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-random_bidirec-...              0.802
# 1    edge_removal_nodes_choose_type-random_bidirec-...              0.791
# 2    edge_removal_nodes_choose_type-random_bidirec-...              0.795
# 3    edge_removal_nodes_choose_type-random_bidirec-...              0.791
# 4    edge_removal_nodes_choose_type-random_bidirec-...              0.798
# ..                                                 ...                ...
# 427  edge_removal_nodes_choose_type-random_bidirec-...              0.742
# 428  edge_removal_nodes_choose_type-random_bidirec-...              0.695
# 429  edge_removal_nodes_choose_type-random_bidirec-...              0.685
# 430  edge_removal_nodes_choose_type-random_bidirec-...              0.724
# 431  edge_removal_nodes_choose_type-random_bidirec-...              0.714
#
#                    test_accuracies  num_epochs  \
# 0    0.814,0.801,0.802,0.796,0.799          25
# 1    0.802,0.791,0.792,0.777,0.793          25
# 2    0.801,0.797,0.803,0.789,0.787          25
# 3     0.783,0.78,0.809,0.801,0.782          25
# 4    0.791,0.796,0.807,0.807,0.791          25
# ..                             ...         ...
# 427  0.756,0.751,0.745,0.737,0.719          25
# 428    0.685,0.699,0.7,0.694,0.695          25
# 429  0.695,0.666,0.685,0.692,0.686          25
# 430   0.722,0.704,0.73,0.726,0.739          25
# 431  0.735,0.731,0.713,0.696,0.696          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# ..                                                 ...         ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...           5
#
#     choose_type bidirectional k_nodes noise_level
# 0        random          True     135           0
# 1        random          True     135        0.01
# 2        random          True     135        0.05
# 3        random          True     135         0.1
# 4        random          True     135        0.15
# ..          ...           ...     ...         ...
# 427      random          True    2708         0.6
# 428      random          True    2708         0.9
# 429      random          True    2708        0.95
# 430      random          True    2708        0.99
# 431      random          True    2708           1
#
# [432 rows x 14 columns]

# %% [markdown]
# ### Experiment 8 - Add Edges: topk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_8_add_topk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9514], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10290], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10292], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10260], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10178], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10208], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10164], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9910], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9990], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9966], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10004], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9950], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9846], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9666], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9360], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9370], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9200] ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.797
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.793
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.796
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.798
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.796
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.774
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.786
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.793
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.788
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.783
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.779
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.789
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.789
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.774
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.799
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.802
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.793
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.788
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.786
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.782
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.792
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.805
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.801
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.802
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.802
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.786
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.797
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.767
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.79
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.786
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.794
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.781
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.785
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.794
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.79
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.791
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.793
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.79
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.773
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.783
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.758
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.79
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.779
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.785
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.77
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.773
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.775
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.788
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.776
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.775
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.766
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.8
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.792
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.764
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.77
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.786
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.762
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.792
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.77
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.774
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.776
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.781
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.767
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.767
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.731
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.763
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.73
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.749
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.783
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.784
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.774
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.776
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.782
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.9 Avg. Test Accuracy: 0.75
# Run GNN: 106/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.778
# Run GNN: 107/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.727
# Run GNN: 108/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.757
# Run GNN: 109/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0 Avg. Test Accuracy: 0.791
# Run GNN: 110/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.01 Avg. Test Accuracy: 0.782
# Run GNN: 111/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.05 Avg. Test Accuracy: 0.761
# Run GNN: 112/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.1 Avg. Test Accuracy: 0.775
# Run GNN: 113/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.15 Avg. Test Accuracy: 0.783
# Run GNN: 114/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.3 Avg. Test Accuracy: 0.784
# Run GNN: 115/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.45 Avg. Test Accuracy: 0.749
# Run GNN: 116/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0
432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.717
# Run Graphsage: 395/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.718
# Run Graphsage: 396/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.735
# Run Graphsage: 397/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0 Avg. Test Accuracy: 0.782
# Run Graphsage: 398/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.01 Avg. Test Accuracy: 0.747
# Run Graphsage: 399/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.05 Avg. Test Accuracy: 0.756
# Run Graphsage: 400/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.1 Avg. Test Accuracy: 0.755
# Run Graphsage: 401/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.15 Avg. Test Accuracy: 0.757
# Run Graphsage: 402/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.3 Avg. Test Accuracy: 0.759
# Run Graphsage: 403/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.45 Avg. Test Accuracy: 0.751
# Run Graphsage: 404/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.6 Avg. Test Accuracy: 0.748
# Run Graphsage: 405/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.9 Avg. Test Accuracy: 0.711
# Run Graphsage: 406/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.95 Avg. Test Accuracy: 0.702
# Run Graphsage: 407/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-0.99 Avg. Test Accuracy: 0.712
# Run Graphsage: 408/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2573_noiselvl-1 Avg. Test Accuracy: 0.687
# Run Graphsage: 409/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0 Avg. Test Accuracy: 0.772
# Run Graphsage: 410/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.01 Avg. Test Accuracy: 0.752
# Run Graphsage: 411/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.05 Avg. Test Accuracy: 0.756
# Run Graphsage: 412/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.1 Avg. Test Accuracy: 0.763
# Run Graphsage: 413/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.15 Avg. Test Accuracy: 0.755
# Run Graphsage: 414/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.3 Avg. Test Accuracy: 0.761
# Run Graphsage: 415/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.45 Avg. Test Accuracy: 0.754
# Run Graphsage: 416/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.6 Avg. Test Accuracy: 0.756
# Run Graphsage: 417/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.9 Avg. Test Accuracy: 0.712
# Run Graphsage: 418/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.95 Avg. Test Accuracy: 0.726
# Run Graphsage: 419/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-0.99 Avg. Test Accuracy: 0.715
# Run Graphsage: 420/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2437_noiselvl-1 Avg. Test Accuracy: 0.735
# Run Graphsage: 421/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0 Avg. Test Accuracy: 0.771
# Run Graphsage: 422/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.01 Avg. Test Accuracy: 0.749
# Run Graphsage: 423/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.05 Avg. Test Accuracy: 0.755
# Run Graphsage: 424/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.1 Avg. Test Accuracy: 0.753
# Run Graphsage: 425/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.15 Avg. Test Accuracy: 0.753
# Run Graphsage: 426/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.3 Avg. Test Accuracy: 0.753
# Run Graphsage: 427/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.45 Avg. Test Accuracy: 0.758
# Run Graphsage: 428/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.6 Avg. Test Accuracy: 0.722
# Run Graphsage: 429/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.9 Avg. Test Accuracy: 0.705
# Run Graphsage: 430/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.95 Avg. Test Accuracy: 0.718
# Run Graphsage: 431/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-0.99 Avg. Test Accuracy: 0.692
# Run Graphsage: 432/432: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.69
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.798
# 1    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.797
# 2    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.795
# 3    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.791
# 4    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.793
# ..                                                 ...                ...
# 427  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.722
# 428  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.705
# 429  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.718
# 430  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.692
# 431  edge_removal_nodes_choose_type-top_k_bidirec-T...               0.69
#
#                    test_accuracies  num_epochs  \
# 0    0.799,0.804,0.792,0.796,0.801          25
# 1    0.787,0.805,0.804,0.787,0.801          25
# 2      0.792,0.796,0.801,0.788,0.8          25
# 3      0.788,0.8,0.792,0.782,0.793          25
# 4    0.781,0.797,0.802,0.792,0.792          25
# ..                             ...         ...
# 427   0.71,0.741,0.727,0.726,0.708          25
# 428  0.699,0.695,0.717,0.721,0.695          25
# 429  0.716,0.701,0.702,0.724,0.746          25
# 430  0.689,0.691,0.687,0.692,0.699          25
# 431    0.7,0.692,0.692,0.685,0.682          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           5
# ..                                                 ...         ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...           5
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...           5
#
#     choose_type bidirectional k_nodes noise_level
# 0        bottom          True     135           0
# 1        bottom          True     135        0.01
# 2        bottom          True     135        0.05
# 3        bottom          True     135         0.1
# 4        bottom          True     135        0.15
# ..          ...           ...     ...         ...
# 427      bottom          True    2708         0.6
# 428      bottom          True    2708         0.9
# 429      bottom          True    2708        0.95
# 430      bottom          True    2708        0.99
# 431      bottom          True    2708           1
#
# [432 rows x 14 columns]

# %% [markdown]
# ### Experiment 9 - Add Edges: bottomk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_9_add_bottomk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9514], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9526], edge_removal_all_edges__noiselvl-0.15=[2, 9020], edge_removal_all_edges__noiselvl-0.3=[2, 7642], edge_removal_all_edges__noiselvl-0.45=[2, 6350], edge_removal_all_edges__noiselvl-0.6=[2, 5188], edge_removal_all_edges__noiselvl-0.9=[2, 3184], edge_removal_all_edges__noiselvl-0.95=[2, 2908], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2582], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10290], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10292], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10260], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10178], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10208], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10164], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9910], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9940], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9990], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9966], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10010], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10004], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9950], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9846], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9666], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9360], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9370], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9200] ...
# Run GNN: 1/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.802
# Run GNN: 2/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.797
# Run GNN: 3/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 4/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 5/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.79
# Run GNN: 6/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.794
# Run GNN: 7/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.799
# Run GNN: 8/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 9/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 10/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.795
# Run GNN: 11/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.798
# Run GNN: 12/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.791
# Run GNN: 13/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 14/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 15/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 16/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 17/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.79
# Run GNN: 18/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 19/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.795
# Run GNN: 20/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.782
# Run GNN: 21/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.793
# Run GNN: 22/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.794
# Run GNN: 23/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.785
# Run GNN: 24/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.796
# Run GNN: 25/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 26/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.794
# Run GNN: 27/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 28/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.801
# Run GNN: 29/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.796
# Run GNN: 30/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 31/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.792
# Run GNN: 32/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 33/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.796
# Run GNN: 34/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.79
# Run GNN: 35/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.791
# Run GNN: 36/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.797
# Run GNN: 37/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 38/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.788
# Run GNN: 39/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 40/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 41/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 42/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.792
# Run GNN: 43/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.791
# Run GNN: 44/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.79
# Run GNN: 45/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.793
# Run GNN: 46/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.795
# Run GNN: 47/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.792
# Run GNN: 48/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.796
# Run GNN: 49/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.793
# Run GNN: 50/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.787
# Run GNN: 51/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 52/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 53/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.781
# Run GNN: 54/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.792
# Run GNN: 55/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.786
# Run GNN: 56/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.795
# Run GNN: 57/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.782
# Run GNN: 58/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.801
# Run GNN: 59/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.99 Avg. Test Accuracy: 0.792
# Run GNN: 60/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-1 Avg. Test Accuracy: 0.798
# Run GNN: 61/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 62/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.01 Avg. Test Accuracy: 0.789
# Run GNN: 63/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 64/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.1 Avg. Test Accuracy: 0.786
# Run GNN: 65/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.15 Avg. Test Accuracy: 0.773
# Run GNN: 66/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.3 Avg. Test Accuracy: 0.798
# Run GNN: 67/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.45 Avg. Test Accuracy: 0.786
# Run GNN: 68/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run GNN: 69/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.9 Avg. Test Accuracy: 0.785
# Run GNN: 70/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.95 Avg. Test Accuracy: 0.779
# Run GNN: 71/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-0.99 Avg. Test Accuracy: 0.797
# Run GNN: 72/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1354_noiselvl-1 Avg. Test Accuracy: 0.788
# Run GNN: 73/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 74/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.01 Avg. Test Accuracy: 0.785
# Run GNN: 75/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.05 Avg. Test Accuracy: 0.783
# Run GNN: 76/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.1 Avg. Test Accuracy: 0.778
# Run GNN: 77/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.15 Avg. Test Accuracy: 0.771
# Run GNN: 78/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.3 Avg. Test Accuracy: 0.775
# Run GNN: 79/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.45 Avg. Test Accuracy: 0.767
# Run GNN: 80/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 81/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.9 Avg. Test Accuracy: 0.765
# Run GNN: 82/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.95 Avg. Test Accuracy: 0.771
# Run GNN: 83/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-0.99 Avg. Test Accuracy: 0.765
# Run GNN: 84/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1625_noiselvl-1 Avg. Test Accuracy: 0.768
# Run GNN: 85/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 86/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.01 Avg. Test Accuracy: 0.771
# Run GNN: 87/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.05 Avg. Test Accuracy: 0.787
# Run GNN: 88/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.1 Avg. Test Accuracy: 0.772
# Run GNN: 89/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 90/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run GNN: 91/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.45 Avg. Test Accuracy: 0.776
# Run GNN: 92/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 93/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.9 Avg. Test Accuracy: 0.764
# Run GNN: 94/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.95 Avg. Test Accuracy: 0.77
# Run GNN: 95/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-0.99 Avg. Test Accuracy: 0.775
# Run GNN: 96/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1896_noiselvl-1 Avg. Test Accuracy: 0.777
# Run GNN: 97/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 98/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.01 Avg. Test Accuracy: 0.783
# Run GNN: 99/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.05 Avg. Test Accuracy: 0.774
# Run GNN: 100/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GNN: 101/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.15 Avg. Test Accuracy: 0.786
# Run GNN: 102/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.3 Avg. Test Accuracy: 0.786
# Run GNN: 103/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.45 Avg. Test Accuracy: 0.787
# Run GNN: 104/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.6 Avg. Test Accuracy: 0.773
# Run GNN: 105/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.9 Avg. Test Accuracy: 0.776
# Run GNN: 106/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.95 Avg. Test Accuracy: 0.761
# Run GNN: 107/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-0.99 Avg. Test Accuracy: 0.77
# Run GNN: 108/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2166_noiselvl-1 Avg. Test Accuracy: 0.782
# Run GNN: 109/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 110/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.01 Avg. Test Accuracy: 0.78
# Run GNN: 111/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.05 Avg. Test Accuracy: 0.768
# Run GNN: 112/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 113/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 114/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.3 Avg. Test Accuracy: 0.77
# Run GNN: 115/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.45 Avg. Test Accuracy: 0.765
# Run GNN: 116/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.6 Avg. Test Accuracy: 0.763
# Run GNN: 117/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GNN: 118/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.95 Avg. Test Accuracy: 0.783
# Run GNN: 119/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-0.99 Avg. Test Accuracy: 0.751
# Run GNN: 120/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2573_noiselvl-1 Avg. Test Accuracy: 0.763
# Run GNN: 121/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0 Avg. Test Accuracy: 0.799
# Run GNN: 122/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.01 Avg. Test Accuracy: 0.773
# Run GNN: 123/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 124/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.1 Avg. Test Accuracy: 0.774
# Run GNN: 125/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.15 Avg. Test Accuracy: 0.766
# Run GNN: 126/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.3 Avg. Test Accuracy: 0.781
# Run GNN: 127/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.45 Avg. Test Accuracy: 0.766
# Run GNN: 128/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.6 Avg. Test Accuracy: 0.769
# Run GNN: 129/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.9 Avg. Test Accuracy: 0.767
# Run GNN: 130/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.95 Avg. Test Accuracy: 0.764
# Run GNN: 131/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-0.99 Avg. Test Accuracy: 0.786
# Run GNN: 132/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2437_noiselvl-1 Avg. Test Accuracy: 0.77
# Run GNN: 133/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 134/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.01 Avg. Test Accuracy: 0.783
# Run GNN: 135/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.05 Avg. Test Accuracy: 0.781
# Run GNN: 136/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.1 Avg. Test Accuracy: 0.766
# Run GNN: 137/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 138/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.3 Avg. Test Accuracy: 0.771
# Run GNN: 139/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.45 Avg. Test Accuracy: 0.773
# Run GNN: 140/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.6 Avg. Test Accuracy: 0.745
# Run GNN: 141/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.9 Avg. Test Accuracy: 0.767
# Run GNN: 142/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.95 Avg. Test Accuracy: 0.743
# Run GNN: 143/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-0.99 Avg. Test Accuracy: 0.75
# Run GNN: 144/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.74
# Run GAT: 145/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.748
# Run GAT: 146/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.769
# Run GAT: 147/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.749
# Run GAT: 148/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.776
# Run GAT: 149/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.77
# Run GAT: 150/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.773
# Run GAT: 151/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.77
# Run GAT: 152/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.765
# Run GAT: 153/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.752
# Run GAT: 154/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.745
# Run GAT: 155/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.747
# Run GAT: 156/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.77
# Run GAT: 157/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.739
# Run GAT: 158/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.759
# Run GAT: 159/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.758
# Run GAT: 160/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 161/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run GAT: 162/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.771
# Run GAT: 163/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.712
# Run GAT: 164/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.762
# Run GAT: 165/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.748
# Run GAT: 166/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.758
# Run GAT: 167/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.76
# Run GAT: 168/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.764
# Run GAT: 169/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.764
# Run GAT: 170/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.757
# Run GAT: 171/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.755
# Run GAT: 172/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.765
# Run GAT: 173/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.752
# Run GAT: 174/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.761
# Run GAT: 175/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.756
# Run GAT: 176/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.744
# Run GAT: 177/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.764
# Run GAT: 178/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.762
# Run GAT: 179/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.762
# Run GAT: 180/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.772
# Run GAT: 181/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0 Avg. Test Accuracy: 0.758
# Run GAT: 182/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.01 Avg. Test Accuracy: 0.766
# Run GAT: 183/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.05 Avg. Test Accuracy: 0.771
# Run GAT: 184/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.1 Avg. Test Accuracy: 0.778
# Run GAT: 185/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.15 Avg. Test Accuracy: 0.756
# Run GAT: 186/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.3 Avg. Test Accuracy: 0.767
# Run GAT: 187/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.45 Avg. Test Accuracy: 0.763
# Run GAT: 188/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.6 Avg. Test Accuracy: 0.759
# Run GAT: 189/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.9 Avg. Test Accuracy: 0.75
# Run GAT: 190/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run GAT: 191/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-0.99 Avg. Test Accuracy: 0.783
# Run GAT: 192/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-677_noiselvl-1 Avg. Test Accuracy: 0.76
# Run GAT: 193/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0 Avg. Test Accuracy: 0.783
# Run GAT: 194/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.01 Avg. Test Accuracy: 0.763
# Run GAT: 195/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GAT: 196/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 197/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.15 Avg. Test Accuracy: 0.767
# Run GAT: 198/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.3 Avg. Test Accuracy: 0.772
# Run GAT: 199/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.45 Avg. Test Accuracy: 0.752
# Run GAT: 200/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.6 Avg. Test Accuracy: 0.765
# Run GAT: 201/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.9 Avg. Test Accuracy: 0.784
# Run GAT: 202/432: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-1083_noiselvl-0.95 Avg. Test Accuracy: 0.772

# %%
import shutil
shutil.make_archive('results_v5', 'zip', 'results_v5')
# Out:
# '/content/results_v4.zip'

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/deneme.csv'
# **** DONT forget to change this *****

nodes_percent =  [0.05, 0.2, 0.5, 0.7, 0.8]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[1], #[0, 0.3, 0.6, 0.9, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9502], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10028], edge_removal_all_edges__noiselvl-0.1=[2, 9500], edge_removal_all_edges__noiselvl-0.15=[2, 8972], edge_removal_all_edges__noiselvl-0.3=[2, 7389], edge_removal_all_edges__noiselvl-0.45=[2, 5805], edge_removal_all_edges__noiselvl-0.6=[2, 4222], edge_removal_all_edges__noiselvl-0.9=[2, 1055], edge_removal_all_edges__noiselvl-0.95=[2, 527], edge_removal_all_edges__noiselvl-0.99=[2, 105], edge_removal_all_edges__noiselvl-1=[2, 0], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10661], edge_addition_all_edges__noiselvl-0.05=[2, 11083], edge_addition_all_edges__noiselvl-0.1=[2, 11611], edge_addition_all_edges__noiselvl-0.15=[2, 12139], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16889], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10294], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10278], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10252], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10202], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10100], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9962], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9880], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9930], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9990], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10012], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10020], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10004], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9952], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9790], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9672], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9334], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9424], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9360], edg ...
# Run GNN: 1/3: x - edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.74
# Run GAT: 2/3: x - edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.701
# Run Graphsage: 3/3: x - edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-2708_noiselvl-1 Avg. Test Accuracy: 0.585
#   dataset_name model_name x_type  \
# 0         Cora        GNN      x
# 1         Cora        GAT      x
# 2         Cora  Graphsage      x
#
#                                            edge_type mean_test_accuracy  \
# 0  edge_removal_nodes_choose_type-bottom_k_bidire...               0.74
# 1  edge_removal_nodes_choose_type-bottom_k_bidire...              0.701
# 2  edge_removal_nodes_choose_type-bottom_k_bidire...              0.585
#
#                  test_accuracies  num_epochs  \
# 0  0.729,0.739,0.748,0.742,0.744          25
# 1  0.727,0.714,0.712,0.657,0.696          25
# 2  0.579,0.584,0.588,0.591,0.585          25
#
#                                         model_params  \
# 0  {'in_channels': 1433, 'hidden_channels': 30, '...
# 1  {'in_channels': 1433, 'hidden_channels': 15, '...
# 2  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                           noise_info  repeat_num choose_type  \
# 0  {'noise_type': 'edge_removal', 'strategy': 'no...           5      bottom
# 1  {'noise_type': 'edge_removal', 'strategy': 'no...           5      bottom
# 2  {'noise_type': 'edge_removal', 'strategy': 'no...           5      bottom
#
#   bidirectional k_nodes noise_level
# 0         False    2708           1
# 1         False    2708           1
# 2         False    2708           1

# %%
data['edge_index'].shape
# Out:
# torch.Size([2, 10556])

# %%
print(data['edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-135_noiselvl-0.05'].shape)
print(data['edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-135_noiselvl-0.3'].shape)
print(data['edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-135_noiselvl-0.6'].shape)
print(data['edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-135_noiselvl-0.9'].shape)
print(data['edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-135_noiselvl-1'].shape)
# Out:
# torch.Size([2, 10421])
# torch.Size([2, 10421])
# torch.Size([2, 10421])
# torch.Size([2, 10421])
# torch.Size([2, 10421])

# %%
k_nod= 1354
#print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.05'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.3'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.6'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.9'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-1'].shape)
# Out:
# torch.Size([2, 9202])
# torch.Size([2, 8333])
# torch.Size([2, 8047])
# torch.Size([2, 8047])

# %%
k_nod= 2708
#print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.05'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.3'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.6'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-0.9'].shape)
print(data[f'edge_removal_nodes_choose_type-bottom_k_bidirec-False_knodes-{k_nod}_noiselvl-1'].shape)
# Out:
# torch.Size([2, 6121])
# torch.Size([2, 3027])
# torch.Size([2, 188])
# torch.Size([2, 0])

# %%
data.num_nodes
# Out:
# 2708

# %%
nodes_percent =  [0.05, 0.2, 0.5, 0.7, 0.8] # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)
k_nodes_list
# Out:
# [135, 542, 1354, 1896, 2166]

# %%
[0.1, 0.2, 0.4, 0.6, 0.8, 0.9, 0.95, 0.99, 1]
