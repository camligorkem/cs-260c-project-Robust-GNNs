# %% [markdown]
# <a href="https://colab.research.google.com/github/camligorkem/cs-260c-project/blob/main/CS_260_Node_Classification_Experiments_GC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd "/content/drive/My Drive/cs260c/"
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1-bDtZYVHjXvEKyCHsWYKtRJzDcS-Jjub/cs260c

# %%
import pandas as pd

res = pd.read_csv('exp_results/results_v5/Experiment_1_add_gaussian_noise_bidirectional_True.csv')
res
# Out:
#     Unnamed: 0 dataset_name model_name                        x_type  \
# 0            0         Cora        GNN     feature_noise__noiselvl-0
# 1            1         Cora        GNN  feature_noise__noiselvl-0.01
# 2            2         Cora        GNN  feature_noise__noiselvl-0.05
# 3            3         Cora        GNN   feature_noise__noiselvl-0.1
# 4            4         Cora        GNN  feature_noise__noiselvl-0.15
# 5            5         Cora        GNN   feature_noise__noiselvl-0.3
# 6            6         Cora        GNN  feature_noise__noiselvl-0.45
# 7            7         Cora        GNN   feature_noise__noiselvl-0.6
# 8            8         Cora        GNN   feature_noise__noiselvl-0.9
# 9            9         Cora        GNN  feature_noise__noiselvl-0.95
# 10          10         Cora        GNN  feature_noise__noiselvl-0.99
# 11          11         Cora        GNN     feature_noise__noiselvl-1
# 12          12         Cora        GAT     feature_noise__noiselvl-0
# 13          13         Cora        GAT  feature_noise__noiselvl-0.01
# 14          14         Cora        GAT  feature_noise__noiselvl-0.05
# 15          15         Cora        GAT   feature_noise__noiselvl-0.1
# 16          16         Cora        GAT  feature_noise__noiselvl-0.15
# 17          17         Cora        GAT   feature_noise__noiselvl-0.3
# 18          18         Cora        GAT  feature_noise__noiselvl-0.45
# 19          19         Cora        GAT   feature_noise__noiselvl-0.6
# 20          20         Cora        GAT   feature_noise__noiselvl-0.9
# 21          21         Cora        GAT  feature_noise__noiselvl-0.95
# 22          22         Cora        GAT  feature_noise__noiselvl-0.99
# 23          23         Cora        GAT     feature_noise__noiselvl-1
# 24          24         Cora  Graphsage     feature_noise__noiselvl-0
# 25          25         Cora  Graphsage  feature_noise__noiselvl-0.01
# 26          26         Cora  Graphsage  feature_noise__noiselvl-0.05
# 27          27         Cora  Graphsage   feature_noise__noiselvl-0.1
# 28          28         Cora  Graphsage  feature_noise__noiselvl-0.15
# 29          29         Cora  Graphsage   feature_noise__noiselvl-0.3
# 30          30         Cora  Graphsage  feature_noise__noiselvl-0.45
# 31          31         Cora  Graphsage   feature_noise__noiselvl-0.6
# 32          32         Cora  Graphsage   feature_noise__noiselvl-0.9
# 33          33         Cora  Graphsage  feature_noise__noiselvl-0.95
# 34          34         Cora  Graphsage  feature_noise__noiselvl-0.99
# 35          35         Cora  Graphsage     feature_noise__noiselvl-1
# 36          36         Cora        MLP     feature_noise__noiselvl-0
# 37          37         Cora        MLP  feature_noise__noiselvl-0.01
# 38          38         Cora        MLP  feature_noise__noiselvl-0.05
# 39          39         Cora        MLP   feature_noise__noiselvl-0.1
# 40          40         Cora        MLP  feature_noise__noiselvl-0.15
# 41          41         Cora        MLP   feature_noise__noiselvl-0.3
# 42          42         Cora        MLP  feature_noise__noiselvl-0.45
# 43          43         Cora        MLP   feature_noise__noiselvl-0.6
# 44          44         Cora        MLP   feature_noise__noiselvl-0.9
# 45          45         Cora        MLP  feature_noise__noiselvl-0.95
# 46          46         Cora        MLP  feature_noise__noiselvl-0.99
# 47          47         Cora        MLP     feature_noise__noiselvl-1
#
#      edge_type  mean_test_accuracy                test_accuracies  num_epochs  \
# 0   edge_index               0.798    0.787,0.799,0.799,0.803,0.8          25
# 1   edge_index               0.782  0.779,0.796,0.771,0.785,0.779          25
# 2   edge_index               0.747   0.735,0.747,0.753,0.752,0.75          25
# 3   edge_index               0.633  0.636,0.596,0.689,0.623,0.619          25
# 4   edge_index               0.517  0.566,0.553,0.516,0.501,0.447          25
# 5   edge_index               0.128   0.121,0.08,0.125,0.182,0.134          25
# 6   edge_index               0.130   0.171,0.144,0.07,0.088,0.177          25
# 7   edge_index               0.064  0.064,0.064,0.064,0.064,0.064          25
# 8   edge_index               0.171    0.331,0.132,0.133,0.13,0.13          25
# 9   edge_index               0.162  0.143,0.134,0.152,0.286,0.096          25
# 10  edge_index               0.147  0.154,0.158,0.091,0.129,0.202          25
# 11  edge_index               0.200  0.187,0.136,0.151,0.358,0.167          25
# 12  edge_index               0.770  0.765,0.756,0.767,0.803,0.759          25
# 13  edge_index               0.646  0.715,0.658,0.608,0.544,0.703          25
# 14  edge_index               0.365  0.445,0.379,0.244,0.367,0.389          25
# 15  edge_index               0.214   0.21,0.148,0.311,0.336,0.064          25
# 16  edge_index               0.246   0.144,0.321,0.319,0.13,0.314          25
# 17  edge_index               0.106  0.064,0.273,0.064,0.066,0.064          25
# 18  edge_index               0.135  0.091,0.064,0.144,0.064,0.314          25
# 19  edge_index               0.095  0.128,0.072,0.064,0.064,0.149          25
# 20  edge_index               0.161   0.154,0.144,0.13,0.272,0.103          25
# 21  edge_index               0.130    0.103,0.12,0.103,0.193,0.13          25
# 22  edge_index               0.160    0.13,0.32,0.188,0.093,0.069          25
# 23  edge_index               0.122   0.103,0.144,0.144,0.13,0.091          25
# 24  edge_index               0.779   0.769,0.772,0.774,0.79,0.791          25
# 25  edge_index               0.768  0.768,0.754,0.786,0.757,0.775          25
# 26  edge_index               0.731   0.731,0.74,0.728,0.725,0.731          25
# 27  edge_index               0.659  0.671,0.668,0.674,0.632,0.649          25
# 28  edge_index               0.511    0.577,0.508,0.5,0.482,0.486          25
# 29  edge_index               0.197  0.158,0.217,0.165,0.285,0.159          25
# 30  edge_index               0.077  0.065,0.125,0.065,0.065,0.064          25
# 31  edge_index               0.064  0.064,0.064,0.064,0.064,0.064          25
# 32  edge_index               0.150    0.129,0.129,0.26,0.13,0.103          25
# 33  edge_index               0.161   0.13,0.145,0.065,0.314,0.152          25
# 34  edge_index               0.117  0.103,0.099,0.149,0.132,0.102          25
# 35  edge_index               0.150  0.104,0.131,0.319,0.103,0.091          25
# 36  edge_index               0.498     0.53,0.52,0.51,0.468,0.462          25
# 37  edge_index               0.534   0.565,0.494,0.555,0.515,0.54          25
# 38  edge_index               0.544  0.572,0.541,0.545,0.527,0.533          25
# 39  edge_index               0.561  0.593,0.561,0.526,0.553,0.571          25
# 40  edge_index               0.525   0.517,0.518,0.51,0.539,0.543          25
# 41  edge_index               0.442  0.399,0.401,0.508,0.467,0.435          25
# 42  edge_index               0.135   0.108,0.196,0.084,0.069,0.22          25
# 43  edge_index               0.159   0.266,0.144,0.17,0.085,0.128          25
# 44  edge_index               0.064  0.064,0.064,0.064,0.064,0.064          25
# 45  edge_index               0.319  0.319,0.319,0.319,0.319,0.319          25
# 46  edge_index               0.130       0.13,0.13,0.13,0.13,0.13          25
# 47  edge_index               0.128  0.153,0.073,0.142,0.145,0.128          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
# 36  {'in_channels': 1433, 'hidden_channels': 100, ...
# 37  {'in_channels': 1433, 'hidden_channels': 100, ...
# 38  {'in_channels': 1433, 'hidden_channels': 100, ...
# 39  {'in_channels': 1433, 'hidden_channels': 100, ...
# 40  {'in_channels': 1433, 'hidden_channels': 100, ...
# 41  {'in_channels': 1433, 'hidden_channels': 100, ...
# 42  {'in_channels': 1433, 'hidden_channels': 100, ...
# 43  {'in_channels': 1433, 'hidden_channels': 100, ...
# 44  {'in_channels': 1433, 'hidden_channels': 100, ...
# 45  {'in_channels': 1433, 'hidden_channels': 100, ...
# 46  {'in_channels': 1433, 'hidden_channels': 100, ...
# 47  {'in_channels': 1433, 'hidden_channels': 100, ...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'feature_noise', 'params': {'da...           5
# 1   {'noise_type': 'feature_noise', 'params': {'da...           5
# 2   {'noise_type': 'feature_noise', 'params': {'da...           5
# 3   {'noise_type': 'feature_noise', 'params': {'da...           5
# 4   {'noise_type': 'feature_noise', 'params': {'da...           5
# 5   {'noise_type': 'feature_noise', 'params': {'da...           5
# 6   {'noise_type': 'feature_noise', 'params': {'da...           5
# 7   {'noise_type': 'feature_noise', 'params': {'da...           5
# 8   {'noise_type': 'feature_noise', 'params': {'da...           5
# 9   {'noise_type': 'feature_noise', 'params': {'da...           5
# 10  {'noise_type': 'feature_noise', 'params': {'da...           5
# 11  {'noise_type': 'feature_noise', 'params': {'da...           5
# 12  {'noise_type': 'feature_noise', 'params': {'da...           5
# 13  {'noise_type': 'feature_noise', 'params': {'da...           5
# 14  {'noise_type': 'feature_noise', 'params': {'da...           5
# 15  {'noise_type': 'feature_noise', 'params': {'da...           5
# 16  {'noise_type': 'feature_noise', 'params': {'da...           5
# 17  {'noise_type': 'feature_noise', 'params': {'da...           5
# 18  {'noise_type': 'feature_noise', 'params': {'da...           5
# 19  {'noise_type': 'feature_noise', 'params': {'da...           5
# 20  {'noise_type': 'feature_noise', 'params': {'da...           5
# 21  {'noise_type': 'feature_noise', 'params': {'da...           5
# 22  {'noise_type': 'feature_noise', 'params': {'da...           5
# 23  {'noise_type': 'feature_noise', 'params': {'da...           5
# 24  {'noise_type': 'feature_noise', 'params': {'da...           5
# 25  {'noise_type': 'feature_noise', 'params': {'da...           5
# 26  {'noise_type': 'feature_noise', 'params': {'da...           5
# 27  {'noise_type': 'feature_noise', 'params': {'da...           5
# 28  {'noise_type': 'feature_noise', 'params': {'da...           5
# 29  {'noise_type': 'feature_noise', 'params': {'da...           5
# 30  {'noise_type': 'feature_noise', 'params': {'da...           5
# 31  {'noise_type': 'feature_noise', 'params': {'da...           5
# 32  {'noise_type': 'feature_noise', 'params': {'da...           5
# 33  {'noise_type': 'feature_noise', 'params': {'da...           5
# 34  {'noise_type': 'feature_noise', 'params': {'da...           5
# 35  {'noise_type': 'feature_noise', 'params': {'da...           5
# 36  {'noise_type': 'feature_noise', 'params': {'da...           5
# 37  {'noise_type': 'feature_noise', 'params': {'da...           5
# 38  {'noise_type': 'feature_noise', 'params': {'da...           5
# 39  {'noise_type': 'feature_noise', 'params': {'da...           5
# 40  {'noise_type': 'feature_noise', 'params': {'da...           5
# 41  {'noise_type': 'feature_noise', 'params': {'da...           5
# 42  {'noise_type': 'feature_noise', 'params': {'da...           5
# 43  {'noise_type': 'feature_noise', 'params': {'da...           5
# 44  {'noise_type': 'feature_noise', 'params': {'da...           5
# 45  {'noise_type': 'feature_noise', 'params': {'da...           5
# 46  {'noise_type': 'feature_noise', 'params': {'da...           5
# 47  {'noise_type': 'feature_noise', 'params': {'da...           5

# %%
res['noise_info'][0]
# Out:
# "{'noise_type': 'feature_noise', 'params': {'data': Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10024], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01=[2, 9496], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9528], edge_removal_all_edges__noiselvl-0.15=[2, 9046], edge_removal_all_edges__noiselvl-0.3=[2, 7646], edge_removal_all_edges__noiselvl-0.45=[2, 6344], edge_removal_all_edges__noiselvl-0.6=[2, 5102], edge_removal_all_edges__noiselvl-0.9=[2, 3214], edge_removal_all_edges__noiselvl-0.95=[2, 2922], edge_removal_all_edges__noiselvl-0.99=[2, 2684], edge_removal_all_edges__noiselvl-1=[2, 2636], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10258], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10186], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9946], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 10052], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9780], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9986], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9930], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9852], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9696], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9304], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9352], edge_removal_nodes_choose_type-r ...

# %%
# Install required packages.
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
#      |████████████████████████████████| 7.9 MB 4.1 MB/s
#      |████████████████████████████████| 3.5 MB 4.3 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch 
import numpy as np
import math


from torch_geometric.utils import degree
import torch_geometric
import torch_geometric.utils as tg_utils
import pandas as pd

# %%
# !rm -r data

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Done!

# %%
def get_masked_noise(data,  noise_level=0.15):
  x = data.x
  noise_added_node_num = int(noise_level * x.shape[0])
  chose_random_rows = np.random.choice(x.shape[0], noise_added_node_num, replace=False)
  #print(chose_random_rows)
  mask_rows = torch.zeros(x.shape)
  mask_rows[chose_random_rows,:] = torch.ones(1, x.shape[1])
  noise = (0.1**0.5)*torch.randn(x.shape)
  masked_noise = noise* mask_rows.int().float()

  #print(mask_rows)
  #print(noise)
  #print(masked_noise)
  return x + masked_noise

# %%
# remove x% edges
def remove_from_all_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index

  if bidirectional:
    noise_level /= 2
  
  edge_ratio_to_keep = 1 - noise_level
  num_edges_keep= int(edge_ratio_to_keep * edge_index.shape[1])
  chose_random_edge_indices = np.random.choice(edge_index.shape[1], num_edges_keep, replace=False)

  #print(edge_index[0][chose_random_edge_indices].shape)
  #print(num_edges_keep)
  #print(edge_index.shape[1])

  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_index_removed[0] = edge_index[0][chose_random_edge_indices]
  edge_index_removed[1] = edge_index[1][chose_random_edge_indices]

  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    edge_index_removed = torch.zeros((2,len(final_edges_bidirec_1)), dtype=torch.int64)
    edge_index_removed[0] = final_edges_bidirec_0
    edge_index_removed[1] = final_edges_bidirec_1

  return edge_index_removed

# %%
# remove x% edges from random k, top_k, bottom_k nodes

def choose_nodes(data, num_nodes, k_nodes, choose_type):
  if choose_type=='random':
    nodes_chosen = torch.from_numpy(np.random.choice(num_nodes, k_nodes, replace=False))
  elif choose_type=='top_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    top_k_nodes_degrees, top_k_nodes_indices = torch.topk(dg, k_nodes)
    #print(top_k_nodes_degrees, top_k_nodes_indices)
    nodes_chosen = top_k_nodes_indices
  elif choose_type=='bottom_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    bottom_k_nodes_degrees, bottom_k_nodes_indices = torch.topk(dg, k_nodes, largest=False)
    #print(bottom_k_nodes_degrees, bottom_k_nodes_indices)
    nodes_chosen = bottom_k_nodes_indices
  else:
    raise 'choose_type should be from random, top_k, bottom_k'
  return nodes_chosen

# to do loop for each node separately
def remove_edges_from_chosen_nodes(data, nodes_chosen, edges_to_remove_per_node_ratio):
  edges_0_list, edges_1_list = [],[]
  for nc in nodes_chosen:
    edge_0, edge_1 = remove_edge_per_node(data=data, node=nc, 
                                          edges_to_remove_per_node_ratio=edges_to_remove_per_node_ratio)
    edges_0_list.append(edge_0)
    edges_1_list.append(edge_1)

  edges_0 = torch.cat(edges_0_list, 0)
  edges_1 = torch.cat(edges_1_list, 0)

  return edges_0, edges_1

def remove_edge_per_node(data, node, edges_to_remove_per_node_ratio=0.1):
  mask_node_indices = torch.isin(data.edge_index[0], node)

  select_node_edges_0 = data.edge_index[0][mask_node_indices]
  select_node_edges_1 = data.edge_index[1][mask_node_indices]
  #print(select_node_edges_0)
  #print(select_node_edges_1)

  # choose how much of the edges we will remove for this node
  # we decide on number of edges to remove for each node based on the number of edges each node has
  # and by taking the ratio given by edges_to_remove_per_node_ratio
  # note: we use ceil to remove at least one node (unless ratio is 0)
  num_edges_remove = int(math.ceil(edges_to_remove_per_node_ratio* select_node_edges_0.shape[0]))
  # print(num_edges_remove)
  num_edges_keep = select_node_edges_0.shape[0] - num_edges_remove

  # choose random edges to keep, the rest is removed
  chose_random_edge_indices = np.random.choice(select_node_edges_0.shape[0], num_edges_keep, replace=False)
  # print(num_edges_keep)
  
  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_node_index_removed_0 = select_node_edges_0[chose_random_edge_indices]
  edge_node_index_removed_1 = select_node_edges_1[chose_random_edge_indices]

  return edge_node_index_removed_0, edge_node_index_removed_1

def remove_edges_from_nodes(data, noise_level = 0.15, k_nodes=10,
                            choose_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  edge_p_node_ratio_to_keep = 1 - noise_level

  # choose topk, bottomk, or random
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=choose_type)

  # keep edges from remaining nodes
  mask_node_indices = torch.isin(data.edge_index[0],nodes_chosen)
  index_keep = torch.ones(data.edge_index[0].shape[0], dtype=bool)
  index_keep[mask_node_indices] = False
  edges_to_keep_0 = data.edge_index[0][index_keep]
  edges_to_keep_1 = data.edge_index[1][index_keep]
  #print(edges_to_keep_0) 
  #print(edges_to_keep_1)

  # remove one-directional or bi-directional
  edges_0_kept_chosen_nodes, edges_1_kept_chosen_nodes = remove_edges_from_chosen_nodes(data=data, 
                                                                                        nodes_chosen=nodes_chosen,
                                                                                        edges_to_remove_per_node_ratio=noise_level)
  # concat edges to keep and edges_kept_chosen_nodes
  final_edges_0 = torch.cat([edges_to_keep_0, edges_0_kept_chosen_nodes], 0)
  final_edges_1 = torch.cat([edges_to_keep_1, edges_1_kept_chosen_nodes], 0)

  # do bidirectional here! IF bidirectional set to true remove both directions of the edges.
  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    final_edges_0 = final_edges_bidirec_0
    final_edges_1 = final_edges_bidirec_1
  edge_index_removed = torch.zeros((2, final_edges_0.shape[0]), dtype=torch.int64)
  edge_index_removed[0] = final_edges_0
  edge_index_removed[1] = final_edges_1

    
  # use TORCH_GEOMETRIC.UTILS.SORT_EDGE_INDEX
  edge_index_removed_sorted = tg_utils.sort_edge_index(edge_index_removed)
  return edge_index_removed_sorted

# %%
def add_random_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index
  num_nodes = data.num_nodes

  if bidirectional:
    noise_level /= 2

  new_edges = edge_index.T
  edge_num = new_edges.shape[0]
  num_of_new_edges = int(edge_num * noise_level)

  for i in range(num_of_new_edges):
    while True:
      new_edge = ((torch.rand(1,2) * 1000000).to(int) % num_nodes)
      new_edge_flip = torch.flip(new_edge, [1])
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break

  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %%
for added_ratio in [0.15]:
  new_edges = add_random_edges(data,  noise_level=added_ratio, bidirectional=True)
  data[f'edge_index_added_n_{added_ratio}'] = new_edges

# %%
## Helper function of add_edges_to_nodes

def add_edges_to_a_node(data, new_edges, node, num_to_add=0, bidirectional=False):
  for i in range(num_to_add):

    # Running till we find the right edge to add
    while True:
      #create a random node. 1000000 is a arbitrary number which can be replaced to any number bigger than data.num_nodes
      new_index = ((torch.rand(1) * 1000000).to(int) % data.num_nodes).item()
      new_edge = torch.tensor([[node, new_index]])
      new_edge_flip = torch.flip(new_edge, [1])
      #check whether the new edge and flip one exists or not 
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
  return new_edges

## Adding x% edges to random k, top k, or bottom k nodes

def add_edges_to_nodes(data, noise_level=0.15, k_nodes=10, choose_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  #choose nodes by three different types
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=choose_type)
  
  new_edges = data.edge_index.T

  #add new edges to every chosen node
  for node in nodes_chosen:
    edge_num_of_node = torch.isin(data.edge_index, node).to(int).sum()
    edge_num_to_add = int(edge_num_of_node * noise_level)
    
    new_edges = add_edges_to_a_node(data, new_edges, node.item(), edge_num_to_add, bidirectional)
  
  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %% [markdown]
# ## Experiments

# %%
# !pip install class-resolver

from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT
from class_resolver import ClassResolver
# Out:
# Collecting class-resolver
#   Downloading class_resolver-0.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: class-resolver
# Successfully installed class-resolver-0.3.4

# %%
def get_model(model_name, model_params):
  # add more model from here if needed: https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#models
  # you can also check model parameters from above
  model = None
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
  if model_name=='MLP':
    model = MLP(**model_params).to(device)
  elif model_name=='GNN':
    model = GCN(**model_params).to(device)
  elif model_name=='GAT':
    model = GAT(**model_params).to(device)
  elif model_name=='Graphsage':
    model = GraphSAGE(**model_params).to(device)
  else:
    raise 'Model names should be within MLP, GNN, GAT, Graphsage'
  return model

# %%
# Creating MLP example, add all parameters you want to use to create/tune model in the below dictionary
model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3}
mlp_model = get_model(model_name='MLP', model_params=model_params)
print(mlp_model)

model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
gnn_model = get_model(model_name='GNN', model_params=model_params)
print(gnn_model)
# Out:
# MLP(1433, 16, 16, 7)
# GCN(1433, 7, num_layers=3)

# %%
def get_noise_function(noise_info):
  '''
  This function directly returns the function we created for different noise logics
  Change the name of the function below if noise logic function name is changed.
  '''
  noise_fn = None 
  if noise_info['noise_type']=='feature_noise':
    noise_fn = get_masked_noise
  elif noise_info['noise_type']=='edge_removal':
    if noise_info['strategy']=='all_edges' :
      noise_fn = remove_from_all_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = remove_edges_from_nodes
  elif noise_info['noise_type']=='edge_addition':
    if noise_info['strategy']=='all_edges' :
      noise_fn = add_random_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = add_edges_to_nodes
  else:
    raise 'Noise type should be chosen from feature_noise, edge_removal, edge_addition' 
  return noise_fn
  

def nodes_percent_to_num_nodes(percents, num_nodes):
  return [round(pct*num_nodes) for pct in percents]

def create_noised_data_for_experiment(data, noise_info):
  '''
  Create noised data outside of experiment, so that you can use same data in different experiments
  '''
  noise_data_names = []
  noise_fn = get_noise_function(noise_info)
  
  noise_info_copy = noise_info.copy()
  if noise_info_copy.get('strategy')=='nodes':
    nodes_percent =  noise_info_copy['nodes_percent'] 
    k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

    for k_nodes, node_pct in zip(k_nodes_list, nodes_percent):
      for noise_level in noise_info_copy['noise_levels']:
        #noise_data_name = f'{noise_info["noise_type"]}{add_prefix}knodes-{k_nodes}_noiselvl-{noise_level}'
        noise_info_copy['params']['noise_level'] = noise_level
        noise_info_copy['params']['k_nodes'] = k_nodes
        noised_data = noise_fn(**noise_info_copy['params'])

        exp_info_feats_g1 = ['noise_type', 'strategy']
        exp_info_feats_g2 = ['noise_level','bidirectional','choose_type','k_nodes','node_percent']
        prefix = '__'.join([f'{ef}-{noise_info_copy[ef]}' for ef in exp_info_feats_g1 if ef in noise_info_copy]) 
        postfix = '__'.join([f'{ef}-{noise_info_copy["params"][ef]}' for ef in exp_info_feats_g2 if ef in noise_info_copy['params']]) 
        noise_data_name = prefix+'__'+postfix+'__node_percent-'+str(node_pct)
        data[noise_data_name] = noised_data
        noise_data_names.append(noise_data_name)

  else: # all_edges and gaussian noisee case
    for noise_level in noise_info_copy['noise_levels']:
      #noise_data_name = f'{noise_info["noise_type"]}{add_prefix}noiselvl-{noise_level}'
      noise_info_copy['params']['noise_level'] = noise_level
      noised_data = noise_fn(**noise_info_copy['params'])
      exp_info_feats_g1 = ['noise_type', 'strategy']
      exp_info_feats_g2 = ['noise_level','bidirectional','choose_type','k_nodes']
      prefix = '__'.join([f'{ef}-{noise_info_copy[ef]}' for ef in exp_info_feats_g1 if ef in noise_info_copy]) 
      postfix = '__'.join([f'{ef}-{noise_info_copy["params"][ef]}' for ef in exp_info_feats_g2 if ef in noise_info_copy['params']]) 
      noise_data_name = prefix+'__'+postfix
      data[noise_data_name] = noised_data
      noise_data_names.append(noise_data_name)
  return noise_data_names
 
# reuse train and test
def train(model, optimizer, model_name, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  model.train()
  optimizer.zero_grad()  # Clear gradients.
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

def test(model, model_name, x_type='x', edge_type='edge_index'):
  model.eval()
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.

  pred = out.argmax(dim=1)  # Use the class with highest probability.
  test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
  test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
  return test_acc

def validation(model, model_name, x_type='x', edge_type='edge_index'):
  model.eval()
  if model_name == 'MLP':
    out = model(data[x_type])
  else:
    out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  val_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
  val_acc = int(val_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
  return val_acc

def experiment(dataset_name, model_names, model_params, data, x_types, edge_types, noise_info, opt_params,  num_epochs=50, mlp_epochs=50, repeat_num=1, print_updates=False,print_updates_detail=False):
  '''
  Assumes the noisy data is already created and inside the data object (so that we can use same data sample for different models to compare)
  '''
  exp_count = len(x_types)*len(edge_types)*len(model_names)
  count=0
  res = []
  
  for model_name in model_names:
    for x_type in x_types:
      for ed_type in edge_types:
        count+=1
        test_accs = []
        for exp_num in range(1, repeat_num+1): # we will repeat experiment repeat many times, to increase results reliability
          model =  get_model(model_name=model_name, model_params=model_params[model_name])
          optimizer = torch.optim.Adam(model.parameters(), lr=opt_params[model_name]['lr'], weight_decay=opt_params[model_name]['weight_decay']) 
          epochs = mlp_epochs if model_name=='MLP' else num_epochs

          for epoch in range(num_epochs):
              loss = train(model, optimizer, model_name=model_name, x_type=x_type, edge_type=ed_type)
              # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

          # we test our results in original data, no noise added ones 
          # if you want to test on noised data change them to x_type=x_type and edge_type=ed_type below
          test_acc = test(model, model_name=model_name, x_type='x',edge_type='edge_index') 
          test_accs.append(test_acc)
          if print_updates_detail:
            print(f'Exp_num:{exp_num} Test Accuracy: {test_acc:.4f}')

        mean_test_acc = round(np.mean(test_accs), 3)
        noise_info_copy = noise_info.copy()
        noise_info_params_copy = noise_info_copy['params'].copy()
        del noise_info_params_copy['data']
        noise_info_copy['params'] = noise_info_params_copy
        # TODO we can add other metrics such as runtime to log in here later
        exp_res = {'dataset_name': dataset_name,
                  'model_name':model_name, 'x_type':x_type, 
                  'edge_type':ed_type, 'mean_test_accuracy':str(mean_test_acc), 'test_accuracies': ','.join([str(acc) for acc in test_accs]),
                  'num_epochs':epochs, 'repeat_num':repeat_num, 'model_params': model_params[model_name],
                  'noise_info':noise_info_copy} # TODO add more info on experiment noise_info
  
        if 'edge' in noise_info['noise_type']:
          name_type = ed_type
        else: #feature experiment  
          name_type = x_type
        
        key_val_list = [key_value.split('-')  for key_value in name_type.split('__')]
        #print('name type', name_type)
        #print('key_val_list', key_val_list)
        for kv in key_val_list:
          exp_res[kv[0]]=kv[1]

        res.append(exp_res)
        if print_updates:
            print(f'Run {model_name}: {count}/{exp_count}: {x_type} - {ed_type} Avg. Test Accuracy: {mean_test_acc}')
        
  res_df = pd.DataFrame(res, columns=exp_res.keys())
  return res_df

# %%
# Optimized Model Params


model_params = {
    'GNN':{'in_channels':1433, 'hidden_channels':30, 'out_channels':7, 'num_layers':2, 'dropout':0.2, 'aggr' :'add'},
    'GAT':{'in_channels':1433, 'hidden_channels':15, 'out_channels':7, 'num_layers':2, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels': 42, 'out_channels':7, 'num_layers':2, 'dropout':0.2},
    'MLP': {'in_channels':1433, 'hidden_channels':100,  'out_channels':7, 'num_layers':2, 'dropout': 0.2 },
}
opt_params = {
    'GNN':{'lr':0.05, 'weight_decay':1e-6}, 
    'GAT':{'lr':0.05, 'weight_decay':5e-4}, 
    'Graphsage':{'lr':0.05, 'weight_decay':5e-4}, 
    'MLP':{'lr':0.05, 'weight_decay':0.001}, 
}

# %%
dataset_name='Cora'
folder_name = f'exp_results/{dataset_name}/results_v6'
bidirectional_type = True
post_fix= f'_bidirectional_{bidirectional_type}'
num_repeat = 5

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Experiment 1 - Add gaussian noise

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_1_add_gaussian_noise{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

feature_noise_params = {'data':data}
noise_info = {'noise_type':'feature_noise', 'params':feature_noise_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'noise_level'}

noise_var_names_feat_exp = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage', 'MLP']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=noise_var_names_feat_exp, edge_types=['edge_index'],
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10558], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10586], noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10596], noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10690], noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10830], noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10982], noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11284], noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11260], noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11226], noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11734], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10580], noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10624], noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10890], noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 11144], noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 11556], noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12002], noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12200], noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12226], noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 13004], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10578], noise_type-edge_addition__strateg ...
# Run GNN: 1/48: noise_type-feature_noise__noise_level-0 - edge_index Avg. Test Accuracy: 0.799
# Run GNN: 2/48: noise_type-feature_noise__noise_level-0.01 - edge_index Avg. Test Accuracy: 0.762
# Run GNN: 3/48: noise_type-feature_noise__noise_level-0.05 - edge_index Avg. Test Accuracy: 0.745
# Run GNN: 4/48: noise_type-feature_noise__noise_level-0.1 - edge_index Avg. Test Accuracy: 0.68
# Run GNN: 5/48: noise_type-feature_noise__noise_level-0.15 - edge_index Avg. Test Accuracy: 0.655
# Run GNN: 6/48: noise_type-feature_noise__noise_level-0.3 - edge_index Avg. Test Accuracy: 0.188
# Run GNN: 7/48: noise_type-feature_noise__noise_level-0.45 - edge_index Avg. Test Accuracy: 0.167
# Run GNN: 8/48: noise_type-feature_noise__noise_level-0.6 - edge_index Avg. Test Accuracy: 0.065
# Run GNN: 9/48: noise_type-feature_noise__noise_level-0.9 - edge_index Avg. Test Accuracy: 0.163
# Run GNN: 10/48: noise_type-feature_noise__noise_level-0.95 - edge_index Avg. Test Accuracy: 0.171
# Run GNN: 11/48: noise_type-feature_noise__noise_level-0.99 - edge_index Avg. Test Accuracy: 0.17
# Run GNN: 12/48: noise_type-feature_noise__noise_level-1 - edge_index Avg. Test Accuracy: 0.169
# Run GAT: 13/48: noise_type-feature_noise__noise_level-0 - edge_index Avg. Test Accuracy: 0.771
# Run GAT: 14/48: noise_type-feature_noise__noise_level-0.01 - edge_index Avg. Test Accuracy: 0.522
# Run GAT: 15/48: noise_type-feature_noise__noise_level-0.05 - edge_index Avg. Test Accuracy: 0.309
# Run GAT: 16/48: noise_type-feature_noise__noise_level-0.1 - edge_index Avg. Test Accuracy: 0.205
# Run GAT: 17/48: noise_type-feature_noise__noise_level-0.15 - edge_index Avg. Test Accuracy: 0.208
# Run GAT: 18/48: noise_type-feature_noise__noise_level-0.3 - edge_index Avg. Test Accuracy: 0.067
# Run GAT: 19/48: noise_type-feature_noise__noise_level-0.45 - edge_index Avg. Test Accuracy: 0.241
# Run GAT: 20/48: noise_type-feature_noise__noise_level-0.6 - edge_index Avg. Test Accuracy: 0.167
# Run GAT: 21/48: noise_type-feature_noise__noise_level-0.9 - edge_index Avg. Test Accuracy: 0.208
# Run GAT: 22/48: noise_type-feature_noise__noise_level-0.95 - edge_index Avg. Test Accuracy: 0.13
# Run GAT: 23/48: noise_type-feature_noise__noise_level-0.99 - edge_index Avg. Test Accuracy: 0.215
# Run GAT: 24/48: noise_type-feature_noise__noise_level-1 - edge_index Avg. Test Accuracy: 0.173
# Run Graphsage: 25/48: noise_type-feature_noise__noise_level-0 - edge_index Avg. Test Accuracy: 0.783
# Run Graphsage: 26/48: noise_type-feature_noise__noise_level-0.01 - edge_index Avg. Test Accuracy: 0.762
# Run Graphsage: 27/48: noise_type-feature_noise__noise_level-0.05 - edge_index Avg. Test Accuracy: 0.736
# Run Graphsage: 28/48: noise_type-feature_noise__noise_level-0.1 - edge_index Avg. Test Accuracy: 0.638
# Run Graphsage: 29/48: noise_type-feature_noise__noise_level-0.15 - edge_index Avg. Test Accuracy: 0.574
# Run Graphsage: 30/48: noise_type-feature_noise__noise_level-0.3 - edge_index Avg. Test Accuracy: 0.148
# Run Graphsage: 31/48: noise_type-feature_noise__noise_level-0.45 - edge_index Avg. Test Accuracy: 0.158
# Run Graphsage: 32/48: noise_type-feature_noise__noise_level-0.6 - edge_index Avg. Test Accuracy: 0.114
# Run Graphsage: 33/48: noise_type-feature_noise__noise_level-0.9 - edge_index Avg. Test Accuracy: 0.164
# Run Graphsage: 34/48: noise_type-feature_noise__noise_level-0.95 - edge_index Avg. Test Accuracy: 0.221
# Run Graphsage: 35/48: noise_type-feature_noise__noise_level-0.99 - edge_index Avg. Test Accuracy: 0.156
# Run Graphsage: 36/48: noise_type-feature_noise__noise_level-1 - edge_index Avg. Test Accuracy: 0.149
# Run MLP: 37/48: noise_type-feature_noise__noise_level-0 - edge_index Avg. Test Accuracy: 0.517
# Run MLP: 38/48: noise_type-feature_noise__noise_level-0.01 - edge_index Avg. Test Accuracy: 0.525
# Run MLP: 39/48: noise_type-feature_noise__noise_level-0.05 - edge_index Avg. Test Accuracy: 0.53
# Run MLP: 40/48: noise_type-feature_noise__noise_level-0.1 - edge_index Avg. Test Accuracy: 0.546
# Run MLP: 41/48: noise_type-feature_noise__noise_level-0.15 - edge_index Avg. Test Accuracy: 0.53
# Run MLP: 42/48: noise_type-feature_noise__noise_level-0.3 - edge_index Avg. Test Accuracy: 0.383
# Run MLP: 43/48: noise_type-feature_noise__noise_level-0.45 - edge_index Avg. Test Accuracy: 0.243
# Run MLP: 44/48: noise_type-feature_noise__noise_level-0.6 - edge_index Avg. Test Accuracy: 0.195
# Run MLP: 45/48: noise_type-feature_noise__noise_level-0.9 - edge_index Avg. Test Accuracy: 0.144
# Run MLP: 46/48: noise_type-feature_noise__noise_level-0.95 - edge_index Avg. Test Accuracy: 0.144
# Run MLP: 47/48: noise_type-feature_noise__noise_level-0.99 - edge_index Avg. Test Accuracy: 0.149
# Run MLP: 48/48: noise_type-feature_noise__noise_level-1 - edge_index Avg. Test Accuracy: 0.151
#    dataset_name model_name                                      x_type  \
# 0          Cora        GNN     noise_type-feature_noise__noise_level-0
# 1          Cora        GNN  noise_type-feature_noise__noise_level-0.01
# 2          Cora        GNN  noise_type-feature_noise__noise_level-0.05
# 3          Cora        GNN   noise_type-feature_noise__noise_level-0.1
# 4          Cora        GNN  noise_type-feature_noise__noise_level-0.15
# 5          Cora        GNN   noise_type-feature_noise__noise_level-0.3
# 6          Cora        GNN  noise_type-feature_noise__noise_level-0.45
# 7          Cora        GNN   noise_type-feature_noise__noise_level-0.6
# 8          Cora        GNN   noise_type-feature_noise__noise_level-0.9
# 9          Cora        GNN  noise_type-feature_noise__noise_level-0.95
# 10         Cora        GNN  noise_type-feature_noise__noise_level-0.99
# 11         Cora        GNN     noise_type-feature_noise__noise_level-1
# 12         Cora        GAT     noise_type-feature_noise__noise_level-0
# 13         Cora        GAT  noise_type-feature_noise__noise_level-0.01
# 14         Cora        GAT  noise_type-feature_noise__noise_level-0.05
# 15         Cora        GAT   noise_type-feature_noise__noise_level-0.1
# 16         Cora        GAT  noise_type-feature_noise__noise_level-0.15
# 17         Cora        GAT   noise_type-feature_noise__noise_level-0.3
# 18         Cora        GAT  noise_type-feature_noise__noise_level-0.45
# 19         Cora        GAT   noise_type-feature_noise__noise_level-0.6
# 20         Cora        GAT   noise_type-feature_noise__noise_level-0.9
# 21         Cora        GAT  noise_type-feature_noise__noise_level-0.95
# 22         Cora        GAT  noise_type-feature_noise__noise_level-0.99
# 23         Cora        GAT     noise_type-feature_noise__noise_level-1
# 24         Cora  Graphsage     noise_type-feature_noise__noise_level-0
# 25         Cora  Graphsage  noise_type-feature_noise__noise_level-0.01
# 26         Cora  Graphsage  noise_type-feature_noise__noise_level-0.05
# 27         Cora  Graphsage   noise_type-feature_noise__noise_level-0.1
# 28         Cora  Graphsage  noise_type-feature_noise__noise_level-0.15
# 29         Cora  Graphsage   noise_type-feature_noise__noise_level-0.3
# 30         Cora  Graphsage  noise_type-feature_noise__noise_level-0.45
# 31         Cora  Graphsage   noise_type-feature_noise__noise_level-0.6
# 32         Cora  Graphsage   noise_type-feature_noise__noise_level-0.9
# 33         Cora  Graphsage  noise_type-feature_noise__noise_level-0.95
# 34         Cora  Graphsage  noise_type-feature_noise__noise_level-0.99
# 35         Cora  Graphsage     noise_type-feature_noise__noise_level-1
# 36         Cora        MLP     noise_type-feature_noise__noise_level-0
# 37         Cora        MLP  noise_type-feature_noise__noise_level-0.01
# 38         Cora        MLP  noise_type-feature_noise__noise_level-0.05
# 39         Cora        MLP   noise_type-feature_noise__noise_level-0.1
# 40         Cora        MLP  noise_type-feature_noise__noise_level-0.15
# 41         Cora        MLP   noise_type-feature_noise__noise_level-0.3
# 42         Cora        MLP  noise_type-feature_noise__noise_level-0.45
# 43         Cora        MLP   noise_type-feature_noise__noise_level-0.6
# 44         Cora        MLP   noise_type-feature_noise__noise_level-0.9
# 45         Cora        MLP  noise_type-feature_noise__noise_level-0.95
# 46         Cora        MLP  noise_type-feature_noise__noise_level-0.99
# 47         Cora        MLP     noise_type-feature_noise__noise_level-1
#
#      edge_type mean_test_accuracy                test_accuracies  num_epochs  \
# 0   edge_index              0.799  0.792,0.813,0.804,0.801,0.786          25
# 1   edge_index              0.762   0.77,0.742,0.756,0.762,0.779          25
# 2   edge_index              0.745   0.767,0.735,0.755,0.747,0.72          25
# 3   edge_index               0.68  0.684,0.658,0.719,0.634,0.707          25
# 4   edge_index              0.655    0.672,0.667,0.664,0.573,0.7          25
# 5   edge_index              0.188   0.094,0.241,0.11,0.347,0.147          25
# 6   edge_index              0.167  0.198,0.169,0.154,0.152,0.162          25
# 7   edge_index              0.065  0.064,0.065,0.066,0.064,0.064          25
# 8   edge_index              0.163  0.162,0.155,0.146,0.173,0.178          25
# 9   edge_index              0.171   0.188,0.19,0.205,0.104,0.167          25
# 10  edge_index               0.17     0.3,0.144,0.135,0.141,0.13          25
# 11  edge_index              0.169       0.2,0.17,0.17,0.13,0.175          25
# 12  edge_index              0.771    0.79,0.769,0.75,0.756,0.791          25
# 13  edge_index              0.522   0.538,0.561,0.628,0.424,0.46          25
# 14  edge_index              0.309  0.204,0.455,0.277,0.501,0.108          25
# 15  edge_index              0.205  0.064,0.256,0.305,0.149,0.253          25
# 16  edge_index              0.208   0.327,0.13,0.178,0.222,0.183          25
# 17  edge_index              0.067  0.064,0.064,0.064,0.069,0.076          25
# 18  edge_index              0.241  0.319,0.217,0.189,0.329,0.149          25
# 19  edge_index              0.167  0.133,0.319,0.163,0.116,0.103          25
# 20  edge_index              0.208  0.144,0.103,0.326,0.149,0.319          25
# 21  edge_index               0.13    0.13,0.13,0.143,0.145,0.103          25
# 22  edge_index              0.215   0.319,0.103,0.319,0.144,0.19          25
# 23  edge_index              0.173    0.13,0.317,0.144,0.145,0.13          25
# 24  edge_index              0.783  0.775,0.774,0.791,0.784,0.789          25
# 25  edge_index              0.762    0.76,0.754,0.77,0.759,0.767          25
# 26  edge_index              0.736   0.731,0.734,0.74,0.749,0.725          25
# 27  edge_index              0.638  0.603,0.672,0.584,0.648,0.685          25
# 28  edge_index              0.574  0.629,0.554,0.527,0.553,0.609          25
# 29  edge_index              0.148  0.086,0.137,0.112,0.196,0.207          25
# 30  edge_index              0.158  0.147,0.147,0.144,0.175,0.179          25
# 31  edge_index              0.114  0.149,0.159,0.064,0.068,0.129          25
# 32  edge_index              0.164   0.153,0.103,0.282,0.15,0.132          25
# 33  edge_index              0.221   0.254,0.146,0.244,0.153,0.31          25
# 34  edge_index              0.156  0.199,0.134,0.183,0.122,0.143          25
# 35  edge_index              0.149   0.155,0.079,0.13,0.319,0.064          25
# 36  edge_index              0.517  0.556,0.485,0.507,0.521,0.516          50
# 37  edge_index              0.525  0.536,0.469,0.563,0.527,0.528          50
# 38  edge_index               0.53  0.546,0.554,0.477,0.535,0.537          50
# 39  edge_index              0.546  0.559,0.567,0.551,0.536,0.518          50
# 40  edge_index               0.53   0.461,0.56,0.571,0.513,0.546          50
# 41  edge_index              0.383  0.427,0.378,0.378,0.377,0.356          50
# 42  edge_index              0.243  0.207,0.232,0.275,0.228,0.271          50
# 43  edge_index              0.195  0.216,0.175,0.194,0.234,0.154          50
# 44  edge_index              0.144  0.144,0.144,0.144,0.144,0.144          50
# 45  edge_index              0.144  0.144,0.144,0.144,0.144,0.144          50
# 46  edge_index              0.149  0.149,0.149,0.149,0.149,0.149          50
# 47  edge_index              0.151    0.13,0.128,0.141,0.13,0.226          50
#
#     repeat_num                                       model_params  \
# 0            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 1            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 2            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 3            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 4            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 5            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 6            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 7            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 8            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 9            5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 10           5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11           5  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23           5  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35           5  {'in_channels': 1433, 'hidden_channels': 42, '...
# 36           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 37           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 38           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 39           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 40           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 41           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 42           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 43           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 44           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 45           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 46           5  {'in_channels': 1433, 'hidden_channels': 100, ...
# 47           5  {'in_channels': 1433, 'hidden_channels': 100, ...
#
#                                            noise_info     noise_type  \
# 0   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 1   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 2   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 3   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 4   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 5   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 6   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 7   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 8   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 9   {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 10  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 11  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 12  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 13  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 14  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 15  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 16  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 17  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 18  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 19  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 20  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 21  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 22  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 23  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 24  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 25  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 26  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 27  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 28  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 29  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 30  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 31  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 32  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 33  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 34  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 35  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 36  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 37  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 38  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 39  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 40  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 41  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 42  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 43  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 44  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 45  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 46  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
# 47  {'noise_type': 'feature_noise', 'params': {'no...  feature_noise
#
#    noise_level
# 0            0
# 1         0.01
# 2         0.05
# 3          0.1
# 4         0.15
# 5          0.3
# 6         0.45
# 7          0.6
# 8          0.9
# 9         0.95
# 10        0.99
# 11           1
# 12           0
# 13        0.01
# 14        0.05
# 15         0.1
# 16        0.15
# 17         0.3
# 18        0.45
# 19         0.6
# 20         0.9
# 21        0.95
# 22        0.99
# 23           1
# 24           0
# 25        0.01
# 26        0.05
# 27         0.1
# 28        0.15
# 29         0.3
# 30        0.45
# 31         0.6
# 32         0.9
# 33        0.95
# 34        0.99
# 35           1
# 36           0
# 37        0.01
# 38        0.05
# 39         0.1
# 40        0.15
# 41         0.3
# 42        0.45
# 43         0.6
# 44         0.9
# 45        0.95
# 46        0.99
# 47           1

# %% [markdown]
# ### Experiment 2 - Remove edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_2_remove_random_edges{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

remove_edge_params = {'data':data, 'bidirectional':bidirectional_type}
noise_info = {'noise_type':'edge_removal', 'strategy':'all_edges','params':remove_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_remove_ratio'}

exp_rm_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.798
# Run GNN: 2/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.794
# Run GNN: 3/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.799
# Run GNN: 4/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.782
# Run GNN: 5/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.785
# Run GNN: 6/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.788
# Run GNN: 7/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.789
# Run GNN: 8/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.779
# Run GNN: 9/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.749
# Run GNN: 10/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.732
# Run GNN: 11/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.727
# Run GNN: 12/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.756
# Run GAT: 13/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.773
# Run GAT: 14/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.766
# Run GAT: 15/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.771
# Run GAT: 16/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.781
# Run GAT: 17/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.767
# Run GAT: 18/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.754
# Run GAT: 19/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.752
# Run GAT: 20/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.706
# Run GAT: 21/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.674
# Run GAT: 22/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.712
# Run GAT: 23/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.736
# Run GAT: 24/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.728
# Run Graphsage: 25/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.776
# Run Graphsage: 26/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.777
# Run Graphsage: 27/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.777
# Run Graphsage: 28/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.772
# Run Graphsage: 29/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.758
# Run Graphsage: 30/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.754
# Run Graphsage: 31/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.757
# Run Graphsage: 32/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.75
# Run Graphsage: 33/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.669
# Run Graphsage: 34/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.64
# Run Graphsage: 35/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.576
# Run Graphsage: 36/36: x - noise_type-edge_removal__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.587
#    dataset_name model_name x_type  \
# 0          Cora        GNN      x
# 1          Cora        GNN      x
# 2          Cora        GNN      x
# 3          Cora        GNN      x
# 4          Cora        GNN      x
# 5          Cora        GNN      x
# 6          Cora        GNN      x
# 7          Cora        GNN      x
# 8          Cora        GNN      x
# 9          Cora        GNN      x
# 10         Cora        GNN      x
# 11         Cora        GNN      x
# 12         Cora        GAT      x
# 13         Cora        GAT      x
# 14         Cora        GAT      x
# 15         Cora        GAT      x
# 16         Cora        GAT      x
# 17         Cora        GAT      x
# 18         Cora        GAT      x
# 19         Cora        GAT      x
# 20         Cora        GAT      x
# 21         Cora        GAT      x
# 22         Cora        GAT      x
# 23         Cora        GAT      x
# 24         Cora  Graphsage      x
# 25         Cora  Graphsage      x
# 26         Cora  Graphsage      x
# 27         Cora  Graphsage      x
# 28         Cora  Graphsage      x
# 29         Cora  Graphsage      x
# 30         Cora  Graphsage      x
# 31         Cora  Graphsage      x
# 32         Cora  Graphsage      x
# 33         Cora  Graphsage      x
# 34         Cora  Graphsage      x
# 35         Cora  Graphsage      x
#
#                                             edge_type mean_test_accuracy  \
# 0   noise_type-edge_removal__strategy-all_edges__n...              0.798
# 1   noise_type-edge_removal__strategy-all_edges__n...              0.794
# 2   noise_type-edge_removal__strategy-all_edges__n...              0.799
# 3   noise_type-edge_removal__strategy-all_edges__n...              0.782
# 4   noise_type-edge_removal__strategy-all_edges__n...              0.785
# 5   noise_type-edge_removal__strategy-all_edges__n...              0.788
# 6   noise_type-edge_removal__strategy-all_edges__n...              0.789
# 7   noise_type-edge_removal__strategy-all_edges__n...              0.779
# 8   noise_type-edge_removal__strategy-all_edges__n...              0.749
# 9   noise_type-edge_removal__strategy-all_edges__n...              0.732
# 10  noise_type-edge_removal__strategy-all_edges__n...              0.727
# 11  noise_type-edge_removal__strategy-all_edges__n...              0.756
# 12  noise_type-edge_removal__strategy-all_edges__n...              0.773
# 13  noise_type-edge_removal__strategy-all_edges__n...              0.766
# 14  noise_type-edge_removal__strategy-all_edges__n...              0.771
# 15  noise_type-edge_removal__strategy-all_edges__n...              0.781
# 16  noise_type-edge_removal__strategy-all_edges__n...              0.767
# 17  noise_type-edge_removal__strategy-all_edges__n...              0.754
# 18  noise_type-edge_removal__strategy-all_edges__n...              0.752
# 19  noise_type-edge_removal__strategy-all_edges__n...              0.706
# 20  noise_type-edge_removal__strategy-all_edges__n...              0.674
# 21  noise_type-edge_removal__strategy-all_edges__n...              0.712
# 22  noise_type-edge_removal__strategy-all_edges__n...              0.736
# 23  noise_type-edge_removal__strategy-all_edges__n...              0.728
# 24  noise_type-edge_removal__strategy-all_edges__n...              0.776
# 25  noise_type-edge_removal__strategy-all_edges__n...              0.777
# 26  noise_type-edge_removal__strategy-all_edges__n...              0.777
# 27  noise_type-edge_removal__strategy-all_edges__n...              0.772
# 28  noise_type-edge_removal__strategy-all_edges__n...              0.758
# 29  noise_type-edge_removal__strategy-all_edges__n...              0.754
# 30  noise_type-edge_removal__strategy-all_edges__n...              0.757
# 31  noise_type-edge_removal__strategy-all_edges__n...               0.75
# 32  noise_type-edge_removal__strategy-all_edges__n...              0.669
# 33  noise_type-edge_removal__strategy-all_edges__n...               0.64
# 34  noise_type-edge_removal__strategy-all_edges__n...              0.576
# 35  noise_type-edge_removal__strategy-all_edges__n...              0.587
#
#                   test_accuracies  num_epochs  repeat_num  \
# 0   0.805,0.791,0.798,0.804,0.793          25           5
# 1   0.799,0.801,0.772,0.795,0.805          25           5
# 2   0.806,0.791,0.801,0.801,0.796          25           5
# 3   0.788,0.766,0.782,0.783,0.791          25           5
# 4   0.785,0.784,0.788,0.773,0.794          25           5
# 5   0.779,0.797,0.798,0.793,0.772          25           5
# 6   0.782,0.808,0.783,0.783,0.788          25           5
# 7   0.757,0.769,0.796,0.785,0.786          25           5
# 8    0.74,0.756,0.755,0.747,0.745          25           5
# 9   0.741,0.696,0.743,0.743,0.735          25           5
# 10   0.738,0.757,0.716,0.76,0.665          25           5
# 11  0.742,0.758,0.739,0.785,0.758          25           5
# 12    0.79,0.75,0.753,0.777,0.793          25           5
# 13  0.743,0.762,0.768,0.806,0.749          25           5
# 14  0.808,0.804,0.797,0.683,0.765          25           5
# 15  0.796,0.796,0.779,0.753,0.781          25           5
# 16  0.762,0.782,0.797,0.729,0.763          25           5
# 17   0.734,0.706,0.767,0.77,0.792          25           5
# 18  0.775,0.761,0.796,0.722,0.706          25           5
# 19  0.691,0.691,0.736,0.709,0.704          25           5
# 20  0.679,0.623,0.699,0.663,0.708          25           5
# 21     0.72,0.702,0.729,0.707,0.7          25           5
# 22  0.729,0.736,0.678,0.761,0.777          25           5
# 23   0.764,0.763,0.75,0.644,0.721          25           5
# 24  0.766,0.787,0.769,0.773,0.784          25           5
# 25   0.777,0.79,0.765,0.782,0.769          25           5
# 26  0.791,0.772,0.791,0.772,0.757          25           5
# 27  0.767,0.768,0.775,0.772,0.776          25           5
# 28  0.749,0.758,0.761,0.767,0.757          25           5
# 29    0.738,0.75,0.754,0.76,0.769          25           5
# 30  0.755,0.758,0.762,0.777,0.733          25           5
# 31   0.764,0.753,0.763,0.742,0.73          25           5
# 32    0.66,0.68,0.672,0.665,0.667          25           5
# 33  0.668,0.626,0.649,0.657,0.602          25           5
# 34   0.572,0.569,0.594,0.576,0.57          25           5
# 35   0.593,0.598,0.593,0.569,0.58          25           5
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                            noise_info    noise_type  \
# 0   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 1   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 2   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 3   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 4   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 5   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 6   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 7   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 8   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 9   {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 10  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 11  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 12  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 13  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 14  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 15  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 16  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 17  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 18  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 19  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 20  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 21  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 22  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 23  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 24  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 25  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 26  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 27  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 28  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 29  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 30  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 31  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 32  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 33  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 34  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
# 35  {'noise_type': 'edge_removal', 'strategy': 'al...  edge_removal
#
#      strategy noise_level bidirectional
# 0   all_edges           0         False
# 1   all_edges        0.01         False
# 2   all_edges        0.05         False
# 3   all_edges         0.1         False
# 4   all_edges        0.15         False
# 5   all_edges         0.3         False
# 6   all_edges        0.45         False
# 7   all_edges         0.6         False
# 8   all_edges         0.9         False
# 9   all_edges        0.95         False
# 10  all_edges        0.99         False
# 11  all_edges           1         False
# 12  all_edges           0         False
# 13  all_edges        0.01         False
# 14  all_edges        0.05         False
# 15  all_edges         0.1         False
# 16  all_edges        0.15         False
# 17  all_edges         0.3         False
# 18  all_edges        0.45         False
# 19  all_edges         0.6         False
# 20  all_edges         0.9         False
# 21  all_edges        0.95         False
# 22  all_edges        0.99         False
# 23  all_edges           1         False
# 24  all_edges           0         False
# 25  all_edges        0.01         False
# 26  all_edges        0.05         False
# 27  all_edges         0.1         False
# 28  all_edges        0.15         False
# 29  all_edges         0.3         False
# 30  all_edges        0.45         False
# 31  all_edges         0.6         False
# 32  all_edges         0.9         False
# 33  all_edges        0.95         False
# 34  all_edges        0.99         False
# 35  all_edges           1         False

# %% [markdown]
# ### Experiment 3 - Add edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_3_add_random_edges{post_fix}.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

add_edge_params = {'data':data, 'bidirectional':bidirectional_type}
# edge_addition_params = {'data':data}
noise_info = {'noise_type':'edge_addition', 'strategy':'all_edges','params':add_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_add_ratio'}

exp_add_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.798
# Run GNN: 2/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.803
# Run GNN: 3/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.794
# Run GNN: 4/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.795
# Run GNN: 5/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.768
# Run GNN: 6/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.774
# Run GNN: 7/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.773
# Run GNN: 8/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.745
# Run GNN: 9/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.735
# Run GNN: 10/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.707
# Run GNN: 11/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.737
# Run GNN: 12/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.73
# Run GAT: 13/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.786
# Run GAT: 14/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.752
# Run GAT: 15/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.762
# Run GAT: 16/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.694
# Run GAT: 17/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.725
# Run GAT: 18/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.695
# Run GAT: 19/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.65
# Run GAT: 20/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.654
# Run GAT: 21/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.649
# Run GAT: 22/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.598
# Run GAT: 23/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.574
# Run GAT: 24/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.593
# Run Graphsage: 25/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0__bidirectional-False Avg. Test Accuracy: 0.78
# Run Graphsage: 26/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.01__bidirectional-False Avg. Test Accuracy: 0.784
# Run Graphsage: 27/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.05__bidirectional-False Avg. Test Accuracy: 0.779
# Run Graphsage: 28/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.1__bidirectional-False Avg. Test Accuracy: 0.774
# Run Graphsage: 29/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.15__bidirectional-False Avg. Test Accuracy: 0.763
# Run Graphsage: 30/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.3__bidirectional-False Avg. Test Accuracy: 0.764
# Run Graphsage: 31/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.45__bidirectional-False Avg. Test Accuracy: 0.753
# Run Graphsage: 32/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.6__bidirectional-False Avg. Test Accuracy: 0.746
# Run Graphsage: 33/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.9__bidirectional-False Avg. Test Accuracy: 0.736
# Run Graphsage: 34/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.95__bidirectional-False Avg. Test Accuracy: 0.727
# Run Graphsage: 35/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-0.99__bidirectional-False Avg. Test Accuracy: 0.742
# Run Graphsage: 36/36: x - noise_type-edge_addition__strategy-all_edges__noise_level-1__bidirectional-False Avg. Test Accuracy: 0.726
#    dataset_name model_name x_type  \
# 0          Cora        GNN      x
# 1          Cora        GNN      x
# 2          Cora        GNN      x
# 3          Cora        GNN      x
# 4          Cora        GNN      x
# 5          Cora        GNN      x
# 6          Cora        GNN      x
# 7          Cora        GNN      x
# 8          Cora        GNN      x
# 9          Cora        GNN      x
# 10         Cora        GNN      x
# 11         Cora        GNN      x
# 12         Cora        GAT      x
# 13         Cora        GAT      x
# 14         Cora        GAT      x
# 15         Cora        GAT      x
# 16         Cora        GAT      x
# 17         Cora        GAT      x
# 18         Cora        GAT      x
# 19         Cora        GAT      x
# 20         Cora        GAT      x
# 21         Cora        GAT      x
# 22         Cora        GAT      x
# 23         Cora        GAT      x
# 24         Cora  Graphsage      x
# 25         Cora  Graphsage      x
# 26         Cora  Graphsage      x
# 27         Cora  Graphsage      x
# 28         Cora  Graphsage      x
# 29         Cora  Graphsage      x
# 30         Cora  Graphsage      x
# 31         Cora  Graphsage      x
# 32         Cora  Graphsage      x
# 33         Cora  Graphsage      x
# 34         Cora  Graphsage      x
# 35         Cora  Graphsage      x
#
#                                             edge_type mean_test_accuracy  \
# 0   noise_type-edge_addition__strategy-all_edges__...              0.798
# 1   noise_type-edge_addition__strategy-all_edges__...              0.803
# 2   noise_type-edge_addition__strategy-all_edges__...              0.794
# 3   noise_type-edge_addition__strategy-all_edges__...              0.795
# 4   noise_type-edge_addition__strategy-all_edges__...              0.768
# 5   noise_type-edge_addition__strategy-all_edges__...              0.774
# 6   noise_type-edge_addition__strategy-all_edges__...              0.773
# 7   noise_type-edge_addition__strategy-all_edges__...              0.745
# 8   noise_type-edge_addition__strategy-all_edges__...              0.735
# 9   noise_type-edge_addition__strategy-all_edges__...              0.707
# 10  noise_type-edge_addition__strategy-all_edges__...              0.737
# 11  noise_type-edge_addition__strategy-all_edges__...               0.73
# 12  noise_type-edge_addition__strategy-all_edges__...              0.786
# 13  noise_type-edge_addition__strategy-all_edges__...              0.752
# 14  noise_type-edge_addition__strategy-all_edges__...              0.762
# 15  noise_type-edge_addition__strategy-all_edges__...              0.694
# 16  noise_type-edge_addition__strategy-all_edges__...              0.725
# 17  noise_type-edge_addition__strategy-all_edges__...              0.695
# 18  noise_type-edge_addition__strategy-all_edges__...               0.65
# 19  noise_type-edge_addition__strategy-all_edges__...              0.654
# 20  noise_type-edge_addition__strategy-all_edges__...              0.649
# 21  noise_type-edge_addition__strategy-all_edges__...              0.598
# 22  noise_type-edge_addition__strategy-all_edges__...              0.574
# 23  noise_type-edge_addition__strategy-all_edges__...              0.593
# 24  noise_type-edge_addition__strategy-all_edges__...               0.78
# 25  noise_type-edge_addition__strategy-all_edges__...              0.784
# 26  noise_type-edge_addition__strategy-all_edges__...              0.779
# 27  noise_type-edge_addition__strategy-all_edges__...              0.774
# 28  noise_type-edge_addition__strategy-all_edges__...              0.763
# 29  noise_type-edge_addition__strategy-all_edges__...              0.764
# 30  noise_type-edge_addition__strategy-all_edges__...              0.753
# 31  noise_type-edge_addition__strategy-all_edges__...              0.746
# 32  noise_type-edge_addition__strategy-all_edges__...              0.736
# 33  noise_type-edge_addition__strategy-all_edges__...              0.727
# 34  noise_type-edge_addition__strategy-all_edges__...              0.742
# 35  noise_type-edge_addition__strategy-all_edges__...              0.726
#
#                   test_accuracies  num_epochs  repeat_num  \
# 0       0.805,0.8,0.798,0.8,0.786          25           5
# 1    0.81,0.809,0.801,0.798,0.799          25           5
# 2   0.796,0.807,0.772,0.793,0.802          25           5
# 3    0.798,0.792,0.782,0.793,0.81          25           5
# 4   0.756,0.757,0.778,0.775,0.775          25           5
# 5    0.779,0.762,0.777,0.781,0.77          25           5
# 6   0.772,0.755,0.773,0.791,0.776          25           5
# 7   0.744,0.745,0.745,0.757,0.734          25           5
# 8   0.739,0.723,0.733,0.739,0.742          25           5
# 9   0.707,0.685,0.705,0.716,0.724          25           5
# 10  0.728,0.743,0.728,0.742,0.742          25           5
# 11   0.714,0.736,0.71,0.736,0.753          25           5
# 12  0.773,0.793,0.816,0.771,0.776          25           5
# 13  0.726,0.731,0.768,0.773,0.762          25           5
# 14  0.791,0.772,0.757,0.756,0.732          25           5
# 15  0.673,0.685,0.686,0.741,0.687          25           5
# 16  0.689,0.748,0.699,0.722,0.768          25           5
# 17    0.725,0.722,0.716,0.712,0.6          25           5
# 18   0.68,0.678,0.635,0.612,0.647          25           5
# 19   0.629,0.712,0.631,0.686,0.61          25           5
# 20  0.674,0.638,0.655,0.539,0.737          25           5
# 21  0.675,0.577,0.616,0.599,0.521          25           5
# 22  0.584,0.577,0.566,0.556,0.589          25           5
# 23  0.632,0.424,0.627,0.629,0.653          25           5
# 24  0.782,0.775,0.778,0.784,0.781          25           5
# 25   0.795,0.768,0.782,0.79,0.783          25           5
# 26  0.774,0.777,0.774,0.788,0.783          25           5
# 27  0.769,0.767,0.774,0.778,0.782          25           5
# 28  0.762,0.759,0.756,0.777,0.762          25           5
# 29   0.77,0.764,0.764,0.748,0.773          25           5
# 30  0.748,0.752,0.749,0.748,0.768          25           5
# 31  0.748,0.741,0.751,0.742,0.748          25           5
# 32  0.736,0.734,0.725,0.744,0.742          25           5
# 33   0.735,0.721,0.728,0.742,0.71          25           5
# 34  0.748,0.745,0.739,0.741,0.737          25           5
# 35    0.736,0.73,0.727,0.72,0.718          25           5
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 42, '...
# 25  {'in_channels': 1433, 'hidden_channels': 42, '...
# 26  {'in_channels': 1433, 'hidden_channels': 42, '...
# 27  {'in_channels': 1433, 'hidden_channels': 42, '...
# 28  {'in_channels': 1433, 'hidden_channels': 42, '...
# 29  {'in_channels': 1433, 'hidden_channels': 42, '...
# 30  {'in_channels': 1433, 'hidden_channels': 42, '...
# 31  {'in_channels': 1433, 'hidden_channels': 42, '...
# 32  {'in_channels': 1433, 'hidden_channels': 42, '...
# 33  {'in_channels': 1433, 'hidden_channels': 42, '...
# 34  {'in_channels': 1433, 'hidden_channels': 42, '...
# 35  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                            noise_info     noise_type  \
# 0   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 1   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 2   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 3   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 4   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 5   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 6   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 7   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 8   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 9   {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 10  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 11  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 12  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 13  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 14  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 15  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 16  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 17  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 18  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 19  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 20  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 21  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 22  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 23  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 24  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 25  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 26  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 27  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 28  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 29  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 30  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 31  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 32  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 33  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 34  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
# 35  {'noise_type': 'edge_addition', 'strategy': 'a...  edge_addition
#
#      strategy noise_level bidirectional
# 0   all_edges           0         False
# 1   all_edges        0.01         False
# 2   all_edges        0.05         False
# 3   all_edges         0.1         False
# 4   all_edges        0.15         False
# 5   all_edges         0.3         False
# 6   all_edges        0.45         False
# 7   all_edges         0.6         False
# 8   all_edges         0.9         False
# 9   all_edges        0.95         False
# 10  all_edges        0.99         False
# 11  all_edges           1         False
# 12  all_edges           0         False
# 13  all_edges        0.01         False
# 14  all_edges        0.05         False
# 15  all_edges         0.1         False
# 16  all_edges        0.15         False
# 17  all_edges         0.3         False
# 18  all_edges        0.45         False
# 19  all_edges         0.6         False
# 20  all_edges         0.9         False
# 21  all_edges        0.95         False
# 22  all_edges        0.99         False
# 23  all_edges           1         False
# 24  all_edges           0         False
# 25  all_edges        0.01         False
# 26  all_edges        0.05         False
# 27  all_edges         0.1         False
# 28  all_edges        0.15         False
# 29  all_edges         0.3         False
# 30  all_edges        0.45         False
# 31  all_edges         0.6         False
# 32  all_edges         0.9         False
# 33  all_edges        0.95         False
# 34  all_edges        0.99         False
# 35  all_edges           1         False

# %% [markdown]
# ### Experiment 4 - Remove Edges: Random - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_4_remove_random_nodes{post_fix}.csv'
# **** DONT forget to change this *****


data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'random'}
nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent': nodes_percent,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 2/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 3/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 4/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 5/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 6/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 7/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 8/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 9/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 10/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 11/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.81
# Run GNN: 12/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.784
# Run GNN: 13/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.806
# Run GNN: 14/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.797
# Run GNN: 15/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 16/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 17/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 18/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 19/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.797
# Run GNN: 20/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 21/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 22/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 23/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 24/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 25/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.799
# Run GNN: 26/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.794
# Run GNN: 27/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.786
# Run GNN: 28/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.793
# Run GNN: 29/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.801
# Run GNN: 30/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.785
# Run GNN: 31/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.801
# Run GNN: 32/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.782
# Run GNN: 33/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.782
# Run GNN: 34/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.801
# Run GNN: 35/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.788
# Run GNN: 36/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.771
# Run GNN: 37/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.798
# Run GNN: 38/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 39/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 40/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.785
# Run GNN: 41/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.79
# Run GNN: 42/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.787
# Run GNN: 43/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.794
# Run GNN: 44/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.803
# Run GNN: 45/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.8
# Run GNN: 46/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.792
# Run GNN: 47/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.778
# Run GNN: 48/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.788
# Run GNN: 49/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.798
# Run GNN: 50/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.797
# Run GNN: 51/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.795
# Run GNN: 52/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.796
# Run GNN: 53/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.797
# Run GNN: 54/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.786
# Run GNN: 55/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.799
# Run GNN: 56/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.782
# Run GNN: 57/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.775
# Run GNN: 58/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.783
# Run GNN: 59/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.774
# Run GNN: 60/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.773
# Run GNN: 61/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.789
# Run GNN: 62/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.798
# Run GNN: 63/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 64/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.793
# Run GNN: 65/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.788
# Run GNN: 66/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.788
# Run GNN: 67/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.795
# Run GNN: 68/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.793
# Run GNN: 69/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.747
# Run GNN: 70/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.773
# Run GNN: 71/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.763
# Run GNN: 72/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.798
# Run GNN: 73/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.798
# Run GNN: 74/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.801
# Run GNN: 75/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.776
# Run GNN: 76/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.788
# Run GNN: 77/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.783
# Run GNN: 78/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.798
# Run GNN: 79/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.765
# Run GNN: 80/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 81/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 82/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.76
# Run GNN: 83/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.788
# Run GNN: 84/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.76
# Run GNN: 85/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.793
# Run GNN: 86/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.79
# Run GNN: 87/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.79
# Run GNN: 88/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.789
# Run GNN: 89/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.791
# Run GNN: 90/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.802
# Run GNN: 91/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GNN: 92/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.749
# Run GNN: 93/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.767
# Run GNN: 94/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.718
# Run GNN: 95/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.759
# Run GNN: 96/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.74
# Run GNN: 97/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.8
# Run GNN: 98/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.795
# Run GNN: 99/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.785
# Run GNN: 100/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.784
# Run GNN: 101/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.78
# Run GNN: 102/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.786
# Run GNN: 103/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.789
# Run GNN: 104/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.753
# Run GNN: 105/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.767
# Run GNN: 106/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.741
# Run GNN: 107/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.743
# Run GNN: 108/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.753
# Run GNN: 109/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.795
# Run GNN: 110/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.766
# Run GNN: 111/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 112/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.76
# Run GNN: 113/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.771
# Run GNN: 114/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 115/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.764
# Run GNN: 116/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.753
# Run GNN: 117/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.729
# Run GNN: 118/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.726
# Run GNN: 119/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.714
# Run GNN: 120/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.744
# Run GNN: 121/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.798
# Run GNN: 122/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.777
# Run GNN: 123/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 124/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.798
# Run GNN: 125/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.79
# Run GNN: 126/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.774
# Run GNN: 127/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.778
# Run GNN: 128/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.765
# Run GNN: 129/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.756
# Run GNN: 130/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.694
# Run GNN: 131/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.71
# Run GNN: 132/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.717
# Run GNN: 133/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.797
# Run GNN: 134/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.773
# Run GNN: 135/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.778
# Run GNN: 136/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.784
# Run GNN: 137/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.782
# Run GNN: 138/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.79
# Run GNN: 139/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.765
# Run GNN: 140/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.743
# Run GNN: 141/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.735
# Run GNN: 142/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.721
# Run GNN: 143/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.726
# Run GNN: 144/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.754
# Run GAT: 145/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.739
# Run GAT: 146/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.782
# Run GAT: 147/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.779
# Run GAT: 148/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.765
# Run GAT: 149/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.744
# Run GAT: 150/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.768
# Run GAT: 151/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.778
# Run GAT: 152/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.753
# Run GAT: 153/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.774
# Run GAT: 154/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.77
# Run GAT: 155/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.748
# Run GAT: 156/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.755
# Run GAT: 157/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 158/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.75
# Run GAT: 159/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 160/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 161/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.761
# Run GAT: 162/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.758
# Run GAT: 163/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.757
# Run GAT: 164/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.77
# Run GAT: 165/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.77
# Run GAT: 166/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.774
# Run GAT: 167/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.757
# Run GAT: 168/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 169/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.747
# Run GAT: 170/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.77
# Run GAT: 171/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.773
# Run GAT: 172/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.768
# Run GAT: 173/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.77
# Run GAT: 174/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.763
# Run GAT: 175/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.772
# Run GAT: 176/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.749
# Run GAT: 177/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.743
# Run GAT: 178/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.757
# Run GAT: 179/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.761
# Run GAT: 180/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.765
# Run GAT: 181/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.786
# Run GAT: 182/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.763
# Run GAT: 183/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.76
# Run GAT: 184/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.753
# Run GAT: 185/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.783
# Run GAT: 186/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.762
# Run GAT: 187/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.768
# Run GAT: 188/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.767
# Run GAT: 189/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.755
# Run GAT: 190/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.768
# Run GAT: 191/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.76
# Run GAT: 192/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.732
# Run GAT: 193/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.749
# Run GAT: 194/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.762
# Run GAT: 195/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.763
# Run GAT: 196/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.734
# Run GAT: 197/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.77
# Run GAT: 198/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GAT: 199/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.76
# Run GAT: 200/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.76
# Run GAT: 201/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.767
# Run GAT: 202/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.751
# Run GAT: 203/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.751
# Run GAT: 204/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.751
# Run GAT: 205/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.761
# Run GAT: 206/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.736
# Run GAT: 207/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.784
# Run GAT: 208/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.747
# Run GAT: 209/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.747
# Run GAT: 210/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.745
# Run GAT: 211/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.743
# Run GAT: 212/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.768
# Run GAT: 213/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.717
# Run GAT: 214/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.725
# Run GAT: 215/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.75
# Run GAT: 216/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.752
# Run GAT: 217/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.777
# Run GAT: 218/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.763
# Run GAT: 219/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.763
# Run GAT: 220/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.769
# Run GAT: 221/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.768
# Run GAT: 222/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.755
# Run GAT: 223/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.778
# Run GAT: 224/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.771
# Run GAT: 225/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.762
# Run GAT: 226/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.746
# Run GAT: 227/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.769
# Run GAT: 228/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.755
# Run GAT: 229/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.755
# Run GAT: 230/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.776
# Run GAT: 231/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.777
# Run GAT: 232/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.776
# Run GAT: 233/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.726
# Run GAT: 234/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.775
# Run GAT: 235/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.755
# Run GAT: 236/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.76
# Run GAT: 237/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.748
# Run GAT: 238/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.736
# Run GAT: 239/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.749
# Run GAT: 240/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.727
# Run GAT: 241/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.756
# Run GAT: 242/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.733
# Run GAT: 243/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.762
# Run GAT: 244/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run GAT: 245/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.751
# Run GAT: 246/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.77
# Run GAT: 247/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.774
# Run GAT: 248/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.756
# ...
# Run Graphsage: 371/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.747
# Run Graphsage: 372/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.739
# Run Graphsage: 373/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.777
# Run Graphsage: 374/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.775
# Run Graphsage: 375/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.766
# Run Graphsage: 376/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.766
# Run Graphsage: 377/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.777
# Run Graphsage: 378/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.767
# Run Graphsage: 379/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.758
# Run Graphsage: 380/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.737
# Run Graphsage: 381/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.734
# Run Graphsage: 382/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.708
# Run Graphsage: 383/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.715
# Run Graphsage: 384/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.729
# Run Graphsage: 385/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.777
# Run Graphsage: 386/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.769
# Run Graphsage: 387/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.761
# Run Graphsage: 388/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.748
# Run Graphsage: 389/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run Graphsage: 390/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.761
# Run Graphsage: 391/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.748
# Run Graphsage: 392/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.738
# Run Graphsage: 393/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.708
# Run Graphsage: 394/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.69
# Run Graphsage: 395/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.706
# Run Graphsage: 396/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.687
# Run Graphsage: 397/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.775
# Run Graphsage: 398/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 399/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.761
# Run Graphsage: 400/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run Graphsage: 401/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 402/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.762
# Run Graphsage: 403/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.754
# Run Graphsage: 404/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.74
# Run Graphsage: 405/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.61
# Run Graphsage: 406/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.602
# Run Graphsage: 407/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.627
# Run Graphsage: 408/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.608
# Run Graphsage: 409/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.777
# Run Graphsage: 410/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.762
# Run Graphsage: 411/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.755
# Run Graphsage: 412/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.768
# Run Graphsage: 413/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.763
# Run Graphsage: 414/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.75
# Run Graphsage: 415/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.756
# Run Graphsage: 416/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.74
# Run Graphsage: 417/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.644
# Run Graphsage: 418/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.645
# Run Graphsage: 419/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.591
# Run Graphsage: 420/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.664
# Run Graphsage: 421/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.773
# Run Graphsage: 422/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.75
# Run Graphsage: 423/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.77
# Run Graphsage: 424/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.767
# Run Graphsage: 425/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.75
# Run Graphsage: 426/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 427/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.737
# Run Graphsage: 428/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.721
# Run Graphsage: 429/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.477
# Run Graphsage: 430/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.498
# Run Graphsage: 431/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.585
# Run Graphsage: 432/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.584
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_removal__strategy-nodes__noise...              0.796
# 1    noise_type-edge_removal__strategy-nodes__noise...              0.794
# 2    noise_type-edge_removal__strategy-nodes__noise...              0.793
# 3    noise_type-edge_removal__strategy-nodes__noise...              0.791
# 4    noise_type-edge_removal__strategy-nodes__noise...              0.793
# ..                                                 ...                ...
# 427  noise_type-edge_removal__strategy-nodes__noise...              0.721
# 428  noise_type-edge_removal__strategy-nodes__noise...              0.477
# 429  noise_type-edge_removal__strategy-nodes__noise...              0.498
# 430  noise_type-edge_removal__strategy-nodes__noise...              0.585
# 431  noise_type-edge_removal__strategy-nodes__noise...              0.584
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0    0.808,0.788,0.782,0.797,0.803          25           5
# 1    0.798,0.798,0.795,0.797,0.784          25           5
# 2    0.796,0.788,0.781,0.798,0.801          25           5
# 3    0.766,0.809,0.783,0.802,0.797          25           5
# 4    0.784,0.794,0.789,0.796,0.803          25           5
# ..                             ...         ...         ...
# 427   0.73,0.725,0.709,0.728,0.713          25           5
# 428   0.48,0.495,0.463,0.479,0.466          25           5
# 429   0.44,0.512,0.488,0.533,0.519          25           5
# 430  0.593,0.596,0.578,0.577,0.582          25           5
# 431   0.584,0.579,0.585,0.59,0.581          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info    noise_type strategy  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# ..                                                 ...           ...      ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
#
#     noise_level bidirectional choose_type k_nodes node_percent
# 0             0         False      random     135         0.05
# 1          0.01         False      random     135         0.05
# 2          0.05         False      random     135         0.05
# 3           0.1         False      random     135         0.05
# 4          0.15         False      random     135         0.05
# ..          ...           ...         ...     ...          ...
# 427         0.6         False      random    2708            1
# 428         0.9         False      random    2708            1
# 429        0.95         False      random    2708            1
# 430        0.99         False      random    2708            1
# 431           1         False      random    2708            1
#
# [432 rows x 17 columns]

# %% [markdown]
# ### Experiment 5 - Remove Edges: topk - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_5_remove_topk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent':nodes_percent,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.804
# Run GNN: 2/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 3/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 4/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 5/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 6/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 7/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.781
# Run GNN: 8/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 9/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.782
# Run GNN: 10/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.785
# Run GNN: 11/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.77
# Run GNN: 12/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 13/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 14/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 15/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 16/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 17/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.802
# Run GNN: 18/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 19/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 20/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 21/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.768
# Run GNN: 22/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.774
# Run GNN: 23/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.773
# Run GNN: 24/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.773
# Run GNN: 25/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.795
# Run GNN: 26/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.801
# Run GNN: 27/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.798
# Run GNN: 28/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.795
# Run GNN: 29/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.793
# Run GNN: 30/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 31/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.782
# Run GNN: 32/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 33/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.762
# Run GNN: 34/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.766
# Run GNN: 35/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.763
# Run GNN: 36/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.772
# Run GNN: 37/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.798
# Run GNN: 38/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.799
# Run GNN: 39/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.802
# Run GNN: 40/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.801
# Run GNN: 41/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 42/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.792
# Run GNN: 43/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.799
# Run GNN: 44/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 45/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.776
# Run GNN: 46/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.79
# Run GNN: 47/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.766
# Run GNN: 48/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.771
# Run GNN: 49/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.796
# Run GNN: 50/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.799
# Run GNN: 51/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.799
# Run GNN: 52/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.799
# Run GNN: 53/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.794
# Run GNN: 54/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.803
# Run GNN: 55/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.776
# Run GNN: 56/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.793
# Run GNN: 57/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.755
# Run GNN: 58/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.772
# Run GNN: 59/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.746
# Run GNN: 60/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.761
# Run GNN: 61/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.798
# Run GNN: 62/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.803
# Run GNN: 63/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.802
# Run GNN: 64/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.803
# Run GNN: 65/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.785
# Run GNN: 66/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.782
# Run GNN: 67/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.782
# Run GNN: 68/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.783
# Run GNN: 69/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.766
# Run GNN: 70/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.759
# Run GNN: 71/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.75
# Run GNN: 72/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.74
# Run GNN: 73/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.798
# Run GNN: 74/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 75/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 76/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 77/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 78/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 79/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.781
# Run GNN: 80/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 81/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.731
# Run GNN: 82/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.742
# Run GNN: 83/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.728
# Run GNN: 84/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.73
# Run GNN: 85/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.785
# Run GNN: 86/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.779
# Run GNN: 87/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 88/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 89/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.791
# Run GNN: 90/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.794
# Run GNN: 91/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 92/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.762
# Run GNN: 93/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.753
# Run GNN: 94/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.727
# Run GNN: 95/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.726
# Run GNN: 96/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.717
# Run GNN: 97/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.799
# Run GNN: 98/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GNN: 99/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.799
# Run GNN: 100/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.781
# Run GNN: 101/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.767
# Run GNN: 102/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.794
# Run GNN: 103/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run GNN: 104/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run GNN: 105/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.735
# Run GNN: 106/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.725
# Run GNN: 107/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.737
# Run GNN: 108/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.731
# Run GNN: 109/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.797
# Run GNN: 110/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 111/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.795
# Run GNN: 112/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.783
# Run GNN: 113/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.769
# Run GNN: 114/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.78
# Run GNN: 115/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.77
# Run GNN: 116/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.735
# Run GNN: 117/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.736
# Run GNN: 118/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.738
# Run GNN: 119/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.742
# Run GNN: 120/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.731
# Run GNN: 121/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.796
# Run GNN: 122/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.782
# Run GNN: 123/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.771
# Run GNN: 124/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.788
# Run GNN: 125/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.818
# Run GNN: 126/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.807
# Run GNN: 127/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.756
# Run GNN: 128/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.737
# Run GNN: 129/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.734
# Run GNN: 130/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.722
# Run GNN: 131/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.741
# Run GNN: 132/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.725
# Run GNN: 133/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.79
# Run GNN: 134/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.783
# Run GNN: 135/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.777
# Run GNN: 136/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.784
# Run GNN: 137/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.793
# Run GNN: 138/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.776
# Run GNN: 139/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run GNN: 140/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.73
# Run GNN: 141/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.731
# Run GNN: 142/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.734
# Run GNN: 143/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.733
# Run GNN: 144/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.745
# Run GAT: 145/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.776
# Run GAT: 146/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.754
# Run GAT: 147/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.755
# Run GAT: 148/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.75
# Run GAT: 149/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.782
# Run GAT: 150/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.747
# Run GAT: 151/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.738
# Run GAT: 152/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.762
# Run GAT: 153/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.744
# Run GAT: 154/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.745
# Run GAT: 155/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.717
# Run GAT: 156/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.746
# Run GAT: 157/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.741
# Run GAT: 158/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.772
# Run GAT: 159/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.737
# Run GAT: 160/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.748
# Run GAT: 161/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.771
# Run GAT: 162/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 163/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.729
# Run GAT: 164/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.715
# Run GAT: 165/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.729
# Run GAT: 166/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.764
# Run GAT: 167/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.728
# Run GAT: 168/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.752
# Run GAT: 169/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.785
# Run GAT: 170/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.769
# Run GAT: 171/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.751
# Run GAT: 172/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.764
# Run GAT: 173/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.758
# Run GAT: 174/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.767
# Run GAT: 175/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.762
# Run GAT: 176/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.763
# Run GAT: 177/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.728
# Run GAT: 178/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.753
# Run GAT: 179/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.721
# Run GAT: 180/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.74
# Run GAT: 181/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.745
# Run GAT: 182/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.781
# Run GAT: 183/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.769
# Run GAT: 184/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.769
# Run GAT: 185/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.768
# Run GAT: 186/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.742
# Run GAT: 187/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.737
# Run GAT: 188/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.739
# Run GAT: 189/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.722
# Run GAT: 190/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.723
# Run GAT: 191/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.714
# Run GAT: 192/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.74
# Run GAT: 193/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.745
# Run GAT: 194/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GAT: 195/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.766
# Run GAT: 196/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.766
# Run GAT: 197/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.758
# Run GAT: 198/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.769
# Run GAT: 199/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.742
# Run GAT: 200/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.756
# Run GAT: 201/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.747
# Run GAT: 202/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.757
# Run GAT: 203/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.733
# Run GAT: 204/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.761
# Run GAT: 205/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.73
# Run GAT: 206/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.777
# Run GAT: 207/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.753
# Run GAT: 208/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.763
# Run GAT: 209/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.742
# Run GAT: 210/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.747
# Run GAT: 211/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.756
# Run GAT: 212/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.754
# Run GAT: 213/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.734
# Run GAT: 214/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.736
# Run GAT: 215/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.742
# Run GAT: 216/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GAT: 217/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.786
# Run GAT: 218/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.75
# Run GAT: 219/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.767
# Run GAT: 220/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.766
# Run GAT: 221/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.775
# Run GAT: 222/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.764
# Run GAT: 223/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.763
# Run GAT: 224/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.744
# Run GAT: 225/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.729
# Run GAT: 226/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.73
# Run GAT: 227/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.713
# Run GAT: 228/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.729
# Run GAT: 229/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.757
# Run GAT: 230/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.753
# Run GAT: 231/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.774
# Run GAT: 232/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.743
# Run GAT: 233/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.769
# Run GAT: 234/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.753
# Run GAT: 235/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.75
# Run GAT: 236/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.739
# Run GAT: 237/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.727
# Run GAT: 238/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.678
# Run GAT: 239/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.706
# Run GAT: 240/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.698
# Run GAT: 241/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.767
# Run GAT: 242/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.736
# Run GAT: 243/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.777
# Run GAT: 244/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.759
# Run GAT: 245/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.762
# Run GAT: 246/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.762
# Run GAT: 247/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.768
# Run GAT: 248/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.762
# Run GAT: 249/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.738
# ...
# Run Graphsage: 371/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.679
# Run Graphsage: 372/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.68
# Run Graphsage: 373/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.779
# Run Graphsage: 374/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.77
# Run Graphsage: 375/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.768
# Run Graphsage: 376/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.769
# Run Graphsage: 377/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.768
# Run Graphsage: 378/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.769
# Run Graphsage: 379/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.75
# Run Graphsage: 380/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.74
# Run Graphsage: 381/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.664
# Run Graphsage: 382/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.651
# Run Graphsage: 383/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.628
# Run Graphsage: 384/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.638
# Run Graphsage: 385/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.786
# Run Graphsage: 386/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run Graphsage: 387/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run Graphsage: 388/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.77
# Run Graphsage: 389/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run Graphsage: 390/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.764
# Run Graphsage: 391/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.76
# Run Graphsage: 392/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run Graphsage: 393/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.62
# Run Graphsage: 394/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.633
# Run Graphsage: 395/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.599
# Run Graphsage: 396/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.609
# Run Graphsage: 397/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.78
# Run Graphsage: 398/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.769
# Run Graphsage: 399/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.772
# Run Graphsage: 400/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.761
# Run Graphsage: 401/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.76
# Run Graphsage: 402/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.76
# Run Graphsage: 403/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.74
# Run Graphsage: 404/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.72
# Run Graphsage: 405/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.585
# Run Graphsage: 406/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.578
# Run Graphsage: 407/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.573
# Run Graphsage: 408/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.583
# Run Graphsage: 409/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.782
# Run Graphsage: 410/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.769
# Run Graphsage: 411/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.755
# Run Graphsage: 412/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.762
# Run Graphsage: 413/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.777
# Run Graphsage: 414/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.76
# Run Graphsage: 415/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.739
# Run Graphsage: 416/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.716
# Run Graphsage: 417/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.58
# Run Graphsage: 418/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.6
# Run Graphsage: 419/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.54
# Run Graphsage: 420/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.548
# Run Graphsage: 421/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.779
# Run Graphsage: 422/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.759
# Run Graphsage: 423/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.767
# Run Graphsage: 424/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.769
# Run Graphsage: 425/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.752
# Run Graphsage: 426/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.763
# Run Graphsage: 427/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.753
# Run Graphsage: 428/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.721
# Run Graphsage: 429/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.596
# Run Graphsage: 430/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.582
# Run Graphsage: 431/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.579
# Run Graphsage: 432/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.58
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_removal__strategy-nodes__noise...              0.804
# 1    noise_type-edge_removal__strategy-nodes__noise...              0.797
# 2    noise_type-edge_removal__strategy-nodes__noise...              0.794
# 3    noise_type-edge_removal__strategy-nodes__noise...              0.798
# 4    noise_type-edge_removal__strategy-nodes__noise...              0.795
# ..                                                 ...                ...
# 427  noise_type-edge_removal__strategy-nodes__noise...              0.721
# 428  noise_type-edge_removal__strategy-nodes__noise...              0.596
# 429  noise_type-edge_removal__strategy-nodes__noise...              0.582
# 430  noise_type-edge_removal__strategy-nodes__noise...              0.579
# 431  noise_type-edge_removal__strategy-nodes__noise...               0.58
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0    0.808,0.792,0.798,0.806,0.814          25           5
# 1     0.808,0.773,0.799,0.79,0.815          25           5
# 2    0.791,0.795,0.807,0.782,0.794          25           5
# 3      0.804,0.791,0.794,0.81,0.79          25           5
# 4      0.798,0.8,0.791,0.794,0.794          25           5
# ..                             ...         ...         ...
# 427  0.739,0.727,0.729,0.719,0.691          25           5
# 428    0.588,0.604,0.6,0.598,0.592          25           5
# 429     0.59,0.58,0.575,0.58,0.584          25           5
# 430  0.583,0.571,0.566,0.583,0.591          25           5
# 431  0.571,0.561,0.591,0.577,0.598          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info    noise_type strategy  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# ..                                                 ...           ...      ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
#
#     noise_level bidirectional choose_type k_nodes node_percent
# 0             0         False       top_k     135         0.05
# 1          0.01         False       top_k     135         0.05
# 2          0.05         False       top_k     135         0.05
# 3           0.1         False       top_k     135         0.05
# 4          0.15         False       top_k     135         0.05
# ..          ...           ...         ...     ...          ...
# 427         0.6         False       top_k    2708            1
# 428         0.9         False       top_k    2708            1
# 429        0.95         False       top_k    2708            1
# 430        0.99         False       top_k    2708            1
# 431           1         False       top_k    2708            1
#
# [432 rows x 17 columns]

# %% [markdown]
# ### Experiment 6 - Remove Edges: Bottom k - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_6_remove_bottomk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent =  [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent':nodes_percent,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 2/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 3/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 4/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 5/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.8
# Run GNN: 6/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 7/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 8/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 9/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 10/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 11/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 12/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 13/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.797
# Run GNN: 14/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 15/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 16/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.797
# Run GNN: 17/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 18/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 19/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 20/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 21/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 22/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 23/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 24/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 25/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.799
# Run GNN: 26/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 27/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.786
# Run GNN: 28/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.792
# Run GNN: 29/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.79
# Run GNN: 30/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.785
# Run GNN: 31/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.792
# Run GNN: 32/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.791
# Run GNN: 33/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 34/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 35/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.79
# Run GNN: 36/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.795
# Run GNN: 37/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.801
# Run GNN: 38/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.791
# Run GNN: 39/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.797
# Run GNN: 40/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 41/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.785
# Run GNN: 42/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.796
# Run GNN: 43/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.791
# Run GNN: 44/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 45/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 46/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.791
# Run GNN: 47/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 48/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 49/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.801
# Run GNN: 50/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.787
# Run GNN: 51/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.797
# Run GNN: 52/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.794
# Run GNN: 53/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.796
# Run GNN: 54/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.794
# Run GNN: 55/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.794
# Run GNN: 56/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.796
# Run GNN: 57/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.788
# Run GNN: 58/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.789
# Run GNN: 59/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.788
# Run GNN: 60/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.789
# Run GNN: 61/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.799
# Run GNN: 62/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.791
# Run GNN: 63/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.796
# Run GNN: 64/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.782
# Run GNN: 65/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.782
# Run GNN: 66/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.782
# Run GNN: 67/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.788
# Run GNN: 68/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.791
# Run GNN: 69/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.785
# Run GNN: 70/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.788
# Run GNN: 71/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 72/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.783
# Run GNN: 73/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 74/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 75/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 76/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 77/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.782
# Run GNN: 78/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.78
# Run GNN: 79/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.765
# Run GNN: 80/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 81/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.761
# Run GNN: 82/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.771
# Run GNN: 83/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.763
# Run GNN: 84/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.762
# Run GNN: 85/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.792
# Run GNN: 86/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.781
# Run GNN: 87/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.792
# Run GNN: 88/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.777
# Run GNN: 89/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.783
# Run GNN: 90/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.793
# Run GNN: 91/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 92/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.775
# Run GNN: 93/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.762
# Run GNN: 94/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run GNN: 95/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.758
# Run GNN: 96/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GNN: 97/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.792
# Run GNN: 98/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.786
# Run GNN: 99/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.799
# Run GNN: 100/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.781
# Run GNN: 101/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.785
# Run GNN: 102/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.782
# Run GNN: 103/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.763
# Run GNN: 104/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.764
# Run GNN: 105/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.752
# Run GNN: 106/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.753
# Run GNN: 107/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.739
# Run GNN: 108/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.751
# Run GNN: 109/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.794
# Run GNN: 110/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.784
# Run GNN: 111/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.79
# Run GNN: 112/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 113/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 114/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.795
# Run GNN: 115/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.781
# Run GNN: 116/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.781
# Run GNN: 117/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.756
# Run GNN: 118/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.766
# Run GNN: 119/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.765
# Run GNN: 120/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.758
# Run GNN: 121/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 122/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 123/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.792
# Run GNN: 124/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.78
# Run GNN: 125/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.781
# Run GNN: 126/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 127/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.78
# Run GNN: 128/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.757
# Run GNN: 129/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.763
# Run GNN: 130/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.756
# Run GNN: 131/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.762
# Run GNN: 132/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.761
# Run GNN: 133/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.796
# Run GNN: 134/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.77
# Run GNN: 135/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.79
# Run GNN: 136/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.781
# Run GNN: 137/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.766
# Run GNN: 138/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.786
# Run GNN: 139/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.748
# Run GNN: 140/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.742
# Run GNN: 141/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.73
# Run GNN: 142/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.737
# Run GNN: 143/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.732
# Run GNN: 144/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.727
# Run GAT: 145/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.767
# Run GAT: 146/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.772
# Run GAT: 147/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.767
# Run GAT: 148/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.755
# Run GAT: 149/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.767
# Run GAT: 150/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.775
# Run GAT: 151/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.72
# Run GAT: 152/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.763
# Run GAT: 153/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.753
# Run GAT: 154/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.737
# Run GAT: 155/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.771
# Run GAT: 156/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.758
# Run GAT: 157/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GAT: 158/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.739
# Run GAT: 159/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.747
# Run GAT: 160/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.757
# Run GAT: 161/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.762
# Run GAT: 162/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.74
# Run GAT: 163/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.78
# Run GAT: 164/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 165/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.762
# Run GAT: 166/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.754
# Run GAT: 167/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.761
# Run GAT: 168/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.776
# Run GAT: 169/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.756
# Run GAT: 170/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.765
# Run GAT: 171/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.735
# Run GAT: 172/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.755
# Run GAT: 173/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.749
# Run GAT: 174/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.759
# Run GAT: 175/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.769
# Run GAT: 176/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.755
# Run GAT: 177/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.781
# Run GAT: 178/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.764
# Run GAT: 179/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.767
# Run GAT: 180/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.754
# Run GAT: 181/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.76
# Run GAT: 182/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.78
# Run GAT: 183/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.761
# Run GAT: 184/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.762
# Run GAT: 185/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.77
# Run GAT: 186/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.735
# Run GAT: 187/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.744
# Run GAT: 188/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.755
# Run GAT: 189/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.775
# Run GAT: 190/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.755
# Run GAT: 191/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.779
# Run GAT: 192/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.776
# Run GAT: 193/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GAT: 194/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.776
# Run GAT: 195/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.747
# Run GAT: 196/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.763
# Run GAT: 197/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.768
# Run GAT: 198/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.729
# Run GAT: 199/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.781
# Run GAT: 200/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.754
# Run GAT: 201/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.747
# Run GAT: 202/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GAT: 203/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.751
# Run GAT: 204/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.732
# Run GAT: 205/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GAT: 206/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.76
# Run GAT: 207/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.756
# Run GAT: 208/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.751
# Run GAT: 209/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GAT: 210/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.759
# Run GAT: 211/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.773
# Run GAT: 212/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.767
# Run GAT: 213/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.763
# Run GAT: 214/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.757
# Run GAT: 215/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.759
# Run GAT: 216/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.76
# Run GAT: 217/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.757
# Run GAT: 218/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.75
# Run GAT: 219/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.765
# Run GAT: 220/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.759
# Run GAT: 221/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.773
# Run GAT: 222/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.766
# Run GAT: 223/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.75
# Run GAT: 224/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.774
# Run GAT: 225/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.753
# Run GAT: 226/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.745
# Run GAT: 227/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.743
# Run GAT: 228/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.757
# Run GAT: 229/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.739
# Run GAT: 230/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.744
# Run GAT: 231/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.757
# Run GAT: 232/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.75
# Run GAT: 233/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.753
# Run GAT: 234/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run GAT: 235/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run GAT: 236/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.754
# Run GAT: 237/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.767
# Run GAT: 238/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GAT: 239/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.763
# Run GAT: 240/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.741
# Run GAT: 241/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.764
# Run GAT: 242/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.764
# Run GAT: 243/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.763
# Run GAT: 244/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.749
# Run GAT: 245/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.758
# ...
# Run Graphsage: 372/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.748
# Run Graphsage: 373/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.774
# Run Graphsage: 374/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.759
# Run Graphsage: 375/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.761
# Run Graphsage: 376/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.759
# Run Graphsage: 377/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.758
# Run Graphsage: 378/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run Graphsage: 379/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run Graphsage: 380/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.748
# Run Graphsage: 381/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.75
# Run Graphsage: 382/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.752
# Run Graphsage: 383/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run Graphsage: 384/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.752
# Run Graphsage: 385/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run Graphsage: 386/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.76
# Run Graphsage: 387/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.776
# Run Graphsage: 388/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.758
# Run Graphsage: 389/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.767
# Run Graphsage: 390/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.754
# Run Graphsage: 391/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.75
# Run Graphsage: 392/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.757
# Run Graphsage: 393/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.751
# Run Graphsage: 394/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.745
# Run Graphsage: 395/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.751
# Run Graphsage: 396/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.747
# Run Graphsage: 397/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.776
# Run Graphsage: 398/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run Graphsage: 399/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.769
# Run Graphsage: 400/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.762
# Run Graphsage: 401/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.762
# Run Graphsage: 402/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.775
# Run Graphsage: 403/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.749
# Run Graphsage: 404/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.747
# Run Graphsage: 405/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.664
# Run Graphsage: 406/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.649
# Run Graphsage: 407/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.662
# Run Graphsage: 408/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.666
# Run Graphsage: 409/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.782
# Run Graphsage: 410/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.759
# Run Graphsage: 411/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.751
# Run Graphsage: 412/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.767
# Run Graphsage: 413/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.757
# Run Graphsage: 414/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.747
# Run Graphsage: 415/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.761
# Run Graphsage: 416/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.742
# Run Graphsage: 417/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.714
# Run Graphsage: 418/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.708
# Run Graphsage: 419/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.719
# Run Graphsage: 420/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.706
# Run Graphsage: 421/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.776
# Run Graphsage: 422/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.754
# Run Graphsage: 423/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.765
# Run Graphsage: 424/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.764
# Run Graphsage: 425/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 426/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.774
# Run Graphsage: 427/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.75
# Run Graphsage: 428/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.724
# Run Graphsage: 429/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.525
# Run Graphsage: 430/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.547
# Run Graphsage: 431/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.589
# Run Graphsage: 432/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.582
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_removal__strategy-nodes__noise...              0.796
# 1    noise_type-edge_removal__strategy-nodes__noise...               0.79
# 2    noise_type-edge_removal__strategy-nodes__noise...               0.79
# 3    noise_type-edge_removal__strategy-nodes__noise...               0.79
# 4    noise_type-edge_removal__strategy-nodes__noise...                0.8
# ..                                                 ...                ...
# 427  noise_type-edge_removal__strategy-nodes__noise...              0.724
# 428  noise_type-edge_removal__strategy-nodes__noise...              0.525
# 429  noise_type-edge_removal__strategy-nodes__noise...              0.547
# 430  noise_type-edge_removal__strategy-nodes__noise...              0.589
# 431  noise_type-edge_removal__strategy-nodes__noise...              0.582
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0      0.799,0.795,0.792,0.8,0.793          25           5
# 1      0.772,0.787,0.81,0.789,0.79          25           5
# 2     0.792,0.789,0.79,0.787,0.794          25           5
# 3    0.804,0.787,0.796,0.784,0.779          25           5
# 4    0.808,0.794,0.804,0.798,0.796          25           5
# ..                             ...         ...         ...
# 427   0.71,0.743,0.722,0.725,0.718          25           5
# 428  0.537,0.529,0.523,0.536,0.499          25           5
# 429  0.547,0.557,0.545,0.546,0.542          25           5
# 430  0.582,0.586,0.595,0.592,0.591          25           5
# 431  0.586,0.585,0.585,0.592,0.564          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info    noise_type strategy  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# ..                                                 ...           ...      ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
#
#     noise_level bidirectional choose_type k_nodes node_percent
# 0             0         False    bottom_k     135         0.05
# 1          0.01         False    bottom_k     135         0.05
# 2          0.05         False    bottom_k     135         0.05
# 3           0.1         False    bottom_k     135         0.05
# 4          0.15         False    bottom_k     135         0.05
# ..          ...           ...         ...     ...          ...
# 427         0.6         False    bottom_k    2708            1
# 428         0.9         False    bottom_k    2708            1
# 429        0.95         False    bottom_k    2708            1
# 430        0.99         False    bottom_k    2708            1
# 431           1         False    bottom_k    2708            1
#
# [432 rows x 17 columns]

# %% [markdown]
# ### Experiment 7 - Add Edges: random nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_7_add_random_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'random'}

noise_info = {'noise_type':'edge_addition', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent':nodes_percent,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10558], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10586], noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10596], noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10690], noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10830], noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 10982], noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11284], noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11260], noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11226], noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05=[2, 11734], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10580], noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10624], noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 10890], noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 11144], noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 11556], noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12002], noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12200], noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 12226], noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1=[2, 13004], noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10556], noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2=[2, 10578], noise_type-edge_addition__strateg ...
# Run GNN: 1/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 2/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.805
# Run GNN: 3/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.804
# Run GNN: 4/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 5/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.795
# Run GNN: 6/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 7/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.8
# Run GNN: 8/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 9/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 10/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 11/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.803
# Run GNN: 12/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.787
# Run GNN: 13/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 14/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 15/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.804
# Run GNN: 16/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.802
# Run GNN: 17/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.798
# Run GNN: 18/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 19/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 20/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.809
# Run GNN: 21/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.772
# Run GNN: 22/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.786
# Run GNN: 23/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 24/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 25/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 26/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.793
# Run GNN: 27/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 28/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.8
# Run GNN: 29/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.807
# Run GNN: 30/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.801
# Run GNN: 31/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.787
# Run GNN: 32/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.793
# Run GNN: 33/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.783
# Run GNN: 34/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.781
# Run GNN: 35/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.792
# Run GNN: 36/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.777
# Run GNN: 37/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 38/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.798
# Run GNN: 39/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.796
# Run GNN: 40/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.803
# Run GNN: 41/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.798
# Run GNN: 42/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.79
# Run GNN: 43/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.79
# Run GNN: 44/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.782
# Run GNN: 45/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.783
# Run GNN: 46/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.779
# Run GNN: 47/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.776
# Run GNN: 48/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.772
# Run GNN: 49/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.795
# Run GNN: 50/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.795
# Run GNN: 51/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.798
# Run GNN: 52/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.789
# Run GNN: 53/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.803
# Run GNN: 54/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.784
# Run GNN: 55/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.792
# Run GNN: 56/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.765
# Run GNN: 57/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GNN: 58/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GNN: 59/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.755
# Run GNN: 60/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.752
# Run GNN: 61/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.798
# Run GNN: 62/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.793
# Run GNN: 63/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.804
# Run GNN: 64/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.799
# Run GNN: 65/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.791
# Run GNN: 66/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.781
# Run GNN: 67/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.771
# Run GNN: 68/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.776
# Run GNN: 69/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.752
# Run GNN: 70/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GNN: 71/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.766
# Run GNN: 72/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.74
# Run GNN: 73/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 74/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.793
# Run GNN: 75/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 76/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.8
# Run GNN: 77/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.789
# Run GNN: 78/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 79/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.78
# Run GNN: 80/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.771
# Run GNN: 81/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.751
# Run GNN: 82/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.766
# Run GNN: 83/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.736
# Run GNN: 84/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.72
# Run GNN: 85/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.796
# Run GNN: 86/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.793
# Run GNN: 87/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.801
# Run GNN: 88/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.796
# Run GNN: 89/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.801
# Run GNN: 90/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.79
# Run GNN: 91/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GNN: 92/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.756
# Run GNN: 93/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.724
# Run GNN: 94/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.757
# Run GNN: 95/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.742
# Run GNN: 96/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.711
# Run GNN: 97/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.794
# Run GNN: 98/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.8
# Run GNN: 99/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.799
# Run GNN: 100/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.791
# Run GNN: 101/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.796
# Run GNN: 102/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.765
# Run GNN: 103/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GNN: 104/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GNN: 105/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run GNN: 106/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.751
# Run GNN: 107/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.736
# Run GNN: 108/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.744
# Run GNN: 109/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.797
# Run GNN: 110/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.802
# Run GNN: 111/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 112/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 113/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.794
# Run GNN: 114/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.764
# Run GNN: 115/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.755
# Run GNN: 116/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.763
# Run GNN: 117/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.731
# Run GNN: 118/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.745
# Run GNN: 119/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.701
# Run GNN: 120/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.718
# Run GNN: 121/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.8
# Run GNN: 122/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.799
# Run GNN: 123/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 124/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.786
# Run GNN: 125/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.8
# Run GNN: 126/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 127/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.758
# Run GNN: 128/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.756
# Run GNN: 129/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.746
# Run GNN: 130/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.758
# Run GNN: 131/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.723
# Run GNN: 132/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.727
# Run GNN: 133/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.797
# Run GNN: 134/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.798
# Run GNN: 135/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.801
# Run GNN: 136/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.8
# Run GNN: 137/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.798
# Run GNN: 138/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.775
# Run GNN: 139/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.75
# Run GNN: 140/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run GNN: 141/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.709
# Run GNN: 142/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.701
# Run GNN: 143/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.757
# Run GNN: 144/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.72
# Run GAT: 145/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.777
# Run GAT: 146/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.769
# Run GAT: 147/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.748
# Run GAT: 148/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.764
# Run GAT: 149/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.758
# Run GAT: 150/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.744
# Run GAT: 151/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.758
# Run GAT: 152/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.76
# Run GAT: 153/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.731
# Run GAT: 154/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.765
# Run GAT: 155/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.759
# Run GAT: 156/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.74
# Run GAT: 157/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.763
# Run GAT: 158/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.769
# Run GAT: 159/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.781
# Run GAT: 160/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.749
# Run GAT: 161/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 162/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.743
# Run GAT: 163/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.739
# Run GAT: 164/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.722
# Run GAT: 165/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.724
# Run GAT: 166/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.758
# Run GAT: 167/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.756
# Run GAT: 168/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.74
# Run GAT: 169/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.79
# Run GAT: 170/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.759
# Run GAT: 171/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.74
# Run GAT: 172/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.757
# Run GAT: 173/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.761
# Run GAT: 174/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.771
# Run GAT: 175/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.75
# Run GAT: 176/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.716
# Run GAT: 177/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.691
# Run GAT: 178/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.746
# Run GAT: 179/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.702
# Run GAT: 180/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.721
# Run GAT: 181/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.75
# Run GAT: 182/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.783
# Run GAT: 183/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.786
# Run GAT: 184/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.747
# Run GAT: 185/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.786
# Run GAT: 186/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.757
# Run GAT: 187/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.765
# Run GAT: 188/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.725
# Run GAT: 189/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.725
# Run GAT: 190/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.722
# Run GAT: 191/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.727
# Run GAT: 192/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.649
# Run GAT: 193/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.75
# Run GAT: 194/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.77
# Run GAT: 195/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.765
# Run GAT: 196/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.773
# Run GAT: 197/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.762
# Run GAT: 198/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.737
# Run GAT: 199/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.711
# Run GAT: 200/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.704
# Run GAT: 201/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.669
# Run GAT: 202/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.691
# Run GAT: 203/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.719
# Run GAT: 204/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.714
# Run GAT: 205/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.739
# Run GAT: 206/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.776
# Run GAT: 207/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.763
# Run GAT: 208/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.752
# Run GAT: 209/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.747
# Run GAT: 210/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.749
# Run GAT: 211/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.737
# Run GAT: 212/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.663
# Run GAT: 213/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.67
# Run GAT: 214/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.605
# Run GAT: 215/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.707
# Run GAT: 216/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.664
# Run GAT: 217/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.75
# Run GAT: 218/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.744
# Run GAT: 219/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.755
# Run GAT: 220/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.756
# Run GAT: 221/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.774
# Run GAT: 222/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.742
# Run GAT: 223/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.732
# Run GAT: 224/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.658
# Run GAT: 225/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.664
# Run GAT: 226/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.605
# Run GAT: 227/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.605
# Run GAT: 228/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.635
# Run GAT: 229/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.752
# Run GAT: 230/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run GAT: 231/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.77
# Run GAT: 232/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run GAT: 233/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.738
# Run GAT: 234/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run GAT: 235/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.687
# Run GAT: 236/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.65
# Run GAT: 237/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.639
# Run GAT: 238/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.636
# Run GAT: 239/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.681
# Run GAT: 240/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.639
# Run GAT: 241/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GAT: 242/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GAT: 243/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.747
# Run GAT: 244/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.766
# Run GAT: 245/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.771
# Run GAT: 246/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.69
# Run GAT: 247/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.677
# Run GAT: 248/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.709
# ...
# Run Graphsage: 372/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.738
# Run Graphsage: 373/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.783
# Run Graphsage: 374/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run Graphsage: 375/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.786
# Run Graphsage: 376/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.773
# Run Graphsage: 377/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.774
# Run Graphsage: 378/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.768
# Run Graphsage: 379/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.769
# Run Graphsage: 380/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.754
# Run Graphsage: 381/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.747
# Run Graphsage: 382/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.744
# Run Graphsage: 383/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.736
# Run Graphsage: 384/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.736
# Run Graphsage: 385/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.774
# Run Graphsage: 386/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run Graphsage: 387/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.776
# Run Graphsage: 388/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run Graphsage: 389/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.776
# Run Graphsage: 390/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.762
# Run Graphsage: 391/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run Graphsage: 392/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.741
# Run Graphsage: 393/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.736
# Run Graphsage: 394/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.741
# Run Graphsage: 395/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.733
# Run Graphsage: 396/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.724
# Run Graphsage: 397/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.779
# Run Graphsage: 398/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.771
# Run Graphsage: 399/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.777
# Run Graphsage: 400/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.771
# Run Graphsage: 401/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.774
# Run Graphsage: 402/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 403/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.755
# Run Graphsage: 404/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.742
# Run Graphsage: 405/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.731
# Run Graphsage: 406/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.722
# Run Graphsage: 407/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.733
# Run Graphsage: 408/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.731
# Run Graphsage: 409/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.771
# Run Graphsage: 410/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.779
# Run Graphsage: 411/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.778
# Run Graphsage: 412/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.773
# Run Graphsage: 413/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.776
# Run Graphsage: 414/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.766
# Run Graphsage: 415/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.754
# Run Graphsage: 416/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.753
# Run Graphsage: 417/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.741
# Run Graphsage: 418/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.725
# Run Graphsage: 419/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.718
# Run Graphsage: 420/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.721
# Run Graphsage: 421/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.776
# Run Graphsage: 422/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.783
# Run Graphsage: 423/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.777
# Run Graphsage: 424/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.77
# Run Graphsage: 425/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.776
# Run Graphsage: 426/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.762
# Run Graphsage: 427/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.744
# Run Graphsage: 428/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.733
# Run Graphsage: 429/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.733
# Run Graphsage: 430/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.727
# Run Graphsage: 431/432: x - noise_type-edge_addition__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.739
# Run Graphsage: 432/432: x - noise_type-edge_addition__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.702
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_addition__strategy-nodes__nois...              0.794
# 1    noise_type-edge_addition__strategy-nodes__nois...              0.805
# 2    noise_type-edge_addition__strategy-nodes__nois...              0.804
# 3    noise_type-edge_addition__strategy-nodes__nois...              0.791
# 4    noise_type-edge_addition__strategy-nodes__nois...              0.795
# ..                                                 ...                ...
# 427  noise_type-edge_addition__strategy-nodes__nois...              0.733
# 428  noise_type-edge_addition__strategy-nodes__nois...              0.733
# 429  noise_type-edge_addition__strategy-nodes__nois...              0.727
# 430  noise_type-edge_addition__strategy-nodes__nois...              0.739
# 431  noise_type-edge_addition__strategy-nodes__nois...              0.702
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0    0.802,0.769,0.798,0.806,0.795          25           5
# 1      0.8,0.812,0.793,0.808,0.811          25           5
# 2      0.795,0.788,0.82,0.805,0.81          25           5
# 3    0.792,0.807,0.796,0.781,0.781          25           5
# 4    0.787,0.799,0.798,0.794,0.799          25           5
# ..                             ...         ...         ...
# 427  0.757,0.737,0.713,0.718,0.738          25           5
# 428   0.729,0.735,0.737,0.74,0.724          25           5
# 429  0.731,0.722,0.725,0.728,0.728          25           5
# 430    0.742,0.744,0.7,0.746,0.763          25           5
# 431  0.701,0.708,0.709,0.685,0.705          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info     noise_type  \
# 0    {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 1    {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 2    {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 3    {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 4    {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# ..                                                 ...            ...
# 427  {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 428  {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 429  {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 430  {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
# 431  {'noise_type': 'edge_addition', 'strategy': 'n...  edge_addition
#
#     strategy noise_level bidirectional choose_type k_nodes node_percent
# 0      nodes           0          True      random     135         0.05
# 1      nodes        0.01          True      random     135         0.05
# 2      nodes        0.05          True      random     135         0.05
# 3      nodes         0.1          True      random     135         0.05
# 4      nodes        0.15          True      random     135         0.05
# ..       ...         ...           ...         ...     ...          ...
# 427    nodes         0.6          True      random    2708            1
# 428    nodes         0.9          True      random    2708            1
# 429    nodes        0.95          True      random    2708            1
# 430    nodes        0.99          True      random    2708            1
# 431    nodes           1          True      random    2708            1
#
# [432 rows x 17 columns]

# %% [markdown]
# ### Experiment 8 - Add Edges: topk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_8_add_topk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_addition', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent':nodes_percent,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 2/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 3/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.801
# Run GNN: 4/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 5/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.787
# Run GNN: 6/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 7/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 8/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.784
# Run GNN: 9/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.78
# Run GNN: 10/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 11/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.775
# Run GNN: 12/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.778
# Run GNN: 13/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 14/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.798
# Run GNN: 15/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.795
# Run GNN: 16/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 17/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.798
# Run GNN: 18/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 19/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 20/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.782
# Run GNN: 21/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GNN: 22/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.768
# Run GNN: 23/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.78
# Run GNN: 24/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.779
# Run GNN: 25/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 26/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.795
# Run GNN: 27/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.804
# Run GNN: 28/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.791
# Run GNN: 29/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.802
# Run GNN: 30/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.802
# Run GNN: 31/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.794
# Run GNN: 32/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.791
# Run GNN: 33/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.774
# Run GNN: 34/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.752
# Run GNN: 35/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.766
# Run GNN: 36/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.77
# Run GNN: 37/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.798
# Run GNN: 38/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.797
# Run GNN: 39/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.802
# Run GNN: 40/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.807
# Run GNN: 41/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.797
# Run GNN: 42/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.782
# Run GNN: 43/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.799
# Run GNN: 44/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.784
# Run GNN: 45/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.799
# Run GNN: 46/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.78
# Run GNN: 47/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.786
# Run GNN: 48/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.77
# Run GNN: 49/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.797
# Run GNN: 50/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.799
# Run GNN: 51/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.797
# Run GNN: 52/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.808
# Run GNN: 53/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.806
# Run GNN: 54/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.784
# Run GNN: 55/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.775
# Run GNN: 56/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.801
# Run GNN: 57/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.742
# Run GNN: 58/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.761
# Run GNN: 59/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.756
# Run GNN: 60/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.768
# Run GNN: 61/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.797
# Run GNN: 62/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.806
# Run GNN: 63/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.804
# Run GNN: 64/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.796
# Run GNN: 65/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 66/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 67/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.784
# Run GNN: 68/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.769
# Run GNN: 69/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.768
# Run GNN: 70/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.756
# Run GNN: 71/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.732
# Run GNN: 72/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.75
# Run GNN: 73/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 74/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 75/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.792
# Run GNN: 76/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.807
# Run GNN: 77/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 78/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 79/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.758
# Run GNN: 80/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.746
# Run GNN: 81/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.701
# Run GNN: 82/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.729
# Run GNN: 83/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.711
# Run GNN: 84/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.71
# Run GNN: 85/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.797
# Run GNN: 86/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.789
# Run GNN: 87/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.799
# Run GNN: 88/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.792
# Run GNN: 89/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.789
# Run GNN: 90/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.786
# Run GNN: 91/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.781
# Run GNN: 92/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GNN: 93/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.741
# Run GNN: 94/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.718
# Run GNN: 95/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.718
# Run GNN: 96/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.71
# Run GNN: 97/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.799
# Run GNN: 98/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run GNN: 99/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.781
# Run GNN: 100/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.759
# Run GNN: 101/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.796
# Run GNN: 102/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.79
# Run GNN: 103/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.745
# Run GNN: 104/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.758
# Run GNN: 105/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.718
# Run GNN: 106/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.729
# Run GNN: 107/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.741
# Run GNN: 108/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.71
# Run GNN: 109/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.801
# Run GNN: 110/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 111/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 112/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.777
# Run GNN: 113/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.804
# Run GNN: 114/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.779
# Run GNN: 115/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.765
# Run GNN: 116/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.753
# Run GNN: 117/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.745
# Run GNN: 118/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.733
# Run GNN: 119/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.731
# Run GNN: 120/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.727
# Run GNN: 121/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.79
# Run GNN: 122/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.8
# Run GNN: 123/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.798
# Run GNN: 124/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.786
# Run GNN: 125/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.768
# Run GNN: 126/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 127/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.747
# Run GNN: 128/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.766
# Run GNN: 129/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.723
# Run GNN: 130/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.734
# Run GNN: 131/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.724
# Run GNN: 132/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.727
# Run GNN: 133/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.797
# Run GNN: 134/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.787
# Run GNN: 135/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.798
# Run GNN: 136/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.785
# Run GNN: 137/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.787
# Run GNN: 138/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.782
# Run GNN: 139/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.714
# Run GNN: 140/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.769
# Run GNN: 141/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.727
# Run GNN: 142/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.721
# Run GNN: 143/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.731
# Run GNN: 144/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.725
# Run GAT: 145/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.767
# Run GAT: 146/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.735
# Run GAT: 147/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.76
# Run GAT: 148/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.782
# Run GAT: 149/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.757
# Run GAT: 150/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.74
# Run GAT: 151/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.764
# Run GAT: 152/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.762
# Run GAT: 153/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.74
# Run GAT: 154/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.754
# Run GAT: 155/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.731
# Run GAT: 156/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.729
# Run GAT: 157/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 158/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.759
# Run GAT: 159/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.751
# Run GAT: 160/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.754
# Run GAT: 161/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.782
# Run GAT: 162/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.746
# Run GAT: 163/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.758
# Run GAT: 164/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.732
# Run GAT: 165/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.727
# Run GAT: 166/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.723
# Run GAT: 167/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.74
# Run GAT: 168/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.761
# Run GAT: 169/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.727
# Run GAT: 170/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.75
# Run GAT: 171/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.752
# Run GAT: 172/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.761
# Run GAT: 173/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.748
# Run GAT: 174/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.757
# Run GAT: 175/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.762
# Run GAT: 176/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.744
# Run GAT: 177/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.716
# Run GAT: 178/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.744
# Run GAT: 179/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.723
# Run GAT: 180/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.749
# Run GAT: 181/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.768
# Run GAT: 182/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.756
# Run GAT: 183/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.772
# Run GAT: 184/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.762
# Run GAT: 185/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.769
# Run GAT: 186/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.717
# Run GAT: 187/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.764
# Run GAT: 188/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.735
# Run GAT: 189/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.732
# Run GAT: 190/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.755
# Run GAT: 191/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.749
# Run GAT: 192/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.751
# Run GAT: 193/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.76
# Run GAT: 194/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.74
# Run GAT: 195/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.752
# Run GAT: 196/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.745
# Run GAT: 197/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.764
# Run GAT: 198/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.742
# Run GAT: 199/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.752
# Run GAT: 200/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.757
# Run GAT: 201/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.733
# Run GAT: 202/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.748
# Run GAT: 203/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.742
# Run GAT: 204/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.76
# Run GAT: 205/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GAT: 206/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.757
# Run GAT: 207/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.777
# Run GAT: 208/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.761
# Run GAT: 209/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.785
# Run GAT: 210/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.759
# Run GAT: 211/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.749
# Run GAT: 212/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.745
# Run GAT: 213/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.741
# Run GAT: 214/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.749
# Run GAT: 215/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.728
# Run GAT: 216/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.744
# Run GAT: 217/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.76
# Run GAT: 218/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.775
# Run GAT: 219/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.782
# Run GAT: 220/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.771
# Run GAT: 221/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.744
# Run GAT: 222/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.758
# Run GAT: 223/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.754
# Run GAT: 224/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.732
# Run GAT: 225/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.727
# Run GAT: 226/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.72
# Run GAT: 227/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.725
# Run GAT: 228/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.711
# Run GAT: 229/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.725
# Run GAT: 230/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.748
# Run GAT: 231/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.772
# Run GAT: 232/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run GAT: 233/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run GAT: 234/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.743
# Run GAT: 235/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.744
# Run GAT: 236/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.756
# Run GAT: 237/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.708
# Run GAT: 238/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.713
# Run GAT: 239/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.698
# Run GAT: 240/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.685
# Run GAT: 241/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.778
# Run GAT: 242/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.766
# Run GAT: 243/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.737
# Run GAT: 244/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.754
# Run GAT: 245/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.773
# Run GAT: 246/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.753
# Run GAT: 247/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.735
# Run GAT: 248/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.742
# Run GAT: 249/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.737
# ...
# Run Graphsage: 371/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.663
# Run Graphsage: 372/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.674
# Run Graphsage: 373/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run Graphsage: 374/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run Graphsage: 375/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run Graphsage: 376/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.778
# Run Graphsage: 377/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.773
# Run Graphsage: 378/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.766
# Run Graphsage: 379/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.762
# Run Graphsage: 380/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.752
# Run Graphsage: 381/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.638
# Run Graphsage: 382/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.641
# Run Graphsage: 383/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.631
# Run Graphsage: 384/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.637
# Run Graphsage: 385/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.778
# Run Graphsage: 386/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.77
# Run Graphsage: 387/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.769
# Run Graphsage: 388/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.771
# Run Graphsage: 389/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.78
# Run Graphsage: 390/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.764
# Run Graphsage: 391/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.76
# Run Graphsage: 392/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.727
# Run Graphsage: 393/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.628
# Run Graphsage: 394/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.602
# Run Graphsage: 395/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.607
# Run Graphsage: 396/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.62
# Run Graphsage: 397/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.777
# Run Graphsage: 398/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.766
# Run Graphsage: 399/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.771
# Run Graphsage: 400/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.763
# Run Graphsage: 401/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.774
# Run Graphsage: 402/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.773
# Run Graphsage: 403/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run Graphsage: 404/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.732
# Run Graphsage: 405/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.595
# Run Graphsage: 406/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.576
# Run Graphsage: 407/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.579
# Run Graphsage: 408/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.58
# Run Graphsage: 409/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.776
# Run Graphsage: 410/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.759
# Run Graphsage: 411/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.765
# Run Graphsage: 412/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.759
# Run Graphsage: 413/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.764
# Run Graphsage: 414/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.768
# Run Graphsage: 415/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.718
# Run Graphsage: 416/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.736
# Run Graphsage: 417/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.623
# Run Graphsage: 418/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.575
# Run Graphsage: 419/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.538
# Run Graphsage: 420/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.534
# Run Graphsage: 421/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.782
# Run Graphsage: 422/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 423/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.763
# Run Graphsage: 424/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.752
# Run Graphsage: 425/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.758
# Run Graphsage: 426/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.772
# Run Graphsage: 427/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.736
# Run Graphsage: 428/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.705
# Run Graphsage: 429/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.47
# Run Graphsage: 430/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.428
# Run Graphsage: 431/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.581
# Run Graphsage: 432/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-top_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.587
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_removal__strategy-nodes__noise...              0.793
# 1    noise_type-edge_removal__strategy-nodes__noise...              0.794
# 2    noise_type-edge_removal__strategy-nodes__noise...              0.801
# 3    noise_type-edge_removal__strategy-nodes__noise...              0.797
# 4    noise_type-edge_removal__strategy-nodes__noise...              0.787
# ..                                                 ...                ...
# 427  noise_type-edge_removal__strategy-nodes__noise...              0.705
# 428  noise_type-edge_removal__strategy-nodes__noise...               0.47
# 429  noise_type-edge_removal__strategy-nodes__noise...              0.428
# 430  noise_type-edge_removal__strategy-nodes__noise...              0.581
# 431  noise_type-edge_removal__strategy-nodes__noise...              0.587
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0    0.809,0.784,0.802,0.766,0.805          25           5
# 1    0.794,0.798,0.788,0.795,0.794          25           5
# 2    0.786,0.805,0.801,0.804,0.807          25           5
# 3     0.79,0.804,0.796,0.795,0.801          25           5
# 4    0.792,0.772,0.804,0.782,0.787          25           5
# ..                             ...         ...         ...
# 427  0.726,0.693,0.693,0.702,0.713          25           5
# 428  0.446,0.468,0.465,0.468,0.505          25           5
# 429  0.418,0.456,0.408,0.452,0.407          25           5
# 430  0.586,0.566,0.589,0.574,0.589          25           5
# 431    0.59,0.585,0.593,0.59,0.578          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info    noise_type strategy  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# ..                                                 ...           ...      ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
#
#     noise_level bidirectional choose_type k_nodes node_percent
# 0             0         False       top_k     135         0.05
# 1          0.01         False       top_k     135         0.05
# 2          0.05         False       top_k     135         0.05
# 3           0.1         False       top_k     135         0.05
# 4          0.15         False       top_k     135         0.05
# ..          ...           ...         ...     ...          ...
# 427         0.6         False       top_k    2708            1
# 428         0.9         False       top_k    2708            1
# 429        0.95         False       top_k    2708            1
# 430        0.99         False       top_k    2708            1
# 431           1         False       top_k    2708            1
#
# [432 rows x 17 columns]

# %% [markdown]
# ### Experiment 9 - Add Edges: bottomk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = f'./{folder_name}/Experiment_9_add_bottomk_nodes{post_fix}.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.95, 0.9, 1] #[0.05, 0.1, 0.2, 0.25, 0.4, 0.5]

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':bidirectional_type, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_addition', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'nodes_percent':nodes_percent,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=num_repeat, print_updates=True)

data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent-0.05__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10284], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10288], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10276], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10246], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10198], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 10092], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9938], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9980], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9892], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-135__node_percent0.05=[2, 9970], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10020], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10018], noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10026], noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 10008], noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9952], noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9748], noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9600], noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9508], noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9362], noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-True__choose_type-random__k_nodes-271__node_percent0.1=[2, 9358], noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 10556], noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-True__choose_type-random__k_nodes-542__node_percent0.2=[2, 9496], noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-True__choose_type-random__k_nodes-542__node_p ...
# Run GNN: 1/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 2/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 3/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 4/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 5/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 6/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.788
# Run GNN: 7/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 8/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 9/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.792
# Run GNN: 10/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 11/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 12/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.79
# Run GNN: 13/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 14/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 15/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 16/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 17/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.785
# Run GNN: 18/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.797
# Run GNN: 19/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.788
# Run GNN: 20/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.792
# Run GNN: 21/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 22/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 23/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.79
# Run GNN: 24/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.787
# Run GNN: 25/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.8
# Run GNN: 26/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.796
# Run GNN: 27/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.786
# Run GNN: 28/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 29/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.792
# Run GNN: 30/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.783
# Run GNN: 31/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 32/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.786
# Run GNN: 33/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.783
# Run GNN: 34/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.789
# Run GNN: 35/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.787
# Run GNN: 36/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.793
# Run GNN: 37/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.792
# Run GNN: 38/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.795
# Run GNN: 39/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.787
# Run GNN: 40/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.787
# Run GNN: 41/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.792
# Run GNN: 42/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.783
# Run GNN: 43/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.791
# Run GNN: 44/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.788
# Run GNN: 45/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.785
# Run GNN: 46/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 47/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.789
# Run GNN: 48/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.787
# Run GNN: 49/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.804
# Run GNN: 50/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.787
# Run GNN: 51/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.791
# Run GNN: 52/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.793
# Run GNN: 53/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.785
# Run GNN: 54/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.793
# Run GNN: 55/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.791
# Run GNN: 56/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.791
# Run GNN: 57/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.795
# Run GNN: 58/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.791
# Run GNN: 59/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.784
# Run GNN: 60/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.785
# Run GNN: 61/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.801
# Run GNN: 62/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 63/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 64/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.79
# Run GNN: 65/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.793
# Run GNN: 66/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.794
# Run GNN: 67/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.786
# Run GNN: 68/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.781
# Run GNN: 69/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.789
# Run GNN: 70/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.787
# Run GNN: 71/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.783
# Run GNN: 72/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.791
# Run GNN: 73/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 74/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.784
# Run GNN: 75/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.786
# Run GNN: 76/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 77/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 78/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.779
# Run GNN: 79/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.773
# Run GNN: 80/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.788
# Run GNN: 81/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.773
# Run GNN: 82/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.769
# Run GNN: 83/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.771
# Run GNN: 84/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.767
# Run GNN: 85/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.8
# Run GNN: 86/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 87/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.786
# Run GNN: 88/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.796
# Run GNN: 89/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.79
# Run GNN: 90/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run GNN: 91/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.777
# Run GNN: 92/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.781
# Run GNN: 93/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.761
# Run GNN: 94/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.768
# Run GNN: 95/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run GNN: 96/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.761
# Run GNN: 97/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.805
# Run GNN: 98/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.792
# Run GNN: 99/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.779
# Run GNN: 100/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.792
# Run GNN: 101/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.778
# Run GNN: 102/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.794
# Run GNN: 103/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.758
# Run GNN: 104/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.768
# Run GNN: 105/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.761
# Run GNN: 106/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.754
# Run GNN: 107/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.76
# Run GNN: 108/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.745
# Run GNN: 109/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 110/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.791
# Run GNN: 111/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.784
# Run GNN: 112/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.789
# Run GNN: 113/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 114/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.778
# Run GNN: 115/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.785
# Run GNN: 116/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.773
# Run GNN: 117/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run GNN: 118/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.752
# Run GNN: 119/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.752
# Run GNN: 120/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run GNN: 121/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.798
# Run GNN: 122/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.787
# Run GNN: 123/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.784
# Run GNN: 124/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.785
# Run GNN: 125/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.785
# Run GNN: 126/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.781
# Run GNN: 127/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.754
# Run GNN: 128/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 129/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.764
# Run GNN: 130/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.75
# Run GNN: 131/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.761
# Run GNN: 132/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.764
# Run GNN: 133/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.806
# Run GNN: 134/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.797
# Run GNN: 135/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.786
# Run GNN: 136/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.779
# Run GNN: 137/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.798
# Run GNN: 138/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run GNN: 139/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.771
# Run GNN: 140/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.769
# Run GNN: 141/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.726
# Run GNN: 142/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.732
# Run GNN: 143/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.739
# Run GNN: 144/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.735
# Run GAT: 145/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.744
# Run GAT: 146/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.764
# Run GAT: 147/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.762
# Run GAT: 148/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.766
# Run GAT: 149/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.716
# Run GAT: 150/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.769
# Run GAT: 151/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.753
# Run GAT: 152/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.77
# Run GAT: 153/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.76
# Run GAT: 154/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.75
# Run GAT: 155/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.759
# Run GAT: 156/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-135__node_percent-0.05 Avg. Test Accuracy: 0.77
# Run GAT: 157/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.762
# Run GAT: 158/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.74
# Run GAT: 159/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 160/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.752
# Run GAT: 161/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.75
# Run GAT: 162/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.748
# Run GAT: 163/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.753
# Run GAT: 164/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.758
# Run GAT: 165/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.745
# Run GAT: 166/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.759
# Run GAT: 167/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.743
# Run GAT: 168/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-271__node_percent-0.1 Avg. Test Accuracy: 0.766
# Run GAT: 169/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.754
# Run GAT: 170/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.761
# Run GAT: 171/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.759
# Run GAT: 172/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.758
# Run GAT: 173/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.756
# Run GAT: 174/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.766
# Run GAT: 175/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.77
# Run GAT: 176/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.763
# Run GAT: 177/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.741
# Run GAT: 178/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.767
# Run GAT: 179/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.772
# Run GAT: 180/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-542__node_percent-0.2 Avg. Test Accuracy: 0.761
# Run GAT: 181/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.767
# Run GAT: 182/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.774
# Run GAT: 183/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.772
# Run GAT: 184/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.783
# Run GAT: 185/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.771
# Run GAT: 186/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.781
# Run GAT: 187/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.752
# Run GAT: 188/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.785
# Run GAT: 189/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.761
# Run GAT: 190/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.759
# Run GAT: 191/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.776
# Run GAT: 192/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-677__node_percent-0.25 Avg. Test Accuracy: 0.757
# Run GAT: 193/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.772
# Run GAT: 194/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.762
# Run GAT: 195/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.749
# Run GAT: 196/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.773
# Run GAT: 197/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.738
# Run GAT: 198/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.766
# Run GAT: 199/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.759
# Run GAT: 200/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.763
# Run GAT: 201/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.728
# Run GAT: 202/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.765
# Run GAT: 203/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.755
# Run GAT: 204/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1083__node_percent-0.4 Avg. Test Accuracy: 0.761
# Run GAT: 205/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.739
# Run GAT: 206/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.772
# Run GAT: 207/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.739
# Run GAT: 208/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.753
# Run GAT: 209/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.758
# Run GAT: 210/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.756
# Run GAT: 211/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.746
# Run GAT: 212/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.757
# Run GAT: 213/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.759
# Run GAT: 214/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.749
# Run GAT: 215/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.761
# Run GAT: 216/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1354__node_percent-0.5 Avg. Test Accuracy: 0.771
# Run GAT: 217/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.742
# Run GAT: 218/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.763
# Run GAT: 219/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.778
# Run GAT: 220/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.746
# Run GAT: 221/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.759
# Run GAT: 222/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.733
# Run GAT: 223/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.755
# Run GAT: 224/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.746
# Run GAT: 225/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.746
# Run GAT: 226/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.743
# Run GAT: 227/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.731
# Run GAT: 228/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.739
# Run GAT: 229/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.774
# Run GAT: 230/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.762
# Run GAT: 231/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run GAT: 232/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.769
# Run GAT: 233/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.772
# Run GAT: 234/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.746
# Run GAT: 235/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run GAT: 236/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.767
# Run GAT: 237/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.761
# Run GAT: 238/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.774
# Run GAT: 239/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.755
# Run GAT: 240/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.764
# Run GAT: 241/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.745
# Run GAT: 242/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.766
# Run GAT: 243/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.755
# Run GAT: 244/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.746
# Run GAT: 245/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.769
# ...
# Run Graphsage: 372/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1625__node_percent-0.6 Avg. Test Accuracy: 0.744
# Run Graphsage: 373/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.784
# Run Graphsage: 374/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.759
# Run Graphsage: 375/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.771
# Run Graphsage: 376/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.768
# Run Graphsage: 377/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.765
# Run Graphsage: 378/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.755
# Run Graphsage: 379/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.753
# Run Graphsage: 380/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.756
# Run Graphsage: 381/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.735
# Run Graphsage: 382/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.752
# Run Graphsage: 383/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.745
# Run Graphsage: 384/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-1896__node_percent-0.7 Avg. Test Accuracy: 0.747
# Run Graphsage: 385/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.776
# Run Graphsage: 386/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.772
# Run Graphsage: 387/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.763
# Run Graphsage: 388/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.761
# Run Graphsage: 389/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.763
# Run Graphsage: 390/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.772
# Run Graphsage: 391/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.761
# Run Graphsage: 392/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.747
# Run Graphsage: 393/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.752
# Run Graphsage: 394/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.76
# Run Graphsage: 395/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.749
# Run Graphsage: 396/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2166__node_percent-0.8 Avg. Test Accuracy: 0.748
# Run Graphsage: 397/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.779
# Run Graphsage: 398/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.757
# Run Graphsage: 399/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.758
# Run Graphsage: 400/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.758
# Run Graphsage: 401/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.762
# Run Graphsage: 402/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.766
# Run Graphsage: 403/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.761
# Run Graphsage: 404/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.736
# Run Graphsage: 405/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.656
# Run Graphsage: 406/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.655
# Run Graphsage: 407/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.658
# Run Graphsage: 408/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2573__node_percent-0.95 Avg. Test Accuracy: 0.655
# Run Graphsage: 409/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.78
# Run Graphsage: 410/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.765
# Run Graphsage: 411/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.763
# Run Graphsage: 412/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.759
# Run Graphsage: 413/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.766
# Run Graphsage: 414/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.762
# Run Graphsage: 415/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.745
# Run Graphsage: 416/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.752
# Run Graphsage: 417/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.702
# Run Graphsage: 418/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.701
# Run Graphsage: 419/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.714
# Run Graphsage: 420/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2437__node_percent-0.9 Avg. Test Accuracy: 0.7
# Run Graphsage: 421/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.772
# Run Graphsage: 422/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.01__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.768
# Run Graphsage: 423/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.05__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.757
# Run Graphsage: 424/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.765
# Run Graphsage: 425/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.15__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.761
# Run Graphsage: 426/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.3__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.765
# Run Graphsage: 427/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.45__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 428/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.6__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.733
# Run Graphsage: 429/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.9__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.551
# Run Graphsage: 430/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.95__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.562
# Run Graphsage: 431/432: x - noise_type-edge_removal__strategy-nodes__noise_level-0.99__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.584
# Run Graphsage: 432/432: x - noise_type-edge_removal__strategy-nodes__noise_level-1__bidirectional-False__choose_type-bottom_k__k_nodes-2708__node_percent-1 Avg. Test Accuracy: 0.579
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 427         Cora  Graphsage      x
# 428         Cora  Graphsage      x
# 429         Cora  Graphsage      x
# 430         Cora  Graphsage      x
# 431         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    noise_type-edge_removal__strategy-nodes__noise...              0.796
# 1    noise_type-edge_removal__strategy-nodes__noise...              0.794
# 2    noise_type-edge_removal__strategy-nodes__noise...              0.791
# 3    noise_type-edge_removal__strategy-nodes__noise...              0.792
# 4    noise_type-edge_removal__strategy-nodes__noise...              0.791
# ..                                                 ...                ...
# 427  noise_type-edge_removal__strategy-nodes__noise...              0.733
# 428  noise_type-edge_removal__strategy-nodes__noise...              0.551
# 429  noise_type-edge_removal__strategy-nodes__noise...              0.562
# 430  noise_type-edge_removal__strategy-nodes__noise...              0.584
# 431  noise_type-edge_removal__strategy-nodes__noise...              0.579
#
#                    test_accuracies  num_epochs  repeat_num  \
# 0     0.792,0.805,0.79,0.808,0.786          25           5
# 1      0.783,0.801,0.796,0.792,0.8          25           5
# 2    0.784,0.786,0.791,0.799,0.794          25           5
# 3    0.778,0.797,0.797,0.796,0.793          25           5
# 4     0.769,0.799,0.79,0.798,0.799          25           5
# ..                             ...         ...         ...
# 427   0.713,0.75,0.731,0.734,0.736          25           5
# 428  0.521,0.535,0.582,0.567,0.552          25           5
# 429  0.542,0.573,0.562,0.572,0.561          25           5
# 430  0.592,0.579,0.587,0.577,0.584          25           5
# 431  0.584,0.587,0.583,0.571,0.571          25           5
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 427  {'in_channels': 1433, 'hidden_channels': 42, '...
# 428  {'in_channels': 1433, 'hidden_channels': 42, '...
# 429  {'in_channels': 1433, 'hidden_channels': 42, '...
# 430  {'in_channels': 1433, 'hidden_channels': 42, '...
# 431  {'in_channels': 1433, 'hidden_channels': 42, '...
#
#                                             noise_info    noise_type strategy  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# ..                                                 ...           ...      ...
# 427  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 428  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 429  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 430  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
# 431  {'noise_type': 'edge_removal', 'strategy': 'no...  edge_removal    nodes
#
#     noise_level bidirectional choose_type k_nodes node_percent
# 0             0         False    bottom_k     135         0.05
# 1          0.01         False    bottom_k     135         0.05
# 2          0.05         False    bottom_k     135         0.05
# 3           0.1         False    bottom_k     135         0.05
# 4          0.15         False    bottom_k     135         0.05
# ..          ...           ...         ...     ...          ...
# 427         0.6         False    bottom_k    2708            1
# 428         0.9         False    bottom_k    2708            1
# 429        0.95         False    bottom_k    2708            1
# 430        0.99         False    bottom_k    2708            1
# 431           1         False    bottom_k    2708            1
#
# [432 rows x 17 columns]

# %%
#import shutil
#shutil.make_archive('results_v5', 'zip', 'results_v5')
# Out:
# '/content/results_v4.zip'
