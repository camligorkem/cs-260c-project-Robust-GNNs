# %%
import pickle

# %%
# Install required packages.
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
#      |████████████████████████████████| 7.9 MB 5.0 MB/s
#      |████████████████████████████████| 3.5 MB 3.9 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch 
import numpy as np
import math
import torch.nn as nn
import torch.optim as optim

from torch_geometric.utils import degree
import torch_geometric
import torch_geometric.utils as tg_utils

# %%
# !rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %%
# !pip install class_resolver
# Out:
# Collecting class_resolver
#   Downloading class_resolver-0.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: class-resolver
# Successfully installed class-resolver-0.3.4

# %%
# reuse train and test
def train(model, optimizer, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  model.train()
  optimizer.zero_grad()  # Clear gradients.
  out = model(data[x_type].to(device), data[edge_type].to(device))  # Perform a single forward pass.
  loss = criterion(out[data.train_mask].to(device), data.y[data.train_mask].to(device))  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

def test(model, x_type='x', edge_type='edge_index'):
  model.eval()
  out = model(data[x_type].to(device), data[edge_type].to(device))
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  test_correct = pred[data.test_mask] == data.y[data.test_mask].to(device)  # Check against ground-truth labels.
  test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
  return test_acc

# %%
def experiment(model, lr, data, num_epochs=25, repeat_num=1, print_updates=False):
  '''
  Assumes the noisy data is already created and inside the data object (so that we can use same data sample for different models to compare)
  '''
           
  model =  model
  optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4) # parametrize similar to model later TODO
  for epoch in range(num_epochs):
    loss = train(model, optimizer)
              # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

          # we test our results in original data, no noise added ones 
          # if you want to test on noised data change them to x_type=x_type and edge_type=ed_type below
    test_acc = test(model, x_type='x',edge_type='edge_index') 
    print(f"Test accuracy at epoch {epoch}: {test_acc:.4f}")
    grid_search_solution[(h_c, n_l, o_c, d, lr, epoch, iter)] = test_acc
    if print_updates:
        print(f'Exp_num:{epoch} Test Accuracy: {test_acc:.4f}')

  return test_acc

# %%
# !pip install class_resolver
# Out:
# Requirement already satisfied: class_resolver in /usr/local/lib/python3.7/dist-packages (0.3.4)

# %%
## model parameter results
import time
import pickle
from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT
from torch_geometric.datasets import Planetoid, Coauthor, Amazon
from torch_geometric.transforms import NormalizeFeatures

startTime = time.time()
dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())
data = dataset[0]

# dataset = load_data('CoraSmall', transform = True)
# data = dataset[0]
# data = get_train_mask(data, debug = True)
# print(data)

in_channels = 1433
hidden_channels = [5,6,8,9,12,15,18, 25, 30, 45, 50]
num_layers = [2,3,5,6,7,8]
out_channels = [7]
dropout = [0.1, 0.2, 0.3]
epochs = 25
lr_list = [0.01, 0.03, 0.05, 0.06, 0.07]
iterations = 10

grid_search_solution = {}
acc = 0
for iter in range(iterations):
  for h_c in hidden_channels:
    for n_l in num_layers:
      for o_c in out_channels:
        for d in dropout:
            for lr in lr_list:
            # model
              print(f"Training model for h_c : {h_c}, n_l : {n_l} d : {d}, lr : {lr}, iter : {iter}")
              device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
              model = GAT(in_channels = 1433, hidden_channels = h_c, \
                          out_channels = o_c, num_layers = n_l, dropout = d).to(device)
              a = experiment(model, lr, data)
              test_accuracy = test(model)
              print("Final test accuracy is:", test_accuracy)
              grid_search_solution[(h_c, n_l, o_c, d, lr, iter)] = test_accuracy
              f = open("./results/GS_GAT_parameterTuning_v4.pkl","wb")
              pickle.dump(grid_search_solution, f)
              f.close()


executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Streaming output truncated to the last 5000 lines.
# Test accuracy at epoch 22: 0.3190
# Test accuracy at epoch 23: 0.0640
# Test accuracy at epoch 24: 0.0640
# Final test accuracy is: 0.064
# Training model for h_c : 30, n_l : 8 d : 0.3, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.1030
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1030
# Test accuracy at epoch 4: 0.1030
# Test accuracy at epoch 5: 0.3190
# Test accuracy at epoch 6: 0.3190
# Test accuracy at epoch 7: 0.1300
# Test accuracy at epoch 8: 0.1300
# Test accuracy at epoch 9: 0.1300
# Test accuracy at epoch 10: 0.1300
# Test accuracy at epoch 11: 0.1300
# Test accuracy at epoch 12: 0.1300
# Test accuracy at epoch 13: 0.1300
# Test accuracy at epoch 14: 0.1300
# Test accuracy at epoch 15: 0.1300
# Test accuracy at epoch 16: 0.1300
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.1440
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1490
# Test accuracy at epoch 22: 0.1490
# Test accuracy at epoch 23: 0.0910
# Test accuracy at epoch 24: 0.0910
# Final test accuracy is: 0.091
# Training model for h_c : 30, n_l : 8 d : 0.3, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.0640
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.1300
# Test accuracy at epoch 5: 0.1300
# Test accuracy at epoch 6: 0.1300
# Test accuracy at epoch 7: 0.1300
# Test accuracy at epoch 8: 0.1300
# Test accuracy at epoch 9: 0.1440
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.0910
# Test accuracy at epoch 12: 0.0910
# Test accuracy at epoch 13: 0.0910
# Test accuracy at epoch 14: 0.0910
# Test accuracy at epoch 15: 0.0910
# Test accuracy at epoch 16: 0.0910
# Test accuracy at epoch 17: 0.3190
# Test accuracy at epoch 18: 0.3190
# Test accuracy at epoch 19: 0.1030
# Test accuracy at epoch 20: 0.1030
# Test accuracy at epoch 21: 0.1300
# Test accuracy at epoch 22: 0.1300
# Test accuracy at epoch 23: 0.1300
# Test accuracy at epoch 24: 0.1300
# Final test accuracy is: 0.13
# Training model for h_c : 30, n_l : 8 d : 0.3, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1300
# Test accuracy at epoch 4: 0.1300
# Test accuracy at epoch 5: 0.1300
# Test accuracy at epoch 6: 0.1300
# Test accuracy at epoch 7: 0.0910
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.1030
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1440
# Test accuracy at epoch 14: 0.0910
# Test accuracy at epoch 15: 0.0910
# Test accuracy at epoch 16: 0.0910
# Test accuracy at epoch 17: 0.0910
# Test accuracy at epoch 18: 0.0910
# Test accuracy at epoch 19: 0.1300
# Test accuracy at epoch 20: 0.1300
# Test accuracy at epoch 21: 0.1300
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.0640
# Test accuracy at epoch 24: 0.0640
# Final test accuracy is: 0.064
# Training model for h_c : 30, n_l : 8 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.3190
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.1490
# Test accuracy at epoch 5: 0.1490
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.0640
# Test accuracy at epoch 8: 0.0640
# Test accuracy at epoch 9: 0.0640
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.3190
# Test accuracy at epoch 14: 0.3190
# Test accuracy at epoch 15: 0.0910
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.1440
# Test accuracy at epoch 18: 0.1440
# Test accuracy at epoch 19: 0.1440
# Test accuracy at epoch 20: 0.0640
# Test accuracy at epoch 21: 0.0910
# Test accuracy at epoch 22: 0.0910
# Test accuracy at epoch 23: 0.0910
# Test accuracy at epoch 24: 0.0910
# Final test accuracy is: 0.091
# Training model for h_c : 30, n_l : 8 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.3190
# Test accuracy at epoch 2: 0.1440
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.1030
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.1490
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.3190
# Test accuracy at epoch 10: 0.1300
# Test accuracy at epoch 11: 0.1300
# Test accuracy at epoch 12: 0.1300
# Test accuracy at epoch 13: 0.0910
# Test accuracy at epoch 14: 0.0640
# Test accuracy at epoch 15: 0.0640
# Test accuracy at epoch 16: 0.0640
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.1440
# Test accuracy at epoch 21: 0.1440
# Test accuracy at epoch 22: 0.3190
# Test accuracy at epoch 23: 0.3190
# Test accuracy at epoch 24: 0.3190
# Final test accuracy is: 0.319
# Training model for h_c : 45, n_l : 2 d : 0.1, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.4190
# Test accuracy at epoch 1: 0.5400
# Test accuracy at epoch 2: 0.6410
# Test accuracy at epoch 3: 0.6870
# Test accuracy at epoch 4: 0.7340
# Test accuracy at epoch 5: 0.7510
# Test accuracy at epoch 6: 0.7680
# Test accuracy at epoch 7: 0.7770
# Test accuracy at epoch 8: 0.7930
# Test accuracy at epoch 9: 0.7900
# Test accuracy at epoch 10: 0.7880
# Test accuracy at epoch 11: 0.7900
# Test accuracy at epoch 12: 0.7890
# Test accuracy at epoch 13: 0.7920
# Test accuracy at epoch 14: 0.7880
# Test accuracy at epoch 15: 0.7870
# Test accuracy at epoch 16: 0.7880
# Test accuracy at epoch 17: 0.8000
# Test accuracy at epoch 18: 0.8050
# Test accuracy at epoch 19: 0.8060
# Test accuracy at epoch 20: 0.8060
# Test accuracy at epoch 21: 0.8020
# Test accuracy at epoch 22: 0.8010
# Test accuracy at epoch 23: 0.7980
# Test accuracy at epoch 24: 0.7980
# Final test accuracy is: 0.798
# Training model for h_c : 45, n_l : 2 d : 0.1, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.4070
# Test accuracy at epoch 1: 0.7490
# Test accuracy at epoch 2: 0.7170
# Test accuracy at epoch 3: 0.7240
# Test accuracy at epoch 4: 0.7500
# Test accuracy at epoch 5: 0.7920
# Test accuracy at epoch 6: 0.7940
# Test accuracy at epoch 7: 0.7820
# Test accuracy at epoch 8: 0.7780
# Test accuracy at epoch 9: 0.7920
# Test accuracy at epoch 10: 0.7990
# Test accuracy at epoch 11: 0.8050
# Test accuracy at epoch 12: 0.7980
# Test accuracy at epoch 13: 0.7950
# Test accuracy at epoch 14: 0.7900
# Test accuracy at epoch 15: 0.7910
# Test accuracy at epoch 16: 0.7890
# Test accuracy at epoch 17: 0.7850
# Test accuracy at epoch 18: 0.7840
# Test accuracy at epoch 19: 0.7850
# Test accuracy at epoch 20: 0.7640
# Test accuracy at epoch 21: 0.7750
# Test accuracy at epoch 22: 0.7780
# Test accuracy at epoch 23: 0.7760
# Test accuracy at epoch 24: 0.7690
# Final test accuracy is: 0.769
# Training model for h_c : 45, n_l : 2 d : 0.1, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.4320
# Test accuracy at epoch 2: 0.6830
# Test accuracy at epoch 3: 0.8150
# Test accuracy at epoch 4: 0.8040
# Test accuracy at epoch 5: 0.8050
# Test accuracy at epoch 6: 0.8010
# Test accuracy at epoch 7: 0.7970
# Test accuracy at epoch 8: 0.8020
# Test accuracy at epoch 9: 0.8020
# Test accuracy at epoch 10: 0.7970
# Test accuracy at epoch 11: 0.7900
# Test accuracy at epoch 12: 0.7850
# Test accuracy at epoch 13: 0.7860
# Test accuracy at epoch 14: 0.7860
# Test accuracy at epoch 15: 0.7810
# Test accuracy at epoch 16: 0.7790
# Test accuracy at epoch 17: 0.7710
# Test accuracy at epoch 18: 0.7660
# Test accuracy at epoch 19: 0.7600
# Test accuracy at epoch 20: 0.7610
# Test accuracy at epoch 21: 0.7590
# Test accuracy at epoch 22: 0.7470
# Test accuracy at epoch 23: 0.7500
# Test accuracy at epoch 24: 0.7530
# Final test accuracy is: 0.753
# Training model for h_c : 45, n_l : 2 d : 0.1, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1770
# Test accuracy at epoch 1: 0.5650
# Test accuracy at epoch 2: 0.5260
# Test accuracy at epoch 3: 0.6920
# Test accuracy at epoch 4: 0.7160
# Test accuracy at epoch 5: 0.7090
# Test accuracy at epoch 6: 0.7450
# Test accuracy at epoch 7: 0.7370
# Test accuracy at epoch 8: 0.7630
# Test accuracy at epoch 9: 0.7920
# Test accuracy at epoch 10: 0.7810
# Test accuracy at epoch 11: 0.7840
# Test accuracy at epoch 12: 0.7920
# Test accuracy at epoch 13: 0.7940
# Test accuracy at epoch 14: 0.7930
# Test accuracy at epoch 15: 0.7850
# Test accuracy at epoch 16: 0.7680
# Test accuracy at epoch 17: 0.7610
# Test accuracy at epoch 18: 0.7590
# Test accuracy at epoch 19: 0.7660
# Test accuracy at epoch 20: 0.7680
# Test accuracy at epoch 21: 0.7600
# Test accuracy at epoch 22: 0.7550
# Test accuracy at epoch 23: 0.7660
# Test accuracy at epoch 24: 0.7580
# Final test accuracy is: 0.758
# Training model for h_c : 45, n_l : 2 d : 0.1, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.3080
# Test accuracy at epoch 1: 0.2220
# Test accuracy at epoch 2: 0.6010
# Test accuracy at epoch 3: 0.7450
# Test accuracy at epoch 4: 0.7000
# Test accuracy at epoch 5: 0.6820
# Test accuracy at epoch 6: 0.7480
# Test accuracy at epoch 7: 0.7690
# Test accuracy at epoch 8: 0.7710
# Test accuracy at epoch 9: 0.7720
# Test accuracy at epoch 10: 0.7520
# Test accuracy at epoch 11: 0.7400
# Test accuracy at epoch 12: 0.7490
# Test accuracy at epoch 13: 0.7610
# Test accuracy at epoch 14: 0.7660
# Test accuracy at epoch 15: 0.7410
# Test accuracy at epoch 16: 0.7220
# Test accuracy at epoch 17: 0.7260
# Test accuracy at epoch 18: 0.7430
# Test accuracy at epoch 19: 0.7420
# Test accuracy at epoch 20: 0.7440
# Test accuracy at epoch 21: 0.7510
# Test accuracy at epoch 22: 0.7740
# Test accuracy at epoch 23: 0.7700
# Test accuracy at epoch 24: 0.7480
# Final test accuracy is: 0.748
# Training model for h_c : 45, n_l : 2 d : 0.2, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.4870
# Test accuracy at epoch 1: 0.6510
# Test accuracy at epoch 2: 0.7570
# Test accuracy at epoch 3: 0.7330
# Test accuracy at epoch 4: 0.6950
# Test accuracy at epoch 5: 0.6820
# Test accuracy at epoch 6: 0.6780
# Test accuracy at epoch 7: 0.6990
# Test accuracy at epoch 8: 0.7220
# Test accuracy at epoch 9: 0.7550
# Test accuracy at epoch 10: 0.7680
# Test accuracy at epoch 11: 0.7780
# Test accuracy at epoch 12: 0.7880
# Test accuracy at epoch 13: 0.8000
# Test accuracy at epoch 14: 0.7990
# Test accuracy at epoch 15: 0.8000
# Test accuracy at epoch 16: 0.8010
# Test accuracy at epoch 17: 0.8040
# Test accuracy at epoch 18: 0.8030
# Test accuracy at epoch 19: 0.8010
# Test accuracy at epoch 20: 0.7980
# Test accuracy at epoch 21: 0.7940
# Test accuracy at epoch 22: 0.7930
# Test accuracy at epoch 23: 0.7880
# Test accuracy at epoch 24: 0.7910
# Final test accuracy is: 0.791
# Training model for h_c : 45, n_l : 2 d : 0.2, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.2710
# Test accuracy at epoch 1: 0.3810
# Test accuracy at epoch 2: 0.4000
# Test accuracy at epoch 3: 0.4870
# Test accuracy at epoch 4: 0.5420
# Test accuracy at epoch 5: 0.5750
# Test accuracy at epoch 6: 0.6310
# Test accuracy at epoch 7: 0.6800
# Test accuracy at epoch 8: 0.7160
# Test accuracy at epoch 9: 0.7230
# Test accuracy at epoch 10: 0.7290
# Test accuracy at epoch 11: 0.7170
# Test accuracy at epoch 12: 0.7180
# Test accuracy at epoch 13: 0.7270
# Test accuracy at epoch 14: 0.7390
# Test accuracy at epoch 15: 0.7370
# Test accuracy at epoch 16: 0.7250
# Test accuracy at epoch 17: 0.7070
# Test accuracy at epoch 18: 0.7190
# Test accuracy at epoch 19: 0.7120
# Test accuracy at epoch 20: 0.7190
# Test accuracy at epoch 21: 0.7240
# Test accuracy at epoch 22: 0.7350
# Test accuracy at epoch 23: 0.7230
# Test accuracy at epoch 24: 0.7170
# Final test accuracy is: 0.717
# Training model for h_c : 45, n_l : 2 d : 0.2, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.4460
# Test accuracy at epoch 1: 0.6450
# Test accuracy at epoch 2: 0.7000
# Test accuracy at epoch 3: 0.7680
# Test accuracy at epoch 4: 0.8130
# Test accuracy at epoch 5: 0.7570
# Test accuracy at epoch 6: 0.7590
# Test accuracy at epoch 7: 0.7560
# Test accuracy at epoch 8: 0.7850
# Test accuracy at epoch 9: 0.7840
# Test accuracy at epoch 10: 0.7680
# Test accuracy at epoch 11: 0.7350
# Test accuracy at epoch 12: 0.7240
# Test accuracy at epoch 13: 0.7310
# Test accuracy at epoch 14: 0.7590
# Test accuracy at epoch 15: 0.7670
# Test accuracy at epoch 16: 0.7590
# Test accuracy at epoch 17: 0.7330
# Test accuracy at epoch 18: 0.7350
# Test accuracy at epoch 19: 0.7580
# Test accuracy at epoch 20: 0.7600
# Test accuracy at epoch 21: 0.7370
# Test accuracy at epoch 22: 0.7240
# Test accuracy at epoch 23: 0.7450
# Test accuracy at epoch 24: 0.7680
# Final test accuracy is: 0.768
# Training model for h_c : 45, n_l : 2 d : 0.2, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.2230
# Test accuracy at epoch 1: 0.6250
# Test accuracy at epoch 2: 0.6760
# Test accuracy at epoch 3: 0.7170
# Test accuracy at epoch 4: 0.6210
# Test accuracy at epoch 5: 0.6350
# Test accuracy at epoch 6: 0.7300
# Test accuracy at epoch 7: 0.7590
# Test accuracy at epoch 8: 0.7560
# Test accuracy at epoch 9: 0.7790
# Test accuracy at epoch 10: 0.7780
# Test accuracy at epoch 11: 0.7660
# Test accuracy at epoch 12: 0.7630
# Test accuracy at epoch 13: 0.7780
# Test accuracy at epoch 14: 0.7870
# Test accuracy at epoch 15: 0.7870
# Test accuracy at epoch 16: 0.7870
# Test accuracy at epoch 17: 0.8000
# Test accuracy at epoch 18: 0.7790
# Test accuracy at epoch 19: 0.7720
# Test accuracy at epoch 20: 0.7880
# Test accuracy at epoch 21: 0.7970
# Test accuracy at epoch 22: 0.7980
# Test accuracy at epoch 23: 0.7910
# Test accuracy at epoch 24: 0.7790
# Final test accuracy is: 0.779
# Training model for h_c : 45, n_l : 2 d : 0.2, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.2040
# Test accuracy at epoch 1: 0.4760
# Test accuracy at epoch 2: 0.5260
# Test accuracy at epoch 3: 0.7220
# Test accuracy at epoch 4: 0.8010
# Test accuracy at epoch 5: 0.7840
# Test accuracy at epoch 6: 0.8010
# Test accuracy at epoch 7: 0.7980
# Test accuracy at epoch 8: 0.8100
# Test accuracy at epoch 9: 0.8000
# Test accuracy at epoch 10: 0.7980
# Test accuracy at epoch 11: 0.8100
# Test accuracy at epoch 12: 0.8250
# Test accuracy at epoch 13: 0.8280
# Test accuracy at epoch 14: 0.8280
# Test accuracy at epoch 15: 0.8140
# Test accuracy at epoch 16: 0.7840
# Test accuracy at epoch 17: 0.7870
# Test accuracy at epoch 18: 0.8160
# Test accuracy at epoch 19: 0.8070
# Test accuracy at epoch 20: 0.7890
# Test accuracy at epoch 21: 0.7920
# Test accuracy at epoch 22: 0.7940
# Test accuracy at epoch 23: 0.7820
# Test accuracy at epoch 24: 0.7820
# Final test accuracy is: 0.782
# Training model for h_c : 45, n_l : 2 d : 0.3, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1250
# Test accuracy at epoch 1: 0.3030
# Test accuracy at epoch 2: 0.4130
# Test accuracy at epoch 3: 0.6700
# Test accuracy at epoch 4: 0.7790
# Test accuracy at epoch 5: 0.7570
# Test accuracy at epoch 6: 0.7650
# Test accuracy at epoch 7: 0.7650
# Test accuracy at epoch 8: 0.7770
# Test accuracy at epoch 9: 0.7930
# Test accuracy at epoch 10: 0.7890
# Test accuracy at epoch 11: 0.8000
# Test accuracy at epoch 12: 0.8060
# Test accuracy at epoch 13: 0.7990
# Test accuracy at epoch 14: 0.7900
# Test accuracy at epoch 15: 0.7890
# Test accuracy at epoch 16: 0.7810
# Test accuracy at epoch 17: 0.7850
# Test accuracy at epoch 18: 0.7890
# Test accuracy at epoch 19: 0.7900
# Test accuracy at epoch 20: 0.7980
# Test accuracy at epoch 21: 0.8060
# Test accuracy at epoch 22: 0.8060
# Test accuracy at epoch 23: 0.8040
# Test accuracy at epoch 24: 0.8010
# Final test accuracy is: 0.801
# Training model for h_c : 45, n_l : 2 d : 0.3, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1720
# Test accuracy at epoch 1: 0.3190
# Test accuracy at epoch 2: 0.5330
# Test accuracy at epoch 3: 0.6510
# Test accuracy at epoch 4: 0.7210
# Test accuracy at epoch 5: 0.7750
# Test accuracy at epoch 6: 0.7410
# Test accuracy at epoch 7: 0.7970
# Test accuracy at epoch 8: 0.8130
# Test accuracy at epoch 9: 0.8050
# Test accuracy at epoch 10: 0.7950
# Test accuracy at epoch 11: 0.7830
# Test accuracy at epoch 12: 0.7720
# Test accuracy at epoch 13: 0.7660
# Test accuracy at epoch 14: 0.7430
# Test accuracy at epoch 15: 0.7280
# Test accuracy at epoch 16: 0.7310
# Test accuracy at epoch 17: 0.7610
# Test accuracy at epoch 18: 0.7760
# Test accuracy at epoch 19: 0.7830
# Test accuracy at epoch 20: 0.7910
# Test accuracy at epoch 21: 0.7840
# Test accuracy at epoch 22: 0.7850
# Test accuracy at epoch 23: 0.7720
# Test accuracy at epoch 24: 0.7600
# Final test accuracy is: 0.76
# Training model for h_c : 45, n_l : 2 d : 0.3, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.2230
# Test accuracy at epoch 1: 0.2340
# Test accuracy at epoch 2: 0.3620
# Test accuracy at epoch 3: 0.5090
# Test accuracy at epoch 4: 0.5420
# Test accuracy at epoch 5: 0.5500
# Test accuracy at epoch 6: 0.6230
# Test accuracy at epoch 7: 0.7290
# Test accuracy at epoch 8: 0.7830
# Test accuracy at epoch 9: 0.7690
# Test accuracy at epoch 10: 0.7470
# Test accuracy at epoch 11: 0.7660
# Test accuracy at epoch 12: 0.7740
# Test accuracy at epoch 13: 0.7840
# Test accuracy at epoch 14: 0.7960
# Test accuracy at epoch 15: 0.8030
# Test accuracy at epoch 16: 0.7980
# Test accuracy at epoch 17: 0.8090
# Test accuracy at epoch 18: 0.7970
# Test accuracy at epoch 19: 0.8030
# Test accuracy at epoch 20: 0.8040
# Test accuracy at epoch 21: 0.8010
# Test accuracy at epoch 22: 0.8010
# Test accuracy at epoch 23: 0.7990
# Test accuracy at epoch 24: 0.8030
# Final test accuracy is: 0.803
# Training model for h_c : 45, n_l : 2 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1580
# Test accuracy at epoch 1: 0.3370
# Test accuracy at epoch 2: 0.5380
# Test accuracy at epoch 3: 0.5610
# Test accuracy at epoch 4: 0.6650
# Test accuracy at epoch 5: 0.7060
# Test accuracy at epoch 6: 0.8030
# Test accuracy at epoch 7: 0.8040
# Test accuracy at epoch 8: 0.7860
# Test accuracy at epoch 9: 0.7650
# Test accuracy at epoch 10: 0.7980
# Test accuracy at epoch 11: 0.8030
# Test accuracy at epoch 12: 0.7920
# Test accuracy at epoch 13: 0.7780
# Test accuracy at epoch 14: 0.7780
# Test accuracy at epoch 15: 0.7810
# Test accuracy at epoch 16: 0.7800
# Test accuracy at epoch 17: 0.7830
# Test accuracy at epoch 18: 0.7870
# Test accuracy at epoch 19: 0.7720
# Test accuracy at epoch 20: 0.7600
# Test accuracy at epoch 21: 0.7580
# Test accuracy at epoch 22: 0.7740
# Test accuracy at epoch 23: 0.7710
# Test accuracy at epoch 24: 0.7750
# Final test accuracy is: 0.775
# Training model for h_c : 45, n_l : 2 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.3290
# Test accuracy at epoch 1: 0.1900
# Test accuracy at epoch 2: 0.5600
# Test accuracy at epoch 3: 0.5600
# Test accuracy at epoch 4: 0.7750
# Test accuracy at epoch 5: 0.8080
# Test accuracy at epoch 6: 0.7350
# Test accuracy at epoch 7: 0.7250
# Test accuracy at epoch 8: 0.7840
# Test accuracy at epoch 9: 0.7780
# Test accuracy at epoch 10: 0.7810
# Test accuracy at epoch 11: 0.7570
# Test accuracy at epoch 12: 0.7510
# Test accuracy at epoch 13: 0.7660
# Test accuracy at epoch 14: 0.7840
# Test accuracy at epoch 15: 0.7710
# Test accuracy at epoch 16: 0.7460
# Test accuracy at epoch 17: 0.7530
# Test accuracy at epoch 18: 0.7750
# Test accuracy at epoch 19: 0.7620
# Test accuracy at epoch 20: 0.7650
# Test accuracy at epoch 21: 0.7350
# Test accuracy at epoch 22: 0.7350
# Test accuracy at epoch 23: 0.7260
# Test accuracy at epoch 24: 0.7390
# Final test accuracy is: 0.739
# Training model for h_c : 45, n_l : 3 d : 0.1, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.0910
# Test accuracy at epoch 1: 0.1010
# Test accuracy at epoch 2: 0.1940
# Test accuracy at epoch 3: 0.3280
# Test accuracy at epoch 4: 0.4430
# Test accuracy at epoch 5: 0.5120
# Test accuracy at epoch 6: 0.5180
# Test accuracy at epoch 7: 0.5370
# Test accuracy at epoch 8: 0.5630
# Test accuracy at epoch 9: 0.6890
# Test accuracy at epoch 10: 0.7430
# Test accuracy at epoch 11: 0.7500
# Test accuracy at epoch 12: 0.7480
# Test accuracy at epoch 13: 0.7410
# Test accuracy at epoch 14: 0.7290
# Test accuracy at epoch 15: 0.7460
# Test accuracy at epoch 16: 0.7620
# Test accuracy at epoch 17: 0.7800
# Test accuracy at epoch 18: 0.7660
# Test accuracy at epoch 19: 0.7440
# Test accuracy at epoch 20: 0.7450
# Test accuracy at epoch 21: 0.7600
# Test accuracy at epoch 22: 0.7540
# Test accuracy at epoch 23: 0.7360
# Test accuracy at epoch 24: 0.7270
# Final test accuracy is: 0.727
# Training model for h_c : 45, n_l : 3 d : 0.1, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.1420
# Test accuracy at epoch 2: 0.3820
# Test accuracy at epoch 3: 0.3180
# Test accuracy at epoch 4: 0.3970
# Test accuracy at epoch 5: 0.4120
# Test accuracy at epoch 6: 0.4750
# Test accuracy at epoch 7: 0.5290
# Test accuracy at epoch 8: 0.5660
# Test accuracy at epoch 9: 0.5690
# Test accuracy at epoch 10: 0.5890
# Test accuracy at epoch 11: 0.6500
# Test accuracy at epoch 12: 0.7320
# Test accuracy at epoch 13: 0.7600
# Test accuracy at epoch 14: 0.7550
# Test accuracy at epoch 15: 0.7420
# Test accuracy at epoch 16: 0.7510
# Test accuracy at epoch 17: 0.7560
# Test accuracy at epoch 18: 0.7620
# Test accuracy at epoch 19: 0.7630
# Test accuracy at epoch 20: 0.7560
# Test accuracy at epoch 21: 0.7670
# Test accuracy at epoch 22: 0.7430
# Test accuracy at epoch 23: 0.7540
# Test accuracy at epoch 24: 0.7670
# Final test accuracy is: 0.767
# Training model for h_c : 45, n_l : 3 d : 0.1, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.4420
# Test accuracy at epoch 2: 0.1380
# Test accuracy at epoch 3: 0.2880
# Test accuracy at epoch 4: 0.2920
# Test accuracy at epoch 5: 0.4870
# Test accuracy at epoch 6: 0.6120
# Test accuracy at epoch 7: 0.5720
# Test accuracy at epoch 8: 0.6210
# Test accuracy at epoch 9: 0.7470
# Test accuracy at epoch 10: 0.7480
# Test accuracy at epoch 11: 0.7280
# Test accuracy at epoch 12: 0.7120
# Test accuracy at epoch 13: 0.7510
# Test accuracy at epoch 14: 0.7710
# Test accuracy at epoch 15: 0.7440
# Test accuracy at epoch 16: 0.7160
# Test accuracy at epoch 17: 0.7190
# Test accuracy at epoch 18: 0.7490
# Test accuracy at epoch 19: 0.7640
# Test accuracy at epoch 20: 0.7600
# Test accuracy at epoch 21: 0.7540
# Test accuracy at epoch 22: 0.7380
# Test accuracy at epoch 23: 0.7140
# Test accuracy at epoch 24: 0.7650
# Final test accuracy is: 0.765
# Training model for h_c : 45, n_l : 3 d : 0.1, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1460
# Test accuracy at epoch 1: 0.4080
# Test accuracy at epoch 2: 0.3370
# Test accuracy at epoch 3: 0.4000
# Test accuracy at epoch 4: 0.5020
# Test accuracy at epoch 5: 0.5310
# Test accuracy at epoch 6: 0.5770
# Test accuracy at epoch 7: 0.6640
# Test accuracy at epoch 8: 0.7780
# Test accuracy at epoch 9: 0.7200
# Test accuracy at epoch 10: 0.7540
# Test accuracy at epoch 11: 0.7150
# Test accuracy at epoch 12: 0.7640
# Test accuracy at epoch 13: 0.7310
# Test accuracy at epoch 14: 0.7380
# Test accuracy at epoch 15: 0.7610
# Test accuracy at epoch 16: 0.7600
# Test accuracy at epoch 17: 0.7470
# Test accuracy at epoch 18: 0.7660
# Test accuracy at epoch 19: 0.7650
# Test accuracy at epoch 20: 0.7880
# Test accuracy at epoch 21: 0.7760
# Test accuracy at epoch 22: 0.7190
# Test accuracy at epoch 23: 0.6780
# Test accuracy at epoch 24: 0.7720
# Final test accuracy is: 0.772
# Training model for h_c : 45, n_l : 3 d : 0.1, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1930
# Test accuracy at epoch 1: 0.1370
# Test accuracy at epoch 2: 0.1310
# Test accuracy at epoch 3: 0.3540
# Test accuracy at epoch 4: 0.2960
# Test accuracy at epoch 5: 0.4870
# Test accuracy at epoch 6: 0.4950
# Test accuracy at epoch 7: 0.6110
# Test accuracy at epoch 8: 0.6720
# Test accuracy at epoch 9: 0.7030
# Test accuracy at epoch 10: 0.7070
# Test accuracy at epoch 11: 0.6950
# Test accuracy at epoch 12: 0.7600
# Test accuracy at epoch 13: 0.7830
# Test accuracy at epoch 14: 0.6890
# Test accuracy at epoch 15: 0.7260
# Test accuracy at epoch 16: 0.7320
# Test accuracy at epoch 17: 0.7280
# Test accuracy at epoch 18: 0.7380
# Test accuracy at epoch 19: 0.7240
# Test accuracy at epoch 20: 0.7700
# Test accuracy at epoch 21: 0.7200
# Test accuracy at epoch 22: 0.7370
# Test accuracy at epoch 23: 0.6760
# Test accuracy at epoch 24: 0.7120
# Final test accuracy is: 0.712
# Training model for h_c : 45, n_l : 3 d : 0.2, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1650
# Test accuracy at epoch 1: 0.1680
# Test accuracy at epoch 2: 0.2880
# Test accuracy at epoch 3: 0.3150
# Test accuracy at epoch 4: 0.3570
# Test accuracy at epoch 5: 0.4130
# Test accuracy at epoch 6: 0.4350
# Test accuracy at epoch 7: 0.4560
# Test accuracy at epoch 8: 0.5000
# Test accuracy at epoch 9: 0.5120
# Test accuracy at epoch 10: 0.5460
# Test accuracy at epoch 11: 0.5730
# Test accuracy at epoch 12: 0.5860
# Test accuracy at epoch 13: 0.5900
# Test accuracy at epoch 14: 0.5990
# Test accuracy at epoch 15: 0.6080
# Test accuracy at epoch 16: 0.6230
# Test accuracy at epoch 17: 0.6320
# Test accuracy at epoch 18: 0.6530
# Test accuracy at epoch 19: 0.6720
# Test accuracy at epoch 20: 0.6740
# Test accuracy at epoch 21: 0.6850
# Test accuracy at epoch 22: 0.7100
# Test accuracy at epoch 23: 0.7500
# Test accuracy at epoch 24: 0.7740
# Final test accuracy is: 0.774
# Training model for h_c : 45, n_l : 3 d : 0.2, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.1460
# Test accuracy at epoch 2: 0.3610
# Test accuracy at epoch 3: 0.5240
# Test accuracy at epoch 4: 0.4080
# Test accuracy at epoch 5: 0.3840
# Test accuracy at epoch 6: 0.4350
# Test accuracy at epoch 7: 0.5580
# Test accuracy at epoch 8: 0.5240
# Test accuracy at epoch 9: 0.5540
# Test accuracy at epoch 10: 0.5690
# Test accuracy at epoch 11: 0.5470
# Test accuracy at epoch 12: 0.7100
# Test accuracy at epoch 13: 0.7060
# Test accuracy at epoch 14: 0.6960
# Test accuracy at epoch 15: 0.6900
# Test accuracy at epoch 16: 0.7210
# Test accuracy at epoch 17: 0.7180
# Test accuracy at epoch 18: 0.6830
# Test accuracy at epoch 19: 0.7100
# Test accuracy at epoch 20: 0.7520
# Test accuracy at epoch 21: 0.7590
# Test accuracy at epoch 22: 0.7360
# Test accuracy at epoch 23: 0.7250
# Test accuracy at epoch 24: 0.7350
# Final test accuracy is: 0.735
# Training model for h_c : 45, n_l : 3 d : 0.2, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.3680
# Test accuracy at epoch 2: 0.0640
# Test accuracy at epoch 3: 0.2130
# Test accuracy at epoch 4: 0.2870
# Test accuracy at epoch 5: 0.2610
# Test accuracy at epoch 6: 0.4140
# Test accuracy at epoch 7: 0.4880
# Test accuracy at epoch 8: 0.5750
# Test accuracy at epoch 9: 0.6490
# Test accuracy at epoch 10: 0.6930
# Test accuracy at epoch 11: 0.6670
# Test accuracy at epoch 12: 0.7190
# Test accuracy at epoch 13: 0.7260
# Test accuracy at epoch 14: 0.7030
# Test accuracy at epoch 15: 0.7950
# Test accuracy at epoch 16: 0.7660
# Test accuracy at epoch 17: 0.7870
# Test accuracy at epoch 18: 0.7560
# Test accuracy at epoch 19: 0.7400
# Test accuracy at epoch 20: 0.7670
# Test accuracy at epoch 21: 0.7800
# Test accuracy at epoch 22: 0.7610
# Test accuracy at epoch 23: 0.7290
# Test accuracy at epoch 24: 0.7320
# Final test accuracy is: 0.732
# Training model for h_c : 45, n_l : 3 d : 0.2, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.1320
# Test accuracy at epoch 2: 0.5510
# Test accuracy at epoch 3: 0.4260
# Test accuracy at epoch 4: 0.4400
# Test accuracy at epoch 5: 0.4950
# Test accuracy at epoch 6: 0.7230
# Test accuracy at epoch 7: 0.6210
# Test accuracy at epoch 8: 0.7350
# Test accuracy at epoch 9: 0.6970
# Test accuracy at epoch 10: 0.7150
# Test accuracy at epoch 11: 0.7270
# Test accuracy at epoch 12: 0.6350
# Test accuracy at epoch 13: 0.7040
# Test accuracy at epoch 14: 0.7620
# Test accuracy at epoch 15: 0.7690
# Test accuracy at epoch 16: 0.7760
# Test accuracy at epoch 17: 0.7300
# Test accuracy at epoch 18: 0.7660
# Test accuracy at epoch 19: 0.7740
# Test accuracy at epoch 20: 0.7740
# Test accuracy at epoch 21: 0.7830
# Test accuracy at epoch 22: 0.7990
# Test accuracy at epoch 23: 0.7750
# Test accuracy at epoch 24: 0.7610
# Final test accuracy is: 0.761
# Training model for h_c : 45, n_l : 3 d : 0.2, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.3190
# Test accuracy at epoch 1: 0.1460
# Test accuracy at epoch 2: 0.1510
# Test accuracy at epoch 3: 0.5350
# Test accuracy at epoch 4: 0.4760
# Test accuracy at epoch 5: 0.4040
# Test accuracy at epoch 6: 0.5300
# Test accuracy at epoch 7: 0.6580
# Test accuracy at epoch 8: 0.6770
# Test accuracy at epoch 9: 0.5760
# Test accuracy at epoch 10: 0.7100
# Test accuracy at epoch 11: 0.6570
# Test accuracy at epoch 12: 0.6800
# Test accuracy at epoch 13: 0.7030
# Test accuracy at epoch 14: 0.7180
# Test accuracy at epoch 15: 0.7030
# Test accuracy at epoch 16: 0.7300
# Test accuracy at epoch 17: 0.7640
# Test accuracy at epoch 18: 0.7610
# Test accuracy at epoch 19: 0.7190
# Test accuracy at epoch 20: 0.7550
# Test accuracy at epoch 21: 0.7610
# Test accuracy at epoch 22: 0.7710
# Test accuracy at epoch 23: 0.7380
# Test accuracy at epoch 24: 0.7310
# Final test accuracy is: 0.731
# Training model for h_c : 45, n_l : 3 d : 0.3, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1500
# Test accuracy at epoch 1: 0.4430
# Test accuracy at epoch 2: 0.3300
# Test accuracy at epoch 3: 0.2290
# Test accuracy at epoch 4: 0.3440
# Test accuracy at epoch 5: 0.4630
# Test accuracy at epoch 6: 0.4510
# Test accuracy at epoch 7: 0.4270
# Test accuracy at epoch 8: 0.4220
# Test accuracy at epoch 9: 0.5300
# Test accuracy at epoch 10: 0.6580
# Test accuracy at epoch 11: 0.7200
# Test accuracy at epoch 12: 0.7430
# Test accuracy at epoch 13: 0.7500
# Test accuracy at epoch 14: 0.7450
# Test accuracy at epoch 15: 0.7050
# Test accuracy at epoch 16: 0.6650
# Test accuracy at epoch 17: 0.6410
# Test accuracy at epoch 18: 0.6410
# Test accuracy at epoch 19: 0.6940
# Test accuracy at epoch 20: 0.7400
# Test accuracy at epoch 21: 0.7560
# Test accuracy at epoch 22: 0.7530
# Test accuracy at epoch 23: 0.7550
# Test accuracy at epoch 24: 0.7520
# Final test accuracy is: 0.752
# Training model for h_c : 45, n_l : 3 d : 0.3, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.0930
# Test accuracy at epoch 1: 0.4480
# Test accuracy at epoch 2: 0.2030
# Test accuracy at epoch 3: 0.5120
# Test accuracy at epoch 4: 0.5190
# Test accuracy at epoch 5: 0.5120
# Test accuracy at epoch 6: 0.5670
# Test accuracy at epoch 7: 0.5710
# Test accuracy at epoch 8: 0.5760
# Test accuracy at epoch 9: 0.5520
# Test accuracy at epoch 10: 0.5570
# Test accuracy at epoch 11: 0.6590
# Test accuracy at epoch 12: 0.7010
# Test accuracy at epoch 13: 0.7470
# Test accuracy at epoch 14: 0.7400
# Test accuracy at epoch 15: 0.7410
# Test accuracy at epoch 16: 0.7490
# Test accuracy at epoch 17: 0.7480
# Test accuracy at epoch 18: 0.7410
# Test accuracy at epoch 19: 0.7350
# Test accuracy at epoch 20: 0.7510
# Test accuracy at epoch 21: 0.7620
# Test accuracy at epoch 22: 0.7660
# Test accuracy at epoch 23: 0.7590
# Test accuracy at epoch 24: 0.7340
# Final test accuracy is: 0.734
# Training model for h_c : 45, n_l : 3 d : 0.3, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.3190
# Test accuracy at epoch 1: 0.0700
# Test accuracy at epoch 2: 0.2070
# Test accuracy at epoch 3: 0.2430
# Test accuracy at epoch 4: 0.4290
# Test accuracy at epoch 5: 0.5310
# Test accuracy at epoch 6: 0.5300
# Test accuracy at epoch 7: 0.5740
# Test accuracy at epoch 8: 0.6820
# Test accuracy at epoch 9: 0.5780
# Test accuracy at epoch 10: 0.6410
# Test accuracy at epoch 11: 0.7130
# Test accuracy at epoch 12: 0.7300
# Test accuracy at epoch 13: 0.7330
# Test accuracy at epoch 14: 0.6930
# Test accuracy at epoch 15: 0.7300
# Test accuracy at epoch 16: 0.7630
# Test accuracy at epoch 17: 0.7090
# Test accuracy at epoch 18: 0.7130
# Test accuracy at epoch 19: 0.7290
# Test accuracy at epoch 20: 0.7600
# Test accuracy at epoch 21: 0.7870
# Test accuracy at epoch 22: 0.7900
# Test accuracy at epoch 23: 0.7620
# Test accuracy at epoch 24: 0.7770
# Final test accuracy is: 0.777
# Training model for h_c : 45, n_l : 3 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.2810
# Test accuracy at epoch 3: 0.5720
# Test accuracy at epoch 4: 0.5670
# Test accuracy at epoch 5: 0.5250
# Test accuracy at epoch 6: 0.4740
# Test accuracy at epoch 7: 0.5290
# Test accuracy at epoch 8: 0.5280
# Test accuracy at epoch 9: 0.7090
# Test accuracy at epoch 10: 0.7180
# Test accuracy at epoch 11: 0.6550
# Test accuracy at epoch 12: 0.7290
# Test accuracy at epoch 13: 0.7420
# Test accuracy at epoch 14: 0.7330
# Test accuracy at epoch 15: 0.7330
# Test accuracy at epoch 16: 0.7070
# Test accuracy at epoch 17: 0.6800
# Test accuracy at epoch 18: 0.7310
# Test accuracy at epoch 19: 0.7660
# Test accuracy at epoch 20: 0.7530
# Test accuracy at epoch 21: 0.7690
# Test accuracy at epoch 22: 0.7560
# Test accuracy at epoch 23: 0.7500
# Test accuracy at epoch 24: 0.7440
# Final test accuracy is: 0.744
# Training model for h_c : 45, n_l : 3 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1350
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.3680
# Test accuracy at epoch 3: 0.4260
# Test accuracy at epoch 4: 0.4450
# Test accuracy at epoch 5: 0.4760
# Test accuracy at epoch 6: 0.6170
# Test accuracy at epoch 7: 0.6990
# Test accuracy at epoch 8: 0.7480
# Test accuracy at epoch 9: 0.6030
# Test accuracy at epoch 10: 0.7620
# Test accuracy at epoch 11: 0.7480
# Test accuracy at epoch 12: 0.7800
# Test accuracy at epoch 13: 0.7290
# Test accuracy at epoch 14: 0.7730
# Test accuracy at epoch 15: 0.7770
# Test accuracy at epoch 16: 0.7910
# Test accuracy at epoch 17: 0.7340
# Test accuracy at epoch 18: 0.7350
# Test accuracy at epoch 19: 0.7840
# Test accuracy at epoch 20: 0.7910
# Test accuracy at epoch 21: 0.7980
# Test accuracy at epoch 22: 0.7930
# Test accuracy at epoch 23: 0.7810
# Test accuracy at epoch 24: 0.7600
# Final test accuracy is: 0.76
# Training model for h_c : 45, n_l : 5 d : 0.1, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.3220
# Test accuracy at epoch 2: 0.1490
# Test accuracy at epoch 3: 0.0940
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.2000
# Test accuracy at epoch 6: 0.2970
# Test accuracy at epoch 7: 0.3830
# Test accuracy at epoch 8: 0.5040
# Test accuracy at epoch 9: 0.4910
# Test accuracy at epoch 10: 0.3210
# Test accuracy at epoch 11: 0.3100
# Test accuracy at epoch 12: 0.2890
# Test accuracy at epoch 13: 0.2800
# Test accuracy at epoch 14: 0.2820
# Test accuracy at epoch 15: 0.2640
# Test accuracy at epoch 16: 0.2660
# Test accuracy at epoch 17: 0.2820
# Test accuracy at epoch 18: 0.3730
# Test accuracy at epoch 19: 0.4650
# Test accuracy at epoch 20: 0.5050
# Test accuracy at epoch 21: 0.4720
# Test accuracy at epoch 22: 0.4940
# Test accuracy at epoch 23: 0.5810
# Test accuracy at epoch 24: 0.5500
# Final test accuracy is: 0.55
# Training model for h_c : 45, n_l : 5 d : 0.1, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.3330
# Test accuracy at epoch 2: 0.1470
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.2210
# Test accuracy at epoch 5: 0.2180
# Test accuracy at epoch 6: 0.1730
# Test accuracy at epoch 7: 0.2370
# Test accuracy at epoch 8: 0.2400
# Test accuracy at epoch 9: 0.2230
# Test accuracy at epoch 10: 0.2680
# Test accuracy at epoch 11: 0.2740
# Test accuracy at epoch 12: 0.2440
# Test accuracy at epoch 13: 0.2750
# Test accuracy at epoch 14: 0.4100
# Test accuracy at epoch 15: 0.3170
# Test accuracy at epoch 16: 0.3760
# Test accuracy at epoch 17: 0.3820
# Test accuracy at epoch 18: 0.4180
# Test accuracy at epoch 19: 0.3860
# Test accuracy at epoch 20: 0.4910
# Test accuracy at epoch 21: 0.5160
# Test accuracy at epoch 22: 0.3360
# Test accuracy at epoch 23: 0.5080
# Test accuracy at epoch 24: 0.3260
# Final test accuracy is: 0.326
# Training model for h_c : 45, n_l : 5 d : 0.1, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.1030
# Test accuracy at epoch 2: 0.0670
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.3260
# Test accuracy at epoch 5: 0.3400
# Test accuracy at epoch 6: 0.3240
# Test accuracy at epoch 7: 0.2350
# Test accuracy at epoch 8: 0.1920
# Test accuracy at epoch 9: 0.2190
# Test accuracy at epoch 10: 0.2180
# Test accuracy at epoch 11: 0.2320
# Test accuracy at epoch 12: 0.2340
# Test accuracy at epoch 13: 0.2670
# Test accuracy at epoch 14: 0.2710
# Test accuracy at epoch 15: 0.2630
# Test accuracy at epoch 16: 0.2880
# Test accuracy at epoch 17: 0.2710
# Test accuracy at epoch 18: 0.2640
# Test accuracy at epoch 19: 0.2260
# Test accuracy at epoch 20: 0.2860
# Test accuracy at epoch 21: 0.4110
# Test accuracy at epoch 22: 0.3370
# Test accuracy at epoch 23: 0.2710
# Test accuracy at epoch 24: 0.3220
# Final test accuracy is: 0.322
# Training model for h_c : 45, n_l : 5 d : 0.1, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.3190
# Test accuracy at epoch 3: 0.1030
# Test accuracy at epoch 4: 0.1160
# Test accuracy at epoch 5: 0.1300
# Test accuracy at epoch 6: 0.1060
# Test accuracy at epoch 7: 0.1190
# Test accuracy at epoch 8: 0.1130
# Test accuracy at epoch 9: 0.1750
# Test accuracy at epoch 10: 0.1170
# Test accuracy at epoch 11: 0.1260
# Test accuracy at epoch 12: 0.0850
# Test accuracy at epoch 13: 0.0850
# Test accuracy at epoch 14: 0.2250
# Test accuracy at epoch 15: 0.1970
# Test accuracy at epoch 16: 0.1290
# Test accuracy at epoch 17: 0.2550
# Test accuracy at epoch 18: 0.1750
# Test accuracy at epoch 19: 0.3160
# Test accuracy at epoch 20: 0.2580
# Test accuracy at epoch 21: 0.4310
# Test accuracy at epoch 22: 0.2510
# Test accuracy at epoch 23: 0.4140
# Test accuracy at epoch 24: 0.4250
# Final test accuracy is: 0.425
# Training model for h_c : 45, n_l : 5 d : 0.1, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.0910
# Test accuracy at epoch 1: 0.1490
# Test accuracy at epoch 2: 0.1440
# Test accuracy at epoch 3: 0.1440
# Test accuracy at epoch 4: 0.1300
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.1440
# Test accuracy at epoch 8: 0.1440
# Test accuracy at epoch 9: 0.1440
# Test accuracy at epoch 10: 0.0640
# Test accuracy at epoch 11: 0.1740
# Test accuracy at epoch 12: 0.1300
# Test accuracy at epoch 13: 0.0830
# Test accuracy at epoch 14: 0.3560
# Test accuracy at epoch 15: 0.2060
# Test accuracy at epoch 16: 0.2070
# Test accuracy at epoch 17: 0.1850
# Test accuracy at epoch 18: 0.1760
# Test accuracy at epoch 19: 0.1730
# Test accuracy at epoch 20: 0.1230
# Test accuracy at epoch 21: 0.1720
# Test accuracy at epoch 22: 0.2520
# Test accuracy at epoch 23: 0.1580
# Test accuracy at epoch 24: 0.3650
# Final test accuracy is: 0.365
# Training model for h_c : 45, n_l : 5 d : 0.2, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1600
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1980
# Test accuracy at epoch 3: 0.2480
# Test accuracy at epoch 4: 0.5170
# Test accuracy at epoch 5: 0.3290
# Test accuracy at epoch 6: 0.5340
# Test accuracy at epoch 7: 0.2970
# Test accuracy at epoch 8: 0.3530
# Test accuracy at epoch 9: 0.4650
# Test accuracy at epoch 10: 0.4640
# Test accuracy at epoch 11: 0.4130
# Test accuracy at epoch 12: 0.4130
# Test accuracy at epoch 13: 0.4380
# Test accuracy at epoch 14: 0.4330
# Test accuracy at epoch 15: 0.5260
# Test accuracy at epoch 16: 0.5290
# Test accuracy at epoch 17: 0.5800
# Test accuracy at epoch 18: 0.5410
# Test accuracy at epoch 19: 0.5620
# Test accuracy at epoch 20: 0.5980
# Test accuracy at epoch 21: 0.5200
# Test accuracy at epoch 22: 0.4860
# Test accuracy at epoch 23: 0.6110
# Test accuracy at epoch 24: 0.6610
# Final test accuracy is: 0.661
# Training model for h_c : 45, n_l : 5 d : 0.2, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1030
# Test accuracy at epoch 4: 0.1990
# Test accuracy at epoch 5: 0.1700
# Test accuracy at epoch 6: 0.2210
# Test accuracy at epoch 7: 0.2110
# Test accuracy at epoch 8: 0.2940
# Test accuracy at epoch 9: 0.2740
# Test accuracy at epoch 10: 0.2650
# Test accuracy at epoch 11: 0.2770
# Test accuracy at epoch 12: 0.3130
# Test accuracy at epoch 13: 0.3660
# Test accuracy at epoch 14: 0.2880
# Test accuracy at epoch 15: 0.3510
# Test accuracy at epoch 16: 0.2550
# Test accuracy at epoch 17: 0.2570
# Test accuracy at epoch 18: 0.3340
# Test accuracy at epoch 19: 0.2290
# Test accuracy at epoch 20: 0.4480
# Test accuracy at epoch 21: 0.3770
# Test accuracy at epoch 22: 0.3790
# Test accuracy at epoch 23: 0.4200
# Test accuracy at epoch 24: 0.4510
# Final test accuracy is: 0.451
# Training model for h_c : 45, n_l : 5 d : 0.2, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.0910
# Test accuracy at epoch 2: 0.1050
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.1490
# Test accuracy at epoch 5: 0.1490
# Test accuracy at epoch 6: 0.1500
# Test accuracy at epoch 7: 0.2890
# Test accuracy at epoch 8: 0.3870
# Test accuracy at epoch 9: 0.4180
# Test accuracy at epoch 10: 0.3730
# Test accuracy at epoch 11: 0.4110
# Test accuracy at epoch 12: 0.1840
# Test accuracy at epoch 13: 0.2100
# Test accuracy at epoch 14: 0.1940
# Test accuracy at epoch 15: 0.3070
# Test accuracy at epoch 16: 0.3070
# Test accuracy at epoch 17: 0.2570
# Test accuracy at epoch 18: 0.3360
# Test accuracy at epoch 19: 0.3750
# Test accuracy at epoch 20: 0.4360
# Test accuracy at epoch 21: 0.4250
# Test accuracy at epoch 22: 0.2860
# Test accuracy at epoch 23: 0.3130
# Test accuracy at epoch 24: 0.3540
# Final test accuracy is: 0.354
# Training model for h_c : 45, n_l : 5 d : 0.2, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.1030
# Test accuracy at epoch 2: 0.1530
# Test accuracy at epoch 3: 0.1440
# Test accuracy at epoch 4: 0.1760
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.1200
# Test accuracy at epoch 7: 0.1430
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.1420
# Test accuracy at epoch 10: 0.1650
# Test accuracy at epoch 11: 0.1470
# Test accuracy at epoch 12: 0.0910
# Test accuracy at epoch 13: 0.0940
# Test accuracy at epoch 14: 0.1490
# Test accuracy at epoch 15: 0.3220
# Test accuracy at epoch 16: 0.3300
# Test accuracy at epoch 17: 0.3340
# Test accuracy at epoch 18: 0.3330
# Test accuracy at epoch 19: 0.3340
# Test accuracy at epoch 20: 0.1690
# Test accuracy at epoch 21: 0.1910
# Test accuracy at epoch 22: 0.2250
# Test accuracy at epoch 23: 0.1630
# Test accuracy at epoch 24: 0.1930
# Final test accuracy is: 0.193
# Training model for h_c : 45, n_l : 5 d : 0.2, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.0690
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1030
# Test accuracy at epoch 4: 0.1440
# Test accuracy at epoch 5: 0.1300
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.0910
# Test accuracy at epoch 8: 0.1440
# Test accuracy at epoch 9: 0.1400
# Test accuracy at epoch 10: 0.0910
# Test accuracy at epoch 11: 0.1700
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.2090
# Test accuracy at epoch 14: 0.1360
# Test accuracy at epoch 15: 0.1530
# Test accuracy at epoch 16: 0.3090
# Test accuracy at epoch 17: 0.1960
# Test accuracy at epoch 18: 0.2420
# Test accuracy at epoch 19: 0.2870
# Test accuracy at epoch 20: 0.2410
# Test accuracy at epoch 21: 0.1000
# Test accuracy at epoch 22: 0.1040
# Test accuracy at epoch 23: 0.1600
# Test accuracy at epoch 24: 0.3770
# Final test accuracy is: 0.377
# Training model for h_c : 45, n_l : 5 d : 0.3, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1470
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1660
# Test accuracy at epoch 3: 0.3470
# Test accuracy at epoch 4: 0.1090
# Test accuracy at epoch 5: 0.5280
# Test accuracy at epoch 6: 0.1820
# Test accuracy at epoch 7: 0.2370
# Test accuracy at epoch 8: 0.2470
# Test accuracy at epoch 9: 0.2480
# Test accuracy at epoch 10: 0.2450
# Test accuracy at epoch 11: 0.2430
# Test accuracy at epoch 12: 0.2420
# Test accuracy at epoch 13: 0.2550
# Test accuracy at epoch 14: 0.2490
# Test accuracy at epoch 15: 0.2690
# Test accuracy at epoch 16: 0.2660
# Test accuracy at epoch 17: 0.3010
# Test accuracy at epoch 18: 0.3790
# Test accuracy at epoch 19: 0.4400
# Test accuracy at epoch 20: 0.4270
# Test accuracy at epoch 21: 0.4140
# Test accuracy at epoch 22: 0.5130
# Test accuracy at epoch 23: 0.5020
# Test accuracy at epoch 24: 0.5010
# Final test accuracy is: 0.501
# Training model for h_c : 45, n_l : 5 d : 0.3, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.0660
# Test accuracy at epoch 1: 0.1210
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.0920
# Test accuracy at epoch 4: 0.1530
# Test accuracy at epoch 5: 0.2340
# Test accuracy at epoch 6: 0.2710
# Test accuracy at epoch 7: 0.2720
# Test accuracy at epoch 8: 0.1790
# Test accuracy at epoch 9: 0.2160
# Test accuracy at epoch 10: 0.2770
# Test accuracy at epoch 11: 0.3100
# Test accuracy at epoch 12: 0.4400
# Test accuracy at epoch 13: 0.3020
# Test accuracy at epoch 14: 0.2450
# Test accuracy at epoch 15: 0.2240
# Test accuracy at epoch 16: 0.2880
# Test accuracy at epoch 17: 0.2790
# Test accuracy at epoch 18: 0.2780
# Test accuracy at epoch 19: 0.3240
# Test accuracy at epoch 20: 0.3880
# Test accuracy at epoch 21: 0.3400
# Test accuracy at epoch 22: 0.4850
# Test accuracy at epoch 23: 0.4900
# Test accuracy at epoch 24: 0.3980
# Final test accuracy is: 0.398
# Training model for h_c : 45, n_l : 5 d : 0.3, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.3190
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.3190
# Test accuracy at epoch 7: 0.3190
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.1490
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1320
# Test accuracy at epoch 14: 0.3210
# Test accuracy at epoch 15: 0.2540
# Test accuracy at epoch 16: 0.4250
# Test accuracy at epoch 17: 0.3770
# Test accuracy at epoch 18: 0.4460
# Test accuracy at epoch 19: 0.4280
# Test accuracy at epoch 20: 0.4260
# Test accuracy at epoch 21: 0.4120
# Test accuracy at epoch 22: 0.3270
# Test accuracy at epoch 23: 0.2420
# Test accuracy at epoch 24: 0.1780
# Final test accuracy is: 0.178
# Training model for h_c : 45, n_l : 5 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.0640
# Test accuracy at epoch 5: 0.2520
# Test accuracy at epoch 6: 0.4260
# Test accuracy at epoch 7: 0.3660
# Test accuracy at epoch 8: 0.3200
# Test accuracy at epoch 9: 0.2600
# Test accuracy at epoch 10: 0.2610
# Test accuracy at epoch 11: 0.1950
# Test accuracy at epoch 12: 0.1800
# Test accuracy at epoch 13: 0.1130
# Test accuracy at epoch 14: 0.1810
# Test accuracy at epoch 15: 0.3550
# Test accuracy at epoch 16: 0.3900
# Test accuracy at epoch 17: 0.2370
# Test accuracy at epoch 18: 0.3600
# Test accuracy at epoch 19: 0.2650
# Test accuracy at epoch 20: 0.2570
# Test accuracy at epoch 21: 0.2310
# Test accuracy at epoch 22: 0.2310
# Test accuracy at epoch 23: 0.3650
# Test accuracy at epoch 24: 0.3020
# Final test accuracy is: 0.302
# Training model for h_c : 45, n_l : 5 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1490
# Test accuracy at epoch 3: 0.0930
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.1300
# Test accuracy at epoch 6: 0.3190
# Test accuracy at epoch 7: 0.3190
# Test accuracy at epoch 8: 0.3190
# Test accuracy at epoch 9: 0.1440
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.0910
# Test accuracy at epoch 13: 0.1330
# Test accuracy at epoch 14: 0.1030
# Test accuracy at epoch 15: 0.2060
# Test accuracy at epoch 16: 0.1060
# Test accuracy at epoch 17: 0.2320
# Test accuracy at epoch 18: 0.2670
# Test accuracy at epoch 19: 0.2190
# Test accuracy at epoch 20: 0.2440
# Test accuracy at epoch 21: 0.2410
# Test accuracy at epoch 22: 0.2630
# Test accuracy at epoch 23: 0.2290
# Test accuracy at epoch 24: 0.2570
# Final test accuracy is: 0.257
# Training model for h_c : 45, n_l : 6 d : 0.1, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.0910
# Test accuracy at epoch 2: 0.0910
# Test accuracy at epoch 3: 0.2020
# Test accuracy at epoch 4: 0.1540
# Test accuracy at epoch 5: 0.1730
# Test accuracy at epoch 6: 0.2610
# Test accuracy at epoch 7: 0.2890
# Test accuracy at epoch 8: 0.2600
# Test accuracy at epoch 9: 0.2800
# Test accuracy at epoch 10: 0.2400
# Test accuracy at epoch 11: 0.2320
# Test accuracy at epoch 12: 0.3020
# Test accuracy at epoch 13: 0.3040
# Test accuracy at epoch 14: 0.3130
# Test accuracy at epoch 15: 0.3270
# Test accuracy at epoch 16: 0.2690
# Test accuracy at epoch 17: 0.3410
# Test accuracy at epoch 18: 0.4070
# Test accuracy at epoch 19: 0.4010
# Test accuracy at epoch 20: 0.6530
# Test accuracy at epoch 21: 0.5520
# Test accuracy at epoch 22: 0.6320
# Test accuracy at epoch 23: 0.5270
# Test accuracy at epoch 24: 0.6460
# Final test accuracy is: 0.646
# Training model for h_c : 45, n_l : 6 d : 0.1, lr : 0.03, iter : 9
# ...
# Final test accuracy is: 0.064
# Training model for h_c : 50, n_l : 7 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.0910
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.1490
# Test accuracy at epoch 3: 0.0910
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.0910
# Test accuracy at epoch 8: 0.1030
# Test accuracy at epoch 9: 0.1030
# Test accuracy at epoch 10: 0.1030
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1490
# Test accuracy at epoch 14: 0.3190
# Test accuracy at epoch 15: 0.3190
# Test accuracy at epoch 16: 0.3190
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.1300
# Test accuracy at epoch 20: 0.1300
# Test accuracy at epoch 21: 0.1440
# Test accuracy at epoch 22: 0.1440
# Test accuracy at epoch 23: 0.1440
# Test accuracy at epoch 24: 0.1490
# Final test accuracy is: 0.149
# Training model for h_c : 50, n_l : 7 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.1490
# Test accuracy at epoch 5: 0.1490
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.1490
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.0640
# Test accuracy at epoch 10: 0.0640
# Test accuracy at epoch 11: 0.0640
# Test accuracy at epoch 12: 0.1030
# Test accuracy at epoch 13: 0.1030
# Test accuracy at epoch 14: 0.1030
# Test accuracy at epoch 15: 0.3190
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.1490
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.1490
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1490
# Test accuracy at epoch 22: 0.1490
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.1030
# Final test accuracy is: 0.103
# Training model for h_c : 50, n_l : 8 d : 0.1, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.3190
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.0640
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.0640
# Test accuracy at epoch 5: 0.1490
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.0910
# Test accuracy at epoch 8: 0.3190
# Test accuracy at epoch 9: 0.3190
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1440
# Test accuracy at epoch 14: 0.1440
# Test accuracy at epoch 15: 0.1440
# Test accuracy at epoch 16: 0.0640
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.1300
# Test accuracy at epoch 19: 0.1300
# Test accuracy at epoch 20: 0.1300
# Test accuracy at epoch 21: 0.1300
# Test accuracy at epoch 22: 0.1300
# Test accuracy at epoch 23: 0.1300
# Test accuracy at epoch 24: 0.3190
# Final test accuracy is: 0.319
# Training model for h_c : 50, n_l : 8 d : 0.1, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.3190
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.1030
# Test accuracy at epoch 4: 0.0640
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.1300
# Test accuracy at epoch 8: 0.1300
# Test accuracy at epoch 9: 0.3190
# Test accuracy at epoch 10: 0.3190
# Test accuracy at epoch 11: 0.0640
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1490
# Test accuracy at epoch 14: 0.1490
# Test accuracy at epoch 15: 0.1490
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.3190
# Test accuracy at epoch 18: 0.3190
# Test accuracy at epoch 19: 0.0910
# Test accuracy at epoch 20: 0.0910
# Test accuracy at epoch 21: 0.0910
# Test accuracy at epoch 22: 0.0910
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.1030
# Final test accuracy is: 0.103
# Training model for h_c : 50, n_l : 8 d : 0.1, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.0640
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.0910
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.1440
# Test accuracy at epoch 7: 0.1030
# Test accuracy at epoch 8: 0.1030
# Test accuracy at epoch 9: 0.1030
# Test accuracy at epoch 10: 0.0640
# Test accuracy at epoch 11: 0.0640
# Test accuracy at epoch 12: 0.3190
# Test accuracy at epoch 13: 0.3190
# Test accuracy at epoch 14: 0.0910
# Test accuracy at epoch 15: 0.0910
# Test accuracy at epoch 16: 0.1300
# Test accuracy at epoch 17: 0.1300
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.0640
# Test accuracy at epoch 21: 0.1030
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.1300
# Final test accuracy is: 0.13
# Training model for h_c : 50, n_l : 8 d : 0.1, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.0910
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.1030
# Test accuracy at epoch 5: 0.1440
# Test accuracy at epoch 6: 0.1440
# Test accuracy at epoch 7: 0.1490
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.0910
# Test accuracy at epoch 10: 0.0910
# Test accuracy at epoch 11: 0.0910
# Test accuracy at epoch 12: 0.3190
# Test accuracy at epoch 13: 0.0640
# Test accuracy at epoch 14: 0.0640
# Test accuracy at epoch 15: 0.0640
# Test accuracy at epoch 16: 0.1440
# Test accuracy at epoch 17: 0.1440
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.0640
# Test accuracy at epoch 21: 0.0640
# Test accuracy at epoch 22: 0.1300
# Test accuracy at epoch 23: 0.1440
# Test accuracy at epoch 24: 0.0640
# Final test accuracy is: 0.064
# Training model for h_c : 50, n_l : 8 d : 0.1, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1300
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.1030
# Test accuracy at epoch 5: 0.1030
# Test accuracy at epoch 6: 0.1440
# Test accuracy at epoch 7: 0.1440
# Test accuracy at epoch 8: 0.1440
# Test accuracy at epoch 9: 0.1440
# Test accuracy at epoch 10: 0.0640
# Test accuracy at epoch 11: 0.0640
# Test accuracy at epoch 12: 0.1300
# Test accuracy at epoch 13: 0.1300
# Test accuracy at epoch 14: 0.1300
# Test accuracy at epoch 15: 0.1300
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.1490
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.1490
# Test accuracy at epoch 20: 0.3190
# Test accuracy at epoch 21: 0.1030
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.3190
# Test accuracy at epoch 24: 0.0910
# Final test accuracy is: 0.091
# Training model for h_c : 50, n_l : 8 d : 0.2, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.0910
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.0910
# Test accuracy at epoch 3: 0.3190
# Test accuracy at epoch 4: 0.3190
# Test accuracy at epoch 5: 0.3190
# Test accuracy at epoch 6: 0.1440
# Test accuracy at epoch 7: 0.3190
# Test accuracy at epoch 8: 0.3190
# Test accuracy at epoch 9: 0.1490
# Test accuracy at epoch 10: 0.1490
# Test accuracy at epoch 11: 0.1300
# Test accuracy at epoch 12: 0.1300
# Test accuracy at epoch 13: 0.1300
# Test accuracy at epoch 14: 0.1300
# Test accuracy at epoch 15: 0.1300
# Test accuracy at epoch 16: 0.1300
# Test accuracy at epoch 17: 0.1030
# Test accuracy at epoch 18: 0.1030
# Test accuracy at epoch 19: 0.1030
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1490
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.3190
# Final test accuracy is: 0.319
# Training model for h_c : 50, n_l : 8 d : 0.2, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.3190
# Test accuracy at epoch 2: 0.3190
# Test accuracy at epoch 3: 0.1440
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.1300
# Test accuracy at epoch 7: 0.0640
# Test accuracy at epoch 8: 0.0640
# Test accuracy at epoch 9: 0.0640
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.0910
# Test accuracy at epoch 14: 0.1030
# Test accuracy at epoch 15: 0.1030
# Test accuracy at epoch 16: 0.1030
# Test accuracy at epoch 17: 0.1300
# Test accuracy at epoch 18: 0.1300
# Test accuracy at epoch 19: 0.1300
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1490
# Test accuracy at epoch 22: 0.1490
# Test accuracy at epoch 23: 0.3190
# Test accuracy at epoch 24: 0.3190
# Final test accuracy is: 0.319
# Training model for h_c : 50, n_l : 8 d : 0.2, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.1440
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.1300
# Test accuracy at epoch 4: 0.1300
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.0640
# Test accuracy at epoch 7: 0.0640
# Test accuracy at epoch 8: 0.0910
# Test accuracy at epoch 9: 0.0910
# Test accuracy at epoch 10: 0.1030
# Test accuracy at epoch 11: 0.1030
# Test accuracy at epoch 12: 0.1030
# Test accuracy at epoch 13: 0.1030
# Test accuracy at epoch 14: 0.1440
# Test accuracy at epoch 15: 0.1440
# Test accuracy at epoch 16: 0.0640
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.3190
# Test accuracy at epoch 19: 0.3190
# Test accuracy at epoch 20: 0.0910
# Test accuracy at epoch 21: 0.0910
# Test accuracy at epoch 22: 0.0910
# Test accuracy at epoch 23: 0.1490
# Test accuracy at epoch 24: 0.1490
# Final test accuracy is: 0.149
# Training model for h_c : 50, n_l : 8 d : 0.2, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.3190
# Test accuracy at epoch 1: 0.1300
# Test accuracy at epoch 2: 0.1490
# Test accuracy at epoch 3: 0.1440
# Test accuracy at epoch 4: 0.1440
# Test accuracy at epoch 5: 0.1030
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.3190
# Test accuracy at epoch 8: 0.3190
# Test accuracy at epoch 9: 0.1440
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1490
# Test accuracy at epoch 13: 0.1490
# Test accuracy at epoch 14: 0.1490
# Test accuracy at epoch 15: 0.1300
# Test accuracy at epoch 16: 0.1300
# Test accuracy at epoch 17: 0.0910
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.0640
# Test accuracy at epoch 21: 0.1440
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.1300
# Final test accuracy is: 0.13
# Training model for h_c : 50, n_l : 8 d : 0.2, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.1030
# Test accuracy at epoch 2: 0.0910
# Test accuracy at epoch 3: 0.0640
# Test accuracy at epoch 4: 0.0640
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.1490
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.1490
# Test accuracy at epoch 10: 0.1300
# Test accuracy at epoch 11: 0.0910
# Test accuracy at epoch 12: 0.0910
# Test accuracy at epoch 13: 0.1300
# Test accuracy at epoch 14: 0.0910
# Test accuracy at epoch 15: 0.3190
# Test accuracy at epoch 16: 0.0640
# Test accuracy at epoch 17: 0.0640
# Test accuracy at epoch 18: 0.0640
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.1030
# Test accuracy at epoch 21: 0.1030
# Test accuracy at epoch 22: 0.1440
# Test accuracy at epoch 23: 0.1440
# Test accuracy at epoch 24: 0.1440
# Final test accuracy is: 0.144
# Training model for h_c : 50, n_l : 8 d : 0.3, lr : 0.01, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.1030
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1440
# Test accuracy at epoch 4: 0.1440
# Test accuracy at epoch 5: 0.1440
# Test accuracy at epoch 6: 0.1440
# Test accuracy at epoch 7: 0.1440
# Test accuracy at epoch 8: 0.1490
# Test accuracy at epoch 9: 0.1490
# Test accuracy at epoch 10: 0.1490
# Test accuracy at epoch 11: 0.0640
# Test accuracy at epoch 12: 0.0640
# Test accuracy at epoch 13: 0.0640
# Test accuracy at epoch 14: 0.0640
# Test accuracy at epoch 15: 0.1980
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.1490
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.1490
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1750
# Test accuracy at epoch 22: 0.1030
# Test accuracy at epoch 23: 0.1030
# Test accuracy at epoch 24: 0.1030
# Final test accuracy is: 0.103
# Training model for h_c : 50, n_l : 8 d : 0.3, lr : 0.03, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.0640
# Test accuracy at epoch 2: 0.1440
# Test accuracy at epoch 3: 0.1490
# Test accuracy at epoch 4: 0.1490
# Test accuracy at epoch 5: 0.1490
# Test accuracy at epoch 6: 0.1490
# Test accuracy at epoch 7: 0.0640
# Test accuracy at epoch 8: 0.0640
# Test accuracy at epoch 9: 0.0640
# Test accuracy at epoch 10: 0.1440
# Test accuracy at epoch 11: 0.1440
# Test accuracy at epoch 12: 0.1440
# Test accuracy at epoch 13: 0.1440
# Test accuracy at epoch 14: 0.1440
# Test accuracy at epoch 15: 0.1440
# Test accuracy at epoch 16: 0.1440
# Test accuracy at epoch 17: 0.1440
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.1490
# Test accuracy at epoch 20: 0.1490
# Test accuracy at epoch 21: 0.1490
# Test accuracy at epoch 22: 0.1490
# Test accuracy at epoch 23: 0.1490
# Test accuracy at epoch 24: 0.1490
# Final test accuracy is: 0.149
# Training model for h_c : 50, n_l : 8 d : 0.3, lr : 0.05, iter : 9
# Test accuracy at epoch 0: 0.1490
# Test accuracy at epoch 1: 0.0910
# Test accuracy at epoch 2: 0.1030
# Test accuracy at epoch 3: 0.1490
# Test accuracy at epoch 4: 0.1490
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.0640
# Test accuracy at epoch 7: 0.1300
# Test accuracy at epoch 8: 0.0640
# Test accuracy at epoch 9: 0.0640
# Test accuracy at epoch 10: 0.1300
# Test accuracy at epoch 11: 0.1300
# Test accuracy at epoch 12: 0.1030
# Test accuracy at epoch 13: 0.1030
# Test accuracy at epoch 14: 0.1030
# Test accuracy at epoch 15: 0.3190
# Test accuracy at epoch 16: 0.3190
# Test accuracy at epoch 17: 0.3190
# Test accuracy at epoch 18: 0.1490
# Test accuracy at epoch 19: 0.0640
# Test accuracy at epoch 20: 0.0640
# Test accuracy at epoch 21: 0.0910
# Test accuracy at epoch 22: 0.0910
# Test accuracy at epoch 23: 0.0910
# Test accuracy at epoch 24: 0.0910
# Final test accuracy is: 0.091
# Training model for h_c : 50, n_l : 8 d : 0.3, lr : 0.06, iter : 9
# Test accuracy at epoch 0: 0.1030
# Test accuracy at epoch 1: 0.0910
# Test accuracy at epoch 2: 0.1490
# Test accuracy at epoch 3: 0.1490
# Test accuracy at epoch 4: 0.0910
# Test accuracy at epoch 5: 0.0910
# Test accuracy at epoch 6: 0.0910
# Test accuracy at epoch 7: 0.1030
# Test accuracy at epoch 8: 0.1030
# Test accuracy at epoch 9: 0.1030
# Test accuracy at epoch 10: 0.1030
# Test accuracy at epoch 11: 0.0910
# Test accuracy at epoch 12: 0.1490
# Test accuracy at epoch 13: 0.1490
# Test accuracy at epoch 14: 0.1490
# Test accuracy at epoch 15: 0.1490
# Test accuracy at epoch 16: 0.1490
# Test accuracy at epoch 17: 0.1490
# Test accuracy at epoch 18: 0.3190
# Test accuracy at epoch 19: 0.1300
# Test accuracy at epoch 20: 0.1300
# Test accuracy at epoch 21: 0.1300
# Test accuracy at epoch 22: 0.0910
# Test accuracy at epoch 23: 0.0640
# Test accuracy at epoch 24: 0.0910
# Final test accuracy is: 0.091
# Training model for h_c : 50, n_l : 8 d : 0.3, lr : 0.07, iter : 9
# Test accuracy at epoch 0: 0.1440
# Test accuracy at epoch 1: 0.1490
# Test accuracy at epoch 2: 0.1300
# Test accuracy at epoch 3: 0.1300
# Test accuracy at epoch 4: 0.1440
# Test accuracy at epoch 5: 0.0640
# Test accuracy at epoch 6: 0.0640
# Test accuracy at epoch 7: 0.3190
# Test accuracy at epoch 8: 0.3190
# Test accuracy at epoch 9: 0.1300
# Test accuracy at epoch 10: 0.1300
# Test accuracy at epoch 11: 0.1490
# Test accuracy at epoch 12: 0.1030
# Test accuracy at epoch 13: 0.0640
# Test accuracy at epoch 14: 0.0910
# Test accuracy at epoch 15: 0.0910
# Test accuracy at epoch 16: 0.3190
# Test accuracy at epoch 17: 0.3190
# Test accuracy at epoch 18: 0.3190
# Test accuracy at epoch 19: 0.1030
# Test accuracy at epoch 20: 0.1030
# Test accuracy at epoch 21: 0.1030
# Test accuracy at epoch 22: 0.1300
# Test accuracy at epoch 23: 0.1300
# Test accuracy at epoch 24: 0.1300
# Final test accuracy is: 0.13
# Execution time in seconds: 8993.325975179672

# %%
file = open("./results/GS_GAT_parameterTuning_v3.pkl",'rb')
file.seek(0)
df = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8306878da588> in <module>()
# ----> 1 file = open("./GS_GAT_parameterTuning_v3.pkl",'rb')
#       2 file.seek(0)
#       3 df = pickle.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: './GS_GAT_parameterTuning_v3.pkl'

# %% [markdown]
# # New section

# %%
# %cd
# Out:
# /root

# %%
ls = grid_search_solution.values()
print(max(ls))
# Out:
# 0.821

# %%
def train(model, lr, num_epochs, data, x_type='x', edge_type='edge_index'):
  """ TODO: Define your optimizer """
  opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
  criterion = nn.CrossEntropyLoss()
  for epoch in range(1, num_epochs + 1):
    opt.zero_grad()
    out = model(data[x_type], data[edge_type])
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    opt.step()
    test_accuracy = test(model, data)
    print(f"Test accuracy at epoch {epoch}: {test_accuracy:.4f}")

# %%
def train_1(model, data, optimizer, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  # model.train()
  optimizer.zero_grad()  # Clear gradients.
  out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

# %%
# noise data creation example: add edges
edge_addition_params = {'edge_index':data.edge_index, 'node_num': data.x.shape[0]}
noise_info = {'noise_type':'edge_addition', 'params':edge_addition_params, 'noise_levels':[0.3, 0.6, 0.9 ], 'noise_param_name':'added_level'}

noise_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge addition noise
model_names = ['GNN', 'GAT', 'Graphsage']
model_params = {  # TODO random params change later
    'GNN':{'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1},
    'GAT':{'in_channels':1433, 'hidden_channels':12, 'out_channels':7, 'num_layers':3, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':14, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
}
exp_df = experiment(dataset_name=dataset_name, model_names=model_names, model_params=model_params, data=data, x_types=['x'], 
           edge_types=noise_var_names, noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

exp_df

# %%
# !pip install class_resolver
# Out:
# Collecting class_resolver
#   Downloading class_resolver-0.3.3-py3-none-any.whl (20 kB)
# Installing collected packages: class-resolver
# Successfully installed class-resolver-0.3.3

# %%
## model parameter results
import time
import pickle
from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT

startTime = time.time()

in_channels = 1433
hidden_channels = [5,6,8,9,12,15,18]
num_layers = [2,3,5,6,7,8]
out_channels = [3,5,7,9]
dropout = [0.1, 0.2, 0.3]
epochs = 25
lr_list = [0.001, 0.005, 0.01, 0.05]

grid_search_solution = {}
acc = 0
for h_c in hidden_channels:
  for n_l in num_layers:
    for o_c in out_channels:
      for d in dropout:
          for lr in lr_list:
          # model
            model = GAT(in_channels = 1433, hidden_channels = h_c, out_channels = o_c, num_layers = n_l, dropout = d)
            opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
            for ep in range(epochs):
              train_loss = train_1(model, data, opt)
              test_accuracy = test(model, data)
              print(f"Training loss at epoch {ep}: {train_loss:.4f}")
              print(f"Test accuracy at epoch {ep}: {test_accuracy:.4f}")

            test_accuracy = test(model, data)
            print("Final test accuracy is:", test_accuracy)
            grid_search_solution[(h_c, n_l, o_c, d, ep, lr)] = test_accuracy
            f = open("GS_GAT_parameterTuning.pkl","wb")
            pickle.dump(grid_search_solution, f)
            f.close()


executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-901175413768> in <module>()
#      25             opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
#      26             for ep in range(epochs):
# ---> 27               train_loss = train_1(model, data, opt)
#      28               test_accuracy = test(model, data)
#      29               print(f"Training loss at epoch {ep}: {train_loss:.4f}")
#
# <ipython-input-30-c8d999d9fcf3> in train_1(model, data, optimizer, x_type, edge_type)
#       3   # model.train()
#       4   optimizer.zero_grad()  # Clear gradients.
# ----> 5   out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
#       6   loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       7   loss.backward()  # Derive gradients.
#
# TypeError: 'NoneType' object is not subscriptable

# %%
 model =  get_model(model_name=model_name, model_params=model_params[model_name])
          optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4) # parametrize similar to model later TODO
          for epoch in range(num_epochs):
              loss = train(model, optimizer, x_type=x_type, edge_type=ed_type)

# %%
CLASSGAT(in_channels: int, hidden_channels: int, num_layers: int, out_channels: Optional[int] = None, \
         dropout: float = 0.0, act: Optional[Union[str, Callable]] = 'relu', norm: Optional[torch.nn.modules.module.Module] = None,\
         jk: Optional[str] = None, act_first: bool = False, act_kwargs: Optional[Dict[str, Any]] = None, **kwargs)

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Done!

# %%
zeros = torch.zeros(data.x.shape)
ones = torch.ones(data.x.shape)

noise = (0.1**0.5)*torch.randn(data.x.shape)
print(noise.shape)
# Out:
# torch.Size([2708, 1433])

# %%
def get_masked_noise(x,  noise_level=0.15):
  noise_added_node_num = int(noise_level * x.shape[0])
  chose_random_rows = np.random.choice(x.shape[0], noise_added_node_num, replace=False)
  #print(chose_random_rows)
  mask_rows = torch.zeros(x.shape)
  mask_rows[chose_random_rows,:] = torch.ones(1, x.shape[1])
  noise = (0.1**0.5)*torch.randn(x.shape)
  masked_noise = noise* mask_rows.int().float()

  #print(mask_rows)
  #print(noise)
  #print(masked_noise)
  return masked_noise

# %%
# data_noisy = data
data.x_noisy = data.x + noise
data.x_zeros = zeros
data.x_ones = ones

for noise_level in [0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99]:
  masked_noise = get_masked_noise(x=data.x,  noise_level=noise_level)
  data[f'x_noisy_n_{noise_level}'] = data.x + masked_noise

# %% [markdown]
# ## Training a Multi-layer Perception Network (MLP)

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F


class MLP(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(12345)
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x):
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x

model = MLP(hidden_channels=16)
print(model)
# Out:
# MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
# )

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.

def train(model, optimizer, x_type='x'):
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data[x_type])  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss

def test(model, x_type='x'):
      model.eval()
      out = model(data[x_type])
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
      test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
      return test_acc

# %%
x_type='x'
model = MLP(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  
for epoch in range(1, 201):
    loss = train(model, optimizer, x_type=x_type)
    #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
test_acc = test(model, x_type=x_type)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Test Accuracy: 0.5740

# %% [markdown]
# ## MLP different X features noise levels

# %%
noise_levels = [0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99]
x_noises =[f'x_noisy_n_{x}' for x in noise_levels ]

x_types=['x', 'x_noisy', 'x_ones'] +x_noises+['x']
for x_type in x_types:
  model = MLP(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.
  for epoch in range(1, 201):
      loss = train(model, optimizer, x_type=x_type)
      #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type=x_type)
  print(f'{x_type} Test Accuracy: {test_acc:.4f}')
# Out:
# x Test Accuracy: 0.5740
# x_noisy Test Accuracy: 0.1390
# x_ones Test Accuracy: 0.1030
# x_noisy_n_0.15 Test Accuracy: 0.5300
# x_noisy_n_0.3 Test Accuracy: 0.4280
# x_noisy_n_0.45 Test Accuracy: 0.3530
# x_noisy_n_0.6 Test Accuracy: 0.2670
# x_noisy_n_0.9 Test Accuracy: 0.1520
# x_noisy_n_0.95 Test Accuracy: 0.1370
# x_noisy_n_0.99 Test Accuracy: 0.1570
# x Test Accuracy: 0.5740

# %% [markdown]
# # GCN

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x

model = GCN(hidden_channels=16)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
# )

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

criterion = torch.nn.CrossEntropyLoss()

def train(model, optimizer, x_type='x', edge_type='edge_index'):

      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss

def test(model, x_type='x', edge_type='edge_index'):
      model.eval()
      out = model(data[x_type], data[edge_type])
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
      test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
      return test_acc

# %% [markdown]
# ## GCN different X features noise levels

# %%
noise_levels = [0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99]
x_noises =[f'x_noisy_n_{x}' for x in noise_levels ]

x_types=['x', 'x_noisy', 'x_ones'] +x_noises
for x_type in x_types:
  model = GCN(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  for epoch in range(1, 101):
      loss = train(model, optimizer, x_type=x_type)
      #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type=x_type)
  print(f'{x_type} Test Accuracy: {test_acc:.4f}')
# Out:
# x Test Accuracy: 0.8150
# x_noisy Test Accuracy: 0.5270
# x_ones Test Accuracy: 0.3190
# x_noisy_n_0.15 Test Accuracy: 0.5540
# x_noisy_n_0.3 Test Accuracy: 0.5130
# x_noisy_n_0.45 Test Accuracy: 0.5380
# x_noisy_n_0.6 Test Accuracy: 0.5230
# x_noisy_n_0.9 Test Accuracy: 0.5390
# x_noisy_n_0.95 Test Accuracy: 0.5570
# x_noisy_n_0.99 Test Accuracy: 0.5260

# %%
# remove x% edges
def remove_from_all_edges(edge_index, edges_to_remove_ratio = 0.15, remove_bidirectional=False):
  if remove_bidirectional:
    edges_to_remove_ratio /= 2
  else:
    edges_to_remove_ratio
  #print(edges_to_remove_ratio)
  edge_ratio_to_keep = 1 - edges_to_remove_ratio
  num_edges_keep= int(edge_ratio_to_keep * edge_index.shape[1])
  chose_random_edge_indices = np.random.choice(edge_index.shape[1], num_edges_keep, replace=False)

  #print(edge_index[0][chose_random_edge_indices].shape)
  #print(num_edges_keep)
  #print(edge_index.shape[1])

  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_index_removed[0] = edge_index[0][chose_random_edge_indices]
  edge_index_removed[1] = edge_index[1][chose_random_edge_indices]

  if remove_bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    edge_index_removed = torch.zeros((2,len(final_edges_bidirec_1)), dtype=torch.int64)
    edge_index_removed[0] = final_edges_bidirec_0
    edge_index_removed[1] = final_edges_bidirec_1

  return edge_index_removed

# %%
edge_index_removed = remove_from_all_edges(edge_index=data.edge_index, edges_to_remove_ratio = 0.15, remove_bidirectional=False)
data.edge_index_85 = edge_index_removed

# %%
edge_index_removed = remove_from_all_edges(edge_index=data.edge_index, edges_to_remove_ratio = 0.15, remove_bidirectional=True)
data.edge_index_85 = edge_index_removed

# %%
ed_type = 'edge_index_85'
noise_levels = [0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99]
x_noises =[f'x_noisy_n_{x}' for x in noise_levels ]

x_types=['x', 'x_noisy', 'x_ones'] +x_noises
for x_type in x_types:
  model = GCN(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  for epoch in range(1, 101):
      loss = train(model, optimizer,x_type=x_type, edge_type=ed_type)
      #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type=x_type,edge_type=ed_type)
  print(f'{x_type} Test Accuracy: {test_acc:.4f}')
# Out:
# x Test Accuracy: 0.7980
# x_noisy Test Accuracy: 0.5200
# x_ones Test Accuracy: 0.1490
# x_noisy_n_0.15 Test Accuracy: 0.6010
# x_noisy_n_0.3 Test Accuracy: 0.5360
# x_noisy_n_0.45 Test Accuracy: 0.5290
# x_noisy_n_0.6 Test Accuracy: 0.5080
# x_noisy_n_0.9 Test Accuracy: 0.4890
# x_noisy_n_0.95 Test Accuracy: 0.5160
# x_noisy_n_0.99 Test Accuracy: 0.5290

# %%
# remove x% edges from random k, top_k, bottom_k nodes

def choose_nodes(data, num_nodes, k_nodes, choose_type):
  if choose_type=='random':
    nodes_chosen = torch.from_numpy(np.random.choice(num_nodes, k_nodes, replace=False))
  elif choose_type=='top_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    top_k_nodes_degrees, top_k_nodes_indices = torch.topk(dg, k_nodes)
    #print(top_k_nodes_degrees, top_k_nodes_indices)
    nodes_chosen = top_k_nodes_indices
  elif choose_type=='bottom_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    bottom_k_nodes_degrees, bottom_k_nodes_indices = torch.topk(dg, k_nodes, largest=False)
    #print(bottom_k_nodes_degrees, bottom_k_nodes_indices)
    nodes_chosen = bottom_k_nodes_indices
  else:
    raise 'choose_type should be from random, top_k, bottom_k'
  return nodes_chosen

# to do loop for each node separately
def remove_edges_from_chosen_nodes(data, nodes_chosen, edges_to_remove_per_node_ratio):
  edges_0_list, edges_1_list = [],[]
  for nc in nodes_chosen:
    edge_0, edge_1 = remove_edge_per_node(data=data, node=nc, 
                                          edges_to_remove_per_node_ratio=edges_to_remove_per_node_ratio)
    edges_0_list.append(edge_0)
    edges_1_list.append(edge_1)

  edges_0 = torch.cat(edges_0_list, 0)
  edges_1 = torch.cat(edges_1_list, 0)

  return edges_0, edges_1

def remove_edge_per_node(data, node, edges_to_remove_per_node_ratio=0.1):
  mask_node_indices = torch.isin(data.edge_index[0], node)

  select_node_edges_0 = data.edge_index[0][mask_node_indices]
  select_node_edges_1 = data.edge_index[1][mask_node_indices]
  #print(select_node_edges_0)
  #print(select_node_edges_1)

  # choose how much of the edges we will remove for this node
  # we decide on number of edges to remove for each node based on the number of edges each node has
  # and by taking the ratio given by edges_to_remove_per_node_ratio
  # note: we use ceil to remove at least one node (unless ratio is 0)
  num_edges_remove = int(math.ceil(edges_to_remove_per_node_ratio* select_node_edges_0.shape[0]))
  # print(num_edges_remove)
  num_edges_keep = select_node_edges_0.shape[0] - num_edges_remove

  # choose random edges to keep, the rest is removed
  chose_random_edge_indices = np.random.choice(select_node_edges_0.shape[0], num_edges_keep, replace=False)
  # print(num_edges_keep)
  
  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_node_index_removed_0 = select_node_edges_0[chose_random_edge_indices]
  edge_node_index_removed_1 = select_node_edges_1[chose_random_edge_indices]

  return edge_node_index_removed_0, edge_node_index_removed_1

def remove_edges_from_nodes(data, edges_to_remove_per_node_ratio = 0.15, k_nodes=10,
                            remove_type='random', remove_bidirectional=False):
  edge_p_node_ratio_to_keep = 1 - edges_to_remove_per_node_ratio

  # choose topk, bottomk, or random
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=remove_type)

  # keep edges from remaining nodes
  mask_node_indices = torch.isin(data.edge_index[0],nodes_chosen)
  index_keep = torch.ones(data.edge_index[0].shape[0], dtype=bool)
  index_keep[mask_node_indices] = False
  edges_to_keep_0 = data.edge_index[0][index_keep]
  edges_to_keep_1 = data.edge_index[1][index_keep]
  #print(edges_to_keep_0) 
  #print(edges_to_keep_1)

  # remove one-directional or bi-directional
  edges_0_kept_chosen_nodes, edges_1_kept_chosen_nodes = remove_edges_from_chosen_nodes(data=data, 
                                                                                        nodes_chosen=nodes_chosen,
                                                                                        edges_to_remove_per_node_ratio=edges_to_remove_per_node_ratio)
  # concat edges to keep and edges_kept_chosen_nodes
  final_edges_0 = torch.cat([edges_to_keep_0, edges_0_kept_chosen_nodes], 0)
  final_edges_1 = torch.cat([edges_to_keep_1, edges_1_kept_chosen_nodes], 0)

  # do bidirectional here! IF bidirectional set to true remove both directions of the edges.
  if remove_bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    final_edges_0 = final_edges_bidirec_0
    final_edges_1 = final_edges_bidirec_1
  edge_index_removed = torch.zeros((2, final_edges_0.shape[0]), dtype=torch.int64)
  edge_index_removed[0] = final_edges_0
  edge_index_removed[1] = final_edges_1

    
  # use TORCH_GEOMETRIC.UTILS.SORT_EDGE_INDEX
  edge_index_removed_sorted = tg_utils.sort_edge_index(edge_index_removed)
  return edge_index_removed_sorted

# %%
edges = remove_edges_from_nodes(data=data, edges_to_remove_per_node_ratio = 0.5, k_nodes=1000,
                            remove_type='random', remove_bidirectional=False)

edges.shape
# Out:
# torch.Size([2, 8261])

# %%
edges = remove_edges_from_nodes(data=data, edges_to_remove_per_node_ratio = 0.5, k_nodes=1000,
                            remove_type='random', remove_bidirectional=True)

edges.shape
# Out:
# torch.Size([2, 6538])

# %%
edges = remove_edges_from_nodes(data=data, edges_to_remove_per_node_ratio = 0.5, k_nodes=1000,
                            remove_type='top_k', remove_bidirectional=False)
edges.shape
# Out:
# torch.Size([2, 6889])

# %%
# add different types of edge removals in the data

remove_type = 'bottom_k' #'top_k', 'bottom_k', 'random'
remove_bidirectional = True #False, True
k_nodes = 1000
edges_to_remove_ratios =  [0, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95]

for remove_ratio in edges_to_remove_ratios:
  edges = remove_edges_from_nodes(data=data, edges_to_remove_per_node_ratio = remove_ratio, k_nodes=k_nodes,
                              remove_type=remove_type, remove_bidirectional=remove_bidirectional)
  print(edges.shape)
  data[f'edge_removed_{remove_type}_bidirec_{remove_bidirectional}_nodes_{k_nodes}_ratio_{remove_ratio}'] = edges


edge_noises = [f'edge_removed_{remove_type}_bidirec_{remove_bidirectional}_nodes_{k_nodes}_ratio_{x}' for x in edges_to_remove_ratios ]
edge_types = ['edge_index'] + edge_noises

for ed_type in edge_types:
  model = GCN(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  for epoch in range(1, 101):
      loss = train(model, optimizer, x_type='x', edge_type=ed_type)
      #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type='x',edge_type=ed_type)
  print(f'{ed_type} Test Accuracy: {test_acc:.4f}')
# Out:
# torch.Size([2, 10556])
# torch.Size([2, 8782])
# torch.Size([2, 8758])
# torch.Size([2, 8766])
# torch.Size([2, 8768])
# torch.Size([2, 7922])
# torch.Size([2, 7922])
# torch.Size([2, 7922])
# edge_index Test Accuracy: 0.8150
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0 Test Accuracy: 0.8150
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.1 Test Accuracy: 0.7850
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.15 Test Accuracy: 0.7770
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.3 Test Accuracy: 0.7890
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.45 Test Accuracy: 0.7760
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.6 Test Accuracy: 0.7660
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.9 Test Accuracy: 0.7660
# edge_removed_bottom_k_bidirec_True_nodes_1000_ratio_0.95 Test Accuracy: 0.7660

# %%
# TODOs:
# TODO remove bidirectional - DONE

# TODO add edges:
  # TODO add random edges
  # TODO add edges to top k node 
  # TODO add edges to bottom k node 
  # TODO add edges to random k node 

# decide on experiments
# experiments/research questions
# decide on datasets
# decide models to use (mlp, gnn, graphsage, ??)
# decide on what to log, save, how to design experiments 
# reliability of experiments: 10 experiments and avg results (log each experiment)
# Run each experiment
# plots for experiments

# %%
def add_random_edges(edge_index, node_num, added_ratio = 0.15, add_bidirectional=False):
  new_edges = edge_index.T
  edge_num = new_edges.shape[0]
  num_of_new_edges = int(edge_num * added_ratio)

  for i in range(num_of_new_edges):
    while True:
      new_edge = ((torch.rand(1,2) * 1000000).to(int) % node_num)
      new_edge_flip = torch.flip(new_edge, [1])
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if add_bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break

  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %%
for added_ratio in [0.15, 0.3, 0.45, 0.6, 0.9, 1.2]:
  new_edges = add_random_edges(data.edge_index, data.x.shape[0],  added_ratio=added_ratio, add_bidirectional=True)
  data[f'edge_index_added_n_{added_ratio}'] = new_edges

# %%
added_levels = [0.15, 0.3, 0.45, 0.6, 0.9, 1.2]
edge_noises = [f'edge_index_added_n_{x}' for x in added_levels ]
edge_types = ['edge_index'] + edge_noises

for ed_type in edge_types:
  model = GCN(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  for epoch in range(1, 101):
      loss = train(model, optimizer, x_type='x', edge_type=ed_type)
      # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type='x',edge_type=ed_type)
  print(f'{ed_type} Test Accuracy: {test_acc:.4f}')
# Out:
# edge_index Test Accuracy: 0.8150
# edge_index_added_n_0.15 Test Accuracy: 0.7470
# edge_index_added_n_0.3 Test Accuracy: 0.7030
# edge_index_added_n_0.45 Test Accuracy: 0.6810
# edge_index_added_n_0.6 Test Accuracy: 0.5630
# edge_index_added_n_0.9 Test Accuracy: 0.5300
# edge_index_added_n_1.2 Test Accuracy: 0.4330

# %%
## Helper function of add_edges_to_nodes

def add_edges_to_a_node(data, new_edges, node, num_to_add=0, add_bidirectional=False):
  for i in range(num_to_add):

    # Running till we find the right edge to add
    while True:
      #create a random node. 1000000 is a arbitrary number which can be replaced to any number bigger than data.num_nodes
      new_index = ((torch.rand(1) * 1000000).to(int) % data.num_nodes).item()
      new_edge = torch.tensor([[node, new_index]])
      new_edge_flip = torch.flip(new_edge, [1])
      #check whether the new edge and flip one exists or not 
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if add_bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
  return new_edges

## Adding x% edges to random k, top k, or bottom k nodes

def add_edges_to_nodes(data, added_ratio=0.15, k_nodes=10, add_type='random', add_bidirectional=False):
  #choose nodes by three different types
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=add_type)
  
  new_edges = data.edge_index.T

  #add new edges to every chosen node
  for node in nodes_chosen:
    edge_num_of_node = torch.isin(data.edge_index, node).to(int).sum()
    edge_num_to_add = int(edge_num_of_node * added_ratio)
    
    new_edges = add_edges_to_a_node(data, new_edges, node.item(), edge_num_to_add, add_bidirectional)
  
  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %%
from re import X
# add different types of edge addition in the data
add_type = 'top_k' #'top_k', 'bottom_k', 'random'
add_bidirectional = True #False, True
k_nodes = 1000
edges_to_add_ratios =  [0, 0.1, 0.15, 0.3, 0.45, 0.6]

for add_ratio in edges_to_add_ratios:
  edges = add_edges_to_nodes(data=data, added_ratio = add_ratio, k_nodes=k_nodes,
                              add_type=add_type, add_bidirectional=add_bidirectional)
  print(edges.shape)
  data[f'edge_added_{add_type}_bidirec_{add_bidirectional}_nodes_{k_nodes}_ratio_{add_ratio}'] = edges


edge_noises = [f'edge_added_{add_type}_bidirec_{add_bidirectional}_nodes_{k_nodes}_ratio_{x}' for x in edges_to_add_ratios ]
edge_types = ['edge_index'] + edge_noises

for ed_type in edge_types:
  model = GCN(hidden_channels=16)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
  for epoch in range(1, 101):
      loss = train(model, optimizer, x_type='x', edge_type=ed_type)
      #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
  test_acc = test(model, x_type='x',edge_type=ed_type)
  print(f'{ed_type} Test Accuracy: {test_acc:.4f}')
# Out:
# torch.Size([2, 10556])
# torch.Size([2, 12530])
# torch.Size([2, 13894])
# torch.Size([2, 18212])
# torch.Size([2, 22034])
# torch.Size([2, 26326])
# edge_index Test Accuracy: 0.8150
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0 Test Accuracy: 0.8150
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0.1 Test Accuracy: 0.7690
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0.15 Test Accuracy: 0.7590
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0.3 Test Accuracy: 0.6430
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0.45 Test Accuracy: 0.5500
# edge_added_top_k_bidirec_True_nodes_1000_ratio_0.6 Test Accuracy: 0.4480

# %% [markdown]
# ## Experiments

# %%
from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT

# %%
def get_model(model_name, model_params):
  # add more model from here if needed: https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#models
  # you can also check model parameters from above
  model = None
  if model_name=='MLP':
    model = MLP(**model_params)
  elif model_name=='GNN':
    model = GCN(**model_params)
  elif model_name=='Graphsage':
    model = GraphSAGE(**model_params)
  elif model_name=='GAT':
    model = GAT(**model_params)
  else:
    raise 'Model names should be within MLP, GNN, GAT, Graphsage'
  return model

# %%
# Creating MLP example, add all parameters you want to use to create/tune model in the below dictionary
model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3}
mlp_model = get_model(model_name='MLP', model_params=model_params)
print(mlp_model)

model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
gnn_model = get_model(model_name='GNN', model_params=model_params)
print(gnn_model)
# Out:
# MLP(1433, 16, 16, 7)
# GCN(1433, 7, num_layers=3)

# %%
def get_noise_function(noise_info):
  '''
  This function directly returns the function we created for different noise logics
  Change the name of the function below if noise logic function name is changed.
  '''
  noise_fn = None 
  if noise_info['noise_type']=='feature_noise':
    noise_fn = get_masked_noise
  elif noise_info['noise_type']=='edge_removal':
    if noise_info['strategy']=='all_edges' :
      noise_fn = remove_from_all_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = remove_edges_from_nodes
  elif noise_info['noise_type']=='edge_addition':
    noise_fn = add_edges
  else:
    raise 'Noise type should be chosen from feature_noise, edge_removal, edge_addition' 
  return noise_fn
  

def create_noised_data_for_experiment(data, noise_info):
  '''
  Create noised data outside of experiment, so that you can use same data in different experiments
  '''
  noise_data_names = []
  noise_fn = get_noise_function(noise_info)
  
  if noise_info['noise_type']=='edge_removal' and  noise_info.get('strategy')=='nodes':
    add_prefix = f"{noise_info['params'].get('strategy', '')}_removetype-{noise_info['params'].get('remove_type', '')}_knodes-{noise_info['params'].get('k_nodes', '')}_bidirec-{noise_info['params'].get('remove_bidirectional', '')}"
  elif noise_info['noise_type']=='edge_removal' and  noise_info.get('strategy')=='all_edges':
    add_prefix = f"{noise_info.get('strategy', '')}_"
  else: 
    add_prefix=''
  for noise_level in noise_info['noise_levels']:
    noise_data_name = f'{noise_info["noise_type"]}_{add_prefix}{noise_level}'
    noise_info['params'][noise_info['noise_param_name']] = noise_level
    noised_data = noise_fn(**noise_info['params'])
    data[noise_data_name] = noised_data
    noise_data_names.append(noise_data_name)
  return noise_data_names
 
# reuse train and test
def train(model, optimizer, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  model.train()
  optimizer.zero_grad()  # Clear gradients.
  out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

def test(model, x_type='x', edge_type='edge_index'):
  model.eval()
  out = model(data[x_type], data[edge_type])
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
  test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
  return test_acc

def experiment(dataset_name, model_names, model_params, data, x_types, edge_types, noise_info, num_epochs=50, repeat_num=1, print_updates=False):
  '''
  Assumes the noisy data is already created and inside the data object (so that we can use same data sample for different models to compare)
  '''
  exp_count = len(x_types)*len(edge_types)*len(model_names)
  count=0
  res = []
  for model_name in model_names:
    for x_type in x_types:
      for ed_type in edge_types:
        count+=1
        if print_updates:
            print(f'Run {model_name}: {count}/{exp_count}: {x_type} - {ed_type}')
            
        for exp_num in range(1, repeat_num+1): # we will repeat experiment repeat many times, to increase results reliability
           
          model =  get_model(model_name=model_name, model_params=model_params[model_name])
          optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4) # parametrize similar to model later TODO
          for epoch in range(num_epochs):
              loss = train(model, optimizer, x_type=x_type, edge_type=ed_type)
              # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

          # we test our results in original data, no noise added ones 
          # if you want to test on noised data change them to x_type=x_type and edge_type=ed_type below
          test_acc = test(model, x_type='x',edge_type='edge_index') 
          if print_updates:
            print(f'Exp_num:{exp_num} Test Accuracy: {test_acc:.4f}')

          # TODO we can add other metrics such as runtime to log in here later
          exp_res = {'dataset_name': dataset_name,
                    'model_name':model_name, 'x_type':x_type, 
                    'edge_type':ed_type, 'test_accuracy':test_acc, 
                    'num_epochs':num_epochs, 'model_params':model_params[model_name],
                    'noise_info':noise_info, 'experiment_run_number':exp_num} # TODO add more info on experiment noise_info
          res.append(exp_res)
        

  res_df = pd.DataFrame(res, columns=exp_res.keys())
  return res_df

# %%
import pandas as pd

# %% [markdown]
# ## Sample Experiments for each type of noise

# %%
dataset_name='Cora'

# %%
# noise data creation example: add edges
edge_addition_params = {'edge_index':data.edge_index, 'node_num': data.x.shape[0]}
noise_info = {'noise_type':'edge_addition', 'params':edge_addition_params, 'noise_levels':[0.3, 0.6, 0.9 ], 'noise_param_name':'added_level'}

noise_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge addition noise
model_names = ['GNN', 'GAT', 'Graphsage']
model_params = {  # TODO random params change later
    'GNN':{'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1},
    'GAT':{'in_channels':1433, 'hidden_channels':12, 'out_channels':7, 'num_layers':3, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':14, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
}
exp_df = experiment(dataset_name=dataset_name, model_names=model_names, model_params=model_params, data=data, x_types=['x'], 
           edge_types=noise_var_names, noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

exp_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_addition_0.6=[2, 16889], edge_addition_0.9=[2, 20056], edge_addition_0=[2, 10556], edge_addition_0.3=[2, 13722], feature_noise_0=[2708, 1433], feature_noise_0.3=[2708, 1433], feature_noise_0.6=[2708, 1433], edge_removal_all_edges_0=[2, 10556], edge_removal_all_edges_0.3=[2, 7600], edge_removal_all_edges_0.6=[2, 5162], edge_removal_all_edges_0.9=[2, 3234], edge_removal_nodes_removetype-_knodes-_bidirec-0=[2, 10556], edge_removal_nodes_removetype-_knodes-_bidirec-0.3=[2, 8218], edge_removal_nodes_removetype-_knodes-_bidirec-0.6=[2, 6412], edge_removal_nodes_removetype-_knodes-_bidirec-0.9=[2, 5108], edge_removal__removetype-random_knodes-1000_bidirec-True0=[2, 10556], edge_removal__removetype-random_knodes-1000_bidirec-True0.3=[2, 8356], edge_removal__removetype-random_knodes-1000_bidirec-True0.6=[2, 6368], edge_removal__removetype-random_knodes-1000_bidirec-True0.9=[2, 4596])
# Run GNN: 1/9: x - edge_addition_0.3
# Exp_num:1 Test Accuracy: 0.5370
# Exp_num:2 Test Accuracy: 0.6300
# Exp_num:3 Test Accuracy: 0.5300
# Run GNN: 2/9: x - edge_addition_0.6
# Exp_num:1 Test Accuracy: 0.3330
# Exp_num:2 Test Accuracy: 0.4670
# Exp_num:3 Test Accuracy: 0.5530
# Run GNN: 3/9: x - edge_addition_0.9
# Exp_num:1 Test Accuracy: 0.2820
# Exp_num:2 Test Accuracy: 0.5360
# Exp_num:3 Test Accuracy: 0.4430
# Run GAT: 4/9: x - edge_addition_0.3
# Exp_num:1 Test Accuracy: 0.4340
# Exp_num:2 Test Accuracy: 0.5040
# Exp_num:3 Test Accuracy: 0.3190
# Run GAT: 5/9: x - edge_addition_0.6
# Exp_num:1 Test Accuracy: 0.3600
# Exp_num:2 Test Accuracy: 0.2490
# Exp_num:3 Test Accuracy: 0.2770
# Run GAT: 6/9: x - edge_addition_0.9
# Exp_num:1 Test Accuracy: 0.4570
# Exp_num:2 Test Accuracy: 0.6170
# Exp_num:3 Test Accuracy: 0.3180
# Run Graphsage: 7/9: x - edge_addition_0.3
# Exp_num:1 Test Accuracy: 0.5710
# Exp_num:2 Test Accuracy: 0.4270
# Exp_num:3 Test Accuracy: 0.5260
# Run Graphsage: 8/9: x - edge_addition_0.6
# Exp_num:1 Test Accuracy: 0.5800
# Exp_num:2 Test Accuracy: 0.4410
# Exp_num:3 Test Accuracy: 0.4220
# Run Graphsage: 9/9: x - edge_addition_0.9
# Exp_num:1 Test Accuracy: 0.3570
# Exp_num:2 Test Accuracy: 0.5210
# Exp_num:3 Test Accuracy: 0.3170
#    dataset_name  ... experiment_run_number
# 0          Cora  ...                     1
# 1          Cora  ...                     2
# 2          Cora  ...                     3
# 3          Cora  ...                     1
# 4          Cora  ...                     2
# 5          Cora  ...                     3
# 6          Cora  ...                     1
# 7          Cora  ...                     2
# 8          Cora  ...                     3
# 9          Cora  ...                     1
# 10         Cora  ...                     2
# 11         Cora  ...                     3
# 12         Cora  ...                     1
# 13         Cora  ...                     2
# 14         Cora  ...                     3
# 15         Cora  ...                     1
# 16         Cora  ...                     2
# 17         Cora  ...                     3
# 18         Cora  ...                     1
# 19         Cora  ...                     2
# 20         Cora  ...                     3
# 21         Cora  ...                     1
# 22         Cora  ...                     2
# 23         Cora  ...                     3
# 24         Cora  ...                     1
# 25         Cora  ...                     2
# 26         Cora  ...                     3
#
# [27 rows x 9 columns]

# %%
# noise data creation example: add noise feature
feature_noise_params = {'x':data.x}
noise_info = {'noise_type':'feature_noise', 'params':feature_noise_params, 'noise_levels':[0, 0.3, 0.6 ], 'noise_param_name':'noise_level'}

noise_var_names_feat_exp =  create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on feature noise 
model_names = ['GNN', 'GAT']
model_params = {  # TODO random params change later
    'GNN':{'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1},
    'GAT':{'in_channels':1433, 'hidden_channels':12, 'out_channels':7, 'num_layers':3, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':14, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
}
exp_df2 = experiment(dataset_name=dataset_name,model_names=model_names, model_params=model_params, data=data, x_types=noise_var_names_feat_exp, 
           edge_types=['edge_index'], noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

exp_df2
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_addition_0.6=[2, 16889], edge_addition_0.9=[2, 20056], edge_addition_0=[2, 10556], edge_addition_0.3=[2, 13722], feature_noise_0=[2708, 1433], feature_noise_0.3=[2708, 1433], feature_noise_0.6=[2708, 1433], edge_removal_all_edges_0=[2, 10556], edge_removal_all_edges_0.3=[2, 7600], edge_removal_all_edges_0.6=[2, 5162], edge_removal_all_edges_0.9=[2, 3234], edge_removal_nodes_removetype-_knodes-_bidirec-0=[2, 10556], edge_removal_nodes_removetype-_knodes-_bidirec-0.3=[2, 8218], edge_removal_nodes_removetype-_knodes-_bidirec-0.6=[2, 6412], edge_removal_nodes_removetype-_knodes-_bidirec-0.9=[2, 5108], edge_removal__removetype-random_knodes-1000_bidirec-True0=[2, 10556], edge_removal__removetype-random_knodes-1000_bidirec-True0.3=[2, 8356], edge_removal__removetype-random_knodes-1000_bidirec-True0.6=[2, 6368], edge_removal__removetype-random_knodes-1000_bidirec-True0.9=[2, 4596])
# Run GNN: 1/6: feature_noise_0 - edge_index
# Exp_num:1 Test Accuracy: 0.1300
# Exp_num:2 Test Accuracy: 0.1300
# Exp_num:3 Test Accuracy: 0.1300
# Run GNN: 2/6: feature_noise_0.3 - edge_index
# Exp_num:1 Test Accuracy: 0.1220
# Exp_num:2 Test Accuracy: 0.1930
# Exp_num:3 Test Accuracy: 0.3190
# Run GNN: 3/6: feature_noise_0.6 - edge_index
# Exp_num:1 Test Accuracy: 0.1440
# Exp_num:2 Test Accuracy: 0.1370
# Exp_num:3 Test Accuracy: 0.1290
# Run GAT: 4/6: feature_noise_0 - edge_index
# Exp_num:1 Test Accuracy: 0.1440
# Exp_num:2 Test Accuracy: 0.1030
# Exp_num:3 Test Accuracy: 0.1490
# Run GAT: 5/6: feature_noise_0.3 - edge_index
# Exp_num:1 Test Accuracy: 0.1640
# Exp_num:2 Test Accuracy: 0.0650
# Exp_num:3 Test Accuracy: 0.1390
# Run GAT: 6/6: feature_noise_0.6 - edge_index
# Exp_num:1 Test Accuracy: 0.1090
# Exp_num:2 Test Accuracy: 0.1300
# Exp_num:3 Test Accuracy: 0.1430
#    dataset_name  ... experiment_run_number
# 0          Cora  ...                     1
# 1          Cora  ...                     2
# 2          Cora  ...                     3
# 3          Cora  ...                     1
# 4          Cora  ...                     2
# 5          Cora  ...                     3
# 6          Cora  ...                     1
# 7          Cora  ...                     2
# 8          Cora  ...                     3
# 9          Cora  ...                     1
# 10         Cora  ...                     2
# 11         Cora  ...                     3
# 12         Cora  ...                     1
# 13         Cora  ...                     2
# 14         Cora  ...                     3
# 15         Cora  ...                     1
# 16         Cora  ...                     2
# 17         Cora  ...                     3
#
# [18 rows x 9 columns]

# %%
# noise data creation example: remove edges -- strategy 1: from all edges

remove_edge_params = {'edge_index':data.edge_index, 'remove_bidirectional':True}
noise_info = {'noise_type':'edge_removal', 'strategy':'all_edges', 'params':remove_edge_params, 
              'noise_levels':[0, 0.3, 0.6, 0.9 ], 'noise_param_name':'edges_to_remove_ratio'}

exp3_edge_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)


# Experiment on edge removal - strategy-all edges
model_names = ['GNN', 'Graphsage']
model_params = {  # TODO random params change later
    'GNN':{'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1},
    'GAT':{'in_channels':1433, 'hidden_channels':12, 'out_channels':7, 'num_layers':3, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':14, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
}
exp_df3 = experiment(dataset_name=dataset_name,model_names=model_names, model_params=model_params, data=data, x_types=['x'], 
           edge_types=exp3_edge_var_names, noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

exp_df3
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_addition_0.6=[2, 16889], edge_addition_0.9=[2, 20056], edge_addition_0=[2, 10556], edge_addition_0.3=[2, 13722], feature_noise_0=[2708, 1433], feature_noise_0.3=[2708, 1433], feature_noise_0.6=[2708, 1433], edge_removal_all_edges_0=[2, 10556], edge_removal_all_edges_0.3=[2, 7628], edge_removal_all_edges_0.6=[2, 5142], edge_removal_all_edges_0.9=[2, 3190], edge_removal_nodes_removetype-_knodes-_bidirec-0=[2, 10556], edge_removal_nodes_removetype-_knodes-_bidirec-0.3=[2, 8218], edge_removal_nodes_removetype-_knodes-_bidirec-0.6=[2, 6412], edge_removal_nodes_removetype-_knodes-_bidirec-0.9=[2, 5108], edge_removal__removetype-random_knodes-1000_bidirec-True0=[2, 10556], edge_removal__removetype-random_knodes-1000_bidirec-True0.3=[2, 8356], edge_removal__removetype-random_knodes-1000_bidirec-True0.6=[2, 6368], edge_removal__removetype-random_knodes-1000_bidirec-True0.9=[2, 4596])
# Run GNN: 1/8: x - edge_removal_all_edges_0
# Exp_num:1 Test Accuracy: 0.4640
# Exp_num:2 Test Accuracy: 0.5540
# Exp_num:3 Test Accuracy: 0.6960
# Run GNN: 2/8: x - edge_removal_all_edges_0.3
# Exp_num:1 Test Accuracy: 0.7450
# Exp_num:2 Test Accuracy: 0.5070
# Exp_num:3 Test Accuracy: 0.6200
# Run GNN: 3/8: x - edge_removal_all_edges_0.6
# Exp_num:1 Test Accuracy: 0.5400
# Exp_num:2 Test Accuracy: 0.4520
# Exp_num:3 Test Accuracy: 0.5310
# Run GNN: 4/8: x - edge_removal_all_edges_0.9
# Exp_num:1 Test Accuracy: 0.5940
# Exp_num:2 Test Accuracy: 0.6300
# Exp_num:3 Test Accuracy: 0.5460
# Run Graphsage: 5/8: x - edge_removal_all_edges_0
# Exp_num:1 Test Accuracy: 0.5380
# Exp_num:2 Test Accuracy: 0.4970
# Exp_num:3 Test Accuracy: 0.4670
# Run Graphsage: 6/8: x - edge_removal_all_edges_0.3
# Exp_num:1 Test Accuracy: 0.5520
# Exp_num:2 Test Accuracy: 0.3940
# Exp_num:3 Test Accuracy: 0.5030
# Run Graphsage: 7/8: x - edge_removal_all_edges_0.6
# Exp_num:1 Test Accuracy: 0.3620
# Exp_num:2 Test Accuracy: 0.6250
# Exp_num:3 Test Accuracy: 0.5790
# Run Graphsage: 8/8: x - edge_removal_all_edges_0.9
# Exp_num:1 Test Accuracy: 0.4780
# Exp_num:2 Test Accuracy: 0.2970
# Exp_num:3 Test Accuracy: 0.5830
#    dataset_name  ... experiment_run_number
# 0          Cora  ...                     1
# 1          Cora  ...                     2
# 2          Cora  ...                     3
# 3          Cora  ...                     1
# 4          Cora  ...                     2
# 5          Cora  ...                     3
# 6          Cora  ...                     1
# 7          Cora  ...                     2
# 8          Cora  ...                     3
# 9          Cora  ...                     1
# 10         Cora  ...                     2
# 11         Cora  ...                     3
# 12         Cora  ...                     1
# 13         Cora  ...                     2
# 14         Cora  ...                     3
# 15         Cora  ...                     1
# 16         Cora  ...                     2
# 17         Cora  ...                     3
# 18         Cora  ...                     1
# 19         Cora  ...                     2
# 20         Cora  ...                     3
# 21         Cora  ...                     1
# 22         Cora  ...                     2
# 23         Cora  ...                     3
#
# [24 rows x 9 columns]

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes
remove_edge_from_nodes_params = {'data':data, 'remove_bidirectional':True, 'k_nodes':1000, 'remove_type':'random'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.3, 0.6, 0.9 ], 'noise_param_name':'edges_to_remove_per_node_ratio'}

exp4_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes

model_names = ['GNN', 'Graphsage']
model_params = {  # TODO random params change later
    'GNN':{'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1},
    'GAT':{'in_channels':1433, 'hidden_channels':12, 'out_channels':7, 'num_layers':3, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':14, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
}
exp_df4 = experiment(dataset_name=dataset_name,model_names=model_names, model_params=model_params, data=data, x_types=['x'], 
           edge_types=exp4_var_names, noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

exp_df4
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_addition_0.6=[2, 16889], edge_addition_0.9=[2, 20056], edge_addition_0=[2, 10556], edge_addition_0.3=[2, 13722], feature_noise_0=[2708, 1433], feature_noise_0.3=[2708, 1433], feature_noise_0.6=[2708, 1433], edge_removal_all_edges_0=[2, 10556], edge_removal_all_edges_0.3=[2, 7628], edge_removal_all_edges_0.6=[2, 5142], edge_removal_all_edges_0.9=[2, 3190], edge_removal_nodes_removetype-_knodes-_bidirec-0=[2, 10556], edge_removal_nodes_removetype-_knodes-_bidirec-0.3=[2, 8218], edge_removal_nodes_removetype-_knodes-_bidirec-0.6=[2, 6412], edge_removal_nodes_removetype-_knodes-_bidirec-0.9=[2, 5108], edge_removal__removetype-random_knodes-1000_bidirec-True0=[2, 10556], edge_removal__removetype-random_knodes-1000_bidirec-True0.3=[2, 8418], edge_removal__removetype-random_knodes-1000_bidirec-True0.6=[2, 6322], edge_removal__removetype-random_knodes-1000_bidirec-True0.9=[2, 4732])
# Run GNN: 1/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0
# Exp_num:1 Test Accuracy: 0.4990
# Exp_num:2 Test Accuracy: 0.5920
# Exp_num:3 Test Accuracy: 0.5260
# Run GNN: 2/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.3
# Exp_num:1 Test Accuracy: 0.4060
# Exp_num:2 Test Accuracy: 0.5160
# Exp_num:3 Test Accuracy: 0.5980
# Run GNN: 3/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.6
# Exp_num:1 Test Accuracy: 0.5810
# Exp_num:2 Test Accuracy: 0.5980
# Exp_num:3 Test Accuracy: 0.3930
# Run GNN: 4/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.9
# Exp_num:1 Test Accuracy: 0.4170
# Exp_num:2 Test Accuracy: 0.6310
# Exp_num:3 Test Accuracy: 0.6950
# Run Graphsage: 5/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0
# Exp_num:1 Test Accuracy: 0.4730
# Exp_num:2 Test Accuracy: 0.6020
# Exp_num:3 Test Accuracy: 0.4990
# Run Graphsage: 6/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.3
# Exp_num:1 Test Accuracy: 0.5890
# Exp_num:2 Test Accuracy: 0.5660
# Exp_num:3 Test Accuracy: 0.3480
# Run Graphsage: 7/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.6
# Exp_num:1 Test Accuracy: 0.5160
# Exp_num:2 Test Accuracy: 0.6400
# Exp_num:3 Test Accuracy: 0.3990
# Run Graphsage: 8/8: x - edge_removal__removetype-random_knodes-1000_bidirec-True0.9
# Exp_num:1 Test Accuracy: 0.4740
# Exp_num:2 Test Accuracy: 0.5740
# Exp_num:3 Test Accuracy: 0.6690
#    dataset_name  ... experiment_run_number
# 0          Cora  ...                     1
# 1          Cora  ...                     2
# 2          Cora  ...                     3
# 3          Cora  ...                     1
# 4          Cora  ...                     2
# 5          Cora  ...                     3
# 6          Cora  ...                     1
# 7          Cora  ...                     2
# 8          Cora  ...                     3
# 9          Cora  ...                     1
# 10         Cora  ...                     2
# 11         Cora  ...                     3
# 12         Cora  ...                     1
# 13         Cora  ...                     2
# 14         Cora  ...                     3
# 15         Cora  ...                     1
# 16         Cora  ...                     2
# 17         Cora  ...                     3
# 18         Cora  ...                     1
# 19         Cora  ...                     2
# 20         Cora  ...                     3
# 21         Cora  ...                     1
# 22         Cora  ...                     2
# 23         Cora  ...                     3
#
# [24 rows x 9 columns]

# %%
# TODO check with different datasets
# Fine tune the models we want to use and decide final parameters
