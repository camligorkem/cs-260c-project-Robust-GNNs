# %%
# Install required packages.
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
#      |████████████████████████████████| 7.9 MB 5.4 MB/s
#      |████████████████████████████████| 3.5 MB 4.7 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch 
import numpy as np
import math


from torch_geometric.utils import degree
import torch_geometric
import torch_geometric.utils as tg_utils
import pandas as pd

# %%
# !rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Done!

# %%
def get_masked_noise(data,  noise_level=0.15):
  x = data.x
  noise_added_node_num = int(noise_level * x.shape[0])
  chose_random_rows = np.random.choice(x.shape[0], noise_added_node_num, replace=False)
  #print(chose_random_rows)
  mask_rows = torch.zeros(x.shape)
  mask_rows[chose_random_rows,:] = torch.ones(1, x.shape[1])
  noise = (0.1**0.5)*torch.randn(x.shape)
  masked_noise = noise* mask_rows.int().float()

  #print(mask_rows)
  #print(noise)
  #print(masked_noise)
  return x + masked_noise

# %%
# remove x% edges
def remove_from_all_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index

  if bidirectional:
    noise_level /= 2
  
  edge_ratio_to_keep = 1 - noise_level
  num_edges_keep= int(edge_ratio_to_keep * edge_index.shape[1])
  chose_random_edge_indices = np.random.choice(edge_index.shape[1], num_edges_keep, replace=False)

  #print(edge_index[0][chose_random_edge_indices].shape)
  #print(num_edges_keep)
  #print(edge_index.shape[1])

  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_index_removed[0] = edge_index[0][chose_random_edge_indices]
  edge_index_removed[1] = edge_index[1][chose_random_edge_indices]

  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(edge_index_removed[0], edge_index_removed[1]):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    edge_index_removed = torch.zeros((2,len(final_edges_bidirec_1)), dtype=torch.int64)
    edge_index_removed[0] = final_edges_bidirec_0
    edge_index_removed[1] = final_edges_bidirec_1

  return edge_index_removed

# %%
# remove x% edges from random k, top_k, bottom_k nodes

def choose_nodes(data, num_nodes, k_nodes, choose_type):
  if choose_type=='random':
    nodes_chosen = torch.from_numpy(np.random.choice(num_nodes, k_nodes, replace=False))
  elif choose_type=='top_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    top_k_nodes_degrees, top_k_nodes_indices = torch.topk(dg, k_nodes)
    #print(top_k_nodes_degrees, top_k_nodes_indices)
    nodes_chosen = top_k_nodes_indices
  elif choose_type=='bottom_k':
    # find indegree edges
    dg = torch_geometric.utils.degree(data.edge_index[0])
    bottom_k_nodes_degrees, bottom_k_nodes_indices = torch.topk(dg, k_nodes, largest=False)
    #print(bottom_k_nodes_degrees, bottom_k_nodes_indices)
    nodes_chosen = bottom_k_nodes_indices
  else:
    raise 'choose_type should be from random, top_k, bottom_k'
  return nodes_chosen

# to do loop for each node separately
def remove_edges_from_chosen_nodes(data, nodes_chosen, edges_to_remove_per_node_ratio):
  edges_0_list, edges_1_list = [],[]
  for nc in nodes_chosen:
    edge_0, edge_1 = remove_edge_per_node(data=data, node=nc, 
                                          edges_to_remove_per_node_ratio=edges_to_remove_per_node_ratio)
    edges_0_list.append(edge_0)
    edges_1_list.append(edge_1)

  edges_0 = torch.cat(edges_0_list, 0)
  edges_1 = torch.cat(edges_1_list, 0)

  return edges_0, edges_1

def remove_edge_per_node(data, node, edges_to_remove_per_node_ratio=0.1):
  mask_node_indices = torch.isin(data.edge_index[0], node)

  select_node_edges_0 = data.edge_index[0][mask_node_indices]
  select_node_edges_1 = data.edge_index[1][mask_node_indices]
  #print(select_node_edges_0)
  #print(select_node_edges_1)

  # choose how much of the edges we will remove for this node
  # we decide on number of edges to remove for each node based on the number of edges each node has
  # and by taking the ratio given by edges_to_remove_per_node_ratio
  # note: we use ceil to remove at least one node (unless ratio is 0)
  num_edges_remove = int(math.ceil(edges_to_remove_per_node_ratio* select_node_edges_0.shape[0]))
  # print(num_edges_remove)
  num_edges_keep = select_node_edges_0.shape[0] - num_edges_remove

  # choose random edges to keep, the rest is removed
  chose_random_edge_indices = np.random.choice(select_node_edges_0.shape[0], num_edges_keep, replace=False)
  # print(num_edges_keep)
  
  edge_index_removed = torch.zeros((2,num_edges_keep), dtype=torch.int64)
  edge_node_index_removed_0 = select_node_edges_0[chose_random_edge_indices]
  edge_node_index_removed_1 = select_node_edges_1[chose_random_edge_indices]

  return edge_node_index_removed_0, edge_node_index_removed_1

def remove_edges_from_nodes(data, noise_level = 0.15, k_nodes=10,
                            choose_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  edge_p_node_ratio_to_keep = 1 - noise_level

  # choose topk, bottomk, or random
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=choose_type)

  # keep edges from remaining nodes
  mask_node_indices = torch.isin(data.edge_index[0],nodes_chosen)
  index_keep = torch.ones(data.edge_index[0].shape[0], dtype=bool)
  index_keep[mask_node_indices] = False
  edges_to_keep_0 = data.edge_index[0][index_keep]
  edges_to_keep_1 = data.edge_index[1][index_keep]
  #print(edges_to_keep_0) 
  #print(edges_to_keep_1)

  # remove one-directional or bi-directional
  edges_0_kept_chosen_nodes, edges_1_kept_chosen_nodes = remove_edges_from_chosen_nodes(data=data, 
                                                                                        nodes_chosen=nodes_chosen,
                                                                                        edges_to_remove_per_node_ratio=noise_level)
  # concat edges to keep and edges_kept_chosen_nodes
  final_edges_0 = torch.cat([edges_to_keep_0, edges_0_kept_chosen_nodes], 0)
  final_edges_1 = torch.cat([edges_to_keep_1, edges_1_kept_chosen_nodes], 0)

  # do bidirectional here! IF bidirectional set to true remove both directions of the edges.
  if bidirectional:
    # find the node names deleted in below indices and delete also for the opposite side.
    final_edges_bidirec_0 = []
    final_edges_bidirec_1 = []

    # create a set with all edges
    edge_maps = set()
    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      edge_maps.add((e_0.item(),e_1.item()))

    for e_0, e_1 in zip(final_edges_0, final_edges_1):
      e_0_val = e_0.item()
      e_1_val = e_1.item()
      # check an edge has its other direction, if yes add to the final list, if not skip
      if (e_0_val, e_1_val) in edge_maps and (e_1_val, e_0_val) in edge_maps:
        final_edges_bidirec_0.append(e_0_val) 
        final_edges_bidirec_1.append(e_1_val)

    final_edges_bidirec_0 = torch.tensor(final_edges_bidirec_0)
    final_edges_bidirec_1 = torch.tensor(final_edges_bidirec_1)
    final_edges_0 = final_edges_bidirec_0
    final_edges_1 = final_edges_bidirec_1
  edge_index_removed = torch.zeros((2, final_edges_0.shape[0]), dtype=torch.int64)
  edge_index_removed[0] = final_edges_0
  edge_index_removed[1] = final_edges_1

    
  # use TORCH_GEOMETRIC.UTILS.SORT_EDGE_INDEX
  edge_index_removed_sorted = tg_utils.sort_edge_index(edge_index_removed)
  return edge_index_removed_sorted

# %%
def add_random_edges(data, noise_level = 0.15, bidirectional=False):
  edge_index = data.edge_index
  num_nodes = data.num_nodes

  if bidirectional:
    noise_level /= 2

  new_edges = edge_index.T
  edge_num = new_edges.shape[0]
  num_of_new_edges = int(edge_num * noise_level)

  for i in range(num_of_new_edges):
    while True:
      new_edge = ((torch.rand(1,2) * 1000000).to(int) % num_nodes)
      new_edge_flip = torch.flip(new_edge, [1])
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break

  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %%
for added_ratio in [0.15]:
  new_edges = add_random_edges(data,  noise_level=added_ratio, bidirectional=True)
  data[f'edge_index_added_n_{added_ratio}'] = new_edges

# %%
## Helper function of add_edges_to_nodes

def add_edges_to_a_node(data, new_edges, node, num_to_add=0, bidirectional=False):
  for i in range(num_to_add):

    # Running till we find the right edge to add
    while True:
      #create a random node. 1000000 is a arbitrary number which can be replaced to any number bigger than data.num_nodes
      new_index = ((torch.rand(1) * 1000000).to(int) % data.num_nodes).item()
      new_edge = torch.tensor([[node, new_index]])
      new_edge_flip = torch.flip(new_edge, [1])
      #check whether the new edge and flip one exists or not 
      new_edge_exist = torch.any(torch.all(torch.eq(new_edges,new_edge),1))
      new_edge_flip_exist = torch.any(torch.all(torch.eq(new_edges,new_edge_flip),1))
      if not new_edge_exist and not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        if bidirectional:
          new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
      elif not new_edge_exist:
        new_edges = torch.cat((new_edges,new_edge), 0)
        break
      elif not new_edge_flip_exist:
        new_edges = torch.cat((new_edges,new_edge_flip), 0)
        break
  return new_edges

## Adding x% edges to random k, top k, or bottom k nodes

def add_edges_to_nodes(data, noise_level=0.15, k_nodes=10, chosse_type='random', bidirectional=False):
  if bidirectional:
    noise_level /= 2

  #choose nodes by three different types
  nodes_chosen = choose_nodes(data=data, num_nodes=data.num_nodes, k_nodes=k_nodes, choose_type=chosse_type)
  
  new_edges = data.edge_index.T

  #add new edges to every chosen node
  for node in nodes_chosen:
    edge_num_of_node = torch.isin(data.edge_index, node).to(int).sum()
    edge_num_to_add = int(edge_num_of_node * noise_level)
    
    new_edges = add_edges_to_a_node(data, new_edges, node.item(), edge_num_to_add, bidirectional)
  
  edge_index_sorted = tg_utils.sort_edge_index(new_edges.T)
  return edge_index_sorted

# %% [markdown]
# ## Experiments

# %%
# !pip install class-resolver

from torch_geometric.nn import MLP, GCN, GraphSAGE, GAT
from class_resolver import ClassResolver
# Out:
# Collecting class-resolver
#   Downloading class_resolver-0.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: class-resolver
# Successfully installed class-resolver-0.3.4

# %%
def get_model(model_name, model_params):
  # add more model from here if needed: https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#models
  # you can also check model parameters from above
  model = None
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
  if model_name=='MLP':
    model = MLP(**model_params).to(device)
  elif model_name=='GNN':
    model = GCN(**model_params).to(device)
  elif model_name=='GAT':
    model = GAT(**model_params).to(device)
  elif model_name=='Graphsage':
    model = GraphSAGE(**model_params).to(device)
  else:
    raise 'Model names should be within MLP, GNN, GAT, Graphsage'
  return model

# %%
# Creating MLP example, add all parameters you want to use to create/tune model in the below dictionary
model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3}
mlp_model = get_model(model_name='MLP', model_params=model_params)
print(mlp_model)

model_params= {'in_channels':1433, 'hidden_channels':16, 'out_channels':7, 'num_layers':3, 'dropout':0.1}
gnn_model = get_model(model_name='GNN', model_params=model_params)
print(gnn_model)
# Out:
# MLP(1433, 16, 16, 7)
# GCN(1433, 7, num_layers=3)

# %%
def get_noise_function(noise_info):
  '''
  This function directly returns the function we created for different noise logics
  Change the name of the function below if noise logic function name is changed.
  '''
  noise_fn = None 
  if noise_info['noise_type']=='feature_noise':
    noise_fn = get_masked_noise
  elif noise_info['noise_type']=='edge_removal':
    if noise_info['strategy']=='all_edges' :
      noise_fn = remove_from_all_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = remove_edges_from_nodes
  elif noise_info['noise_type']=='edge_addition':
    if noise_info['strategy']=='all_edges' :
      noise_fn = add_random_edges
    elif noise_info['strategy']=='nodes' :
      noise_fn = add_edges_to_nodes
  else:
    raise 'Noise type should be chosen from feature_noise, edge_removal, edge_addition' 
  return noise_fn
  

def create_noised_data_for_experiment(data, noise_info):
  '''
  Create noised data outside of experiment, so that you can use same data in different experiments
  '''
  noise_data_names = []
  noise_fn = get_noise_function(noise_info)
  
  if noise_info.get('strategy')=='nodes':
    add_prefix = f"{noise_info.get('strategy', '')}_choose_type-{noise_info['params'].get('choose_type', '')}_bidirec-{noise_info['params'].get('bidirectional', '')}"
  elif noise_info.get('strategy')=='all_edges':
    add_prefix = f"{noise_info.get('strategy', '')}_"
  else: 
    add_prefix=''

  if noise_info.get('strategy')=='nodes':
    for k_nodes in noise_info['k_nodes_list']:
      for noise_level in noise_info['noise_levels']:
        noise_data_name = f'{noise_info["noise_type"]}_{add_prefix}_knodes-{k_nodes}_noiselvl-{noise_level}'
        noise_info['params']['noise_level'] = noise_level
        noise_info['params']['k_nodes'] = k_nodes
        noised_data = noise_fn(**noise_info['params'])
        data[noise_data_name] = noised_data
        noise_data_names.append(noise_data_name)

  else: # all_edges and gaussian noisee case
    for noise_level in noise_info['noise_levels']:
      noise_data_name = f'{noise_info["noise_type"]}_{add_prefix}_noiselvl-{noise_level}'
      noise_info['params']['noise_level'] = noise_level
      noised_data = noise_fn(**noise_info['params'])
      data[noise_data_name] = noised_data
      noise_data_names.append(noise_data_name)
  return noise_data_names
 
# reuse train and test
def train(model, optimizer, x_type='x', edge_type='edge_index'):
  criterion = torch.nn.CrossEntropyLoss()
  model.train()
  optimizer.zero_grad()  # Clear gradients.
  out = model(data[x_type], data[edge_type])  # Perform a single forward pass.
  loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
  loss.backward()  # Derive gradients.
  optimizer.step()  # Update parameters based on gradients.
  return loss

def test(model, x_type='x', edge_type='edge_index'):
  model.eval()
  out = model(data[x_type], data[edge_type])
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
  test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
  return test_acc

def validation(model, x_type='x', edge_type='edge_index'):
  model.eval()
  out = model(data[x_type], data[edge_type])
  pred = out.argmax(dim=1)  # Use the class with highest probability.
  val_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
  val_acc = int(val_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
  return val_acc

def experiment(dataset_name, model_names, model_params, data, x_types, edge_types, noise_info, opt_params,  num_epochs=50, repeat_num=1, print_updates=False,print_updates_detail=False):
  '''
  Assumes the noisy data is already created and inside the data object (so that we can use same data sample for different models to compare)
  '''
  exp_count = len(x_types)*len(edge_types)*len(model_names)
  count=0
  res = []
  for model_name in model_names:
    for x_type in x_types:
      for ed_type in edge_types:
        count+=1
        test_accs = []
        for exp_num in range(1, repeat_num+1): # we will repeat experiment repeat many times, to increase results reliability
           
          model =  get_model(model_name=model_name, model_params=model_params[model_name])
          optimizer = torch.optim.Adam(model.parameters(), lr=opt_params[model_name]['lr'], weight_decay=opt_params[model_name]['weight_decay']) 
          for epoch in range(num_epochs):
              loss = train(model, optimizer, x_type=x_type, edge_type=ed_type)
              # print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

          # we test our results in original data, no noise added ones 
          # if you want to test on noised data change them to x_type=x_type and edge_type=ed_type below
          test_acc = test(model, x_type='x',edge_type='edge_index') 
          test_accs.append(test_acc)
          if print_updates_detail:
            print(f'Exp_num:{exp_num} Test Accuracy: {test_acc:.4f}')

        mean_test_acc = round(np.mean(test_accs), 3)
        # TODO we can add other metrics such as runtime to log in here later
        exp_res = {'dataset_name': dataset_name,
                  'model_name':model_name, 'x_type':x_type, 
                'edge_type':ed_type, 'mean_test_accuracy':str(mean_test_acc), 'test_accuracies': ','.join([str(acc) for acc in test_accs]),
                  'num_epochs':num_epochs, 'model_params': model_params[model_name],
                  'noise_info':noise_info, 'repeat_num':repeat_num} # TODO add more info on experiment noise_info
        res.append(exp_res)
        if print_updates:
            print(f'Run {model_name}: {count}/{exp_count}: {x_type} - {ed_type} Avg. Test Accuracy: {mean_test_acc}')
        
        

  res_df = pd.DataFrame(res, columns=exp_res.keys())
  return res_df

# %%
dataset_name='Cora'

# %%
def nodes_percent_to_num_nodes(percents, num_nodes):
  return [round(pct*num_nodes) for pct in percents]

# %%
# Optimized Model Params

model_params = {
     'MLP': {'in_channels':1433, 'hidden_channels':16, 'bias': True, 'dropout': 0.5 },
    'GNN':{'in_channels':1433, 'hidden_channels':30, 'out_channels':7, 'num_layers':2, 'dropout':0.2, 'aggr' :'add'},
    'GAT':{'in_channels':1433, 'hidden_channels':15, 'out_channels':7, 'num_layers':2, 'dropout':0.2},
    'Graphsage':{'in_channels':1433, 'hidden_channels':50, 'out_channels':7, 'num_layers':2, 'dropout':0.3}
}
opt_params = {
    'MLP':{'lr':0.01, 'weight_decay':5e-4},
    'GNN':{'lr':0.05, 'weight_decay':1e-6}, 
    'GAT':{'lr':0.05, 'weight_decay':5e-4}, 
    'Graphsage':{'lr':0.05, 'weight_decay':5e-4}
}

# %% [markdown]
# ### Experiment 1 - Add gaussian noise

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_1_add_gaussian_noise.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

feature_noise_params = {'data':data}
noise_info = {'noise_type':'feature_noise', 'params':feature_noise_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'noise_level'}

noise_var_names_feat_exp = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=noise_var_names_feat_exp, edge_types=['edge_index'],
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433])
# Run GNN: 1/36: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.795
# Run GNN: 2/36: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.785
# Run GNN: 3/36: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.724
# Run GNN: 4/36: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.457
# Run GNN: 5/36: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.597
# Run GNN: 6/36: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.346
# Run GNN: 7/36: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.085
# Run GNN: 8/36: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.152
# Run GNN: 9/36: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.199
# Run GNN: 10/36: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.149
# Run GNN: 11/36: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.263
# Run GNN: 12/36: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.208
# Run GAT: 13/36: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.772
# Run GAT: 14/36: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.68
# Run GAT: 15/36: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.301
# Run GAT: 16/36: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.118
# Run GAT: 17/36: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.107
# Run GAT: 18/36: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.103
# Run GAT: 19/36: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.2
# Run GAT: 20/36: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.137
# Run GAT: 21/36: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.083
# Run GAT: 22/36: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.139
# Run GAT: 23/36: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.159
# Run GAT: 24/36: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.144
# Run Graphsage: 25/36: feature_noise__noiselvl-0 - edge_index Avg. Test Accuracy: 0.778
# Run Graphsage: 26/36: feature_noise__noiselvl-0.01 - edge_index Avg. Test Accuracy: 0.772
# Run Graphsage: 27/36: feature_noise__noiselvl-0.05 - edge_index Avg. Test Accuracy: 0.69
# Run Graphsage: 28/36: feature_noise__noiselvl-0.1 - edge_index Avg. Test Accuracy: 0.545
# Run Graphsage: 29/36: feature_noise__noiselvl-0.15 - edge_index Avg. Test Accuracy: 0.505
# Run Graphsage: 30/36: feature_noise__noiselvl-0.3 - edge_index Avg. Test Accuracy: 0.407
# Run Graphsage: 31/36: feature_noise__noiselvl-0.45 - edge_index Avg. Test Accuracy: 0.072
# Run Graphsage: 32/36: feature_noise__noiselvl-0.6 - edge_index Avg. Test Accuracy: 0.144
# Run Graphsage: 33/36: feature_noise__noiselvl-0.9 - edge_index Avg. Test Accuracy: 0.193
# Run Graphsage: 34/36: feature_noise__noiselvl-0.95 - edge_index Avg. Test Accuracy: 0.156
# Run Graphsage: 35/36: feature_noise__noiselvl-0.99 - edge_index Avg. Test Accuracy: 0.164
# Run Graphsage: 36/36: feature_noise__noiselvl-1 - edge_index Avg. Test Accuracy: 0.159
#    dataset_name model_name                        x_type   edge_type  \
# 0          Cora        GNN     feature_noise__noiselvl-0  edge_index
# 1          Cora        GNN  feature_noise__noiselvl-0.01  edge_index
# 2          Cora        GNN  feature_noise__noiselvl-0.05  edge_index
# 3          Cora        GNN   feature_noise__noiselvl-0.1  edge_index
# 4          Cora        GNN  feature_noise__noiselvl-0.15  edge_index
# 5          Cora        GNN   feature_noise__noiselvl-0.3  edge_index
# 6          Cora        GNN  feature_noise__noiselvl-0.45  edge_index
# 7          Cora        GNN   feature_noise__noiselvl-0.6  edge_index
# 8          Cora        GNN   feature_noise__noiselvl-0.9  edge_index
# 9          Cora        GNN  feature_noise__noiselvl-0.95  edge_index
# 10         Cora        GNN  feature_noise__noiselvl-0.99  edge_index
# 11         Cora        GNN     feature_noise__noiselvl-1  edge_index
# 12         Cora        GAT     feature_noise__noiselvl-0  edge_index
# 13         Cora        GAT  feature_noise__noiselvl-0.01  edge_index
# 14         Cora        GAT  feature_noise__noiselvl-0.05  edge_index
# 15         Cora        GAT   feature_noise__noiselvl-0.1  edge_index
# 16         Cora        GAT  feature_noise__noiselvl-0.15  edge_index
# 17         Cora        GAT   feature_noise__noiselvl-0.3  edge_index
# 18         Cora        GAT  feature_noise__noiselvl-0.45  edge_index
# 19         Cora        GAT   feature_noise__noiselvl-0.6  edge_index
# 20         Cora        GAT   feature_noise__noiselvl-0.9  edge_index
# 21         Cora        GAT  feature_noise__noiselvl-0.95  edge_index
# 22         Cora        GAT  feature_noise__noiselvl-0.99  edge_index
# 23         Cora        GAT     feature_noise__noiselvl-1  edge_index
# 24         Cora  Graphsage     feature_noise__noiselvl-0  edge_index
# 25         Cora  Graphsage  feature_noise__noiselvl-0.01  edge_index
# 26         Cora  Graphsage  feature_noise__noiselvl-0.05  edge_index
# 27         Cora  Graphsage   feature_noise__noiselvl-0.1  edge_index
# 28         Cora  Graphsage  feature_noise__noiselvl-0.15  edge_index
# 29         Cora  Graphsage   feature_noise__noiselvl-0.3  edge_index
# 30         Cora  Graphsage  feature_noise__noiselvl-0.45  edge_index
# 31         Cora  Graphsage   feature_noise__noiselvl-0.6  edge_index
# 32         Cora  Graphsage   feature_noise__noiselvl-0.9  edge_index
# 33         Cora  Graphsage  feature_noise__noiselvl-0.95  edge_index
# 34         Cora  Graphsage  feature_noise__noiselvl-0.99  edge_index
# 35         Cora  Graphsage     feature_noise__noiselvl-1  edge_index
#
#    mean_test_accuracy    test_accuracies  num_epochs  \
# 0               0.795  0.783,0.796,0.805          25
# 1               0.785    0.769,0.785,0.8          25
# 2               0.724  0.723,0.712,0.737          25
# 3               0.457   0.41,0.505,0.457          25
# 4               0.597  0.662,0.566,0.564          25
# 5               0.346  0.414,0.332,0.293          25
# 6               0.085  0.065,0.108,0.083          25
# 7               0.152  0.144,0.167,0.145          25
# 8               0.199   0.313,0.14,0.144          25
# 9               0.149  0.159,0.185,0.103          25
# 10              0.263  0.319,0.128,0.342          25
# 11              0.208   0.11,0.188,0.325          25
# 12              0.772  0.798,0.725,0.792          25
# 13               0.68  0.683,0.622,0.736          25
# 14              0.301  0.254,0.352,0.297          25
# 15              0.118    0.16,0.064,0.13          25
# 16              0.107  0.098,0.145,0.077          25
# 17              0.103  0.155,0.064,0.091          25
# 18                0.2  0.104,0.312,0.183          25
# 19              0.137   0.136,0.144,0.13          25
# 20              0.083  0.064,0.109,0.076          25
# 21              0.139  0.129,0.144,0.144          25
# 22              0.159  0.139,0.196,0.142          25
# 23              0.144  0.144,0.144,0.144          25
# 24              0.778  0.782,0.777,0.774          25
# 25              0.772  0.768,0.762,0.785          25
# 26               0.69  0.673,0.695,0.701          25
# 27              0.545  0.541,0.509,0.584          25
# 28              0.505  0.391,0.543,0.581          25
# 29              0.407  0.429,0.385,0.406          25
# 30              0.072   0.08,0.064,0.071          25
# 31              0.144  0.144,0.144,0.144          25
# 32              0.193  0.109,0.162,0.309          25
# 33              0.156  0.153,0.226,0.088          25
# 34              0.164   0.134,0.14,0.219          25
# 35              0.159   0.195,0.131,0.15          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 50, '...
# 25  {'in_channels': 1433, 'hidden_channels': 50, '...
# 26  {'in_channels': 1433, 'hidden_channels': 50, '...
# 27  {'in_channels': 1433, 'hidden_channels': 50, '...
# 28  {'in_channels': 1433, 'hidden_channels': 50, '...
# 29  {'in_channels': 1433, 'hidden_channels': 50, '...
# 30  {'in_channels': 1433, 'hidden_channels': 50, '...
# 31  {'in_channels': 1433, 'hidden_channels': 50, '...
# 32  {'in_channels': 1433, 'hidden_channels': 50, '...
# 33  {'in_channels': 1433, 'hidden_channels': 50, '...
# 34  {'in_channels': 1433, 'hidden_channels': 50, '...
# 35  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'feature_noise', 'params': {'da...           3
# 1   {'noise_type': 'feature_noise', 'params': {'da...           3
# 2   {'noise_type': 'feature_noise', 'params': {'da...           3
# 3   {'noise_type': 'feature_noise', 'params': {'da...           3
# 4   {'noise_type': 'feature_noise', 'params': {'da...           3
# 5   {'noise_type': 'feature_noise', 'params': {'da...           3
# 6   {'noise_type': 'feature_noise', 'params': {'da...           3
# 7   {'noise_type': 'feature_noise', 'params': {'da...           3
# 8   {'noise_type': 'feature_noise', 'params': {'da...           3
# 9   {'noise_type': 'feature_noise', 'params': {'da...           3
# 10  {'noise_type': 'feature_noise', 'params': {'da...           3
# 11  {'noise_type': 'feature_noise', 'params': {'da...           3
# 12  {'noise_type': 'feature_noise', 'params': {'da...           3
# 13  {'noise_type': 'feature_noise', 'params': {'da...           3
# 14  {'noise_type': 'feature_noise', 'params': {'da...           3
# 15  {'noise_type': 'feature_noise', 'params': {'da...           3
# 16  {'noise_type': 'feature_noise', 'params': {'da...           3
# 17  {'noise_type': 'feature_noise', 'params': {'da...           3
# 18  {'noise_type': 'feature_noise', 'params': {'da...           3
# 19  {'noise_type': 'feature_noise', 'params': {'da...           3
# 20  {'noise_type': 'feature_noise', 'params': {'da...           3
# 21  {'noise_type': 'feature_noise', 'params': {'da...           3
# 22  {'noise_type': 'feature_noise', 'params': {'da...           3
# 23  {'noise_type': 'feature_noise', 'params': {'da...           3
# 24  {'noise_type': 'feature_noise', 'params': {'da...           3
# 25  {'noise_type': 'feature_noise', 'params': {'da...           3
# 26  {'noise_type': 'feature_noise', 'params': {'da...           3
# 27  {'noise_type': 'feature_noise', 'params': {'da...           3
# 28  {'noise_type': 'feature_noise', 'params': {'da...           3
# 29  {'noise_type': 'feature_noise', 'params': {'da...           3
# 30  {'noise_type': 'feature_noise', 'params': {'da...           3
# 31  {'noise_type': 'feature_noise', 'params': {'da...           3
# 32  {'noise_type': 'feature_noise', 'params': {'da...           3
# 33  {'noise_type': 'feature_noise', 'params': {'da...           3
# 34  {'noise_type': 'feature_noise', 'params': {'da...           3
# 35  {'noise_type': 'feature_noise', 'params': {'da...           3

# %% [markdown]
# ### Experiment 2 - Remove edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_2_remove_random_edges.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

remove_edge_params = {'data':data, 'bidirectional':True}
noise_info = {'noise_type':'edge_removal', 'strategy':'all_edges','params':remove_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_remove_ratio'}

exp_rm_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590])
# Run GNN: 1/36: x - edge_removal_all_edges__noiselvl-0 Avg. Test Accuracy: 0.805
# Run GNN: 2/36: x - edge_removal_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.798
# Run GNN: 3/36: x - edge_removal_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 4/36: x - edge_removal_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 5/36: x - edge_removal_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.791
# Run GNN: 6/36: x - edge_removal_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.793
# Run GNN: 7/36: x - edge_removal_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.77
# Run GNN: 8/36: x - edge_removal_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.772
# Run GNN: 9/36: x - edge_removal_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.764
# Run GNN: 10/36: x - edge_removal_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.77
# Run GNN: 11/36: x - edge_removal_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.719
# Run GNN: 12/36: x - edge_removal_all_edges__noiselvl-1 Avg. Test Accuracy: 0.734
# Run GAT: 13/36: x - edge_removal_all_edges__noiselvl-0 Avg. Test Accuracy: 0.769
# Run GAT: 14/36: x - edge_removal_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.758
# Run GAT: 15/36: x - edge_removal_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.738
# Run GAT: 16/36: x - edge_removal_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GAT: 17/36: x - edge_removal_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.752
# Run GAT: 18/36: x - edge_removal_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.769
# Run GAT: 19/36: x - edge_removal_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.77
# Run GAT: 20/36: x - edge_removal_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.766
# Run GAT: 21/36: x - edge_removal_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.741
# Run GAT: 22/36: x - edge_removal_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.726
# Run GAT: 23/36: x - edge_removal_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.733
# Run GAT: 24/36: x - edge_removal_all_edges__noiselvl-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 25/36: x - edge_removal_all_edges__noiselvl-0 Avg. Test Accuracy: 0.786
# Run Graphsage: 26/36: x - edge_removal_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.781
# Run Graphsage: 27/36: x - edge_removal_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.78
# Run Graphsage: 28/36: x - edge_removal_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.779
# Run Graphsage: 29/36: x - edge_removal_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.765
# Run Graphsage: 30/36: x - edge_removal_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run Graphsage: 31/36: x - edge_removal_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.761
# Run Graphsage: 32/36: x - edge_removal_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.757
# Run Graphsage: 33/36: x - edge_removal_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.729
# Run Graphsage: 34/36: x - edge_removal_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.724
# Run Graphsage: 35/36: x - edge_removal_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.725
# Run Graphsage: 36/36: x - edge_removal_all_edges__noiselvl-1 Avg. Test Accuracy: 0.72
#    dataset_name model_name x_type                              edge_type  \
# 0          Cora        GNN      x     edge_removal_all_edges__noiselvl-0
# 1          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.01
# 2          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.05
# 3          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.1
# 4          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.15
# 5          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.3
# 6          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.45
# 7          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.6
# 8          Cora        GNN      x   edge_removal_all_edges__noiselvl-0.9
# 9          Cora        GNN      x  edge_removal_all_edges__noiselvl-0.95
# 10         Cora        GNN      x  edge_removal_all_edges__noiselvl-0.99
# 11         Cora        GNN      x     edge_removal_all_edges__noiselvl-1
# 12         Cora        GAT      x     edge_removal_all_edges__noiselvl-0
# 13         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.01
# 14         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.05
# 15         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.1
# 16         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.15
# 17         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.3
# 18         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.45
# 19         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.6
# 20         Cora        GAT      x   edge_removal_all_edges__noiselvl-0.9
# 21         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.95
# 22         Cora        GAT      x  edge_removal_all_edges__noiselvl-0.99
# 23         Cora        GAT      x     edge_removal_all_edges__noiselvl-1
# 24         Cora  Graphsage      x     edge_removal_all_edges__noiselvl-0
# 25         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.01
# 26         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.05
# 27         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.1
# 28         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.15
# 29         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.3
# 30         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.45
# 31         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.6
# 32         Cora  Graphsage      x   edge_removal_all_edges__noiselvl-0.9
# 33         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.95
# 34         Cora  Graphsage      x  edge_removal_all_edges__noiselvl-0.99
# 35         Cora  Graphsage      x     edge_removal_all_edges__noiselvl-1
#
#    mean_test_accuracy    test_accuracies  num_epochs  \
# 0               0.805  0.814,0.804,0.796          25
# 1               0.798  0.799,0.793,0.803          25
# 2               0.789  0.799,0.774,0.794          25
# 3               0.793  0.778,0.803,0.798          25
# 4               0.791  0.797,0.801,0.776          25
# 5               0.793  0.787,0.798,0.795          25
# 6                0.77  0.785,0.769,0.757          25
# 7               0.772  0.768,0.783,0.765          25
# 8               0.764  0.761,0.767,0.764          25
# 9                0.77  0.778,0.766,0.765          25
# 10              0.719   0.71,0.714,0.733          25
# 11              0.734  0.733,0.755,0.715          25
# 12              0.769   0.79,0.761,0.756          25
# 13              0.758  0.744,0.734,0.795          25
# 14              0.738  0.736,0.725,0.754          25
# 15              0.787  0.791,0.773,0.797          25
# 16              0.752  0.748,0.733,0.774          25
# 17              0.769  0.762,0.763,0.782          25
# 18               0.77  0.774,0.767,0.769          25
# 19              0.766  0.779,0.765,0.755          25
# 20              0.741  0.745,0.727,0.752          25
# 21              0.726   0.73,0.714,0.733          25
# 22              0.733  0.731,0.708,0.759          25
# 23              0.755  0.763,0.728,0.775          25
# 24              0.786    0.8,0.786,0.773          25
# 25              0.781  0.793,0.778,0.772          25
# 26               0.78  0.782,0.787,0.772          25
# 27              0.779  0.768,0.784,0.784          25
# 28              0.765  0.767,0.756,0.771          25
# 29              0.778  0.784,0.775,0.776          25
# 30              0.761  0.762,0.739,0.783          25
# 31              0.757  0.755,0.762,0.755          25
# 32              0.729  0.735,0.732,0.721          25
# 33              0.724  0.732,0.712,0.727          25
# 34              0.725   0.74,0.726,0.709          25
# 35               0.72  0.715,0.724,0.721          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 50, '...
# 25  {'in_channels': 1433, 'hidden_channels': 50, '...
# 26  {'in_channels': 1433, 'hidden_channels': 50, '...
# 27  {'in_channels': 1433, 'hidden_channels': 50, '...
# 28  {'in_channels': 1433, 'hidden_channels': 50, '...
# 29  {'in_channels': 1433, 'hidden_channels': 50, '...
# 30  {'in_channels': 1433, 'hidden_channels': 50, '...
# 31  {'in_channels': 1433, 'hidden_channels': 50, '...
# 32  {'in_channels': 1433, 'hidden_channels': 50, '...
# 33  {'in_channels': 1433, 'hidden_channels': 50, '...
# 34  {'in_channels': 1433, 'hidden_channels': 50, '...
# 35  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 1   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 2   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 3   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 4   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 5   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 6   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 7   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 8   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 9   {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 10  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 11  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 12  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 13  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 14  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 15  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 16  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 17  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 18  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 19  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 20  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 21  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 22  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 23  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 24  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 25  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 26  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 27  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 28  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 29  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 30  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 31  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 32  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 33  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 34  {'noise_type': 'edge_removal', 'strategy': 'al...           3
# 35  {'noise_type': 'edge_removal', 'strategy': 'al...           3

# %% [markdown]
# ### Experiment 3 - Add edges randomly

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_3_add_random_edges.csv'
# **** DONT forget to change this *****

data = data.to('cpu')

add_edge_params = {'data':data, 'bidirectional':True}
# edge_addition_params = {'data':data}
noise_info = {'noise_type':'edge_addition', 'strategy':'all_edges','params':add_edge_params, \
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ],\
              'noise_param_name':'edges_to_add_ratio'}

exp_add_random_edges = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_edges,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
# exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112])
# Run GNN: 1/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.802
# Run GNN: 2/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.799
# Run GNN: 4/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 5/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 6/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.774
# Run GNN: 7/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.763
# Run GNN: 8/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.741
# Run GNN: 9/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.745
# Run GNN: 10/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.746
# Run GNN: 11/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.739
# Run GNN: 12/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.731
# Run GAT: 13/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.741
# Run GAT: 14/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.757
# Run GAT: 15/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GAT: 16/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.71
# Run GAT: 17/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.663
# Run GAT: 18/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.739
# Run GAT: 19/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.68
# Run GAT: 20/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.602
# Run GAT: 21/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.579
# Run GAT: 22/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.581
# Run GAT: 23/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.546
# Run GAT: 24/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.546
# Run Graphsage: 25/36: x - edge_addition_all_edges__noiselvl-0 Avg. Test Accuracy: 0.785
# Run Graphsage: 26/36: x - edge_addition_all_edges__noiselvl-0.01 Avg. Test Accuracy: 0.782
# Run Graphsage: 27/36: x - edge_addition_all_edges__noiselvl-0.05 Avg. Test Accuracy: 0.772
# Run Graphsage: 28/36: x - edge_addition_all_edges__noiselvl-0.1 Avg. Test Accuracy: 0.776
# Run Graphsage: 29/36: x - edge_addition_all_edges__noiselvl-0.15 Avg. Test Accuracy: 0.77
# Run Graphsage: 30/36: x - edge_addition_all_edges__noiselvl-0.3 Avg. Test Accuracy: 0.76
# Run Graphsage: 31/36: x - edge_addition_all_edges__noiselvl-0.45 Avg. Test Accuracy: 0.757
# Run Graphsage: 32/36: x - edge_addition_all_edges__noiselvl-0.6 Avg. Test Accuracy: 0.744
# Run Graphsage: 33/36: x - edge_addition_all_edges__noiselvl-0.9 Avg. Test Accuracy: 0.749
# Run Graphsage: 34/36: x - edge_addition_all_edges__noiselvl-0.95 Avg. Test Accuracy: 0.768
# Run Graphsage: 35/36: x - edge_addition_all_edges__noiselvl-0.99 Avg. Test Accuracy: 0.744
# Run Graphsage: 36/36: x - edge_addition_all_edges__noiselvl-1 Avg. Test Accuracy: 0.737
#    dataset_name model_name x_type                               edge_type  \
# 0          Cora        GNN      x     edge_addition_all_edges__noiselvl-0
# 1          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.01
# 2          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.05
# 3          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.1
# 4          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.15
# 5          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.3
# 6          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.45
# 7          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.6
# 8          Cora        GNN      x   edge_addition_all_edges__noiselvl-0.9
# 9          Cora        GNN      x  edge_addition_all_edges__noiselvl-0.95
# 10         Cora        GNN      x  edge_addition_all_edges__noiselvl-0.99
# 11         Cora        GNN      x     edge_addition_all_edges__noiselvl-1
# 12         Cora        GAT      x     edge_addition_all_edges__noiselvl-0
# 13         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.01
# 14         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.05
# 15         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.1
# 16         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.15
# 17         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.3
# 18         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.45
# 19         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.6
# 20         Cora        GAT      x   edge_addition_all_edges__noiselvl-0.9
# 21         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.95
# 22         Cora        GAT      x  edge_addition_all_edges__noiselvl-0.99
# 23         Cora        GAT      x     edge_addition_all_edges__noiselvl-1
# 24         Cora  Graphsage      x     edge_addition_all_edges__noiselvl-0
# 25         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.01
# 26         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.05
# 27         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.1
# 28         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.15
# 29         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.3
# 30         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.45
# 31         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.6
# 32         Cora  Graphsage      x   edge_addition_all_edges__noiselvl-0.9
# 33         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.95
# 34         Cora  Graphsage      x  edge_addition_all_edges__noiselvl-0.99
# 35         Cora  Graphsage      x     edge_addition_all_edges__noiselvl-1
#
#    mean_test_accuracy    test_accuracies  num_epochs  \
# 0               0.802  0.807,0.807,0.791          25
# 1               0.791   0.79,0.794,0.788          25
# 2               0.799  0.788,0.803,0.805          25
# 3               0.796  0.793,0.797,0.797          25
# 4               0.787   0.792,0.78,0.789          25
# 5               0.774  0.763,0.784,0.775          25
# 6               0.763   0.76,0.757,0.771          25
# 7               0.741  0.703,0.761,0.758          25
# 8               0.745  0.749,0.734,0.751          25
# 9               0.746  0.737,0.756,0.746          25
# 10              0.739  0.748,0.731,0.739          25
# 11              0.731   0.731,0.732,0.73          25
# 12              0.741   0.716,0.76,0.746          25
# 13              0.757  0.792,0.774,0.704          25
# 14              0.773   0.774,0.775,0.77          25
# 15               0.71   0.657,0.764,0.71          25
# 16              0.663  0.632,0.636,0.721          25
# 17              0.739  0.719,0.766,0.732          25
# 18               0.68  0.599,0.748,0.694          25
# 19              0.602  0.697,0.684,0.426          25
# 20              0.579   0.555,0.68,0.503          25
# 21              0.581   0.51,0.521,0.713          25
# 22              0.546  0.569,0.575,0.493          25
# 23              0.546  0.587,0.593,0.459          25
# 24              0.785   0.789,0.79,0.775          25
# 25              0.782  0.786,0.777,0.784          25
# 26              0.772  0.764,0.772,0.779          25
# 27              0.776  0.783,0.775,0.769          25
# 28               0.77   0.757,0.78,0.772          25
# 29               0.76  0.753,0.772,0.756          25
# 30              0.757  0.762,0.766,0.743          25
# 31              0.744  0.757,0.734,0.742          25
# 32              0.749  0.744,0.754,0.749          25
# 33              0.768  0.759,0.769,0.777          25
# 34              0.744  0.725,0.754,0.752          25
# 35              0.737   0.74,0.737,0.735          25
#
#                                          model_params  \
# 0   {'in_channels': 1433, 'hidden_channels': 30, '...
# 1   {'in_channels': 1433, 'hidden_channels': 30, '...
# 2   {'in_channels': 1433, 'hidden_channels': 30, '...
# 3   {'in_channels': 1433, 'hidden_channels': 30, '...
# 4   {'in_channels': 1433, 'hidden_channels': 30, '...
# 5   {'in_channels': 1433, 'hidden_channels': 30, '...
# 6   {'in_channels': 1433, 'hidden_channels': 30, '...
# 7   {'in_channels': 1433, 'hidden_channels': 30, '...
# 8   {'in_channels': 1433, 'hidden_channels': 30, '...
# 9   {'in_channels': 1433, 'hidden_channels': 30, '...
# 10  {'in_channels': 1433, 'hidden_channels': 30, '...
# 11  {'in_channels': 1433, 'hidden_channels': 30, '...
# 12  {'in_channels': 1433, 'hidden_channels': 15, '...
# 13  {'in_channels': 1433, 'hidden_channels': 15, '...
# 14  {'in_channels': 1433, 'hidden_channels': 15, '...
# 15  {'in_channels': 1433, 'hidden_channels': 15, '...
# 16  {'in_channels': 1433, 'hidden_channels': 15, '...
# 17  {'in_channels': 1433, 'hidden_channels': 15, '...
# 18  {'in_channels': 1433, 'hidden_channels': 15, '...
# 19  {'in_channels': 1433, 'hidden_channels': 15, '...
# 20  {'in_channels': 1433, 'hidden_channels': 15, '...
# 21  {'in_channels': 1433, 'hidden_channels': 15, '...
# 22  {'in_channels': 1433, 'hidden_channels': 15, '...
# 23  {'in_channels': 1433, 'hidden_channels': 15, '...
# 24  {'in_channels': 1433, 'hidden_channels': 50, '...
# 25  {'in_channels': 1433, 'hidden_channels': 50, '...
# 26  {'in_channels': 1433, 'hidden_channels': 50, '...
# 27  {'in_channels': 1433, 'hidden_channels': 50, '...
# 28  {'in_channels': 1433, 'hidden_channels': 50, '...
# 29  {'in_channels': 1433, 'hidden_channels': 50, '...
# 30  {'in_channels': 1433, 'hidden_channels': 50, '...
# 31  {'in_channels': 1433, 'hidden_channels': 50, '...
# 32  {'in_channels': 1433, 'hidden_channels': 50, '...
# 33  {'in_channels': 1433, 'hidden_channels': 50, '...
# 34  {'in_channels': 1433, 'hidden_channels': 50, '...
# 35  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                            noise_info  repeat_num
# 0   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 1   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 2   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 3   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 4   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 5   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 6   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 7   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 8   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 9   {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 10  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 11  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 12  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 13  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 14  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 15  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 16  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 17  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 18  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 19  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 20  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 21  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 22  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 23  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 24  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 25  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 26  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 27  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 28  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 29  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 30  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 31  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 32  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 33  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 34  {'noise_type': 'edge_addition', 'strategy': 'a...           3
# 35  {'noise_type': 'edge_addition', 'strategy': 'a...           3

# %% [markdown]
# ### Experiment 4 - Remove Edges: Random - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_4_remove_random_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'random'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10264], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10210], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9938], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9968], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9948], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9994], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9916], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9404], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9374], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], ed ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.804
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.801
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.802
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.797
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.795
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.799
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.803
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.803
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.793
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.798
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.791
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.798
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.787
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.808
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.8
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.797
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.783
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.793
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.798
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.801
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.787
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.806
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.799
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.78
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.79
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.789
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.791
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.806
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.725
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.755
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.746
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.767
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.766
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.722
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.732
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.755
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.758
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.742
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.765
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.763
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.738
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.738
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.758
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.731
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.756
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.766
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.749
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.762
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.765
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.755
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.736
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.759
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.781
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.777
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.754
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.775
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.773
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.754
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.76
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.755
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.776
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.783
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.768
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.774
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.772
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.777
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.778
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.779
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.768
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.782
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.781
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.768
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.778
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.771
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.774
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.774
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.769
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.783
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.775
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.779
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.776
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.779
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.784
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.774
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.771
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.779
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.784
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.772
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.772
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.756
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.763
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.769
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.781
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.773
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-random_bidirec-...              0.804
# 1    edge_removal_nodes_choose_type-random_bidirec-...              0.795
# 2    edge_removal_nodes_choose_type-random_bidirec-...              0.801
# 3    edge_removal_nodes_choose_type-random_bidirec-...              0.802
# 4    edge_removal_nodes_choose_type-random_bidirec-...              0.797
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-random_bidirec-...              0.756
# 104  edge_removal_nodes_choose_type-random_bidirec-...              0.763
# 105  edge_removal_nodes_choose_type-random_bidirec-...              0.769
# 106  edge_removal_nodes_choose_type-random_bidirec-...              0.781
# 107  edge_removal_nodes_choose_type-random_bidirec-...              0.773
#
#        test_accuracies  num_epochs  \
# 0      0.804,0.8,0.808          25
# 1    0.799,0.801,0.785          25
# 2    0.805,0.793,0.804          25
# 3    0.794,0.806,0.806          25
# 4       0.78,0.812,0.8          25
# ..                 ...         ...
# 103  0.762,0.745,0.761          25
# 104   0.74,0.771,0.777          25
# 105  0.765,0.777,0.764          25
# 106  0.786,0.785,0.773          25
# 107  0.776,0.776,0.768          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0        random          True     135           0
# 1        random          True     135        0.01
# 2        random          True     135        0.05
# 3        random          True     135         0.1
# 4        random          True     135        0.15
# ..          ...           ...     ...         ...
# 103      random          True     542         0.6
# 104      random          True     542         0.9
# 105      random          True     542        0.95
# 106      random          True     542        0.99
# 107      random          True     542           1
#
# [108 rows x 14 columns]

# %% [markdown]
# ### Experiment 5 - Remove Edges: topk - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_5_remove_topk_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10264], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10210], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9938], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9968], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9948], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9994], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9916], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9404], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9374], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], ed ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.8
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.795
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.796
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.796
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.79
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.782
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.771
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.79
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.791
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.8
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.804
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.796
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.797
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.786
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.769
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.774
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.797
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.779
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.783
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.789
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.805
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.798
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.806
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.781
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.782
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.762
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.793
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.764
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.771
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.744
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.714
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.717
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.767
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.778
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.756
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.762
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.748
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.734
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.759
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.737
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.77
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.739
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.752
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.775
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.762
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.763
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.745
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.733
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.774
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.773
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.725
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.752
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.782
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.773
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.767
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.781
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.771
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.782
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.725
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.789
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.739
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.76
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.774
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.784
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.771
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.783
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.773
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.786
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.784
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.77
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.784
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.777
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.774
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.767
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.775
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.783
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.778
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.784
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.776
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.785
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.77
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.779
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.781
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.779
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.773
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.78
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.781
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.783
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.781
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.781
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.78
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.776
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.779
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.766
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.762
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.767
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.767
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-top_k_bidirec-T...                0.8
# 1    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.791
# 2    edge_removal_nodes_choose_type-top_k_bidirec-T...                0.8
# 3    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.787
# 4    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.795
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.779
# 104  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.766
# 105  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.762
# 106  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.767
# 107  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.767
#
#        test_accuracies  num_epochs  \
# 0    0.805,0.801,0.795          25
# 1    0.794,0.799,0.781          25
# 2    0.797,0.804,0.799          25
# 3    0.772,0.792,0.797          25
# 4    0.802,0.798,0.785          25
# ..                 ...         ...
# 103  0.782,0.767,0.787          25
# 104  0.754,0.765,0.779          25
# 105  0.757,0.764,0.766          25
# 106  0.765,0.772,0.765          25
# 107  0.756,0.771,0.775          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0           top          True     135           0
# 1           top          True     135        0.01
# 2           top          True     135        0.05
# 3           top          True     135         0.1
# 4           top          True     135        0.15
# ..          ...           ...     ...         ...
# 103         top          True     542         0.6
# 104         top          True     542         0.9
# 105         top          True     542        0.95
# 106         top          True     542        0.99
# 107         top          True     542           1
#
# [108 rows x 14 columns]

# %% [markdown]
# ### Experiment 6 - Remove Edges: Bottom k - nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_6_remove_bottomk_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
remove_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':remove_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_rm_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_rm_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_rm_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_rm_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_rm_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_rm_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10284], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10264], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10210], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10146], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9938], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9968], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9948], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10028], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10016], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 9994], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9916], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9728], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9366], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9404], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9374], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], ed ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.793
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.791
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.799
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.794
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.794
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.792
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.783
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.788
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.786
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.801
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.792
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.796
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.789
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.799
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.79
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.798
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.796
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.786
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.793
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.798
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.801
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.798
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.791
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.798
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.787
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.799
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.764
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.734
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.746
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.759
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.769
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.758
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.761
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.729
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.754
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.757
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.737
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.759
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.779
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.739
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.77
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.789
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.747
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.749
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.752
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.78
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.753
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.768
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.72
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.774
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.779
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.784
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.763
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.755
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.764
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.758
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.742
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.788
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.734
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.782
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.779
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.764
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.776
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.774
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.767
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.774
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.774
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.776
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.772
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.768
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.765
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.778
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.764
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.776
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.77
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.779
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.781
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.766
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.765
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.761
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.768
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.765
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.78
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.767
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.764
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.767
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.754
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.773
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.765
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.762
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.768
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.772
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.776
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.771
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-bottom_k_bidire...              0.793
# 1    edge_removal_nodes_choose_type-bottom_k_bidire...              0.791
# 2    edge_removal_nodes_choose_type-bottom_k_bidire...              0.789
# 3    edge_removal_nodes_choose_type-bottom_k_bidire...              0.799
# 4    edge_removal_nodes_choose_type-bottom_k_bidire...              0.794
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-bottom_k_bidire...              0.762
# 104  edge_removal_nodes_choose_type-bottom_k_bidire...              0.768
# 105  edge_removal_nodes_choose_type-bottom_k_bidire...              0.772
# 106  edge_removal_nodes_choose_type-bottom_k_bidire...              0.776
# 107  edge_removal_nodes_choose_type-bottom_k_bidire...              0.771
#
#        test_accuracies  num_epochs  \
# 0    0.785,0.806,0.789          25
# 1    0.785,0.789,0.798          25
# 2     0.784,0.79,0.794          25
# 3    0.799,0.796,0.803          25
# 4    0.804,0.791,0.787          25
# ..                 ...         ...
# 103  0.765,0.765,0.757          25
# 104  0.774,0.768,0.763          25
# 105  0.767,0.775,0.773          25
# 106  0.779,0.777,0.773          25
# 107  0.779,0.773,0.762          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0        bottom          True     135           0
# 1        bottom          True     135        0.01
# 2        bottom          True     135        0.05
# 3        bottom          True     135         0.1
# 4        bottom          True     135        0.15
# ..          ...           ...     ...         ...
# 103      bottom          True     542         0.6
# 104      bottom          True     542         0.9
# 105      bottom          True     542        0.95
# 106      bottom          True     542        0.99
# 107      bottom          True     542           1
#
# [108 rows x 14 columns]

# %% [markdown]
# ### Experiment 7 - Add Edges: random nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_7_add_random_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'random'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_add_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10252], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10174], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10152], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9998], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9928], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9902], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10026], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10020], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10018], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9912], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9788], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9694], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9442], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9346], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9354], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9538], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], e ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.796
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.789
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.798
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.801
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.788
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.788
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.796
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.785
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.796
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.794
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.796
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.801
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.8
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.794
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.793
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.795
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.796
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.782
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.786
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.801
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.8
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.795
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.796
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.789
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.793
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.791
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.791
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.781
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.785
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.774
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.774
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.728
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.753
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.733
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.787
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.774
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.766
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.736
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.767
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.761
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.757
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.768
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.788
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.776
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.765
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.782
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.753
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.781
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.759
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.751
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.779
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.763
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.758
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.77
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.781
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.775
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.767
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.758
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.768
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.744
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.763
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.76
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.733
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.753
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.786
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.779
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.783
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.78
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.765
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.782
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.771
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.782
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.782
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.774
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.762
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.788
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.78
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.776
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.766
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.769
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.767
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.778
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.764
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.774
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.77
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.768
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.777
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.769
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.777
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.765
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.771
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.754
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.766
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.771
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.76
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.765
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.748
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-random_bidirec-...              0.798
# 1    edge_removal_nodes_choose_type-random_bidirec-...              0.796
# 2    edge_removal_nodes_choose_type-random_bidirec-...              0.789
# 3    edge_removal_nodes_choose_type-random_bidirec-...              0.798
# 4    edge_removal_nodes_choose_type-random_bidirec-...              0.801
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-random_bidirec-...              0.766
# 104  edge_removal_nodes_choose_type-random_bidirec-...              0.771
# 105  edge_removal_nodes_choose_type-random_bidirec-...               0.76
# 106  edge_removal_nodes_choose_type-random_bidirec-...              0.765
# 107  edge_removal_nodes_choose_type-random_bidirec-...              0.748
#
#        test_accuracies  num_epochs  \
# 0     0.804,0.811,0.78          25
# 1      0.8,0.799,0.788          25
# 2    0.793,0.769,0.804          25
# 3    0.798,0.808,0.789          25
# 4      0.8,0.805,0.797          25
# ..                 ...         ...
# 103   0.766,0.763,0.77          25
# 104  0.767,0.778,0.768          25
# 105  0.744,0.763,0.773          25
# 106  0.764,0.769,0.761          25
# 107  0.757,0.752,0.735          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0        random          True     135           0
# 1        random          True     135        0.01
# 2        random          True     135        0.05
# 3        random          True     135         0.1
# 4        random          True     135        0.15
# ..          ...           ...     ...         ...
# 103      random          True     542         0.6
# 104      random          True     542         0.9
# 105      random          True     542        0.95
# 106      random          True     542        0.99
# 107      random          True     542           1
#
# [108 rows x 14 columns]

# %% [markdown]
# ### Experiment 8 - Add Edges: topk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_8_add_topk_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'top_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10252], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10174], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10152], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9998], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9928], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9902], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10026], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10020], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10018], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9912], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9788], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9694], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9442], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9346], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9354], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9538], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], e ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.792
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.794
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.791
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.797
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.783
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.794
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.795
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.798
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.778
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.797
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.798
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.796
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.787
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.797
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.795
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.796
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.789
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.785
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.77
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.782
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.791
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.794
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.788
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.794
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.808
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.799
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.794
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.787
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.779
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.782
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.788
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.775
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.785
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.765
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.765
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.772
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.734
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.772
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.765
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.76
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.769
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.739
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.737
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.753
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.768
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.745
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.757
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.759
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.742
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.773
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.78
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.774
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.748
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.77
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.766
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.756
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.719
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.747
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.783
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.775
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.785
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.774
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.728
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.768
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.761
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.756
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.743
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.785
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.773
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.781
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.779
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.77
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.784
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.777
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.779
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.78
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.77
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.766
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.775
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.781
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.786
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.773
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.783
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.781
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.787
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.777
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.759
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.778
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.759
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.792
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.782
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.791
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.78
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.775
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.767
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.768
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.769
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.777
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-top_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.762
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.798
# 1    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.792
# 2    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.791
# 3    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.794
# 4    edge_removal_nodes_choose_type-top_k_bidirec-T...              0.791
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.767
# 104  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.768
# 105  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.769
# 106  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.777
# 107  edge_removal_nodes_choose_type-top_k_bidirec-T...              0.762
#
#        test_accuracies  num_epochs  \
# 0      0.799,0.796,0.8          25
# 1    0.788,0.795,0.792          25
# 2    0.797,0.784,0.792          25
# 3    0.796,0.787,0.799          25
# 4    0.789,0.797,0.786          25
# ..                 ...         ...
# 103   0.769,0.773,0.76          25
# 104  0.774,0.765,0.766          25
# 105  0.792,0.765,0.751          25
# 106   0.78,0.766,0.785          25
# 107  0.746,0.772,0.767          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0        bottom          True     135           0
# 1        bottom          True     135        0.01
# 2        bottom          True     135        0.05
# 3        bottom          True     135         0.1
# 4        bottom          True     135        0.15
# ..          ...           ...     ...         ...
# 103      bottom          True     542         0.6
# 104      bottom          True     542         0.9
# 105      bottom          True     542        0.95
# 106      bottom          True     542        0.99
# 107      bottom          True     542           1
#
# [108 rows x 14 columns]

# %% [markdown]
# ### Experiment 9 - Add Edges: bottomk nodes

# %%
# noise data creation example: remove edges -- strategy 2: remove from selected nodes

# **** DONT forget to change this *****
EXPERIMENT_FILENAME = './results_v3/Experiment_9_add_bottomk_nodes.csv'
# **** DONT forget to change this *****

nodes_percent = [0.05, 0.1, 0.2]  # [0.05, 0.1, 0.2, 0.25, 0.4, 0.5]
k_nodes_list = nodes_percent_to_num_nodes(percents=nodes_percent, num_nodes=data.num_nodes)

data = data.to('cpu')
add_edge_from_nodes_params = {'data':data, 'bidirectional':True, 'choose_type':'bottom_k'}

noise_info = {'noise_type':'edge_removal', 'strategy':'nodes', 'params':add_edge_from_nodes_params, 
              'noise_levels':[0, 0.01, 0.05, 0.1, 0.15, 0.3, 0.45, 0.6, 0.9, 0.95, 0.99, 1 ], 
              'k_nodes_list':k_nodes_list,
              'noise_param_name':'noise_level'}

exp_add_random_nodes_var_names = create_noised_data_for_experiment(data=data, noise_info=noise_info)
print(data)

# Experiment on edge removal - strategy- nodes
# Put names of the models we want to use for this experiment type
data = data.to('cuda:0')
model_names = ['GNN', 'GAT', 'Graphsage']
exp_add_random_nodes_df = experiment(dataset_name=dataset_name, model_names=model_names,
                                    model_params=model_params, opt_params=opt_params,
                                    data=data, x_types=['x'], edge_types=exp_add_random_nodes_var_names,
                                    noise_info=noise_info, num_epochs=25, repeat_num=3, print_updates=True)

# Do for node strategies only
exp_add_random_nodes_df[['choose_type', 'bidirectional','k_nodes','noise_level']] = exp_rm_random_nodes_df.apply(lambda x: [s.split('-')[-1] for s in x['edge_type'].split('_') if '-' in s], axis=1, result_type='expand')
data = data.to('cpu')
exp_add_random_nodes_df.to_csv(EXPERIMENT_FILENAME)
exp_add_random_nodes_df
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708], edge_index_added_n_0.15=[2, 12138], feature_noise__noiselvl-0=[2708, 1433], feature_noise__noiselvl-0.01=[2708, 1433], feature_noise__noiselvl-0.05=[2708, 1433], feature_noise__noiselvl-0.1=[2708, 1433], feature_noise__noiselvl-0.15=[2708, 1433], feature_noise__noiselvl-0.3=[2708, 1433], feature_noise__noiselvl-0.45=[2708, 1433], feature_noise__noiselvl-0.6=[2708, 1433], feature_noise__noiselvl-0.9=[2708, 1433], feature_noise__noiselvl-0.95=[2708, 1433], feature_noise__noiselvl-0.99=[2708, 1433], feature_noise__noiselvl-1=[2708, 1433], edge_removal_all_edges__noiselvl-0=[2, 10556], edge_removal_all_edges__noiselvl-0.01=[2, 10450], edge_removal_all_edges__noiselvl-0.05=[2, 10032], edge_removal_all_edges__noiselvl-0.1=[2, 9530], edge_removal_all_edges__noiselvl-0.15=[2, 9032], edge_removal_all_edges__noiselvl-0.3=[2, 7652], edge_removal_all_edges__noiselvl-0.45=[2, 6340], edge_removal_all_edges__noiselvl-0.6=[2, 5210], edge_removal_all_edges__noiselvl-0.9=[2, 3224], edge_removal_all_edges__noiselvl-0.95=[2, 2904], edge_removal_all_edges__noiselvl-0.99=[2, 2722], edge_removal_all_edges__noiselvl-1=[2, 2590], edge_addition_all_edges__noiselvl-0=[2, 10556], edge_addition_all_edges__noiselvl-0.01=[2, 10660], edge_addition_all_edges__noiselvl-0.05=[2, 11082], edge_addition_all_edges__noiselvl-0.1=[2, 11610], edge_addition_all_edges__noiselvl-0.15=[2, 12138], edge_addition_all_edges__noiselvl-0.3=[2, 13722], edge_addition_all_edges__noiselvl-0.45=[2, 15306], edge_addition_all_edges__noiselvl-0.6=[2, 16888], edge_addition_all_edges__noiselvl-0.9=[2, 20056], edge_addition_all_edges__noiselvl-0.95=[2, 20584], edge_addition_all_edges__noiselvl-0.99=[2, 21006], edge_addition_all_edges__noiselvl-1=[2, 21112], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.01=[2, 10288], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.05=[2, 10286], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.1=[2, 10282], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.15=[2, 10280], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.3=[2, 10252], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.45=[2, 10174], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.6=[2, 10152], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.9=[2, 9956], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.95=[2, 9998], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-0.99=[2, 9928], edge_removal_nodes_choose_type-random_bidirec-True_knodes-135_noiselvl-1=[2, 9902], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0=[2, 10556], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.01=[2, 10026], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.05=[2, 10022], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.1=[2, 10020], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.15=[2, 10018], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.3=[2, 9912], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.45=[2, 9788], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.6=[2, 9694], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.9=[2, 9442], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.95=[2, 9346], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-0.99=[2, 9354], edge_removal_nodes_choose_type-random_bidirec-True_knodes-271_noiselvl-1=[2, 9538], edge_removal_nodes_choose_type-random_bidirec-True_knodes-542_noiselvl-0=[2, 10556], e ...
# Run GNN: 1/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.79
# Run GNN: 2/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.802
# Run GNN: 3/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.797
# Run GNN: 4/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.806
# Run GNN: 5/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.796
# Run GNN: 6/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.781
# Run GNN: 7/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.798
# Run GNN: 8/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.785
# Run GNN: 9/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.789
# Run GNN: 10/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.796
# Run GNN: 11/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.794
# Run GNN: 12/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.787
# Run GNN: 13/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.795
# Run GNN: 14/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.79
# Run GNN: 15/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.801
# Run GNN: 16/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.793
# Run GNN: 17/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.796
# Run GNN: 18/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.795
# Run GNN: 19/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.784
# Run GNN: 20/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.795
# Run GNN: 21/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.794
# Run GNN: 22/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.801
# Run GNN: 23/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.79
# Run GNN: 24/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.792
# Run GNN: 25/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.797
# Run GNN: 26/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.799
# Run GNN: 27/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.791
# Run GNN: 28/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.789
# Run GNN: 29/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.784
# Run GNN: 30/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.801
# Run GNN: 31/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.799
# Run GNN: 32/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.793
# Run GNN: 33/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.807
# Run GNN: 34/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.799
# Run GNN: 35/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.79
# Run GNN: 36/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.802
# Run GAT: 37/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.772
# Run GAT: 38/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.742
# Run GAT: 39/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.742
# Run GAT: 40/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.747
# Run GAT: 41/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.76
# Run GAT: 42/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.779
# Run GAT: 43/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.739
# Run GAT: 44/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.761
# Run GAT: 45/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.78
# Run GAT: 46/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.707
# Run GAT: 47/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.741
# Run GAT: 48/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.71
# Run GAT: 49/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.751
# Run GAT: 50/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.751
# Run GAT: 51/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.756
# Run GAT: 52/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.764
# Run GAT: 53/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.756
# Run GAT: 54/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.759
# Run GAT: 55/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.768
# Run GAT: 56/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.782
# Run GAT: 57/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run GAT: 58/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.762
# Run GAT: 59/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.771
# Run GAT: 60/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.759
# Run GAT: 61/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.756
# Run GAT: 62/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.788
# Run GAT: 63/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.775
# Run GAT: 64/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.767
# Run GAT: 65/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.74
# Run GAT: 66/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.772
# Run GAT: 67/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.778
# Run GAT: 68/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.773
# Run GAT: 69/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.777
# Run GAT: 70/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.755
# Run GAT: 71/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.77
# Run GAT: 72/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.746
# Run Graphsage: 73/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0 Avg. Test Accuracy: 0.78
# Run Graphsage: 74/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.01 Avg. Test Accuracy: 0.777
# Run Graphsage: 75/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.05 Avg. Test Accuracy: 0.773
# Run Graphsage: 76/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.1 Avg. Test Accuracy: 0.778
# Run Graphsage: 77/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.15 Avg. Test Accuracy: 0.77
# Run Graphsage: 78/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.3 Avg. Test Accuracy: 0.765
# Run Graphsage: 79/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.45 Avg. Test Accuracy: 0.76
# Run Graphsage: 80/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.6 Avg. Test Accuracy: 0.762
# Run Graphsage: 81/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.9 Avg. Test Accuracy: 0.772
# Run Graphsage: 82/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.95 Avg. Test Accuracy: 0.772
# Run Graphsage: 83/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-0.99 Avg. Test Accuracy: 0.776
# Run Graphsage: 84/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-135_noiselvl-1 Avg. Test Accuracy: 0.762
# Run Graphsage: 85/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0 Avg. Test Accuracy: 0.782
# Run Graphsage: 86/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.01 Avg. Test Accuracy: 0.776
# Run Graphsage: 87/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.05 Avg. Test Accuracy: 0.777
# Run Graphsage: 88/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.1 Avg. Test Accuracy: 0.773
# Run Graphsage: 89/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.15 Avg. Test Accuracy: 0.763
# Run Graphsage: 90/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.3 Avg. Test Accuracy: 0.778
# Run Graphsage: 91/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.45 Avg. Test Accuracy: 0.763
# Run Graphsage: 92/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.6 Avg. Test Accuracy: 0.775
# Run Graphsage: 93/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.9 Avg. Test Accuracy: 0.775
# Run Graphsage: 94/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.95 Avg. Test Accuracy: 0.765
# Run Graphsage: 95/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-0.99 Avg. Test Accuracy: 0.773
# Run Graphsage: 96/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-271_noiselvl-1 Avg. Test Accuracy: 0.758
# Run Graphsage: 97/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0 Avg. Test Accuracy: 0.783
# Run Graphsage: 98/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.01 Avg. Test Accuracy: 0.769
# Run Graphsage: 99/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.05 Avg. Test Accuracy: 0.766
# Run Graphsage: 100/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.1 Avg. Test Accuracy: 0.762
# Run Graphsage: 101/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.15 Avg. Test Accuracy: 0.771
# Run Graphsage: 102/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.3 Avg. Test Accuracy: 0.767
# Run Graphsage: 103/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.45 Avg. Test Accuracy: 0.772
# Run Graphsage: 104/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.6 Avg. Test Accuracy: 0.757
# Run Graphsage: 105/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.9 Avg. Test Accuracy: 0.766
# Run Graphsage: 106/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.95 Avg. Test Accuracy: 0.776
# Run Graphsage: 107/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-0.99 Avg. Test Accuracy: 0.766
# Run Graphsage: 108/108: x - edge_removal_nodes_choose_type-bottom_k_bidirec-True_knodes-542_noiselvl-1 Avg. Test Accuracy: 0.754
#     dataset_name model_name x_type  \
# 0           Cora        GNN      x
# 1           Cora        GNN      x
# 2           Cora        GNN      x
# 3           Cora        GNN      x
# 4           Cora        GNN      x
# ..           ...        ...    ...
# 103         Cora  Graphsage      x
# 104         Cora  Graphsage      x
# 105         Cora  Graphsage      x
# 106         Cora  Graphsage      x
# 107         Cora  Graphsage      x
#
#                                              edge_type mean_test_accuracy  \
# 0    edge_removal_nodes_choose_type-bottom_k_bidire...               0.79
# 1    edge_removal_nodes_choose_type-bottom_k_bidire...              0.802
# 2    edge_removal_nodes_choose_type-bottom_k_bidire...              0.797
# 3    edge_removal_nodes_choose_type-bottom_k_bidire...              0.806
# 4    edge_removal_nodes_choose_type-bottom_k_bidire...              0.796
# ..                                                 ...                ...
# 103  edge_removal_nodes_choose_type-bottom_k_bidire...              0.757
# 104  edge_removal_nodes_choose_type-bottom_k_bidire...              0.766
# 105  edge_removal_nodes_choose_type-bottom_k_bidire...              0.776
# 106  edge_removal_nodes_choose_type-bottom_k_bidire...              0.766
# 107  edge_removal_nodes_choose_type-bottom_k_bidire...              0.754
#
#        test_accuracies  num_epochs  \
# 0    0.773,0.795,0.801          25
# 1    0.806,0.809,0.791          25
# 2        0.8,0.8,0.792          25
# 3      0.815,0.804,0.8          25
# 4    0.785,0.789,0.815          25
# ..                 ...         ...
# 103   0.763,0.76,0.747          25
# 104  0.756,0.765,0.777          25
# 105   0.768,0.781,0.78          25
# 106  0.764,0.766,0.769          25
# 107  0.742,0.753,0.767          25
#
#                                           model_params  \
# 0    {'in_channels': 1433, 'hidden_channels': 30, '...
# 1    {'in_channels': 1433, 'hidden_channels': 30, '...
# 2    {'in_channels': 1433, 'hidden_channels': 30, '...
# 3    {'in_channels': 1433, 'hidden_channels': 30, '...
# 4    {'in_channels': 1433, 'hidden_channels': 30, '...
# ..                                                 ...
# 103  {'in_channels': 1433, 'hidden_channels': 50, '...
# 104  {'in_channels': 1433, 'hidden_channels': 50, '...
# 105  {'in_channels': 1433, 'hidden_channels': 50, '...
# 106  {'in_channels': 1433, 'hidden_channels': 50, '...
# 107  {'in_channels': 1433, 'hidden_channels': 50, '...
#
#                                             noise_info  repeat_num  \
# 0    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 1    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 2    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 3    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 4    {'noise_type': 'edge_removal', 'strategy': 'no...           3
# ..                                                 ...         ...
# 103  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 104  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 105  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 106  {'noise_type': 'edge_removal', 'strategy': 'no...           3
# 107  {'noise_type': 'edge_removal', 'strategy': 'no...           3
#
#     choose_type bidirectional k_nodes noise_level
# 0        bottom          True     135           0
# 1        bottom          True     135        0.01
# 2        bottom          True     135        0.05
# 3        bottom          True     135         0.1
# 4        bottom          True     135        0.15
# ..          ...           ...     ...         ...
# 103      bottom          True     542         0.6
# 104      bottom          True     542         0.9
# 105      bottom          True     542        0.95
# 106      bottom          True     542        0.99
# 107      bottom          True     542           1
#
# [108 rows x 14 columns]

# %%
import shutil
shutil.make_archive('results_v3', 'zip', 'results_v3')
